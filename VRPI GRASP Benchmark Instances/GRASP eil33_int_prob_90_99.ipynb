# %% [markdown]
# #### Reading the instances

# %%
#import os
#os.environ["OMP_NUM_THREADS"] = '1'

# %%
import pandas as pd
# Step 1: Read the text file and store its lines in a list.
#name = 'ct_7_n_4_k10_t_80_no_inter.txt'
name = 'eil33.txt'
with open(name, 'r') as f:
    lines = f.readlines()

# Step 2: Extract necessary information from the list.
num_vehicles = None
vehicle_capacity = None
optimal_value = None
split_sol = None
demands = []
locations = []

for i, line in enumerate(lines):
    if "Min no of trucks" in line or "Optimal value" in line or "Split" in line:
        num_vehicles = int(line.split("Min no of trucks:")[1].split(",")[0].strip())
        optimal_value = float(line.split("Optimal value:")[1].split(",")[0].strip())
        split_sol = line.split("Split:")[1].split(")")[0].strip()
    elif "CAPACITY" in line:
        vehicle_capacity = int(line.split(":")[1].strip())
    elif "NODE_COORD_SECTION" in line:
        j = i + 1
        while lines[j].strip() != "DEMAND_SECTION":
            _, x, y = map(float, lines[j].split())
            locations.append((x, y))
            j += 1
    elif "DEMAND_SECTION" in line:
        j = i + 1
        while lines[j].strip() != "DEPOT_SECTION":
            _, demand = map(float, lines[j].split())
            demands.append(demand)
            j += 1

# Removing the depot's demand, which is always 0
demands.pop(0)
num_customers = len(demands)

# Step 3: Use the extracted information to generate the desired Python output.
print("# Given data")
print(f"num_vehicles = {num_vehicles}")
print(f"num_customers = {num_customers}")
print(f"vehicle_capacity = {vehicle_capacity}")
print(f"optimal_value = {optimal_value}")
print(f"split_sol = {split_sol}")
print(f"demands = {demands}")
print("\nlocations = [")
for i, (x, y) in enumerate(locations):
    if i == 0:
        print(f"    ({x}, {y}),  # depot")
    else:
        print(f"    ({x}, {y}),  # customer {i}")
print("]")
# Out:
# # Given data
# num_vehicles = 4
# num_customers = 32
# vehicle_capacity = 8000
# optimal_value = 835.0
# split_sol = No
# demands = [700.0, 400.0, 400.0, 1200.0, 40.0, 80.0, 2000.0, 900.0, 600.0, 750.0, 1500.0, 150.0, 250.0, 1600.0, 450.0, 700.0, 550.0, 650.0, 200.0, 400.0, 300.0, 1300.0, 700.0, 750.0, 1400.0, 4000.0, 600.0, 1000.0, 500.0, 2500.0, 1700.0, 1100.0]
#
# locations = [
#     (292.0, 495.0),  # depot
#     (298.0, 427.0),  # customer 1
#     (309.0, 445.0),  # customer 2
#     (307.0, 464.0),  # customer 3
#     (336.0, 475.0),  # customer 4
#     (320.0, 439.0),  # customer 5
#     (321.0, 437.0),  # customer 6
#     (322.0, 437.0),  # customer 7
#     (323.0, 433.0),  # customer 8
#     (324.0, 433.0),  # customer 9
#     (323.0, 429.0),  # customer 10
#     (314.0, 435.0),  # customer 11
#     (311.0, 442.0),  # customer 12
#     (304.0, 427.0),  # customer 13
#     (293.0, 421.0),  # customer 14
#     (296.0, 418.0),  # customer 15
#     (261.0, 384.0),  # customer 16
#     (297.0, 410.0),  # customer 17
#     (315.0, 407.0),  # customer 18
#     (314.0, 406.0),  # customer 19
#     (321.0, 391.0),  # customer 20
#     (321.0, 398.0),  # customer 21
#     (314.0, 394.0),  # customer 22
#     (313.0, 378.0),  # customer 23
#     (304.0, 382.0),  # customer 24
#     (295.0, 402.0),  # customer 25
#     (283.0, 406.0),  # customer 26
#     (279.0, 399.0),  # customer 27
#     (271.0, 401.0),  # customer 28
#     (264.0, 414.0),  # customer 29
#     (277.0, 439.0),  # customer 30
#     (290.0, 434.0),  # customer 31
#     (319.0, 433.0),  # customer 32
# ]

# %% [markdown]
# Preparing for BIG Instances

# %% [markdown]
# 1. Precompute and store all pairwise distances in a matrix instead of calculating them on-the-fly.

# %% [markdown]
# 1. Precompute and store all pairwise distances in a matrix instead of calculating them on-the-fly. +
# 2. Use efficient data structures, such as numpy arrays (from the numpy library), to handle matrix operations.

# %% [markdown]
# 1. Precompute and store all pairwise distances in a matrix instead of calculating them on-the-fly. +
# 2. Use efficient data structures, such as numpy arrays (from the numpy library), to handle matrix operations. +
# 3. Implement a dynamic size for the Restricted Candidate List based on a percentage of the remaining nodes or some other heuristic

# %% [markdown]
# 1. Precompute and store all pairwise distances in a matrix instead of calculating them on-the-fly. +
# 2. Use efficient data structures, such as numpy arrays (from the numpy library), to handle matrix operations. +
# 3. Implement a dynamic size for the Restricted Candidate List based on a percentage of the remaining nodes or some other heuristic +
# 4. Memory Efficiency: Be cautious about storing large numbers of routes in memory. Store only necessary information. Set grasp iterations as parameter at the beginning of code

# %% [markdown]
# 1. Precompute and store all pairwise distances in a matrix instead of calculating them on-the-fly. +
# 2. Use efficient data structures, such as numpy arrays (from the numpy library), to handle matrix operations. +
# 3. Implement a dynamic size for the Restricted Candidate List based on a percentage of the remaining nodes or some other heuristic +
# 4. Memory Efficiency: Be cautious about storing large numbers of routes in memory. Store only necessary information. Set grasp iterations as parameter at the beginning of code +
# 5. Implement additionally more efficient local search techniques like 3-opt or use segment reversal instead of pure swaps. The use of the techniques can be set up as parameters at the beginning of code (fixed or randomly)

# %% [markdown]
# 1. Precompute and store all pairwise distances in a matrix instead of calculating them on-the-fly. +
# 2. Use efficient data structures, such as numpy arrays (from the numpy library), to handle matrix operations. +
# 3. Implement a dynamic size for the Restricted Candidate List based on a percentage of the remaining nodes or some other heuristic +
# 4. Memory Efficiency: Be cautious about storing large numbers of routes in memory. Store only necessary information. Set grasp iterations as parameter at the beginning of code +
# 5. Implement additionally more efficient local search techniques like 3-opt or use segment reversal instead of pure swaps. The use of the techniques can be set up as parameters at the beginning of code (fixed or randomly) +
# 6. Add printing info about split deliveries

# %% [markdown]
# 1. Precompute and store all pairwise distances in a matrix instead of calculating them on-the-fly. +
# 2. Use efficient data structures, such as numpy arrays (from the numpy library), to handle matrix operations. +
# 3. Implement a dynamic size for the Restricted Candidate List based on a percentage of the remaining nodes or some other heuristic +
# 4. Memory Efficiency: Be cautious about storing large numbers of routes in memory. Store only necessary information. Set grasp iterations as parameter at the beginning of code +
# 5. Implement additionally more efficient local search techniques like 3-opt or use segment reversal instead of pure swaps. The use of the techniques can be set up as parameters at the beginning of code (fixed or randomly) +
# 6. Add printing info about split deliveries +
# 7. Add printing info about customers not being served totally or partially

# %% [markdown]
# 1. Precompute and store all pairwise distances in a matrix instead of calculating them on-the-fly. +
# 2. Use efficient data structures, such as numpy arrays (from the numpy library), to handle matrix operations. +
# 3. Implement a dynamic size for the Restricted Candidate List based on a percentage of the remaining nodes or some other heuristic +
# 4. Memory Efficiency: Be cautious about storing large numbers of routes in memory. Store only necessary information. Set grasp iterations as parameter at the beginning of code +
# 5. Implement additionally more efficient local search techniques like 3-opt or use segment reversal instead of pure swaps. The use of the techniques can be set up as parameters at the beginning of code (fixed or randomly) +
# 6. Add printing info about split deliveries +
# 7. Add printing info about customers not being served totally or partially +
# 8. Transform into modular code

# %% [markdown]
# 1. Precompute and store all pairwise distances in a matrix instead of calculating them on-the-fly. +
# 2. Use efficient data structures, such as numpy arrays (from the numpy library), to handle matrix operations. +
# 3. Implement a dynamic size for the Restricted Candidate List based on a percentage of the remaining nodes or some other heuristic +
# 4. Memory Efficiency: Be cautious about storing large numbers of routes in memory. Store only necessary information. Set grasp iterations as parameter at the beginning of code +
# 5. Implement additionally more efficient local search techniques like 3-opt or use segment reversal instead of pure swaps. The use of the techniques can be set up as parameters at the beginning of code (fixed or randomly) +
# 6. Add printing info about split deliveries +
# 7. Add printing info about customers not being served totally or partially +
# 8. Transform into modular code +
# 9. Print cost per iteration

# %% [markdown]
# 1. Precompute and store all pairwise distances in a matrix instead of calculating them on-the-fly. +
# 2. Use efficient data structures, such as numpy arrays (from the numpy library), to handle matrix operations. +
# 3. Implement a dynamic size for the Restricted Candidate List based on a percentage of the remaining nodes or some other heuristic +
# 4. Memory Efficiency: Be cautious about storing large numbers of routes in memory. Store only necessary information. Set grasp iterations as parameter at the beginning of code +
# 5. Implement additionally more efficient local search techniques like 3-opt or use segment reversal instead of pure swaps. The use of the techniques can be set up as parameters at the beginning of code (fixed or randomly) +
# 6. Add printing info about split deliveries +
# 7. Add printing info about customers not being served totally or partially +
# 8. Transform into modular code +
# 9. Print cost per iteration +
# 10. Add conditions for early termination if the solution quality hasn't improved for a certain number of iterations (stagnation)

# %% [markdown]
# 1. Precompute and store all pairwise distances in a matrix instead of calculating them on-the-fly. +
# 2. Use efficient data structures, such as numpy arrays (from the numpy library), to handle matrix operations. +
# 3. Implement a dynamic size for the Restricted Candidate List based on a percentage of the remaining nodes or some other heuristic +
# 4. Memory Efficiency: Be cautious about storing large numbers of routes in memory. Store only necessary information. Set grasp iterations as parameter at the beginning of code +
# 5. Implement additionally more efficient local search techniques like 3-opt or use segment reversal instead of pure swaps. The use of the techniques can be set up as parameters at the beginning of code (fixed or randomly) +
# 6. Add printing info about split deliveries +
# 7. Add printing info about customers not being served totally or partially +
# 8. Transform into modular code +
# 9. Print cost per iteration +
# 10. Add conditions for early termination if the solution quality hasn't improved for a certain number of iterations (stagnation) +
# 11. Perturbation: After constructing a solution, you can apply slight random perturbations to it. For instance, remove a few customers from their routes and reinsert them using greedy or random criteria. This can diversify the search space before the local search

# %% [markdown]
# #### nearest neighbour construct solution

# %% [markdown]
# #### running more with nearest neighbor

# %% [markdown]
# #### split delivery penalty

# %% [markdown]
# #### Adding split deliveries statistics

# %% [markdown]
#  #### Adding the Swap-Based Local Search (SLS)

# %% [markdown]
# Saving the time of best solution

# %% [markdown]
# Nearest neighbour solution saved

# %% [markdown]
# Fixed seed changed again to random seed

# %% [markdown]
# Nearest neighbour flexibility to allow split demand in initial solution

# %% [markdown]
# Optimal value extracted from txt file

# %% [markdown]
# sdvrp check before and after local search

# %% [markdown]
# interdiction matrix added

# %% [markdown]
# Conditions over revised demands for feasibility

# %% [markdown]
# Adding lowest interdiction route logic

# %% [markdown]
# Adding combinations to find feasible solution moving expected demands (pending)

# %% [markdown]
# Adding lowest interdiction route logic (3 opt)

# %% [markdown]
# Adding lowest interdiction route logic (segment-reversal)

# %% [markdown]
# Adding combinations to find feasible solution moving expected demands (working on it)

# %%
import random
import numpy as np
import copy
import pandas as pd
import time
import itertools
from sklearn.cluster import KMeans
from itertools import product
import math


class VRP:
    def __init__(self, num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl_factor=0.98, iterations=10000, local_search_option='2-opt', stagnation_limit=50, perturb_percentage=0.1, split_penalty=1000, sdd = 1, reintegrate_it=1000, split_sol = 'Yes', min_prob_matrix = 1.0, max_prob_matrix = 1.0, int_prob = None, threshold_increment = 5, optimization_solution_finder = "tier"): #, dem_increment = 0.25):
        #random.seed(sdd)
        random.seed()
        #np.random.seed(sdd)
        np.random.seed()
        self.depot_id = 0
        self.number_vehicle = num_vehicles
        self.number_customers = num_customers
        self.number_nodes = num_customers + 1
        self.coordinates = locations
        self.demands = [0] + demands
        self.vehicle_capacity = vehicle_capacity
        self.reintegrate_it = reintegrate_it
        self.saved_initial_solution_split = None
        self.saved_initial_solution_no_split = None
        self.split_sol = split_sol
        self.int_prob = int_prob
        self.optimization_solution_finder = optimization_solution_finder
        #self.dem_increment = dem_increment

        # Set hyperparameters
        self.rcl_factor = rcl_factor
        self.iterations = iterations
        self.local_search_option = local_search_option
        self.stagnation_limit = stagnation_limit
        self.perturb_percentage = perturb_percentage
        self.split_penalty = split_penalty
        self.sdd = sdd
        self.min_prob_matrix = min_prob_matrix
        self.max_prob_matrix = max_prob_matrix
        self.threshold_increment = threshold_increment

        self.coordinates_np = np.array(self.coordinates)
        self.demands = np.array(self.demands)
        diff = self.coordinates_np[:, np.newaxis, :] - self.coordinates_np
        self.distance_matrix = np.sqrt((diff**2).sum(axis=2))

    def cluster_based_init(self, n_clusters=None):
        if n_clusters is None:
            n_clusters = self.number_vehicle  # Or use a heuristic to determine the number of clusters
        # Apply clustering on customer locations only
        customer_coords = np.array(self.coordinates[1:])  # Exclude depot
        kmeans = KMeans(n_clusters=n_clusters, random_state=self.sdd).fit(customer_coords)
        clusters = kmeans.labels_

        remaining_demands = self.demands.copy()
        routes = []

        for cluster_id in range(n_clusters):
            cluster_customers = [i+1 for i, cluster in enumerate(clusters) if cluster == cluster_id and remaining_demands[i+1] > 0]
            # Apply nearest neighbor within each cluster
            cluster_routes, cluster_remaining_demands = self.nearest_neighbor_within_cluster(cluster_customers, remaining_demands)
            routes.extend(cluster_routes)
            remaining_demands = cluster_remaining_demands

        return routes, remaining_demands

    def nearest_neighbor_within_cluster(self, cluster_customers, remaining_demands):
        cluster_routes = []
        demands_copy = remaining_demands.copy()

        while any(demands_copy[customer] > 0 for customer in cluster_customers):
            route = [self.depot_id]
            current_load = 0
            current_location = self.depot_id

            while current_load < self.vehicle_capacity:
                nearest_customer = None
                nearest_distance = float('inf')

                for customer in cluster_customers:
                    if demands_copy[customer] > 0 and customer not in route:
                        distance = self.distance_matrix[current_location][customer]
                        if distance < nearest_distance and current_load + demands_copy[customer] <= self.vehicle_capacity:
                            nearest_distance = distance
                            nearest_customer = customer

                if nearest_customer is None:
                    break  # No more customers can be added without exceeding capacity

                current_load += demands_copy[nearest_customer]
                demands_copy[nearest_customer] = 0
                route.append(nearest_customer)
                current_location = nearest_customer

            route.append(self.depot_id)
            cluster_routes.append(route)

        return cluster_routes, demands_copy


    def nearest_neighbor(self):
        remaining_demands = self.demands.copy()
        routes = []
        fes_cond = None

        for _ in range(self.number_vehicle):
            current_load = 0
            current_location = self.depot_id
            route = [self.depot_id]

            while current_load < self.vehicle_capacity:
                nearest_customer = None
                nearest_distance = float('inf')

                for i in range(1, self.number_customers + 1):
                    if remaining_demands[i] > 0 and i not in route:
                        distance = self.distance_matrix[current_location][i]
                        if distance < nearest_distance and current_load + remaining_demands[i] <= self.vehicle_capacity:
                            nearest_distance = distance
                            nearest_customer = i

                if nearest_customer is None:
                    break

                current_load += remaining_demands[nearest_customer]
                remaining_demands[nearest_customer] = 0
                route.append(nearest_customer)
                current_location = nearest_customer

            route.append(self.depot_id)
            routes.append(route)
            serviced_demands = []
            for route in routes:
                route_demands = {}
                for customer in route[1:-1]:  # Exclude the depot
                    route_demands[customer] = self.demands[customer]
                serviced_demands.append(route_demands)
        # Check if initial solution is feasible
        # Flatten the list
        flat_list = [item for sublist in routes for item in sublist]

        # Convert the flat list to a set to get unique elements
        unique_elements = set(flat_list)

        # Count the number of unique elements
        count_unique = len(unique_elements)
        if num_customers+1 != count_unique:
            fes_cond = 'Infeasible'
            print("Infeasible construction solution")
        else:
            fes_cond = 'Feasible'
            print("Feasible construction solution")
        if self.saved_initial_solution_no_split is None:# and fes_cond == 'Feasible':
            # Save the initial solution right after it's generated, ensuring no split deliveries
            self.saved_initial_solution_no_split = (copy.deepcopy(routes), copy.deepcopy(remaining_demands), copy.deepcopy(serviced_demands), copy.deepcopy(fes_cond))

        return routes, remaining_demands, serviced_demands, fes_cond

    def nearest_neighbor_with_split_demands(self):
        remaining_demands = self.demands.copy()
        routes = []
        serviced_demands = []
        fes_cond = None

        for _ in range(self.number_vehicle):
            current_load = 0
            current_location = self.depot_id
            route = [self.depot_id]
            route_demands = {}

            while current_load < self.vehicle_capacity:
                nearest_customer = None
                nearest_distance = float('inf')

                for i in range(1, self.number_customers + 1):
                    if remaining_demands[i] > 0 and i not in route:
                        distance = self.distance_matrix[current_location][i]
                        if distance < nearest_distance:
                            nearest_distance = distance
                            nearest_customer = i

                if nearest_customer is None:
                    break

                # Determine how much of the demand can be fulfilled by this vehicle
                demand_to_fulfill = min(remaining_demands[nearest_customer], self.vehicle_capacity - current_load)
                if demand_to_fulfill > 0:  # If there's some demand that can be fulfilled
                    current_load += demand_to_fulfill
                    remaining_demands[nearest_customer] -= demand_to_fulfill
                    route_demands[nearest_customer] = demand_to_fulfill

                    if nearest_customer not in route:  # Add to route if not already added
                        route.append(nearest_customer)
                        current_location = nearest_customer

            route.append(self.depot_id)
            routes.append(route)
            serviced_demands.append(route_demands)

        # Prepare the serviced demands in the desired format
        combined_serviced_demands = []
        for route_demands in serviced_demands:
            combined_serviced_demands.append(route_demands)

        # Flatten the list
        flat_list = [item for sublist in routes for item in sublist]

        # Convert the flat list to a set to get unique elements
        unique_elements = set(flat_list)

        # Count the number of unique elements
        count_unique = len(unique_elements)
        if num_customers+1 != count_unique:
            fes_cond = 'Infeasible'
        else:
            fes_cond = 'Feasible'
        
        if self.saved_initial_solution_split is None:# and fes_cond == 'Feasible':
            # Save the initial solution right after it's generated, allowing for split deliveries
            self.saved_initial_solution_split = (copy.deepcopy(routes), copy.deepcopy(remaining_demands), copy.deepcopy(combined_serviced_demands), copy.deepcopy(fes_cond))

        return routes, remaining_demands, combined_serviced_demands, fes_cond    


    def farthest_customer_init(self):
        remaining_demands = self.demands.copy()
        routes = []

        while np.any(remaining_demands[1:] > 0):  # Check if there's any customer demand left
            route = [self.depot_id]
            current_load = 0
            distances_to_depot = self.distance_matrix[self.depot_id][1:]  # Excludes depot itself

            # Prioritize customers based on distance, but consider only those that can be added without exceeding capacity
            eligible_customers = [(i+1, dist) for i, dist in enumerate(distances_to_depot) if remaining_demands[i+1] > 0 and remaining_demands[i+1] <= self.vehicle_capacity - current_load]
            if not eligible_customers:
                break  # If no eligible customers, break

            # Sort eligible customers by distance in descending order (farthest first)
            farthest_customer = sorted(eligible_customers, key=lambda x: x[1], reverse=True)[0][0]

            # Add farthest customer as the first customer of the route
            current_load += remaining_demands[farthest_customer]
            remaining_demands[farthest_customer] = 0
            route.append(farthest_customer)

            while current_load < self.vehicle_capacity:
                nearest_customer = None
                nearest_distance = float('inf')

                for i in range(1, self.number_customers + 1):
                    if remaining_demands[i] > 0 and i not in route:
                        distance = self.distance_matrix[route[-1]][i]  # Distance from the last customer added to potential next customer
                        if distance < nearest_distance and current_load + remaining_demands[i] <= self.vehicle_capacity:
                            nearest_distance = distance
                            nearest_customer = i

                if nearest_customer is None:
                    break  # No more customers can be added without exceeding capacity

                current_load += remaining_demands[nearest_customer]
                remaining_demands[nearest_customer] = 0
                route.append(nearest_customer)

            route.append(self.depot_id)
            routes.append(route)

        return routes, remaining_demands


    def count_split_deliveries(self, routes, route_demands):
        """ Count the number of split deliveries for the given routes and demands. """
        split_count = 0
        deliveries = {}

        for i, demands_dict in enumerate(route_demands):
            for customer, demand in demands_dict.items():
                if customer not in deliveries:
                    deliveries[customer] = 0
                deliveries[customer] += 1

        for customer, delivery_count in deliveries.items():
            if delivery_count > 1:
                split_count += delivery_count - 1  # We add (delivery_count - 1) because if a customer is served by 2 routes, then there is 1 split delivery for that customer.

        return split_count

    def greedy_cost(self, customer_id, current_load):
        return self.demands[customer_id] / (self.distance_matrix[self.depot_id, customer_id] + 1e-5)




    def construct_solution(self, reintegrate=False):
        #print(split_sol)
        # --> name of method: nearest_neighbor_with_split_demands
        if reintegrate:
        # Reintegrate the saved initial solution without modifications
            if split_sol == 'No':
                routes, remaining_demands, serviced_demands, fes_cond = copy.deepcopy(self.saved_initial_solution_no_split)
            else:
                routes, remaining_demands, serviced_demands, fes_cond = copy.deepcopy(self.saved_initial_solution_split)
        else:
            if split_sol == 'No':
                routes, remaining_demands, serviced_demands, fes_cond = self.nearest_neighbor()
                
            else:
                routes, remaining_demands, serviced_demands, fes_cond = self.nearest_neighbor_with_split_demands()

        # Generate a new solution using nearest_neighbor or another method intended for new solutions
            
            #print(routes)
            #print(remaining_demands)
            #print(serviced_demands)

        # First, we use the nearest neighbor method to get the initial routes.
        #routes, remaining_demands, serviced_demands = self.nearest_neighbor()
        #routes, remaining_demands = self.farthest_customer_init()
        #routes, remaining_demands = self.cluster_based_init()
        #print("Routes after cluster solution: ", routes)
        #print("Remaining demands after cluster solution: ", remaining_demands)
        #print("Serviced demands after cluster solution: ", serviced_demands)
        #print(routes)
        #print(remaining_demands)
            serviced_demands = []

            for route in routes:
                route_demands = {}
                for customer in route[1:-1]:  # Exclude the depot
                    route_demands[customer] = self.demands[customer]
                serviced_demands.append(route_demands)

            remaining_demands = self.demands.copy()
            routes = []
            serviced_demands = []

            for _ in range(self.number_vehicle):
                current_load = 0
                route = [self.depot_id]
                route_demands = {}
                while current_load < self.vehicle_capacity:
                    costs = [(i, self.greedy_cost(i, current_load)) for i in range(1, self.number_customers + 1) if remaining_demands[i] > 0 and i not in route]
                    costs.sort(key=lambda x: x[1], reverse=True)
                    rcl_size = max(1, int(len(costs) * self.rcl_factor))
                    rcl = [c[0] for c in costs[:rcl_size]]

                    if not rcl:
                        break

                    random.seed(10)

                    chosen_customer = random.choice(rcl)
                    delivery = min(self.vehicle_capacity - current_load, remaining_demands[chosen_customer])
                    if chosen_customer not in route_demands:
                        route_demands[chosen_customer] = 0
                    route_demands[chosen_customer] += delivery
                    remaining_demands[chosen_customer] -= delivery
                    current_load += delivery
                    route.append(chosen_customer)
                    if current_load == self.vehicle_capacity:
                        break

                route.append(self.depot_id)
                routes.append(route)
                serviced_demands.append(route_demands)

            
        return routes, serviced_demands, remaining_demands

    def is_route_valid(self, route, route_demands):
        total_demand = sum([route_demands[customer] for customer in route if customer in route_demands])
        return total_demand <= self.vehicle_capacity
    
    def filter_demands(self, route_demands, demands):
        # Convert route_demands keys to a set for faster lookup
        route_customers = set(route_demands.keys())
        
        # Filter demands based on route_customers
        filtered_demands = [demand for index, demand in enumerate(demands, start=1) if index in route_customers]
        
        return filtered_demands
    
    # Function to calculate the required values
    def calculate_demands_for_capacity_check(self, demands_list):
        total_demand_by_route = []
        total_demand = 0

        for route_demands in demands_list:
            route_total = sum(route_demands.values())
            total_demand_by_route.append(route_total)
            total_demand += route_total

        number_of_routes = len(demands_list)
        
        return total_demand_by_route, number_of_routes, total_demand

    def swap_local_search(self, routes, route_demands, interdiction_probabilities, iter_num, tier_1_it, tier_2_it):
        improvement_found = True
        it_number = iter_num+1
        
        osf_swl = self.optimization_solution_finder
                                    
        c_it = 1
        while improvement_found:
            # print("Improvement Found in SWAP: ", improvement_found)
            improvement_found = False
            for i in range(len(routes)):
                for j in range(i + 1, len(routes)):
                    for customer_i in routes[i][1:-1]:  # Exclude depot
                        for customer_j in routes[j][1:-1]:  # Exclude depot
                            # Check if customers are not repeated within their new routes before swap
                            c_it = c_it+1
                                        
                            if customer_i not in routes[j] and customer_j not in routes[i]:
                                # Prepare for swap
                                new_route_i = routes[i].copy()
                                new_route_j = routes[j].copy()

                                # Safely get demands or 0 if not found
                                demand_i = route_demands[i].get(customer_i, 0)
                                demand_j = route_demands[j].get(customer_j, 0)

                                # Perform swap
                                new_route_i[new_route_i.index(customer_i)] = customer_j
                                new_route_j[new_route_j.index(customer_j)] = customer_i
                                
                                # Swap demands
                                new_demands_i = route_demands[i].copy()
                                new_demands_j = route_demands[j].copy()
                                new_demands_i[customer_j] = demand_j
                                new_demands_j[customer_i] = demand_i
                                
                                if customer_i in new_demands_i: del new_demands_i[customer_i]
                                if customer_j in new_demands_j: del new_demands_j[customer_j]

                                
                                a1 = self.calculate_cumulative_probabilities_for_routes(routes[i], interdiction_probabilities)
                                a2 = self.calculate_cumulative_probabilities_for_routes(routes[j], interdiction_probabilities)
                                a3 = self.calculate_cumulative_probabilities_for_routes(new_route_i, interdiction_probabilities)
                                a4 = self.calculate_cumulative_probabilities_for_routes(new_route_j, interdiction_probabilities)
                                
                                route_old_i = routes[i]
                                route_old_j = routes[j]
                                route_new_i = new_route_i
                                route_new_j = new_route_j
                                route_demands_old_i = route_demands[i]
                                route_demands_old_j = route_demands[j]
                                route_demands_new_i = new_demands_i
                                route_demands_new_j = new_demands_j

                                
                                route_old_i = self.check_and_transform_path(route_old_i)
                                route_old_j = self.check_and_transform_path(route_old_j)
                                route_new_i = self.check_and_transform_path(route_new_i)
                                route_new_j = self.check_and_transform_path(route_new_j)

                                route_demands_old_i = self.check_and_transform_demands(route_demands_old_i)
                                route_demands_old_j = self.check_and_transform_demands(route_demands_old_j)
                                route_demands_new_i = self.check_and_transform_demands(route_demands_new_i)
                                route_demands_new_j = self.check_and_transform_demands(route_demands_new_j)

                                route_demands_old_i = self.reorder_demands_by_route(route_old_i, route_demands_old_i)
                                route_demands_old_j = self.reorder_demands_by_route(route_old_j, route_demands_old_j)
                                route_demands_new_i = self.reorder_demands_by_route(route_new_i, route_demands_new_i)
                                route_demands_new_j = self.reorder_demands_by_route(route_new_j, route_demands_new_j)

                                
                            
                                # Subset of data source demands to apply vrpi check for 2-opt
                                source_demands_filtered_route_old_i = self.filter_demands(route_demands_old_i[0], demands)
                                source_demands_filtered_route_old_j = self.filter_demands(route_demands_old_j[0], demands)
                                source_demands_filtered_route_new_i = self.filter_demands(route_demands_new_i[0], demands)
                                source_demands_filtered_route_new_j = self.filter_demands(route_demands_new_j[0], demands)

                                
                                revised_demands_old_route_i = self.calculate_revised_demands_for_routes(route_old_i, route_demands_old_i, interdiction_probabilities)
                                revised_demands_old_route_j = self.calculate_revised_demands_for_routes(route_old_j, route_demands_old_j, interdiction_probabilities)
                                revised_demands_new_route_i = self.calculate_revised_demands_for_routes(route_new_i, route_demands_new_i, interdiction_probabilities)
                                revised_demands_new_route_j = self.calculate_revised_demands_for_routes(route_new_j, route_demands_new_j, interdiction_probabilities)
                                
                                all_cumulative_probabilities_old_route_i = self.calculate_cumulative_probabilities_for_routes(route_old_i, interdiction_probabilities)
                                all_cumulative_probabilities_old_route_j = self.calculate_cumulative_probabilities_for_routes(route_old_j, interdiction_probabilities)
                                all_cumulative_probabilities_new_route_i = self.calculate_cumulative_probabilities_for_routes(route_new_i, interdiction_probabilities)
                                all_cumulative_probabilities_new_route_j = self.calculate_cumulative_probabilities_for_routes(route_new_j, interdiction_probabilities)

                                expected_demands_old_route_i = self.calculate_expected_demand_serviced(revised_demands_old_route_i, all_cumulative_probabilities_old_route_i)
                                expected_demands_old_route_j = self.calculate_expected_demand_serviced(revised_demands_old_route_j, all_cumulative_probabilities_old_route_j)
                                expected_demands_new_route_i = self.calculate_expected_demand_serviced(revised_demands_new_route_i, all_cumulative_probabilities_new_route_i)
                                expected_demands_new_route_j = self.calculate_expected_demand_serviced(revised_demands_new_route_j, all_cumulative_probabilities_new_route_j)
                                
                                

                                num_vehicles_old_route_i = sum(1 for item in route_old_i if isinstance(item, list))
                                num_vehicles_old_route_j = sum(1 for item in route_old_j if isinstance(item, list))
                                num_vehicles_new_route_i = sum(1 for item in route_new_i if isinstance(item, list))
                                num_vehicles_new_route_j = sum(1 for item in route_new_j if isinstance(item, list))

                                # Calculate the demands
                                total_demand_by_route_check_old_route_i, number_of_routes_check_old_route_i, total_demand_check_old_route_i = self.calculate_demands_for_capacity_check(revised_demands_old_route_i)
                                
                                total_demand_by_route_check_old_route_j, number_of_routes_check_old_route_j, total_demand_check_old_route_j = self.calculate_demands_for_capacity_check(revised_demands_old_route_j)
                                
                                total_demand_by_route_check_new_route_i, number_of_routes_check_new_route_i, total_demand_check_new_route_i = self.calculate_demands_for_capacity_check(revised_demands_new_route_i)
                                
                                total_demand_by_route_check_new_route_j, number_of_routes_check_new_route_j, total_demand_check_new_route_j = self.calculate_demands_for_capacity_check(revised_demands_new_route_j)
                                
                                # print("Self Route 1 is valid: ", self.is_route_valid(new_route_i, new_demands_i))
                                # print("Self Route 2 is valid: ", self.is_route_valid(new_route_j, new_demands_j))

                                # Check if swap is valid
                                if self.is_route_valid(new_route_i, new_demands_i) and self.is_route_valid(new_route_j, new_demands_j):
                                    cost_before = self.route_cost(routes[i]) + self.route_cost(routes[j])
                                    cost_after = self.route_cost(new_route_i) + self.route_cost(new_route_j)

                                    if osf_swl == "cost":
                                        if cost_after < cost_before:
                                            routes[i], routes[j] = new_route_i, new_route_j
                                            route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                            improvement_found = True

                                    elif osf_swl == "inter_route":
                                        if (a4[0][0]+a3[0][0]<a2[0][0]+a1[0][0]):
                                            routes[i], routes[j] = new_route_i, new_route_j
                                            route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                            improvement_found = True
                                            
                                    elif osf_swl == "min_demand_route":
                                        if ((round(total_demand_check_new_route_i + total_demand_check_new_route_j,1) < round(total_demand_check_old_route_i + total_demand_check_old_route_j,1) )): 
                                            routes[i], routes[j] = new_route_i, new_route_j
                                            route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                            improvement_found = True
                                            
                                    elif osf_swl == "tier":
                                        if it_number <= tier_1_it:
                                            if ((round(total_demand_check_new_route_i + total_demand_check_new_route_j,1) < round(total_demand_check_old_route_i + total_demand_check_old_route_j,1) )): 
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                        elif it_number > tier_1_it and it_number <= tier_2_it:
                                            if (a4[0][0]+a3[0][0]<a2[0][0]+a1[0][0]): 
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                        elif it_number > tier_2_it:
                                            if ((cost_after < cost_before)):
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True

                                    elif osf_swl == "random":
                                        a = random.uniform(0, 1)
                                        if a <= 0.33:
                                            if ((round(total_demand_check_new_route_i + total_demand_check_new_route_j,1) < round(total_demand_check_old_route_i + total_demand_check_old_route_j,1) )): 
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                        elif a > 0.33 and a <= 0.66:
                                            if (a4[0][0]+a3[0][0]<a2[0][0]+a1[0][0]): 
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                        elif a > 0.66:
                                            if ((cost_after < cost_before)):
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True

                                    elif osf_swl == "mixed":
                                        b = random.uniform(0, 1)
                                        if it_number <= tier_1_it and b <= 0.33:
                                            if ((round(total_demand_check_new_route_i + total_demand_check_new_route_j,1) < round(total_demand_check_old_route_i + total_demand_check_old_route_j,1) )): 
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                        elif it_number > tier_1_it and it_number <= tier_2_it and b <= 0.33:
                                            if (a4[0][0]+a3[0][0]<a2[0][0]+a1[0][0]): 
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                        elif it_number > tier_2_it and b <= 0.33:
                                            if ((cost_after < cost_before)):
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                        elif it_number <= tier_1_it and b > 0.33 and b <= 0.66:
                                            if ((round(total_demand_check_new_route_i + total_demand_check_new_route_j,1) < round(total_demand_check_old_route_i + total_demand_check_old_route_j,1) )): 
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                        elif it_number > tier_1_it and it_number <= tier_2_it and b > 0.33 and b <= 0.66:
                                            if (a4[0][0]+a3[0][0]<a2[0][0]+a1[0][0]): 
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                        elif it_number > tier_2_it and b > 0.33 and b <= 0.66:
                                            if ((cost_after < cost_before)):
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                        elif it_number <= tier_1_it and b > 0.66:
                                            if ((round(total_demand_check_new_route_i + total_demand_check_new_route_j,1) < round(total_demand_check_old_route_i + total_demand_check_old_route_j,1) )): 
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                                
                                        elif it_number > tier_1_it and it_number <= tier_2_it and b > 0.66:
                                            
                                            if (a4[0][0]+a3[0][0]<a2[0][0]+a1[0][0]): 
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                                
                                        elif it_number > tier_2_it and b > 0.66:
                                            if ((cost_after < cost_before)):
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                                
                                            
                            



    def two_opt(self, route, route_demands, interdiction_probabilities, iter_num, tier_1_it, tier_2_it):
        best_route = route[:]
        improved = True
        it_number = iter_num+1
        
        osf_swl = self.optimization_solution_finder
        while improved:
            improved = False
            for i in range(1, len(route) - 2):
                for j in range(i + 1, len(route) - 1):
                    c1 = self.calculate_cumulative_probabilities_for_routes(route[:i] + list(reversed(route[i:j+1])) + route[j+1:], interdiction_probabilities)
                    c2 = self.calculate_cumulative_probabilities_for_routes(route[:i] + list((route[i:j+1])) + route[j+1:], interdiction_probabilities)
                    new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                    old_route = route[:i] + list((route[i:j+1])) + route[j+1:]
                    old_demands = route_demands

                    new_route = self.check_and_transform_path(new_route)
                    old_route = self.check_and_transform_path(old_route)
                    old_demands = self.check_and_transform_demands(old_demands)
                    
                    new_demands = self.reorder_demands_by_route(new_route, old_demands)
                    new_demands = self.check_and_transform_demands(new_demands)
                
                    
                    # Subset of data source demands to apply vrpi check for 2-opt
                    source_demands_filtered = self.filter_demands(route_demands, demands)
                    
                    revised_demands_old_route = self.calculate_revised_demands_for_routes(old_route, old_demands, interdiction_probabilities)
                    revised_demands_new_route = self.calculate_revised_demands_for_routes(new_route, new_demands, interdiction_probabilities)
                    all_cumulative_probabilities_old_route = self.calculate_cumulative_probabilities_for_routes(old_route, interdiction_probabilities)
                    all_cumulative_probabilities_new_route = self.calculate_cumulative_probabilities_for_routes(new_route, interdiction_probabilities)
                    
                    expected_demands_old_route = self.calculate_expected_demand_serviced(revised_demands_old_route, all_cumulative_probabilities_old_route)
                    
                    expected_demands_new_route = self.calculate_expected_demand_serviced(revised_demands_new_route, all_cumulative_probabilities_new_route)
                    
                    # Calculate the demands
                    total_demand_by_route_check_old_route, number_of_routes_check_old_route, total_demand_check_old_route = self.calculate_demands_for_capacity_check(revised_demands_old_route)
                    
                    total_demand_by_route_check_new_route, number_of_routes_check_new_route, total_demand_check_new_route = self.calculate_demands_for_capacity_check(revised_demands_new_route)
                    
                    if osf_swl == "tier":
                        if it_number <= tier_1_it:
                            if round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1):
                            
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True

                        elif it_number > tier_1_it and it_number <= tier_2_it:
                            if c1[0][0] < c2[0][0]:
                            
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True
                        
                        elif it_number > tier_2_it :
                            if (self.distance_matrix[route[i-1], route[i]] + self.distance_matrix[route[j], route[j+1]] > 
                         self.distance_matrix[route[i-1], route[j]] + self.distance_matrix[route[i], route[j+1]]):
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True

                    elif osf_swl == "cost":
                        if (self.distance_matrix[route[i-1], route[i]] + self.distance_matrix[route[j], route[j+1]] > 
                         self.distance_matrix[route[i-1], route[j]] + self.distance_matrix[route[i], route[j+1]]):
                            new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                            if self.is_route_valid(new_route, route_demands):
                                route = new_route
                                    
                                improved = True

                    elif osf_swl == "inter_route":
                        if c1[0][0] < c2[0][0]:
                            new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                            if self.is_route_valid(new_route, route_demands):
                                route = new_route
                                    
                                improved = True

                    elif osf_swl == "min_demand_route":
                        if round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1):
                            new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                            if self.is_route_valid(new_route, route_demands):
                                route = new_route
                                    
                                improved = True
                    
                    elif osf_swl == "random":
                        a = random.uniform(0, 1)
                        if a <= 0.33:
                            if round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1):
                            
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True

                        elif a > 0.33 and a <= 0.66:
                            if c1[0][0] < c2[0][0]:
                            
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True
                        
                        elif a > 0.66:
                            if (self.distance_matrix[route[i-1], route[i]] + self.distance_matrix[route[j], route[j+1]] > 
                         self.distance_matrix[route[i-1], route[j]] + self.distance_matrix[route[i], route[j+1]]):
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True

                    elif osf_swl == "mixed":
                        b = random.uniform(0, 1)
                        if it_number <= tier_1_it and b <= 0.33:
                            if round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1):
                            
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True

                        elif it_number > tier_1_it and it_number <= tier_2_it and b <= 0.33:
                            if c1[0][0] < c2[0][0]:
                            
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True
                        
                        elif it_number > tier_2_it and b <= 0.33:
                            if (self.distance_matrix[route[i-1], route[i]] + self.distance_matrix[route[j], route[j+1]] > 
                         self.distance_matrix[route[i-1], route[j]] + self.distance_matrix[route[i], route[j+1]]):
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True

                        elif it_number <= tier_1_it and (b > 0.33 and b <= 0.66):
                            if round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1):
                            
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True

                        elif it_number > tier_1_it and it_number <= tier_2_it and (b > 0.33 and b <= 0.66):
                            if c1[0][0] < c2[0][0]:
                            
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True
                        
                        elif it_number > tier_2_it and (b > 0.33 and b <= 0.66):
                            if (self.distance_matrix[route[i-1], route[i]] + self.distance_matrix[route[j], route[j+1]] > 
                         self.distance_matrix[route[i-1], route[j]] + self.distance_matrix[route[i], route[j+1]]):
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True

                        elif it_number <= tier_1_it and b > 0.66:
                            if round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1):
                            
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True

                        elif it_number > tier_1_it and it_number <= tier_2_it and b > 0.66:
                            if c1[0][0] < c2[0][0]:
                            
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True
                        
                        elif it_number > tier_2_it and b > 0.66:
                            if (self.distance_matrix[route[i-1], route[i]] + self.distance_matrix[route[j], route[j+1]] > 
                         self.distance_matrix[route[i-1], route[j]] + self.distance_matrix[route[i], route[j+1]]):
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True

         
        return route

    def three_opt(self, route, route_demands , interdiction_probabilities, iter_num, tier_1_it, tier_2_it):
        best_route = route[:]
        best_distance = self.route_cost(route)
        it_number = iter_num+1
        
        osf_swl = self.optimization_solution_finder
        for i in range(1, len(route) - 2):
            for j in range(i + 1, len(route) - 1):
                for k in range(j + 1, len(route)):
                    new_routes = [
                        route[:i] + route[j:k] + route[i:j] + route[k:],
                        route[:i] + list(reversed(route[i:j])) + route[j:k] + route[k:],
                        route[:i] + route[j:k] + list(reversed(route[i:j])) + route[k:]
                    ]
                    for new_route in new_routes:
                        
                        
                        old_route = best_route
                        old_demands = route_demands

                        new_route_bu = new_route

                        new_route = self.check_and_transform_path(new_route_bu)
                        old_route = self.check_and_transform_path(old_route)
                        old_demands = self.check_and_transform_demands(old_demands)
                        
                        new_demands = self.reorder_demands_by_route(new_route, old_demands)
                        new_demands_bu = new_demands
                        new_demands = self.check_and_transform_demands(new_demands)

                        
                        revised_demands_old_route = self.calculate_revised_demands_for_routes(old_route, old_demands, interdiction_probabilities)
                        revised_demands_new_route = self.calculate_revised_demands_for_routes(new_route, new_demands, interdiction_probabilities)
                        all_cumulative_probabilities_old_route = self.calculate_cumulative_probabilities_for_routes(old_route, interdiction_probabilities)
                        all_cumulative_probabilities_new_route = self.calculate_cumulative_probabilities_for_routes(new_route, interdiction_probabilities)
                        
                        expected_demands_old_route = self.calculate_expected_demand_serviced(revised_demands_old_route, all_cumulative_probabilities_old_route)
                        
                        expected_demands_new_route = self.calculate_expected_demand_serviced(revised_demands_new_route, all_cumulative_probabilities_new_route)
                        c1 = self.calculate_cumulative_probabilities_for_routes(best_route, interdiction_probabilities)
                        c2 = self.calculate_cumulative_probabilities_for_routes(new_route_bu, interdiction_probabilities)
                        

                        total_demand_by_route_check_old_route, number_of_routes_check_old_route, total_demand_check_old_route = self.calculate_demands_for_capacity_check(revised_demands_old_route)
                        
                        total_demand_by_route_check_new_route, number_of_routes_check_new_route, total_demand_check_new_route = self.calculate_demands_for_capacity_check(revised_demands_new_route)
                        
                        new_route = new_route_bu
                        current_distance = self.route_cost(new_route_bu)

                        total_demand_check_new_route < total_demand_check_old_route
                        route_demands = new_demands_bu
                        
                        if osf_swl == "tier":
                            if it_number <= tier_1_it:
                                if ((round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1)) and self.is_route_valid(new_route_bu, route_demands)):
                                    
                                    best_route = new_route[:]
                                

                            elif it_number > tier_1_it and it_number <= tier_2_it:
                                if (c2[0][0] < c1[0][0]) and self.is_route_valid(new_route_bu, route_demands):
                                    best_route = new_route[:]
                                
                            
                            elif it_number > tier_2_it :
                                if current_distance < best_distance and self.is_route_valid(new_route_bu, route_demands):
                                    best_distance = current_distance
                                    best_route = new_route[:]
                               
                        elif osf_swl == "cost":
                            if current_distance < best_distance and self.is_route_valid(new_route_bu, route_demands):
                                best_distance = current_distance
                                best_route = new_route[:]

                        elif osf_swl == "inter_route":
                            if (c2[0][0] < c1[0][0]) and self.is_route_valid(new_route_bu, route_demands):
                                best_route = new_route[:]

                        elif osf_swl == "min_demand_route":
                            if ((round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1)) and self.is_route_valid(new_route_bu, route_demands)):
                                best_route = new_route[:]
                        
                        elif osf_swl == "random":
                            a = random.uniform(0, 1)
                            if a <= 0.33:
                                if ((round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1)) and self.is_route_valid(new_route_bu, route_demands)):
                                    best_route = new_route[:]
                                

                            elif a > 0.33 and a <= 0.66:
                                if (c2[0][0] < c1[0][0]) and self.is_route_valid(new_route_bu, route_demands):
                                    best_route = new_route[:]
                                
                            
                            elif a > 0.66:
                                if current_distance < best_distance and self.is_route_valid(new_route_bu, route_demands):
                                    best_distance = current_distance
                                    best_route = new_route[:]
                                

                        elif osf_swl == "mixed":
                            b = random.uniform(0, 1)
                            if it_number <= tier_1_it and b <= 0.33:
                                if ((round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1)) and self.is_route_valid(new_route_bu, route_demands)):
                                    best_route = new_route[:]
                                

                            elif it_number > tier_1_it and it_number <= tier_2_it and b <= 0.33:
                                if (c2[0][0] < c1[0][0]) and self.is_route_valid(new_route_bu, route_demands):
                                    best_route = new_route[:]
                                
                            
                            elif it_number > tier_2_it and b <= 0.33:
                                if current_distance < best_distance and self.is_route_valid(new_route_bu, route_demands):
                                    best_distance = current_distance
                                    best_route = new_route[:]
                                

                            elif it_number <= tier_1_it and (b > 0.33 and b <= 0.66):
                                if ((round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1)) and self.is_route_valid(new_route_bu, route_demands)):
                                    best_route = new_route[:]
                                

                            elif it_number > tier_1_it and it_number <= tier_2_it and (b > 0.33 and b <= 0.66):
                                if (c2[0][0] < c1[0][0]) and self.is_route_valid(new_route_bu, route_demands):
                                    best_route = new_route[:]
                                
                            
                            elif it_number > tier_2_it and (b > 0.33 and b <= 0.66):
                                if current_distance < best_distance and self.is_route_valid(new_route_bu, route_demands):
                                    best_distance = current_distance
                                    best_route = new_route[:]
                                
                                

                            elif it_number <= tier_1_it and b > 0.66:
                                if ((round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1)) and self.is_route_valid(new_route_bu, route_demands)):
                                    best_route = new_route[:]
                                

                            elif it_number > tier_1_it and it_number <= tier_2_it and b > 0.66:
                                if (c2[0][0] < c1[0][0]) and self.is_route_valid(new_route_bu, route_demands):
                                    best_route = new_route[:]
                                
                            
                            elif it_number > tier_2_it and b > 0.66:
                                if current_distance < best_distance and self.is_route_valid(new_route_bu, route_demands):
                                    best_distance = current_distance
                                    best_route = new_route[:]
                                

        return best_route

    def segment_reversal(self, route, route_demands , interdiction_probabilities, iter_num, tier_1_it, tier_2_it):
        best_route = route[:]
        best_distance = self.route_cost(route)
        it_number = iter_num+1
        
        osf_swl = self.optimization_solution_finder
        
        for i in range(1, len(route) - 2):
            for j in range(i + 1, len(route)):
                c1 = self.calculate_cumulative_probabilities_for_routes(best_route, interdiction_probabilities)
                new_route = route[:i] + list(reversed(route[i:j])) + route[j:]
                new_route_backup = new_route
                c2 = self.calculate_cumulative_probabilities_for_routes(new_route, interdiction_probabilities)
                current_distance = self.route_cost(new_route)

                old_route = best_route
                old_demands = route_demands

                new_route = self.check_and_transform_path(new_route)
                old_route = self.check_and_transform_path(old_route)
                old_demands = self.check_and_transform_demands(old_demands)
                  
                new_demands = self.reorder_demands_by_route(new_route, old_demands)
                new_demands_bu = new_demands  
                
                new_demands = self.check_and_transform_demands(new_demands)

            
                revised_demands_old_route = self.calculate_revised_demands_for_routes(old_route, old_demands, interdiction_probabilities)
                revised_demands_new_route = self.calculate_revised_demands_for_routes(new_route, new_demands, interdiction_probabilities)
                all_cumulative_probabilities_old_route = self.calculate_cumulative_probabilities_for_routes(old_route, interdiction_probabilities)
                all_cumulative_probabilities_new_route = self.calculate_cumulative_probabilities_for_routes(new_route, interdiction_probabilities)
                
                expected_demands_old_route = self.calculate_expected_demand_serviced(revised_demands_old_route, all_cumulative_probabilities_old_route)
                
                expected_demands_new_route = self.calculate_expected_demand_serviced(revised_demands_new_route, all_cumulative_probabilities_new_route)
                
                # Calculate the demands
                total_demand_by_route_check_old_route, number_of_routes_check_old_route, total_demand_check_old_route = self.calculate_demands_for_capacity_check(revised_demands_old_route)
                
                total_demand_by_route_check_new_route, number_of_routes_check_new_route, total_demand_check_new_route = self.calculate_demands_for_capacity_check(revised_demands_new_route)
                
                total_demand_check_new_route < total_demand_check_old_route
                route_demands = new_demands_bu
                
                if osf_swl == "tier":
                    if it_number <= tier_1_it:
                        if (round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1)) and self.is_route_valid(new_route_backup, route_demands):
                            
                            best_route = new_route_backup[:]
                                

                    elif it_number > tier_1_it and it_number <= tier_2_it:
                        if (c2[0][0] < c1[0][0]) and self.is_route_valid(new_route_backup, route_demands):
                            
                            best_route = new_route_backup[:]
                                
                            
                    elif it_number > tier_2_it :
                        if current_distance < best_distance and self.is_route_valid(new_route_backup, route_demands):
                            best_distance = current_distance
                            best_route = new_route_backup[:]
                               

                elif osf_swl == "cost":
                    if current_distance < best_distance and self.is_route_valid(new_route_backup, route_demands):
                        best_distance = current_distance
                        best_route = new_route_backup[:]

                elif osf_swl == "inter_route":
                    if (c2[0][0] < c1[0][0]) and self.is_route_valid(new_route_backup, route_demands):
                        
                        best_route = new_route_backup[:]
                
                elif osf_swl == "min_demand_route":
                    if (round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1)) and self.is_route_valid(new_route_backup, route_demands):
                        
                        best_route = new_route_backup[:]
                
                elif osf_swl == "random":
                    a = random.uniform(0, 1)
                    if a <= 0.33:
                        if (round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1)) and self.is_route_valid(new_route_backup, route_demands):
                            
                            best_route = new_route_backup[:]
                                

                    elif a > 0.33 and a <= 0.66:
                        if (c2[0][0] < c1[0][0]) and self.is_route_valid(new_route_backup, route_demands):
                            
                            best_route = new_route_backup[:]
                                
                            
                    elif a > 0.66:
                        if current_distance < best_distance and self.is_route_valid(new_route_backup, route_demands):
                            best_distance = current_distance
                            best_route = new_route_backup[:]
                                

                elif osf_swl == "mixed":
                    b = random.uniform(0, 1)
                    if it_number <= tier_1_it and b <= 0.33:
                        if (round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1)) and self.is_route_valid(new_route_backup, route_demands):
                            
                            best_route = new_route_backup[:]
                                

                    elif it_number > tier_1_it and it_number <= tier_2_it and b <= 0.33:
                        if (c2[0][0] < c1[0][0]) and self.is_route_valid(new_route_backup, route_demands):
                            
                            best_route = new_route_backup[:]
                                
                            
                    elif it_number > tier_2_it and b <= 0.33:
                        if current_distance < best_distance and self.is_route_valid(new_route_backup, route_demands):
                            best_distance = current_distance
                            best_route = new_route_backup[:]
                                

                    elif it_number <= tier_1_it and (b > 0.33 and b <= 0.66):
                        if (round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1)) and self.is_route_valid(new_route_backup, route_demands):
                            best_route = new_route_backup[:]
                                

                    elif it_number > tier_1_it and it_number <= tier_2_it and (b > 0.33 and b <= 0.66):
                        if (c2[0][0] < c1[0][0]) and self.is_route_valid(new_route_backup, route_demands):
                            best_route = new_route_backup[:]
                                
                            
                    elif it_number > tier_2_it and (b > 0.33 and b <= 0.66):
                        if current_distance < best_distance and self.is_route_valid(new_route_backup, route_demands):
                            best_distance = current_distance
                            best_route = new_route_backup[:]
                                

                    elif it_number <= tier_1_it and b > 0.66:
                        if (round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1)) and self.is_route_valid(new_route_backup, route_demands):
                            best_route = new_route_backup[:]
                                

                    elif it_number > tier_1_it and it_number <= tier_2_it and b > 0.66:
                        if (c2[0][0] < c1[0][0]) and self.is_route_valid(new_route_backup, route_demands):
                            best_route = new_route_backup[:]
                                
                            
                    elif it_number > tier_2_it and b > 0.66:
                        if current_distance < best_distance and self.is_route_valid(new_route_backup, route_demands):
                            best_distance = current_distance
                            best_route = new_route_backup[:]

        return best_route

    def local_search(self, routes, route_demands, interdiction_probabilities, iter_num, tier_1_it, tier_2_it):
        
        for idx, route in enumerate(routes):

            if self.local_search_option == '2-opt':
                routes[idx] = self.two_opt(route, route_demands[idx], interdiction_probabilities, iter_num, tier_1_it, tier_2_it)
                
            elif self.local_search_option == '3-opt':
                routes[idx] = self.three_opt(route, route_demands[idx] , interdiction_probabilities, iter_num, tier_1_it, tier_2_it)
            elif self.local_search_option == 'segment-reversal':
                routes[idx] = self.segment_reversal(route, route_demands[idx] , interdiction_probabilities, iter_num, tier_1_it, tier_2_it)
            elif self.local_search_option == 'random':
                random_choice = random.choice(['2-opt', '3-opt', 'segment-reversal'])
                if random_choice == '2-opt':
                    # print("ENTERING 2-opt")
                    routes[idx] = self.two_opt(route, route_demands[idx] , interdiction_probabilities, iter_num, tier_1_it, tier_2_it)
                    # print("FINISHING 2-opt")
                elif random_choice == '3-opt':
                    # print("ENTERING 3-opt")
                    routes[idx] = self.three_opt(route, route_demands[idx] , interdiction_probabilities, iter_num, tier_1_it, tier_2_it)
                    # print("FINISHING 3-opt")
                elif random_choice == 'segment-reversal':
                    # print("ENTERING segment-reversal")
                    routes[idx] = self.segment_reversal(route, route_demands[idx] , interdiction_probabilities, iter_num, tier_1_it, tier_2_it)
                    # print("FINISHING segment-reversal")
        # Apply swap-based local search after other local searches
        ordered_demands = self.reorder_demands_by_route(routes, route_demands)
        route_demands = ordered_demands
        
        # print("ENTERING swap")
        # print("Routes before swap: ", routes)
        # print("Demands before swap: ", route_demands)
        # print("Iter Num before swap: ", iter_num)
        # print("Tier 1 before swap: ", tier_1_it)
        # print("Tier 2 before swap: ", tier_2_it)
        self.swap_local_search(routes, route_demands, interdiction_probabilities, iter_num, tier_1_it, tier_2_it)
        # print("FINISHING swap")
        return routes, route_demands
        
    # Function to reorder demands to match the route order
    def reorder_demands_by_route(self, routes, demands):
        ordered_demands = []
        for route, demand in zip(routes, demands):
            ordered_route_demands = {}
            # Skip the first and last element assuming they're the depot (0)
            for node in route[1:-1]:
                if node in demand:
                    ordered_route_demands[node] = demand[node]
            ordered_demands.append(ordered_route_demands)
        return ordered_demands

    def route_cost(self, route):
        total_distance = sum(self.distance_matrix[route[i], route[i+1]] for i in range(len(route)-1))
        # We'll apply the penalty in the grasp function when summing up all routes cost
        return total_distance
    
    # Function to check and transform path
    def check_and_transform_path(self, path):
        if isinstance(path, list) and all(isinstance(item, list) for item in path):
            # path is already a list of lists
            return path
        elif isinstance(path, list):
            # path is a single list
            return [path]
        else:
            raise ValueError("path is not in the expected format")

    # Function to check and transform demands_list
    def check_and_transform_demands(self, demands_list):
        if isinstance(demands_list, list) and all(isinstance(item, dict) for item in demands_list):
            # demands_list is already a list of dictionaries
            return demands_list
        elif isinstance(demands_list, dict):
            # demands_list is a single dictionary
            return [demands_list]
        else:
            raise ValueError("demands_list is not in the expected format")
    
    
    def check_sdvrp_feasibility(self, routes, serviced_demands, demands, num_vehicles, vehicle_capacity):
        num_customers = len(demands)
        total_demands_satisfied = {i+1: 0 for i in range(num_customers)}
        customers_serviced = set()

        # Condition 2: Check if number of routes matches number of vehicles
        if len(routes) != num_vehicles:
            return False, "The number of routes does not match the number of vehicles."

        for vehicle, route_demands in enumerate(serviced_demands):
            route_load = 0  # Total load on the current route

            for customer, amount in route_demands.items():
                route_load += amount
                total_demands_satisfied[customer] += amount
                customers_serviced.add(customer)  # Track which customers are serviced

                # Condition 4: Check if any delivery to a customer exceeds vehicle capacity
                if amount > vehicle_capacity:
                    return False, f"Delivery to customer {customer} exceeds vehicle capacity on route {vehicle+1}."

            # Condition 1: Check if total demand on route exceeds vehicle capacity
            if route_load > vehicle_capacity:
                return False, f"Total demand on route {vehicle+1} exceeds vehicle capacity."

        # Condition 3: Check if all customers are serviced
        if len(customers_serviced) != num_customers:
            return False, "Not all customers are serviced."

        # Condition 5: Check if all demands are met or exceeded
        for customer, demand in enumerate(demands, start=1):
            if total_demands_satisfied[customer] < demand:
                return False, f"Customer {customer}'s total received demand {total_demands_satisfied[customer]} is less than required {demand}."

        return True, "All conditions satisfied."
    
    def check_vrpi_feasibility(self, routes, revised_demands, expected_demands, demands, num_vehicles, vehicle_capacity):
        num_customers = len(demands)
        total_demands_satisfied = {i+1: 0 for i in range(num_customers)}
        customers_serviced = set()

        # Condition 2: Check if number of routes matches number of vehicles
        if len(routes) != num_vehicles:
            return False, "The number of routes does not match the number of vehicles."

        for vehicle, route_demands in enumerate(revised_demands):
            route_load = 0  # Total load on the current route

            for customer, amount in route_demands.items():
                route_load += amount
                total_demands_satisfied[customer] += amount
                customers_serviced.add(customer)  # Track which customers are serviced

                # Condition 4: Check if any delivery to a customer exceeds vehicle capacity
                if amount > vehicle_capacity:
                    return False, f"Delivery to customer {customer} exceeds vehicle capacity on route {vehicle+1}."

            # Condition 1: Check if total demand on route exceeds vehicle capacity
            if route_load > vehicle_capacity:
                return False, f"Total demand on route {vehicle+1} exceeds vehicle capacity."

        # Condition 3: Check if all customers are serviced
        if len(customers_serviced) != num_customers:
            return False, "Not all customers are serviced."

        # Condition 5: Check if all demands are met or exceeded
        # Iterate over the demands list with index (1-based)
        for index, demand in enumerate(demands, start=1):
            expected_demand = expected_demands.get(index, 0)  # Get expected demand or 0 if not found
            # Check if the expected demand meets or exceeds the specified demand
            if expected_demand < demand:
                return False, f"Expected demand for customer {index} is {expected_demand}, which is less than required {demand}."

        return True, "All conditions satisfied."

    def calculate_increments(self, total_demand, increment_threshold):
        increment = total_demand / increment_threshold
        return [i * increment for i in range(increment_threshold + 1)]

    def generate_combinations(self, routes, demands, increment_threshold, interdiction_probabilities, input_demands):
        # Identify customers with split deliveries and calculate their total demands
        split_customers = {}
        total_demands = {}

        
        for route_idx, route in enumerate(routes):
            for customer in route[1:-1]:  # Exclude the depot (0)
                #print(route[1:-1])
                if customer not in total_demands:
                    total_demands[customer] = 0
                total_demands[customer] += demands[route_idx].get(customer, 0)

        for customer, total_demand in total_demands.items():
            route_indices = [route_idx for route_idx, route in enumerate(routes) if customer in demands[route_idx]]
            if len(route_indices) > 1:
                split_customers[customer] = (total_demand, route_indices)
        
        # Generate demand increments for each split customer
        customer_combinations = {}
        for customer, (total_demand, route_indices) in split_customers.items():
            increments = self.calculate_increments(total_demand, increment_threshold)
            customer_combinations[customer] = list(itertools.product(increments, repeat=len(route_indices)))
            # Filter out combinations that don't sum up to the total demand
            customer_combinations[customer] = [comb for comb in customer_combinations[customer] if abs(sum(comb) - total_demand) <= 1e-6]
        
        # Generate all possible combinations
        all_combinations = list(itertools.product(*customer_combinations.values()))
        
        # Initialize error count
        error_count = 0

        
        
        # Process each combination
        for combination_set in all_combinations:
            combination_demands = [{k: v for k, v in route.items()} for route in demands]
            
            for idx, (customer, (total_demand, route_indices)) in enumerate(split_customers.items()):
                combination = combination_set[idx]
                for route_idx, demand in zip(route_indices, combination):
                    combination_demands[route_idx][customer] = demand
            
            all_cumulative_probabilities = self.calculate_cumulative_probabilities_for_routes(routes, interdiction_probabilities)
            revised_demands = self.calculate_revised_demands_for_routes(routes, combination_demands, interdiction_probabilities)
            expected_demands = self.calculate_expected_demand_serviced(revised_demands, all_cumulative_probabilities)
            result_f, message = self.check_vrpi_feasibility(routes, revised_demands, expected_demands, input_demands, num_vehicles, vehicle_capacity)
            total_serviced_demands = {}
            for customer, total_demand in total_demands.items():
                serviced_demand = sum(combination_demands[route_idx].get(customer, 0) for route_idx in range(len(routes)))
                total_serviced_demands[customer] = serviced_demand
                log = True
                if abs(serviced_demand - total_demand) > 1e-6:
                    print(f"Error: Serviced demand for customer {customer} does not match total demand.")
                    print(f"Expected: {total_demand}, Got: {serviced_demand}")
                    error_count += 1
                    log = False
                    
                if any(demand < 0 for demand in (combination_demands[route_idx].get(customer, 0) for route_idx in range(len(routes)))):
                    print(f"Error: Negative demand for customer {customer} in one of the routes.")
                    error_count += 1
                    log = False
            if result_f is True and log is True:
                return "we have a candidate", routes, revised_demands
            
            
        
        print(f"Total errors: {error_count}")
        return "we did not find a candidate", routes, revised_demands    
        
        
    
    def calculate_inverse_cumulative_probability(self, path, interdiction_probabilities):
        cumulative_probabilities = {path[0]: 1}  # Start with depot having a cumulative probability of 1
        for i in range(1, len(path)):
            cumulative_probabilities[path[i]] = cumulative_probabilities[path[i-1]] * interdiction_probabilities[path[i-1]][path[i]]
        inverse_cumulative_probabilities = {node: 1/prob for node, prob in cumulative_probabilities.items() if prob != 0}
        return inverse_cumulative_probabilities

    def calculate_revised_demands_for_routes(self, routes, demands, interdiction_probabilities):
        all_revised_demands = []
        for route, demand_serviced in zip(routes, demands):
            # Calculate inverse cumulative probabilities for the route
            inverse_cumulative_probabilities = self.calculate_inverse_cumulative_probability(route, interdiction_probabilities)
            
            # Calculate revised demands
            revised_demands = {}
            for node, demand in demand_serviced.items():
                if node in inverse_cumulative_probabilities:
                    revised_demands[node] = demand * inverse_cumulative_probabilities[node]
            
            all_revised_demands.append(revised_demands)
        
        return all_revised_demands
    
    def calculate_cumulative_probabilities_for_routes(self, routes, interdiction_probabilities):
        # Ensure that 'routes' is always a list of lists
        if not isinstance(routes[0], list):
            routes = [routes]  # Wrap it in another list if it's not already a list of lists
        
        all_cumulative_probabilities = []
        for path in routes:
            cumulative_probabilities = {path[0]: 1}  # Start with depot having a cumulative probability of 1
            for i in range(1, len(path)):
                # Compute cumulative probability for the current node on the path
                cumulative_probabilities[path[i]] = cumulative_probabilities[path[i-1]] * interdiction_probabilities[path[i-1]][path[i]]
            # Append the calculated cumulative probabilities for this route to the list
            all_cumulative_probabilities.append(cumulative_probabilities)
        return all_cumulative_probabilities
    
    def is_matrix_uniform(self, interdiction_probabilities):
        """Check if the interdiction matrix has all elements as 1."""
        for row in interdiction_probabilities:
            for prob in row:
                if prob != 1:
                    return False
        return True

    
    def calculate_expected_demand_serviced(self, revised_demands, cumulative_probabilities):
    # Dictionary to store the expected demand serviced by each customer
        expected_demand_serviced = {}
        
        # Process each route's data
        for revised, probabilities in zip(revised_demands, cumulative_probabilities):
            for node in revised:
                if node in probabilities:
                    # Calculate expected demand for the node
                    expected_demand = revised[node] * probabilities[node]
                    
                    # Add to existing demand if node appears in multiple routes
                    if node in expected_demand_serviced:
                        expected_demand_serviced[node] += expected_demand
                    else:
                        expected_demand_serviced[node] = expected_demand
        #expected_demand_serviced = {key: value + 1e-10 for key, value in expected_demand_serviced.items()}
        expected_demand_serviced = {key: round(value,2) for key, value in expected_demand_serviced.items()}
        return expected_demand_serviced
    

    def is_square_and_dimensions(self, matrix):
        # Determine the number of rows
        num_rows = len(matrix)
        
        # Determine if all rows have the same length as the number of rows (i.e., it's a square matrix)
        is_square = all(len(row) == num_rows for row in matrix)
        
        # Dimensions are given by the number of rows and the number of columns (assuming it's a square)
        dimensions = (num_rows, num_rows if is_square else None)  # Set columns to None if it's not a square
        
        return is_square, dimensions
    
    def generate_intr_matrix(self, n, a, b):
        # Generate the upper triangle of the matrix with random numbers between min and max
        upper_triangle = np.triu(np.random.uniform(a, b, (n, n)), 1)

        # Create the symmetric matrix by adding the transpose of the upper triangle to itself and the diagonal as 1
        matrix = upper_triangle + upper_triangle.T + np.eye(n)

        # Convert numpy array to a list of lists
        interdiction_probabilities = matrix.tolist()
        return interdiction_probabilities
    
    def is_all_ones(self, matrix, tolerance=1e-9):
        for row in matrix:
            for value in row:
                if abs(value - 1.0) > tolerance:
                    return False
        return True

    def grasp(self):
        start_time = time.time()
        best_routes = None
        best_route_demands = None
        best_cost = float('inf')
        no_improvement_counter = 0
        potential_solution_counter = 0
        sl = 'No'
        if self.int_prob is not None:
            is_square, dimensions = self.is_square_and_dimensions(self.int_prob)
            if dimensions[0] == dimensions [1] and dimensions[0] == num_customers+1:
                interdiction_probabilities = self.int_prob
                print("Interdiction Probabilities: ",interdiction_probabilities)
            else:
                print("The manual interdiction probabilities matrix does not have the right dimensions for this problem")
                print("It was replaced by a matrix full of 1's") 
                interdiction_probabilities = self.generate_intr_matrix(num_customers+1, 1.0, 1.0)
                print(interdiction_probabilities)
        else:
            interdiction_probabilities = self.generate_intr_matrix(num_customers+1, self.min_prob_matrix, self.max_prob_matrix)
            print(interdiction_probabilities)

        tier_1_it = round(self.iterations/3,0)
        tier_2_it = round(self.iterations*2/3,0)
        

        for iter_num in range(self.iterations):
            if iter_num != 0 and iter_num >= self.reintegrate_it:
                # Reintegrate the saved initial solution
                routes, route_demands, remaining_demands = self.construct_solution(reintegrate=True)
                
            else:
                # Normal solution generation
                routes, route_demands, remaining_demands = self.construct_solution()
                
            # print("ENTERING LOCAL SEARCH")
            routes, route_demands = self.local_search(routes, route_demands, interdiction_probabilities, iter_num, tier_1_it, tier_2_it)
            
            revised_demands = self.calculate_revised_demands_for_routes(routes, route_demands, interdiction_probabilities)
            all_cumulative_probabilities = self.calculate_cumulative_probabilities_for_routes(routes, interdiction_probabilities)
            
            input_demands = demands
            
            

            result_matrix = self.is_all_ones(interdiction_probabilities)
            
            if result_matrix is True:
                result_f, message = self.check_sdvrp_feasibility(routes, route_demands, demands, num_vehicles, vehicle_capacity)
                print("This is a candidate for SDVRP")
            elif result_matrix is False:
                expected_demands = self.calculate_expected_demand_serviced(revised_demands, all_cumulative_probabilities)
                result_f, message = self.check_vrpi_feasibility(routes, revised_demands, expected_demands, demands, num_vehicles, vehicle_capacity)
                print("This is a candidate for VRPI")

            

            if result_f is False:
                message2, routes, route_demands = self.generate_combinations(routes, route_demands, self.threshold_increment, interdiction_probabilities, input_demands)
                print("Message 2: ", message2)
                # if message == "we have a candidate":
                if message2 == "we have a candidate":
                    result_f = True
                    revised_demands = route_demands
                else:
                    result_f = False
                    revised_demands = revised_demands
            else:
                print("No need to generate combinations")
                
            

            split_deliveries = self.count_split_deliveries(routes, revised_demands)
            cost = sum(self.route_cost(route) for route in routes) + split_deliveries * self.split_penalty
            print("Iteration: ", iter_num, ". Cost: ", cost)
            #print((cost/known-1), '-->', thres)
            div = round(self.iterations/12,0)
            if (iter_num+1) % div == 0:
                print('Iteration # ', iter_num+1, ' out of ', self.iterations,
                  ' (', round((iter_num+1)/self.iterations,2)*100, '%)')
                print('Elapsed time: ', round(time.time() - start_time,0), ' seconds.')

            if ((cost < known) and (result_f is True or message2 == "we have a candidate")) or (((cost/known-1) <= thres) and (result_f is True or message2 == "we have a candidate")):
            #if (cost < known) or (((cost/known-1) <= thres)):
                #print('True: ', (cost/known-1) )
                improvement_time = time.time() - start_time
                trigger = cost/known-1
                best_cost = cost
                best_routes = routes
                best_route_demands = revised_demands
                potential_solution_counter += 1
                if cost < known and result_f is True:
                    print("Early finish, best cost found was lower than known value. Best cost: ", best_cost, ", and known cost is: ", known)
                else:
                    print("Early finish, difference between known value and best cost was: ", str(trigger*100)+'%',
                 ', which is less than the threshold: ', str(thres*100)+'%')
                break
            #print("Cost is ",cost, ", and Best Cost is ", best_cost)
            if cost < best_cost and (result_f is True or message2 == "we have a candidate"):
                improvement_time = time.time() - start_time
                best_cost = cost
                best_routes = routes
                best_route_demands = revised_demands
                no_improvement_counter = 0
                potential_solution_counter += 1
            else:
                no_improvement_counter += 1

            if no_improvement_counter == int(self.iterations * pert_ct):
                self.perturb(routes)

            if no_improvement_counter >= self.stagnation_limit:
                print("Early termination due to stagnation.")
                sl = 'Yes'
                break

        finish_time = time.time() - start_time

        
        if potential_solution_counter >0:
            improvement_time = improvement_time
        else:
            improvement_time = 1e20
            best_routes = "NA"
            best_cost = "NA"
            best_route_demands = "NA"
            remaining_demands = "NA"

    

        return best_routes, best_cost, best_route_demands, remaining_demands, improvement_time, finish_time, sl

    def perturb(self, routes):
        k = int(self.number_customers * self.perturb_percentage)
        perturbed_customers = random.sample(range(1, self.number_customers + 1), k)
        #print('pert customers',perturbed_customers)

        for customer in perturbed_customers:
            for route in routes:
                if customer in route:
                    route.remove(customer)

        for customer in perturbed_customers:
            insertion_route = random.choice(routes)
            insertion_position = random.randint(1, len(insertion_route) - 1)
            #print('inst route', insertion_route)
            #print('inst pos', insertion_position)
            insertion_route.insert(insertion_position, customer)


    def print_results(self, best_routes, best_cost, best_route_demands, remaining_demands):
        for i, route in enumerate(best_routes):
            print(f"Route {i + 1}: {' -> '.join(map(str, route))}")
            print(f"Cost: {self.route_cost(route):.2f}")

        print("Total cost:", best_cost)

        print("\nServiced demands for each route:")
        #print("Best routes demands: ",best_route_demands)
        for i, demands_dict in enumerate(best_route_demands):
            print(f"Route {i + 1} Total Demand Serviced: {sum(demands_dict.values())}")
            for customer in best_routes[i][1:-1]:
                if customer in demands_dict:
                    print(f"   Customer {customer}: {demands_dict[customer]}")

        print("\nCustomers with split delivery:")

        split_deliveries = {}
        for i, demands_dict in enumerate(best_route_demands):
            for customer, demand in demands_dict.items():
                if customer not in split_deliveries:
                    split_deliveries[customer] = []
                split_deliveries[customer].append((best_routes[i], demand))

        for customer, deliveries in split_deliveries.items():
            if len(deliveries) > 1:
                print(f"  Customer {customer}:")
                for delivery in deliveries:
                    route_str = " -> ".join(map(str, delivery[0]))
                    print(f"    Demand serviced by route ({route_str}): {delivery[1]}")

        # Identify and print customers who were not served (either partially or totally)
        print("\nCustomers not served or partially served:")
        for customer_id, rem_demand in enumerate(remaining_demands):
            if rem_demand > 0 and customer_id != 0:  # Exclude the depot with customer_id = 0
                print(f"  Customer {customer_id}: Unserved Demand {rem_demand}")

        # Count clients with split delivery
        split_clients = [cust for cust, deliveries in split_deliveries.items() if len(deliveries) > 1]
        num_split_clients = len(split_clients)

        # Count total clients and clients without split delivery
        total_clients = self.number_customers
        num_non_split_clients = total_clients - num_split_clients

        return num_split_clients, num_non_split_clients, total_clients

    def run(self):
        best_routes, best_cost, best_route_demands, remaining_demands, improvement_time, finish_time, sl = self.grasp()
        if best_routes == "NA":
            num_split_clients = "NA"
            num_non_split_clients = "NA"
            total_clients = "NA"
            solution = "We did not find a feasible solution"
        else:
            num_split_clients, num_non_split_clients, total_clients = self.print_results(best_routes, best_cost, best_route_demands, remaining_demands)
            solution = "We found a feasible solution"

        print(f"\nNumber of clients with split deliveries: {num_split_clients}")
        print(f"Number of clients without split deliveries: {num_non_split_clients}")
        print(f"Total number of clients: {total_clients}")

        return best_cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, sol
0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  83 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  84 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  85 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  86 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  87 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  88 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  89 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  90 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  91 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  92 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  93 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  94 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  95 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  96 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  97 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  98 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  99 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  100 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  101 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  102 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  103 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  104 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  105 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  106 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  107 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  108 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  109 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  110 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  111 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  112 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  113 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  114 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  115 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  116 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  117 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  118 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  119 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  120 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  121 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  122 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  123 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  124 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  125 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  126 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  127 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  128 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  129 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  130 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  131 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  132 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  133 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  134 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  135 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  136 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  137 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  138 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  139 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  140 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  141 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  142 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  143 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  144 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  145 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  146 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  147 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  148 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  149 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  150 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  151 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  152 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  153 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  154 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  155 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  156 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  157 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  158 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  159 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  160 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  161 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  162 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  163 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  164 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  165 . Cost:  1709.30084397434
# Iteration #  166  out of  1000  ( 17.0 %)
# Elapsed time:  376.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  166 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  167 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  168 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  169 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  170 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  171 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  172 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  173 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  174 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  175 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  176 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  177 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  178 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  179 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  180 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  181 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  182 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  183 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  184 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  185 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  186 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  187 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  188 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  189 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  190 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  191 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  192 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  193 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  194 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  195 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  196 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  197 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  198 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  199 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  200 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  201 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  202 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  203 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  204 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  205 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  206 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  207 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  208 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  209 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  210 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  211 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  212 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  213 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  214 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  215 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  216 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  217 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  218 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  219 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  220 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  221 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  222 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  223 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  224 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  225 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  226 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  227 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  228 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  229 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  230 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  231 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  232 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  233 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  234 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  235 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  236 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  237 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  238 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  239 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  240 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  241 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  242 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  243 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  244 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  245 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  246 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  247 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  248 . Cost:  1577.3008282344167
# Iteration #  249  out of  1000  ( 25.0 %)
# Elapsed time:  560.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  249 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  250 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  251 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  252 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  253 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  254 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  255 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  256 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  257 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  258 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  259 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  260 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  261 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  262 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  263 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  264 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  265 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  266 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  267 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  268 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  269 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  270 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  271 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  272 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  273 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  274 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  275 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  276 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  277 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  278 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  279 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  280 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  281 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  282 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  283 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  284 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  285 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  286 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  287 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  288 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  289 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  290 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  291 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  292 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  293 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  294 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  295 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  296 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  297 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  298 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  299 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  300 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  301 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  302 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  303 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  304 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  305 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  306 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  307 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  308 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  309 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  310 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  311 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  312 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  313 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  314 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  315 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  316 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  317 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  318 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  319 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  320 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  321 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  322 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  323 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  324 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  325 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  326 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  327 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  328 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  329 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  330 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  331 . Cost:  1564.0585660182714
# Iteration #  332  out of  1000  ( 33.0 %)
# Elapsed time:  752.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  332 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  333 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  334 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  335 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  336 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  337 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  338 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  339 . Cost:  1495.792928862868
# This is a candidate for VRPI
# ...
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  779 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  780 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  781 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  782 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  783 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  784 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  785 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  786 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  787 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  788 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  789 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  790 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  791 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  792 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  793 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  794 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  795 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  796 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  797 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  798 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  799 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  800 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  801 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  802 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  803 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  804 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  805 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  806 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  807 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  808 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  809 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  810 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  811 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  812 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  813 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  814 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  815 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  816 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  817 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  818 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  819 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  820 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  821 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  822 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  823 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  824 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  825 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  826 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  827 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  828 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  829 . Cost:  1641.9997780225265
# Iteration #  830  out of  1000  ( 83.0 %)
# Elapsed time:  1843.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  830 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  831 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  832 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  833 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  834 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  835 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  836 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  837 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  838 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  839 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  840 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  841 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  842 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  843 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  844 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  845 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  846 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  847 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  848 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  849 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  850 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  851 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  852 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  853 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  854 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  855 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  856 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  857 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  858 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  859 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  860 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  861 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  862 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  863 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  864 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  865 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  866 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  867 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  868 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  869 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  870 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  871 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  872 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  873 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  874 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  875 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  876 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  877 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  878 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  879 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  880 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  881 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  882 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  883 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  884 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  885 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  886 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  887 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  888 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  889 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  890 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  891 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  892 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  893 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  894 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  895 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  896 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  897 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  898 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  899 . Cost:  1709.30084397434
# Early termination due to stagnation.
#
# Number of clients with split deliveries: NA
# Number of clients without split deliveries: NA
# Total number of clients: NA
# Improvement Time: 1e+20
# Finish Time:  1994.279938697815
# Stag Level:  Yes
# 1e+20
# 1994.279938697815
# Diff_Cost%:  NA
# Pot_Improv%:  NA
# Solution status:  We did not find a feasible solution

# %% [markdown]
# ('Combination', 16, 0.5, 0.5, 'demand', 'no', 50)

# %%
# Setting Parameters
# Optimal Value from Data Source
# Number of Iterations
it = 1000# 50000 #1000
# Solution with split deliveries
split_sol = 'No'
##split_sol = 'Yes'
# Stagmation parameter
#stg = round(it*0.9,0)
stg = round(it*0.9,0)
if optimal_value == None:
    known = 1e-10
    #known = 18.67292881108081
else:
    known = optimal_value
# Split information from Data Source
if split_sol == 'Yes':
    optm = 'split'
else: 
    optm = 'no_split'
# Logic to reintegrate initial solution by nearest neighbour
if optm == 'no_split':
    reit = 1
else:
    reit = round(stg*0.8,0)
sps = split_sol
#pl = 0 # known*.15
pl = known*.15 


# Increment Threshold
ith = 10 #10 #1000
# Optimization Solution Finder ("tier", "random", "mixed", "cost", "inter_route", "min_demand_route")
#osf = "tier" #"random" "mixed"
#osf = 'mixed'

#osf = "random"
#osf = 'cost'
#osf = 'inter_route'
osf = 'min_demand_route'
# Alpha factor for restricted candidate list
rcl = 0.5#0.5 #0.8 #0.8
# rcl = 0.8
# Perturbation percentage
prt = 0.5#0.5 #0.6
# prt = 0.8
# Initial seed (does not apply anymore)
sed = 1
# Interdiction prob (manual or generated--> "None" clause)
iprob = None
iprob = iprob1
# Min no interdiction matrix
min_nint = 1#0.92#1#0.95#0.97 # 0.88 #0.98 #0.95
# Max no interdiction matrix
max_nint = 1#0.92#1 #0.999#0.95#0.97 #0.88 #0.99 #0.99

# Threshold when reaching optimal solution
thres = 0.00001

# Percentage over iterations for no improvement
pert_ct = 0.1
# Local search method ('2-opt', '3-opt', 'segment-reversal', 'random') all include swap-local-search method
#lso = '2-opt'
lso = 'random'
#lso = '3-opt'
#lso = 'segment-reversal'


vrp = VRP(num_vehicles=num_vehicles, num_customers=num_customers, locations=locations, demands=demands, vehicle_capacity=vehicle_capacity, rcl_factor=rcl, iterations=it, local_search_option= lso, stagnation_limit=stg, perturb_percentage=prt,split_penalty= pl, sdd = sed, reintegrate_it=reit, split_sol= sps, min_prob_matrix= min_nint, max_prob_matrix= max_nint, int_prob = iprob, threshold_increment = ith, optimization_solution_finder = osf)
cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = vrp.run()
print('Improvement Time:', improvement_time)
print('Finish Time: ',finish_time)
print('Stag Level: ',sl)
if improvement_time == 1e20:
    diff = "NA"
else:
    diff = str(round(abs((cost/known-1)),2)*100)+'%'
print(improvement_time)
print(finish_time)
if improvement_time == 0  and finish_time == 0:
    pot_impr = str(round((1e10/1e10),2)*100)+'%'   
elif improvement_time == 1e20:
    pot_impr = "NA" 
else:
    pot_impr = str(round((improvement_time/finish_time),2)*100)+'%'
print('Diff_Cost%: ', diff)
print('Pot_Improv%: ', pot_impr)
print("Solution status: ", solution)
# Out:
# Interdiction Probabilities:  [[1.0, 0.9245596093729803, 0.9421224384600982, 0.9281118722090896, 0.9785314546199626, 0.9681146119563971, 0.9601160937637852, 0.9533237169739396, 0.9217886249233886, 0.9581044465882134, 0.979547461445175, 0.977610795183075, 0.9287655278343139, 0.9664321341219351, 0.9803119915077759, 0.9150254450732598, 0.9399681303753511, 0.9757712073838597, 0.9400854762150992, 0.9197061325758853, 0.9787867220324488, 0.9824706939723244, 0.9381160389170244, 0.9793807780421058, 0.9396870296398332, 0.9401673455423657, 0.9814081717202838, 0.9859384753311028, 0.9228217605663368, 0.9337380573517048, 0.9425040877090827, 0.9885802991695554, 0.9452970842338354], [0.9245596093729803, 1.0, 0.9584372833650735, 0.9400140257928693, 0.9299771758359122, 0.9503834264900511, 0.9360898419640802, 0.902380724436002, 0.9660201536071671, 0.9662496655196906, 0.9433889946869619, 0.9345649102346636, 0.9054900573854664, 0.9301369700571391, 0.9695802247486901, 0.9491920980923796, 0.9026029356984477, 0.9855610167531275, 0.9837657379612478, 0.9787974378588218, 0.9042129038318869, 0.9618373105127495, 0.9650092876715939, 0.9515427938067134, 0.9563867110770174, 0.96450652517215, 0.9036634121598764, 0.9787540945917699, 0.907602320523581, 0.9144860741778783, 0.9408579252864454, 0.9855491783510815, 0.9181460514286893], [0.9421224384600982, 0.9584372833650735, 1.0, 0.9264242154819252, 0.9580139296416259, 0.9317593300020401, 0.9518628783973647, 0.9652294185686948, 0.9167030164274126, 0.9647191276508389, 0.9175376081630151, 0.974883661565248, 0.9256949496861441, 0.9599987972914634, 0.9715892121351216, 0.968386356253005, 0.9868663544586418, 0.9460634933276089, 0.9743199792907375, 0.9863164233051496, 0.9019984259505591, 0.950131447112789, 0.9781050951939447, 0.9828010029991583, 0.9086708970654739, 0.9409353154246363, 0.976896359376168, 0.9819180749481291, 0.9513635768476433, 0.9830442119535798, 0.9052016442933383, 0.951941607358771, 0.9043880415124165], [0.9281118722090896, 0.9400140257928693, 0.9264242154819252, 1.0, 0.9637009650561799, 0.9642040350679223, 0.941161618388269, 0.948713188278484, 0.9483414751796131, 0.9898380366151047, 0.927608575314421, 0.9400263455966572, 0.9085915661238244, 0.9813375009858203, 0.9670909137919707, 0.9024051578202773, 0.932492970427768, 0.9389266163243966, 0.9886270145290911, 0.9245891444295257, 0.9043267202967349, 0.9400348895753549, 0.9551019867713755, 0.9400859209013559, 0.9535150028150128, 0.9091030499777119, 0.9302167047399111, 0.9424641171489299, 0.9536640206794328, 0.9188374634994273, 0.970668986905339, 0.9257452689396135, 0.9054353322769534], [0.9785314546199626, 0.9299771758359122, 0.9580139296416259, 0.9637009650561799, 1.0, 0.9640058244061457, 0.9067618278757839, 0.9875464909575913, 0.9359691246305523, 0.963837668746052, 0.9402148687656655, 0.9633637906919923, 0.9014991264393288, 0.9086345998852112, 0.9206772206227004, 0.9755895155614436, 0.9548117979067705, 0.9687064650055403, 0.9842289438769072, 0.9829419864317631, 0.9105843115320451, 0.9781185701506474, 0.9152279303335538, 0.9043520651761386, 0.9655268240126205, 0.9011592745534275, 0.9265703439311508, 0.9553306163153681, 0.9118625438996031, 0.9677891452640103, 0.955982847837417, 0.9827191225313494, 0.9266229054869907], [0.9681146119563971, 0.9503834264900511, 0.9317593300020401, 0.9642040350679223, 0.9640058244061457, 1.0, 0.954641724810021, 0.9715092480110084, 0.9073455543646098, 0.9423115480181214, 0.9513947898178092, 0.9244143004787043, 0.9737919495720608, 0.9002221410882071, 0.9841024606471761, 0.9377528041124721, 0.9651550857286382, 0.9638501535732479, 0.9623855824803988, 0.9457814679308386, 0.9104620519869895, 0.9571447384433396, 0.9682329560093751, 0.9720144384849656, 0.9732432305802801, 0.9418514553832198, 0.9106250339693746, 0.9301935606732554, 0.9160669325979663, 0.9425713711903343, 0.9050762826576827, 0.9892886002608716, 0.9621995830981146], [0.9601160937637852, 0.9360898419640802, 0.9518628783973647, 0.941161618388269, 0.9067618278757839, 0.95464 ...
# Feasible construction solution
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  0 . Cost:  2029.4411376419162
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  1 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  2 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  3 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  4 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  5 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  6 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  7 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  8 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  9 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  10 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  11 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  12 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  13 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  14 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  15 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  16 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  17 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  18 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  19 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  20 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  21 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  22 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  23 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  24 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  25 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  26 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  27 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  28 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  29 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  30 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  31 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  32 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  33 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  34 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  35 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  36 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  37 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  38 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  39 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  40 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  41 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  42 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  43 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  44 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  45 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  46 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  47 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  48 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  49 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  50 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  51 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  52 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  53 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  54 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  55 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  56 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  57 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  58 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  59 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  60 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  61 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  62 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  63 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  64 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  65 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  66 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  67 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  68 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  69 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  70 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  71 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  72 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  73 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  74 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  75 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  76 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  77 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  78 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  79 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  80 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  81 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  82 . Cost:  1434.6859558390956
# Iteration #  83  out of  1000  ( 8.0 %)
# Elapsed time:  190.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  83 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  84 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  85 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  86 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  87 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  88 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  89 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  90 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  91 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  92 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  93 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  94 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  95 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  96 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  97 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  98 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  99 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  100 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  101 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  102 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  103 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  104 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  105 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  106 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  107 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  108 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  109 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  110 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  111 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  112 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  113 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  114 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  115 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  116 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  117 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  118 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  119 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  120 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  121 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  122 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  123 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  124 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  125 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  126 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  127 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  128 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  129 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  130 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  131 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  132 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  133 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  134 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  135 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  136 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  137 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  138 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  139 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  140 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  141 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  142 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  143 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  144 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  145 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  146 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  147 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  148 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  149 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  150 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  151 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  152 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  153 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  154 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  155 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  156 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  157 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  158 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  159 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  160 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  161 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  162 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  163 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  164 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  165 . Cost:  1709.30084397434
# Iteration #  166  out of  1000  ( 17.0 %)
# Elapsed time:  378.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  166 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  167 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  168 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  169 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  170 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  171 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  172 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  173 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  174 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  175 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  176 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  177 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  178 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  179 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  180 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  181 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  182 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  183 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  184 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  185 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  186 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  187 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  188 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  189 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  190 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  191 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  192 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  193 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  194 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  195 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  196 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  197 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  198 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  199 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  200 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  201 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  202 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  203 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  204 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  205 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  206 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  207 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  208 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  209 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  210 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  211 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  212 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  213 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  214 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  215 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  216 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  217 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  218 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  219 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  220 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  221 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  222 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  223 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  224 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  225 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  226 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  227 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  228 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  229 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  230 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  231 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  232 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  233 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  234 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  235 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  236 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  237 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  238 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  239 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  240 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  241 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  242 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  243 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  244 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  245 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  246 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  247 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  248 . Cost:  1577.3008282344167
# Iteration #  249  out of  1000  ( 25.0 %)
# Elapsed time:  564.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  249 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  250 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  251 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  252 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  253 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  254 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  255 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  256 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  257 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  258 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  259 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  260 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  261 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  262 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  263 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  264 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  265 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  266 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  267 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  268 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  269 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  270 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  271 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  272 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  273 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  274 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  275 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  276 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  277 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  278 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  279 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  280 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  281 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  282 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  283 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  284 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  285 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  286 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  287 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  288 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  289 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  290 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  291 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  292 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  293 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  294 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  295 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  296 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  297 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  298 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  299 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  300 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  301 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  302 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  303 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  304 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  305 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  306 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  307 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  308 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  309 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  310 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  311 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  312 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  313 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  314 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  315 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  316 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  317 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  318 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  319 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  320 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  321 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  322 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  323 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  324 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  325 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  326 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  327 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  328 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  329 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  330 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  331 . Cost:  1564.0585660182714
# Iteration #  332  out of  1000  ( 33.0 %)
# Elapsed time:  759.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  332 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  333 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  334 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  335 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  336 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  337 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  338 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  339 . Cost:  1495.792928862868
# This is a candidate for VRPI
# ...
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  779 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  780 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  781 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  782 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  783 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  784 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  785 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  786 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  787 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  788 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  789 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  790 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  791 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  792 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  793 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  794 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  795 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  796 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  797 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  798 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  799 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  800 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  801 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  802 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  803 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  804 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  805 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  806 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  807 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  808 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  809 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  810 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  811 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  812 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  813 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  814 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  815 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  816 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  817 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  818 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  819 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  820 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  821 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  822 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  823 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  824 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  825 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  826 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  827 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  828 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  829 . Cost:  1641.9997780225265
# Iteration #  830  out of  1000  ( 83.0 %)
# Elapsed time:  1895.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  830 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  831 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  832 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  833 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  834 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  835 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  836 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  837 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  838 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  839 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  840 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  841 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  842 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  843 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  844 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  845 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  846 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  847 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  848 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  849 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  850 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  851 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  852 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  853 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  854 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:
#
# Customers not served or partially served:
#
# Number of clients with split deliveries: 3
# Number of clients without split deliveries: 29
# Total number of clients: 32
# Improvement Time: 1965.7070443630219
# Finish Time:  2504.7877304553986
# Stag Level:  No
# 1965.7070443630219
# 2504.7877304553986
# Diff_Cost%:  137.0%
# Pot_Improv%:  78.0%
# Solution status:  We found a feasible solution

# %% [markdown]
# ('Combination', 31, 0.5, 0.8, 'demand', 'no', 0)

# %%
# Setting Parameters
# Optimal Value from Data Source
# Number of Iterations
it = 500# 50000 #1000
# Solution with split deliveries
split_sol = 'No'
#split_sol = 'Yes'
# Stagmation parameter
#stg = round(it*0.9,0)
stg = round(it*0.9,0)
if optimal_value == None:
    known = 1e-10
    #known = 18.67292881108081
else:
    known = optimal_value
# Split information from Data Source
if split_sol == 'Yes':
    optm = 'split'
else: 
    optm = 'no_split'
# Logic to reintegrate initial solution by nearest neighbour
if optm == 'no_split':
    reit = 1
else:
    reit = round(stg*0.8,0)
sps = split_sol
pl = 0 # known*.15
#pl = known*.15 


# Increment Threshold
ith = 10 #10 #1000
# Optimization Solution Finder ("tier", "random", "mixed", "cost", "inter_route", "min_demand_route")
#osf = "tier" #"random" "mixed"
#osf = 'mixed'

#osf = "random"
#osf = 'cost'
#osf = 'inter_route'
osf = 'min_demand_route'
# Alpha factor for restricted candidate list
rcl = 0.5#0.5 #0.8 #0.8
# rcl = 0.8
# Perturbation percentage
prt = 0.8#0.5 #0.6
# prt = 0.8
# Initial seed (does not apply anymore)
sed = 1
# Interdiction prob (manual or generated--> "None" clause)
iprob = None
iprob = iprob1
# Min no interdiction matrix
min_nint = 1#0.92#1#0.95#0.97 # 0.88 #0.98 #0.95
# Max no interdiction matrix
max_nint = 1#0.92#1 #0.999#0.95#0.97 #0.88 #0.99 #0.99

# Threshold when reaching optimal solution
thres = 0.00001

# Percentage over iterations for no improvement
pert_ct = 0.1
# Local search method ('2-opt', '3-opt', 'segment-reversal', 'random') all include swap-local-search method
#lso = '2-opt'
lso = 'random'
#lso = '3-opt'
#lso = 'segment-reversal'


vrp = VRP(num_vehicles=num_vehicles, num_customers=num_customers, locations=locations, demands=demands, vehicle_capacity=vehicle_capacity, rcl_factor=rcl, iterations=it, local_search_option= lso, stagnation_limit=stg, perturb_percentage=prt,split_penalty= pl, sdd = sed, reintegrate_it=reit, split_sol= sps, min_prob_matrix= min_nint, max_prob_matrix= max_nint, int_prob = iprob, threshold_increment = ith, optimization_solution_finder = osf)
cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = vrp.run()
print('Improvement Time:', improvement_time)
print('Finish Time: ',finish_time)
print('Stag Level: ',sl)
if improvement_time == 1e20:
    diff = "NA"
else:
    diff = str(round(abs((cost/known-1)),2)*100)+'%'
print(improvement_time)
print(finish_time)
if improvement_time == 0  and finish_time == 0:
    pot_impr = str(round((1e10/1e10),2)*100)+'%'   
elif improvement_time == 1e20:
    pot_impr = "NA" 
else:
    pot_impr = str(round((improvement_time/finish_time),2)*100)+'%'
print('Diff_Cost%: ', diff)
print('Pot_Improv%: ', pot_impr)
print("Solution status: ", solution)
# Out:
# Interdiction Probabilities:  [[1.0, 0.9245596093729803, 0.9421224384600982, 0.9281118722090896, 0.9785314546199626, 0.9681146119563971, 0.9601160937637852, 0.9533237169739396, 0.9217886249233886, 0.9581044465882134, 0.979547461445175, 0.977610795183075, 0.9287655278343139, 0.9664321341219351, 0.9803119915077759, 0.9150254450732598, 0.9399681303753511, 0.9757712073838597, 0.9400854762150992, 0.9197061325758853, 0.9787867220324488, 0.9824706939723244, 0.9381160389170244, 0.9793807780421058, 0.9396870296398332, 0.9401673455423657, 0.9814081717202838, 0.9859384753311028, 0.9228217605663368, 0.9337380573517048, 0.9425040877090827, 0.9885802991695554, 0.9452970842338354], [0.9245596093729803, 1.0, 0.9584372833650735, 0.9400140257928693, 0.9299771758359122, 0.9503834264900511, 0.9360898419640802, 0.902380724436002, 0.9660201536071671, 0.9662496655196906, 0.9433889946869619, 0.9345649102346636, 0.9054900573854664, 0.9301369700571391, 0.9695802247486901, 0.9491920980923796, 0.9026029356984477, 0.9855610167531275, 0.9837657379612478, 0.9787974378588218, 0.9042129038318869, 0.9618373105127495, 0.9650092876715939, 0.9515427938067134, 0.9563867110770174, 0.96450652517215, 0.9036634121598764, 0.9787540945917699, 0.907602320523581, 0.9144860741778783, 0.9408579252864454, 0.9855491783510815, 0.9181460514286893], [0.9421224384600982, 0.9584372833650735, 1.0, 0.9264242154819252, 0.9580139296416259, 0.9317593300020401, 0.9518628783973647, 0.9652294185686948, 0.9167030164274126, 0.9647191276508389, 0.9175376081630151, 0.974883661565248, 0.9256949496861441, 0.9599987972914634, 0.9715892121351216, 0.968386356253005, 0.9868663544586418, 0.9460634933276089, 0.9743199792907375, 0.9863164233051496, 0.9019984259505591, 0.950131447112789, 0.9781050951939447, 0.9828010029991583, 0.9086708970654739, 0.9409353154246363, 0.976896359376168, 0.9819180749481291, 0.9513635768476433, 0.9830442119535798, 0.9052016442933383, 0.951941607358771, 0.9043880415124165], [0.9281118722090896, 0.9400140257928693, 0.9264242154819252, 1.0, 0.9637009650561799, 0.9642040350679223, 0.941161618388269, 0.948713188278484, 0.9483414751796131, 0.9898380366151047, 0.927608575314421, 0.9400263455966572, 0.9085915661238244, 0.9813375009858203, 0.9670909137919707, 0.9024051578202773, 0.932492970427768, 0.9389266163243966, 0.9886270145290911, 0.9245891444295257, 0.9043267202967349, 0.9400348895753549, 0.9551019867713755, 0.9400859209013559, 0.9535150028150128, 0.9091030499777119, 0.9302167047399111, 0.9424641171489299, 0.9536640206794328, 0.9188374634994273, 0.970668986905339, 0.9257452689396135, 0.9054353322769534], [0.9785314546199626, 0.9299771758359122, 0.9580139296416259, 0.9637009650561799, 1.0, 0.9640058244061457, 0.9067618278757839, 0.9875464909575913, 0.9359691246305523, 0.963837668746052, 0.9402148687656655, 0.9633637906919923, 0.9014991264393288, 0.9086345998852112, 0.9206772206227004, 0.9755895155614436, 0.9548117979067705, 0.9687064650055403, 0.9842289438769072, 0.9829419864317631, 0.9105843115320451, 0.9781185701506474, 0.9152279303335538, 0.9043520651761386, 0.9655268240126205, 0.9011592745534275, 0.9265703439311508, 0.9553306163153681, 0.9118625438996031, 0.9677891452640103, 0.955982847837417, 0.9827191225313494, 0.9266229054869907], [0.9681146119563971, 0.9503834264900511, 0.9317593300020401, 0.9642040350679223, 0.9640058244061457, 1.0, 0.954641724810021, 0.9715092480110084, 0.9073455543646098, 0.9423115480181214, 0.9513947898178092, 0.9244143004787043, 0.9737919495720608, 0.9002221410882071, 0.9841024606471761, 0.9377528041124721, 0.9651550857286382, 0.9638501535732479, 0.9623855824803988, 0.9457814679308386, 0.9104620519869895, 0.9571447384433396, 0.9682329560093751, 0.9720144384849656, 0.9732432305802801, 0.9418514553832198, 0.9106250339693746, 0.9301935606732554, 0.9160669325979663, 0.9425713711903343, 0.9050762826576827, 0.9892886002608716, 0.9621995830981146], [0.9601160937637852, 0.9360898419640802, 0.9518628783973647, 0.941161618388269, 0.9067618278757839, 0.95464 ...
# Feasible construction solution
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  0 . Cost:  1653.6911376419162
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  1 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  2 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  3 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  4 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  5 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  6 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  7 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  8 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  9 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  10 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  11 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  12 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  13 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  14 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  15 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  16 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  17 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  18 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  19 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  20 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  21 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  22 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  23 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  24 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  25 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  26 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  27 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  28 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  29 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  30 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  31 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  32 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  33 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  34 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  35 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  36 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  37 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  38 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  39 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  40 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  41 . Cost:  1577.3008282344167
# Iteration #  42  out of  500  ( 8.0 %)
# Elapsed time:  98.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  42 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  43 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  44 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  45 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  46 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  47 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  48 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  49 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  50 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  51 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  52 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  53 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  54 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  55 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  56 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  57 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  58 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  59 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  60 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  61 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  62 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  63 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  64 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  65 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  66 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  67 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  68 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  69 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  70 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  71 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  72 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  73 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  74 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  75 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  76 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  77 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  78 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  79 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  80 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  81 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  82 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  83 . Cost:  1495.792928862868
# Iteration #  84  out of  500  ( 17.0 %)
# Elapsed time:  193.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  84 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  85 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  86 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  87 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  88 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  89 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  90 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  91 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  92 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  93 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  94 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  95 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  96 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  97 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  98 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  99 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  100 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  101 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  102 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  103 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  104 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  105 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  106 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  107 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  108 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  109 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  110 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  111 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  112 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  113 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  114 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  115 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  116 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  117 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  118 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  119 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  120 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  121 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  122 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  123 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  124 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  125 . Cost:  1411.2621207214222
# Iteration #  126  out of  500  ( 25.0 %)
# Elapsed time:  285.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  126 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  127 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  128 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  129 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  130 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  131 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  132 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  133 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  134 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  135 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  136 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  137 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  138 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  139 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  140 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  141 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  142 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  143 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  144 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  145 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  146 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  147 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  148 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  149 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  150 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  151 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  152 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  153 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  154 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  155 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  156 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  157 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  158 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  159 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  160 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  161 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  162 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  163 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  164 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  165 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  166 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  167 . Cost:  1641.9997780225265
# Iteration #  168  out of  500  ( 34.0 %)
# Elapsed time:  381.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  168 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  169 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  170 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  171 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  172 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  173 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  174 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  175 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  176 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  177 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  178 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  179 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  180 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  181 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  182 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  183 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  184 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  185 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  186 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  187 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  188 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  189 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  190 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  191 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  192 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  193 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  194 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  195 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  196 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  197 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  198 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  199 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  200 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  201 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  202 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  203 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  204 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  205 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  206 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  207 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  208 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  209 . Cost:  1495.792928862868
# Iteration #  210  out of  500  ( 42.0 %)
# Elapsed time:  475.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  210 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  211 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  212 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  213 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  214 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  215 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  216 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  217 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  218 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  219 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  220 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  221 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  222 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  223 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  224 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  225 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  226 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  227 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  228 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  229 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  230 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  231 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  232 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  233 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  234 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  235 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  236 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  237 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  238 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  239 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  240 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  241 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  242 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  243 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  244 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  245 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  246 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  247 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  248 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  249 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  250 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  251 . Cost:  1616.2055191741592
# Iteration #  252  out of  500  ( 50.0 %)
# Elapsed time:  564.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  252 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  253 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  254 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  255 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  256 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  257 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  258 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  259 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  260 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  261 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  262 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  263 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  264 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  265 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  266 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  267 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  268 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  269 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  270 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  271 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  272 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  273 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  274 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  275 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  276 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  277 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  278 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  279 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  280 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  281 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  282 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  283 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  284 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  285 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  286 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  287 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  288 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  289 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  290 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  291 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  292 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  293 . Cost:  1641.9997780225265
# Iteration #  294  out of  500  ( 59.0 %)
# Elapsed time:  658.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  294 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  295 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  296 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  297 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  298 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  299 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  300 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  301 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  302 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  303 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  304 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  305 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  306 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  307 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  308 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  309 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  310 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  311 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  312 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  313 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  314 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  315 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  316 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  317 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  318 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  319 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  320 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  321 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  322 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  323 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  324 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  325 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  326 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  327 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  328 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  329 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  330 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  331 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  332 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  333 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  334 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  335 . Cost:  1618.328362403674
# Iteration #  336  out of  500  ( 67.0 %)
# Elapsed time:  754.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  336 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  337 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  338 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  339 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  340 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  341 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  342 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  343 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  344 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  345 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  346 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  347 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  348 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  349 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  350 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  351 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  352 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  353 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  354 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  355 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  356 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  357 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  358 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  359 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  360 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  361 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  362 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  363 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  364 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  365 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  366 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  367 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  368 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  369 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  370 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  371 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  372 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  373 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  374 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  375 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  376 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  377 . Cost:  1531.9666910602145
# Iteration #  378  out of  500  ( 76.0 %)
# Elapsed time:  833.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  378 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  379 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  380 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  381 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  382 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  383 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  384 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  385 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  386 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  387 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  388 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  389 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  390 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  391 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  392 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  393 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  394 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  395 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  396 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  397 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  398 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  399 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  400 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  401 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  402 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  403 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  404 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  405 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  406 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  407 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  408 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  409 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  410 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  411 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  412 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  413 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  414 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  415 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  416 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  417 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  418 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  419 . Cost:  1495.792928862868
# Iteration #  420  out of  500  ( 84.0 %)
# Elapsed time:  908.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  420 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  421 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  422 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  423 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  424 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  425 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  426 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  427 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  428 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  429 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  430 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  431 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  432 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  433 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  434 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  435 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  436 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  437 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  438 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  439 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  440 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  441 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  442 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  443 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  444 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  445 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  446 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  447 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  448 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  449 . Cost:  1506.6799080126375
# Early termination due to stagnation.
#
# Number of clients with split deliveries: NA
# Number of clients without split deliveries: NA
# Total number of clients: NA
# Improvement Time: 1e+20
# Finish Time:  972.9489450454712
# Stag Level:  Yes
# 1e+20
# 972.9489450454712
# Diff_Cost%:  NA
# Pot_Improv%:  NA
# Solution status:  We did not find a feasible solution

# %% [markdown]
# ('Combination', 32, 0.5, 0.8, 'demand', 'no', 50)

# %%
# Setting Parameters
# Optimal Value from Data Source
# Number of Iterations
it = 500# 50000 #1000
# Solution with split deliveries
split_sol = 'No'
#split_sol = 'Yes'
# Stagmation parameter
#stg = round(it*0.9,0)
stg = round(it*0.9,0)
if optimal_value == None:
    known = 1e-10
    #known = 18.67292881108081
else:
    known = optimal_value
# Split information from Data Source
if split_sol == 'Yes':
    optm = 'split'
else: 
    optm = 'no_split'
# Logic to reintegrate initial solution by nearest neighbour
if optm == 'no_split':
    reit = 1
else:
    reit = round(stg*0.8,0)
sps = split_sol
#pl = 0 # known*.15
pl = known*.15 


# Increment Threshold
ith = 10 #10 #1000
# Optimization Solution Finder ("tier", "random", "mixed", "cost", "inter_route", "min_demand_route")
#osf = "tier" #"random" "mixed"
#osf = 'mixed'

#osf = "random"
#osf = 'cost'
#osf = 'inter_route'
osf = 'min_demand_route'
# Alpha factor for restricted candidate list
rcl = 0.5#0.5 #0.8 #0.8
# rcl = 0.8
# Perturbation percentage
prt = 0.8#0.5 #0.6
# prt = 0.8
# Initial seed (does not apply anymore)
sed = 1
# Interdiction prob (manual or generated--> "None" clause)
iprob = None
iprob = iprob1
# Min no interdiction matrix
min_nint = 1#0.92#1#0.95#0.97 # 0.88 #0.98 #0.95
# Max no interdiction matrix
max_nint = 1#0.92#1 #0.999#0.95#0.97 #0.88 #0.99 #0.99

# Threshold when reaching optimal solution
thres = 0.00001

# Percentage over iterations for no improvement
pert_ct = 0.1
# Local search method ('2-opt', '3-opt', 'segment-reversal', 'random') all include swap-local-search method
#lso = '2-opt'
lso = 'random'
#lso = '3-opt'
#lso = 'segment-reversal'


vrp = VRP(num_vehicles=num_vehicles, num_customers=num_customers, locations=locations, demands=demands, vehicle_capacity=vehicle_capacity, rcl_factor=rcl, iterations=it, local_search_option= lso, stagnation_limit=stg, perturb_percentage=prt,split_penalty= pl, sdd = sed, reintegrate_it=reit, split_sol= sps, min_prob_matrix= min_nint, max_prob_matrix= max_nint, int_prob = iprob, threshold_increment = ith, optimization_solution_finder = osf)
cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = vrp.run()
print('Improvement Time:', improvement_time)
print('Finish Time: ',finish_time)
print('Stag Level: ',sl)
if improvement_time == 1e20:
    diff = "NA"
else:
    diff = str(round(abs((cost/known-1)),2)*100)+'%'
print(improvement_time)
print(finish_time)
if improvement_time == 0  and finish_time == 0:
    pot_impr = str(round((1e10/1e10),2)*100)+'%'   
elif improvement_time == 1e20:
    pot_impr = "NA" 
else:
    pot_impr = str(round((improvement_time/finish_time),2)*100)+'%'
print('Diff_Cost%: ', diff)
print('Pot_Improv%: ', pot_impr)
print("Solution status: ", solution)
# Out:
# Interdiction Probabilities:  [[1.0, 0.9245596093729803, 0.9421224384600982, 0.9281118722090896, 0.9785314546199626, 0.9681146119563971, 0.9601160937637852, 0.9533237169739396, 0.9217886249233886, 0.9581044465882134, 0.979547461445175, 0.977610795183075, 0.9287655278343139, 0.9664321341219351, 0.9803119915077759, 0.9150254450732598, 0.9399681303753511, 0.9757712073838597, 0.9400854762150992, 0.9197061325758853, 0.9787867220324488, 0.9824706939723244, 0.9381160389170244, 0.9793807780421058, 0.9396870296398332, 0.9401673455423657, 0.9814081717202838, 0.9859384753311028, 0.9228217605663368, 0.9337380573517048, 0.9425040877090827, 0.9885802991695554, 0.9452970842338354], [0.9245596093729803, 1.0, 0.9584372833650735, 0.9400140257928693, 0.9299771758359122, 0.9503834264900511, 0.9360898419640802, 0.902380724436002, 0.9660201536071671, 0.9662496655196906, 0.9433889946869619, 0.9345649102346636, 0.9054900573854664, 0.9301369700571391, 0.9695802247486901, 0.9491920980923796, 0.9026029356984477, 0.9855610167531275, 0.9837657379612478, 0.9787974378588218, 0.9042129038318869, 0.9618373105127495, 0.9650092876715939, 0.9515427938067134, 0.9563867110770174, 0.96450652517215, 0.9036634121598764, 0.9787540945917699, 0.907602320523581, 0.9144860741778783, 0.9408579252864454, 0.9855491783510815, 0.9181460514286893], [0.9421224384600982, 0.9584372833650735, 1.0, 0.9264242154819252, 0.9580139296416259, 0.9317593300020401, 0.9518628783973647, 0.9652294185686948, 0.9167030164274126, 0.9647191276508389, 0.9175376081630151, 0.974883661565248, 0.9256949496861441, 0.9599987972914634, 0.9715892121351216, 0.968386356253005, 0.9868663544586418, 0.9460634933276089, 0.9743199792907375, 0.9863164233051496, 0.9019984259505591, 0.950131447112789, 0.9781050951939447, 0.9828010029991583, 0.9086708970654739, 0.9409353154246363, 0.976896359376168, 0.9819180749481291, 0.9513635768476433, 0.9830442119535798, 0.9052016442933383, 0.951941607358771, 0.9043880415124165], [0.9281118722090896, 0.9400140257928693, 0.9264242154819252, 1.0, 0.9637009650561799, 0.9642040350679223, 0.941161618388269, 0.948713188278484, 0.9483414751796131, 0.9898380366151047, 0.927608575314421, 0.9400263455966572, 0.9085915661238244, 0.9813375009858203, 0.9670909137919707, 0.9024051578202773, 0.932492970427768, 0.9389266163243966, 0.9886270145290911, 0.9245891444295257, 0.9043267202967349, 0.9400348895753549, 0.9551019867713755, 0.9400859209013559, 0.9535150028150128, 0.9091030499777119, 0.9302167047399111, 0.9424641171489299, 0.9536640206794328, 0.9188374634994273, 0.970668986905339, 0.9257452689396135, 0.9054353322769534], [0.9785314546199626, 0.9299771758359122, 0.9580139296416259, 0.9637009650561799, 1.0, 0.9640058244061457, 0.9067618278757839, 0.9875464909575913, 0.9359691246305523, 0.963837668746052, 0.9402148687656655, 0.9633637906919923, 0.9014991264393288, 0.9086345998852112, 0.9206772206227004, 0.9755895155614436, 0.9548117979067705, 0.9687064650055403, 0.9842289438769072, 0.9829419864317631, 0.9105843115320451, 0.9781185701506474, 0.9152279303335538, 0.9043520651761386, 0.9655268240126205, 0.9011592745534275, 0.9265703439311508, 0.9553306163153681, 0.9118625438996031, 0.9677891452640103, 0.955982847837417, 0.9827191225313494, 0.9266229054869907], [0.9681146119563971, 0.9503834264900511, 0.9317593300020401, 0.9642040350679223, 0.9640058244061457, 1.0, 0.954641724810021, 0.9715092480110084, 0.9073455543646098, 0.9423115480181214, 0.9513947898178092, 0.9244143004787043, 0.9737919495720608, 0.9002221410882071, 0.9841024606471761, 0.9377528041124721, 0.9651550857286382, 0.9638501535732479, 0.9623855824803988, 0.9457814679308386, 0.9104620519869895, 0.9571447384433396, 0.9682329560093751, 0.9720144384849656, 0.9732432305802801, 0.9418514553832198, 0.9106250339693746, 0.9301935606732554, 0.9160669325979663, 0.9425713711903343, 0.9050762826576827, 0.9892886002608716, 0.9621995830981146], [0.9601160937637852, 0.9360898419640802, 0.9518628783973647, 0.941161618388269, 0.9067618278757839, 0.95464 ...
# Feasible construction solution
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  0 . Cost:  2029.4411376419162
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  1 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  2 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  3 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  4 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  5 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  6 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  7 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  8 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  9 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  10 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  11 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  12 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  13 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  14 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  15 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  16 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  17 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  18 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  19 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  20 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  21 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  22 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  23 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  24 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  25 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  26 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  27 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  28 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  29 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  30 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  31 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  32 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  33 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  34 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  35 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  36 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  37 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  38 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  39 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  40 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  41 . Cost:  1577.3008282344167
# Iteration #  42  out of  500  ( 8.0 %)
# Elapsed time:  88.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  42 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  43 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  44 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  45 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  46 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  47 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  48 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  49 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  50 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  51 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  52 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  53 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  54 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  55 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  56 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  57 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  58 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  59 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  60 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  61 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  62 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  63 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  64 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  65 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  66 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  67 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  68 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  69 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  70 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  71 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  72 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  73 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  74 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  75 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  76 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  77 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  78 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  79 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  80 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  81 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  82 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  83 . Cost:  1495.792928862868
# Iteration #  84  out of  500  ( 17.0 %)
# Elapsed time:  161.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  84 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  85 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  86 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  87 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  88 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  89 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  90 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  91 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  92 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  93 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  94 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  95 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  96 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  97 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  98 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  99 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  100 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  101 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  102 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  103 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  104 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  105 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  106 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  107 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  108 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  109 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  110 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  111 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  112 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  113 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  114 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  115 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  116 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  117 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  118 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  119 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  120 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  121 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  122 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  123 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  124 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  125 . Cost:  1411.2621207214222
# Iteration #  126  out of  500  ( 25.0 %)
# Elapsed time:  233.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  126 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  127 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  128 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  129 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  130 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  131 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  132 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  133 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  134 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  135 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  136 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  137 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  138 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  139 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  140 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  141 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  142 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  143 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  144 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  145 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  146 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  147 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  148 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  149 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  150 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  151 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  152 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  153 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  154 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  155 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  156 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  157 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  158 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  159 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  160 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  161 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  162 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  163 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  164 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  165 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  166 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  167 . Cost:  1641.9997780225265
# Iteration #  168  out of  500  ( 34.0 %)
# Elapsed time:  308.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  168 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  169 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  170 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  171 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  172 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  173 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  174 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  175 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  176 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  177 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  178 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  179 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  180 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  181 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  182 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  183 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  184 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  185 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  186 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  187 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  188 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  189 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  190 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  191 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  192 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  193 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  194 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  195 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  196 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  197 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  198 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  199 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  200 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  201 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  202 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  203 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  204 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  205 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  206 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  207 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  208 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  209 . Cost:  1495.792928862868
# Iteration #  210  out of  500  ( 42.0 %)
# Elapsed time:  387.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  210 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  211 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  212 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  213 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  214 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  215 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  216 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  217 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  218 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  219 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  220 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  221 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  222 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  223 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  224 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  225 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  226 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  227 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  228 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  229 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  230 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  231 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  232 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  233 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  234 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  235 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  236 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  237 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  238 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  239 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  240 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  241 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  242 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  243 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  244 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  245 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  246 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  247 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  248 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  249 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  250 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  251 . Cost:  1616.2055191741592
# Iteration #  252  out of  500  ( 50.0 %)
# Elapsed time:  450.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  252 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  253 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  254 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  255 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  256 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  257 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  258 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  259 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  260 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  261 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  262 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  263 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  264 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  265 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  266 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  267 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  268 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  269 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  270 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  271 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  272 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  273 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  274 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  275 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  276 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  277 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  278 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  279 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  280 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  281 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  282 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  283 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  284 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  285 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  286 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  287 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  288 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  289 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  290 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  291 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  292 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  293 . Cost:  1641.9997780225265
# Iteration #  294  out of  500  ( 59.0 %)
# Elapsed time:  543.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  294 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  295 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  296 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  297 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  298 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  299 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  300 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  301 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  302 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  303 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  304 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  305 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  306 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  307 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  308 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  309 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  310 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  311 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  312 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  313 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  314 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  315 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  316 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  317 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  318 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  319 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  320 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  321 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  322 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  323 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  324 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  325 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  326 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  327 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  328 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  329 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  330 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  331 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  332 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  333 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  334 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  335 . Cost:  1618.328362403674
# Iteration #  336  out of  500  ( 67.0 %)
# Elapsed time:  639.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  336 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  337 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  338 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  339 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  340 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  341 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  342 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  343 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  344 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  345 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  346 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  347 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  348 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  349 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  350 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  351 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  352 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  353 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  354 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  355 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  356 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  357 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  358 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  359 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  360 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  361 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  362 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  363 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  364 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  365 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  366 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  367 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  368 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  369 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  370 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  371 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  372 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  373 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  374 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  375 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  376 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  377 . Cost:  1531.9666910602145
# Iteration #  378  out of  500  ( 76.0 %)
# Elapsed time:  734.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  378 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  379 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  380 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  381 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  382 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  383 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  384 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  385 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  386 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  387 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  388 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  389 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  390 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  391 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  392 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  393 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  394 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  395 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  396 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  397 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  398 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  399 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  400 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  401 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  402 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  403 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  404 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  405 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  406 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  407 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  408 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  409 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  410 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  411 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  412 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  413 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  414 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  415 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  416 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  417 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  418 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  419 . Cost:  1495.792928862868
# Iteration #  420  out of  500  ( 84.0 %)
# Elapsed time:  820.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  420 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  421 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  422 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  423 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  424 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  425 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  426 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  427 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  428 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  429 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  430 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  431 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  432 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  433 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  434 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  435 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  436 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  437 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  438 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  439 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  440 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  441 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  442 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  443 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  444 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  445 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  446 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  447 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  448 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  449 . Cost:  1506.6799080126375
# Early termination due to stagnation.
#
# Number of clients with split deliveries: NA
# Number of clients without split deliveries: NA
# Total number of clients: NA
# Improvement Time: 1e+20
# Finish Time:  868.8080816268921
# Stag Level:  Yes
# 1e+20
# 868.8080816268921
# Diff_Cost%:  NA
# Pot_Improv%:  NA
# Solution status:  We did not find a feasible solution

# %% [markdown]
# ('Combination', 45, 0.8, 0.5, 'demand', 'yes', 0)

# %%
# Setting Parameters
# Optimal Value from Data Source
# Number of Iterations
it = 500# 50000 #1000
# Solution with split deliveries
#split_sol = 'No'
split_sol = 'Yes'
# Stagmation parameter
#stg = round(it*0.9,0)
stg = round(it*0.9,0)
if optimal_value == None:
    known = 1e-10
    #known = 18.67292881108081
else:
    known = optimal_value
# Split information from Data Source
if split_sol == 'Yes':
    optm = 'split'
else: 
    optm = 'no_split'
# Logic to reintegrate initial solution by nearest neighbour
if optm == 'no_split':
    reit = 1
else:
    reit = round(stg*0.8,0)
sps = split_sol
pl = 0 # known*.15
#pl = known*.15 


# Increment Threshold
ith = 10 #10 #1000
# Optimization Solution Finder ("tier", "random", "mixed", "cost", "inter_route", "min_demand_route")
#osf = "tier" #"random" "mixed"
#osf = 'mixed'

#osf = "random"
#osf = 'cost'
#osf = 'inter_route'
osf = 'min_demand_route'
# Alpha factor for restricted candidate list
rcl = 0.8#0.5 #0.8 #0.8
# rcl = 0.8
# Perturbation percentage
prt = 0.5#0.5 #0.6
# prt = 0.8
# Initial seed (does not apply anymore)
sed = 1
# Interdiction prob (manual or generated--> "None" clause)
iprob = None
iprob = iprob1
# Min no interdiction matrix
min_nint = 1#0.92#1#0.95#0.97 # 0.88 #0.98 #0.95
# Max no interdiction matrix
max_nint = 1#0.92#1 #0.999#0.95#0.97 #0.88 #0.99 #0.99

# Threshold when reaching optimal solution
thres = 0.00001

# Percentage over iterations for no improvement
pert_ct = 0.1
# Local search method ('2-opt', '3-opt', 'segment-reversal', 'random') all include swap-local-search method
#lso = '2-opt'
lso = 'random'
#lso = '3-opt'
#lso = 'segment-reversal'


vrp = VRP(num_vehicles=num_vehicles, num_customers=num_customers, locations=locations, demands=demands, vehicle_capacity=vehicle_capacity, rcl_factor=rcl, iterations=it, local_search_option= lso, stagnation_limit=stg, perturb_percentage=prt,split_penalty= pl, sdd = sed, reintegrate_it=reit, split_sol= sps, min_prob_matrix= min_nint, max_prob_matrix= max_nint, int_prob = iprob, threshold_increment = ith, optimization_solution_finder = osf)
cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = vrp.run()
print('Improvement Time:', improvement_time)
print('Finish Time: ',finish_time)
print('Stag Level: ',sl)
if improvement_time == 1e20:
    diff = "NA"
else:
    diff = str(round(abs((cost/known-1)),2)*100)+'%'
print(improvement_time)
print(finish_time)
if improvement_time == 0  and finish_time == 0:
    pot_impr = str(round((1e10/1e10),2)*100)+'%'   
elif improvement_time == 1e20:
    pot_impr = "NA" 
else:
    pot_impr = str(round((improvement_time/finish_time),2)*100)+'%'
print('Diff_Cost%: ', diff)
print('Pot_Improv%: ', pot_impr)
print("Solution status: ", solution)
# Out:
# Interdiction Probabilities:  [[1.0, 0.9245596093729803, 0.9421224384600982, 0.9281118722090896, 0.9785314546199626, 0.9681146119563971, 0.9601160937637852, 0.9533237169739396, 0.9217886249233886, 0.9581044465882134, 0.979547461445175, 0.977610795183075, 0.9287655278343139, 0.9664321341219351, 0.9803119915077759, 0.9150254450732598, 0.9399681303753511, 0.9757712073838597, 0.9400854762150992, 0.9197061325758853, 0.9787867220324488, 0.9824706939723244, 0.9381160389170244, 0.9793807780421058, 0.9396870296398332, 0.9401673455423657, 0.9814081717202838, 0.9859384753311028, 0.9228217605663368, 0.9337380573517048, 0.9425040877090827, 0.9885802991695554, 0.9452970842338354], [0.9245596093729803, 1.0, 0.9584372833650735, 0.9400140257928693, 0.9299771758359122, 0.9503834264900511, 0.9360898419640802, 0.902380724436002, 0.9660201536071671, 0.9662496655196906, 0.9433889946869619, 0.9345649102346636, 0.9054900573854664, 0.9301369700571391, 0.9695802247486901, 0.9491920980923796, 0.9026029356984477, 0.9855610167531275, 0.9837657379612478, 0.9787974378588218, 0.9042129038318869, 0.9618373105127495, 0.9650092876715939, 0.9515427938067134, 0.9563867110770174, 0.96450652517215, 0.9036634121598764, 0.9787540945917699, 0.907602320523581, 0.9144860741778783, 0.9408579252864454, 0.9855491783510815, 0.9181460514286893], [0.9421224384600982, 0.9584372833650735, 1.0, 0.9264242154819252, 0.9580139296416259, 0.9317593300020401, 0.9518628783973647, 0.9652294185686948, 0.9167030164274126, 0.9647191276508389, 0.9175376081630151, 0.974883661565248, 0.9256949496861441, 0.9599987972914634, 0.9715892121351216, 0.968386356253005, 0.9868663544586418, 0.9460634933276089, 0.9743199792907375, 0.9863164233051496, 0.9019984259505591, 0.950131447112789, 0.9781050951939447, 0.9828010029991583, 0.9086708970654739, 0.9409353154246363, 0.976896359376168, 0.9819180749481291, 0.9513635768476433, 0.9830442119535798, 0.9052016442933383, 0.951941607358771, 0.9043880415124165], [0.9281118722090896, 0.9400140257928693, 0.9264242154819252, 1.0, 0.9637009650561799, 0.9642040350679223, 0.941161618388269, 0.948713188278484, 0.9483414751796131, 0.9898380366151047, 0.927608575314421, 0.9400263455966572, 0.9085915661238244, 0.9813375009858203, 0.9670909137919707, 0.9024051578202773, 0.932492970427768, 0.9389266163243966, 0.9886270145290911, 0.9245891444295257, 0.9043267202967349, 0.9400348895753549, 0.9551019867713755, 0.9400859209013559, 0.9535150028150128, 0.9091030499777119, 0.9302167047399111, 0.9424641171489299, 0.9536640206794328, 0.9188374634994273, 0.970668986905339, 0.9257452689396135, 0.9054353322769534], [0.9785314546199626, 0.9299771758359122, 0.9580139296416259, 0.9637009650561799, 1.0, 0.9640058244061457, 0.9067618278757839, 0.9875464909575913, 0.9359691246305523, 0.963837668746052, 0.9402148687656655, 0.9633637906919923, 0.9014991264393288, 0.9086345998852112, 0.9206772206227004, 0.9755895155614436, 0.9548117979067705, 0.9687064650055403, 0.9842289438769072, 0.9829419864317631, 0.9105843115320451, 0.9781185701506474, 0.9152279303335538, 0.9043520651761386, 0.9655268240126205, 0.9011592745534275, 0.9265703439311508, 0.9553306163153681, 0.9118625438996031, 0.9677891452640103, 0.955982847837417, 0.9827191225313494, 0.9266229054869907], [0.9681146119563971, 0.9503834264900511, 0.9317593300020401, 0.9642040350679223, 0.9640058244061457, 1.0, 0.954641724810021, 0.9715092480110084, 0.9073455543646098, 0.9423115480181214, 0.9513947898178092, 0.9244143004787043, 0.9737919495720608, 0.9002221410882071, 0.9841024606471761, 0.9377528041124721, 0.9651550857286382, 0.9638501535732479, 0.9623855824803988, 0.9457814679308386, 0.9104620519869895, 0.9571447384433396, 0.9682329560093751, 0.9720144384849656, 0.9732432305802801, 0.9418514553832198, 0.9106250339693746, 0.9301935606732554, 0.9160669325979663, 0.9425713711903343, 0.9050762826576827, 0.9892886002608716, 0.9621995830981146], [0.9601160937637852, 0.9360898419640802, 0.9518628783973647, 0.941161618388269, 0.9067618278757839, 0.95464 ...
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  0 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  1 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  2 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  3 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  4 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  5 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  6 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  7 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  8 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  9 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  10 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  11 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  12 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  13 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  14 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  15 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  16 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  17 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  18 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  19 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  20 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  21 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  22 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  23 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  24 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  25 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  26 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  27 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  28 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  29 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  30 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  31 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  32 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  33 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  34 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  35 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  36 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  37 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  38 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  39 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  40 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  41 . Cost:  1715.2499037176106
# Iteration #  42  out of  500  ( 8.0 %)
# Elapsed time:  191.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  42 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  43 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  44 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  45 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  46 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  47 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  48 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  49 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  50 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  51 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  52 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  53 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  54 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  55 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  56 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  57 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  58 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  59 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  60 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  61 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  62 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  63 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  64 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  65 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  66 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  67 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  68 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  69 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  70 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  71 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  72 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  73 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  74 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  75 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  76 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  77 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  78 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  79 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  80 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  81 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  82 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  83 . Cost:  1715.2499037176106
# Iteration #  84  out of  500  ( 17.0 %)
# Elapsed time:  391.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  84 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  85 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  86 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  87 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  88 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  89 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  90 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  91 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  92 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  93 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  94 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  95 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  96 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  97 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  98 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  99 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  100 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  101 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  102 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  103 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  104 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  105 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  106 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  107 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  108 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  109 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  110 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  111 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  112 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  113 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  114 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  115 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  116 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  117 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  118 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  119 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  120 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  121 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  122 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  123 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  124 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  125 . Cost:  1715.2499037176106
# Iteration #  126  out of  500  ( 25.0 %)
# Elapsed time:  611.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  126 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  127 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  128 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  129 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  130 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  131 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  132 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  133 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  134 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  135 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  136 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  137 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  138 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  139 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  140 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  141 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  142 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  143 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  144 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  145 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  146 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  147 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  148 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  149 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  150 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  151 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  152 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  153 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  154 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  155 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  156 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  157 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  158 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  159 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  160 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  161 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  162 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  163 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  164 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  165 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  166 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  167 . Cost:  1715.2499037176106
# Iteration #  168  out of  500  ( 34.0 %)
# Elapsed time:  808.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  168 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  169 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  170 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  171 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  172 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  173 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  174 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  175 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  176 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  177 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  178 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  179 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  180 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  181 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  182 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  183 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  184 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  185 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  186 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  187 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  188 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  189 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  190 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  191 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  192 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  193 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  194 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  195 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  196 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  197 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  198 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  199 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  200 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  201 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  202 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  203 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  204 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  205 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  206 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  207 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  208 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  209 . Cost:  1715.2499037176106
# Iteration #  210  out of  500  ( 42.0 %)
# Elapsed time:  1063.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  210 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  211 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  212 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  213 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  214 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  215 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  216 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  217 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  218 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  219 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  220 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  221 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  222 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  223 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  224 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  225 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  226 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  227 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  228 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  229 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  230 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  231 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  232 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  233 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  234 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  235 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  236 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  237 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  238 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  239 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  240 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  241 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  242 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  243 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  244 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  245 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  246 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  247 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  248 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  249 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  250 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  251 . Cost:  1715.2499037176106
# Iteration #  252  out of  500  ( 50.0 %)
# Elapsed time:  1265.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  252 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  253 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  254 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  255 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  256 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  257 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  258 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  259 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  260 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  261 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  262 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  263 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  264 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  265 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  266 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  267 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  268 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  269 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  270 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  271 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  272 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  273 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  274 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  275 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  276 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  277 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  278 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  279 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  280 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  281 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  282 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  283 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  284 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  285 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  286 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  287 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  288 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  289 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  290 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  291 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  292 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  293 . Cost:  1715.2499037176106
# Iteration #  294  out of  500  ( 59.0 %)
# Elapsed time:  1468.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  294 . Cost:  
#    Customer 4: 1331.7261319536954
#    Customer 19: 225.80615986437385
#    Customer 24: 880.7274112345403
# Route 3 Total Demand Serviced: 7956.902799616802
#    Customer 26: 2853.043290939748
#    Customer 30: 2629.833712813258
#    Customer 23: 747.8916672150352
#    Customer 2: 434.84557471537926
#    Customer 29: 497.6391352558029
#    Customer 16: 793.6494186775777
# Route 4 Total Demand Serviced: 7975.264286679281
#    Customer 14: 1632.1334573691263
#    Customer 20: 413.07592730040676
#    Customer 22: 1364.0830865859805
#    Customer 21: 317.99782408360073
#    Customer 8: 986.5214117359428
#    Customer 10: 838.9359286602826
#    Customer 11: 1711.7629217040837
#    Customer 13: 233.95180459708408
#    Customer 3: 476.801924642773
#
# Customers with split delivery:
#   Customer 26:
#     Demand serviced by route (0 -> 26 -> 32 -> 9 -> 25 -> 18 -> 1 -> 27 -> 17 -> 13 -> 12 -> 6 -> 5 -> 0): 1222.7328389741779
#     Demand serviced by route (0 -> 26 -> 30 -> 23 -> 2 -> 29 -> 16 -> 0): 2853.043290939748
#   Customer 13:
#     Demand serviced by route (0 -> 26 -> 32 -> 9 -> 25 -> 18 -> 1 -> 27 -> 17 -> 13 -> 12 -> 6 -> 5 -> 0): 59.70918540189803
#     Demand serviced by route (0 -> 14 -> 20 -> 22 -> 21 -> 8 -> 10 -> 11 -> 13 -> 3 -> 0): 233.95180459708408
#   Customer 29:
#     Demand serviced by route (0 -> 31 -> 7 -> 29 -> 28 -> 15 -> 4 -> 19 -> 24 -> 0): 52.23771547408257
#     Demand serviced by route (0 -> 26 -> 30 -> 23 -> 2 -> 29 -> 16 -> 0): 497.6391352558029
#
# Customers not served or partially served:
#
# Number of clients with split deliveries: 3
# Number of clients without split deliveries: 29
# Total number of clients: 32
# Improvement Time: 1120.3882367610931
# Finish Time:  1358.7352657318115
# Stag Level:  No
# 1120.3882367610931
# 1358.7352657318115
# Diff_Cost%:  137.0%
# Pot_Improv%:  82.0%
# Solution status:  We found a feasible solution

# %% [markdown]
# ('Combination', 47, 0.8, 0.5, 'demand', 'no', 0)

# %%
# Setting Parameters
# Optimal Value from Data Source
# Number of Iterations
it = 500# 50000 #1000
# Solution with split deliveries
split_sol = 'No'
#split_sol = 'Yes'
# Stagmation parameter
#stg = round(it*0.9,0)
stg = round(it*0.9,0)
if optimal_value == None:
    known = 1e-10
    #known = 18.67292881108081
else:
    known = optimal_value
# Split information from Data Source
if split_sol == 'Yes':
    optm = 'split'
else: 
    optm = 'no_split'
# Logic to reintegrate initial solution by nearest neighbour
if optm == 'no_split':
    reit = 1
else:
    reit = round(stg*0.8,0)
sps = split_sol
pl = 0 # known*.15
#pl = known*.15 


# Increment Threshold
ith = 10 #10 #1000
# Optimization Solution Finder ("tier", "random", "mixed", "cost", "inter_route", "min_demand_route")
#osf = "tier" #"random" "mixed"
#osf = 'mixed'

#osf = "random"
#osf = 'cost'
#osf = 'inter_route'
osf = 'min_demand_route'
# Alpha factor for restricted candidate list
rcl = 0.8#0.5 #0.8 #0.8
# rcl = 0.8
# Perturbation percentage
prt = 0.5#0.5 #0.6
# prt = 0.8
# Initial seed (does not apply anymore)
sed = 1
# Interdiction prob (manual or generated--> "None" clause)
iprob = None
iprob = iprob1
# Min no interdiction matrix
min_nint = 1#0.92#1#0.95#0.97 # 0.88 #0.98 #0.95
# Max no interdiction matrix
max_nint = 1#0.92#1 #0.999#0.95#0.97 #0.88 #0.99 #0.99

# Threshold when reaching optimal solution
thres = 0.00001

# Percentage over iterations for no improvement
pert_ct = 0.1
# Local search method ('2-opt', '3-opt', 'segment-reversal', 'random') all include swap-local-search method
#lso = '2-opt'
lso = 'random'
#lso = '3-opt'
#lso = 'segment-reversal'


vrp = VRP(num_vehicles=num_vehicles, num_customers=num_customers, locations=locations, demands=demands, vehicle_capacity=vehicle_capacity, rcl_factor=rcl, iterations=it, local_search_option= lso, stagnation_limit=stg, perturb_percentage=prt,split_penalty= pl, sdd = sed, reintegrate_it=reit, split_sol= sps, min_prob_matrix= min_nint, max_prob_matrix= max_nint, int_prob = iprob, threshold_increment = ith, optimization_solution_finder = osf)
cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = vrp.run()
print('Improvement Time:', improvement_time)
print('Finish Time: ',finish_time)
print('Stag Level: ',sl)
if improvement_time == 1e20:
    diff = "NA"
else:
    diff = str(round(abs((cost/known-1)),2)*100)+'%'
print(improvement_time)
print(finish_time)
if improvement_time == 0  and finish_time == 0:
    pot_impr = str(round((1e10/1e10),2)*100)+'%'   
elif improvement_time == 1e20:
    pot_impr = "NA" 
else:
    pot_impr = str(round((improvement_time/finish_time),2)*100)+'%'
print('Diff_Cost%: ', diff)
print('Pot_Improv%: ', pot_impr)
print("Solution status: ", solution)
# Out:
# Interdiction Probabilities:  [[1.0, 0.9245596093729803, 0.9421224384600982, 0.9281118722090896, 0.9785314546199626, 0.9681146119563971, 0.9601160937637852, 0.9533237169739396, 0.9217886249233886, 0.9581044465882134, 0.979547461445175, 0.977610795183075, 0.9287655278343139, 0.9664321341219351, 0.9803119915077759, 0.9150254450732598, 0.9399681303753511, 0.9757712073838597, 0.9400854762150992, 0.9197061325758853, 0.9787867220324488, 0.9824706939723244, 0.9381160389170244, 0.9793807780421058, 0.9396870296398332, 0.9401673455423657, 0.9814081717202838, 0.9859384753311028, 0.9228217605663368, 0.9337380573517048, 0.9425040877090827, 0.9885802991695554, 0.9452970842338354], [0.9245596093729803, 1.0, 0.9584372833650735, 0.9400140257928693, 0.9299771758359122, 0.9503834264900511, 0.9360898419640802, 0.902380724436002, 0.9660201536071671, 0.9662496655196906, 0.9433889946869619, 0.9345649102346636, 0.9054900573854664, 0.9301369700571391, 0.9695802247486901, 0.9491920980923796, 0.9026029356984477, 0.9855610167531275, 0.9837657379612478, 0.9787974378588218, 0.9042129038318869, 0.9618373105127495, 0.9650092876715939, 0.9515427938067134, 0.9563867110770174, 0.96450652517215, 0.9036634121598764, 0.9787540945917699, 0.907602320523581, 0.9144860741778783, 0.9408579252864454, 0.9855491783510815, 0.9181460514286893], [0.9421224384600982, 0.9584372833650735, 1.0, 0.9264242154819252, 0.9580139296416259, 0.9317593300020401, 0.9518628783973647, 0.9652294185686948, 0.9167030164274126, 0.9647191276508389, 0.9175376081630151, 0.974883661565248, 0.9256949496861441, 0.9599987972914634, 0.9715892121351216, 0.968386356253005, 0.9868663544586418, 0.9460634933276089, 0.9743199792907375, 0.9863164233051496, 0.9019984259505591, 0.950131447112789, 0.9781050951939447, 0.9828010029991583, 0.9086708970654739, 0.9409353154246363, 0.976896359376168, 0.9819180749481291, 0.9513635768476433, 0.9830442119535798, 0.9052016442933383, 0.951941607358771, 0.9043880415124165], [0.9281118722090896, 0.9400140257928693, 0.9264242154819252, 1.0, 0.9637009650561799, 0.9642040350679223, 0.941161618388269, 0.948713188278484, 0.9483414751796131, 0.9898380366151047, 0.927608575314421, 0.9400263455966572, 0.9085915661238244, 0.9813375009858203, 0.9670909137919707, 0.9024051578202773, 0.932492970427768, 0.9389266163243966, 0.9886270145290911, 0.9245891444295257, 0.9043267202967349, 0.9400348895753549, 0.9551019867713755, 0.9400859209013559, 0.9535150028150128, 0.9091030499777119, 0.9302167047399111, 0.9424641171489299, 0.9536640206794328, 0.9188374634994273, 0.970668986905339, 0.9257452689396135, 0.9054353322769534], [0.9785314546199626, 0.9299771758359122, 0.9580139296416259, 0.9637009650561799, 1.0, 0.9640058244061457, 0.9067618278757839, 0.9875464909575913, 0.9359691246305523, 0.963837668746052, 0.9402148687656655, 0.9633637906919923, 0.9014991264393288, 0.9086345998852112, 0.9206772206227004, 0.9755895155614436, 0.9548117979067705, 0.9687064650055403, 0.9842289438769072, 0.9829419864317631, 0.9105843115320451, 0.9781185701506474, 0.9152279303335538, 0.9043520651761386, 0.9655268240126205, 0.9011592745534275, 0.9265703439311508, 0.9553306163153681, 0.9118625438996031, 0.9677891452640103, 0.955982847837417, 0.9827191225313494, 0.9266229054869907], [0.9681146119563971, 0.9503834264900511, 0.9317593300020401, 0.9642040350679223, 0.9640058244061457, 1.0, 0.954641724810021, 0.9715092480110084, 0.9073455543646098, 0.9423115480181214, 0.9513947898178092, 0.9244143004787043, 0.9737919495720608, 0.9002221410882071, 0.9841024606471761, 0.9377528041124721, 0.9651550857286382, 0.9638501535732479, 0.9623855824803988, 0.9457814679308386, 0.9104620519869895, 0.9571447384433396, 0.9682329560093751, 0.9720144384849656, 0.9732432305802801, 0.9418514553832198, 0.9106250339693746, 0.9301935606732554, 0.9160669325979663, 0.9425713711903343, 0.9050762826576827, 0.9892886002608716, 0.9621995830981146], [0.9601160937637852, 0.9360898419640802, 0.9518628783973647, 0.941161618388269, 0.9067618278757839, 0.95464 ...
# Feasible construction solution
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  0 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  1 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  2 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  3 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  4 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  5 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  6 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  7 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  8 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  9 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  10 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  11 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  12 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  13 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  14 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  15 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  16 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  17 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  18 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  19 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  20 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  21 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  22 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  23 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  24 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  25 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  26 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  27 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  28 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  29 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  30 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  31 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  32 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  33 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  34 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  35 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  36 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  37 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  38 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  39 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  40 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  41 . Cost:  1577.3008282344167
# Iteration #  42  out of  500  ( 8.0 %)
# Elapsed time:  45.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  42 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  43 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  44 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  45 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  46 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  47 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  48 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  49 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  50 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  51 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  52 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  53 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  54 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  55 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  56 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  57 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  58 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  59 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  60 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  61 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  62 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  63 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  64 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  65 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  66 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  67 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  68 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  69 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  70 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  71 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  72 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  73 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  74 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  75 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  76 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  77 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  78 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  79 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  80 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  81 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  82 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  83 . Cost:  1493.0699837423356
# Iteration #  84  out of  500  ( 17.0 %)
# Elapsed time:  90.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  84 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  85 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  86 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  87 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  88 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  89 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  90 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  91 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  92 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  93 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  94 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  95 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  96 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  97 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  98 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  99 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  100 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  101 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  102 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  103 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  104 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  105 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  106 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  107 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  108 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  109 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  110 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  111 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  112 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  113 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  114 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  115 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  116 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  117 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  118 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  119 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  120 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  121 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  122 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  123 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  124 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  125 . Cost:  1434.6859558390956
# Iteration #  126  out of  500  ( 25.0 %)
# Elapsed time:  138.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  126 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  127 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  128 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  129 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  130 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  131 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  132 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  133 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  134 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  135 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  136 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  137 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  138 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  139 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  140 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  141 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  142 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  143 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  144 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  145 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  146 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  147 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  148 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  149 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  150 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  151 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  152 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  153 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  154 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  155 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  156 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  157 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  158 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  159 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  160 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  161 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  162 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  163 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  164 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  165 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  166 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  167 . Cost:  1520.0285987153627
# Iteration #  168  out of  500  ( 34.0 %)
# Elapsed time:  185.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  168 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  169 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  170 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  171 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  172 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  173 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  174 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  175 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  176 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  177 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  178 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  179 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  180 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  181 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  182 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  183 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  184 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  185 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  186 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  187 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  188 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  189 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  190 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  191 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  192 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  193 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  194 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  195 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  196 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  197 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  198 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  199 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  200 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  201 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  202 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  203 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  204 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  205 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  206 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  207 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  208 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  209 . Cost:  1616.2055191741592
# Iteration #  210  out of  500  ( 42.0 %)
# Elapsed time:  231.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  210 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  211 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  212 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  213 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  214 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  215 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  216 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  217 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  218 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  219 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  220 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  221 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  222 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  223 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  224 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  225 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  226 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  227 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  228 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  229 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  230 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  231 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  232 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  233 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  234 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  235 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  236 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  237 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  238 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  239 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  240 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  241 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  242 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  243 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  244 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  245 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  246 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  247 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  248 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  249 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  250 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  251 . Cost:  1616.2055191741592
# Iteration #  252  out of  500  ( 50.0 %)
# Elapsed time:  281.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  252 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  253 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  254 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  255 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  256 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  257 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  258 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  259 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  260 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  261 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  262 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  263 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  264 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  265 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  266 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  267 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  268 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  269 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  270 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  271 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  272 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  273 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  274 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  275 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  276 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  277 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  278 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  279 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  280 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  281 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  282 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  283 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  284 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  285 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  286 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  287 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  288 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  289 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  290 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  291 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  292 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  293 . Cost:  1495.792928862868
# Iteration #  294  out of  500  ( 59.0 %)
# Elapsed time:  316.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  294 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  295 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  296 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  297 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  298 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  299 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  300 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  301 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  302 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  303 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  304 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  305 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  306 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  307 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  308 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  309 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  310 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  311 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  312 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  313 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  314 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  315 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  316 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  317 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  318 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  319 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  320 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  321 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  322 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  323 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  324 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  325 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  326 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  327 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  328 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  329 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  330 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  331 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  332 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  333 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  334 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  335 . Cost:  1535.0947177268795
# Iteration #  336  out of  500  ( 67.0 %)
# Elapsed time:  349.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  336 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  337 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  338 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  339 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  340 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  341 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  342 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  343 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  344 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  345 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  346 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  347 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  348 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  349 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  350 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  351 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  352 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  353 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  354 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  355 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  356 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  357 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  358 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  359 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  360 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  361 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  362 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  363 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  364 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  365 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  366 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  367 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  368 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  369 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  370 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  371 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  372 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  373 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  374 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  375 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  376 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  377 . Cost:  1616.2055191741592
# Iteration #  378  out of  500  ( 76.0 %)
# Elapsed time:  380.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  378 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  379 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  380 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  381 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  382 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  383 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  384 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  385 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  386 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  387 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  388 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  389 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  390 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  391 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  392 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  393 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  394 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  395 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  396 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  397 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  398 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  399 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  400 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  401 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  402 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  403 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  404 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  405 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  406 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  407 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  408 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  409 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  410 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  411 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  412 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  413 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  414 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  415 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  416 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  417 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  418 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  419 . Cost:  1495.792928862868
# Iteration #  420  out of  500  ( 84.0 %)
# Elapsed time:  422.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  420 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  421 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  422 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  423 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  424 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  425 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  426 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  427 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  428 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  429 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  430 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  431 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  432 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  433 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  434 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  435 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  436 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  437 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  438 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  439 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  440 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  441 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  442 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  443 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  444 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  445 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  446 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  447 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  448 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  449 . Cost:  1641.9997780225265
# Early termination due to stagnation.
#
# Number of clients with split deliveries: NA
# Number of clients without split deliveries: NA
# Total number of clients: NA
# Improvement Time: 1e+20
# Finish Time:  460.82119965553284
# Stag Level:  Yes
# 1e+20
# 460.82119965553284
# Diff_Cost%:  NA
# Pot_Improv%:  NA
# Solution status:  We did not find a feasible solution

# %% [markdown]
# ('Combination', 48, 0.8, 0.5, 'demand', 'no', 50)

# %%
# Setting Parameters
# Optimal Value from Data Source
# Number of Iterations
it = 500# 50000 #1000
# Solution with split deliveries
split_sol = 'No'
#split_sol = 'Yes'
# Stagmation parameter
#stg = round(it*0.9,0)
stg = round(it*0.9,0)
if optimal_value == None:
    known = 1e-10
    #known = 18.67292881108081
else:
    known = optimal_value
# Split information from Data Source
if split_sol == 'Yes':
    optm = 'split'
else: 
    optm = 'no_split'
# Logic to reintegrate initial solution by nearest neighbour
if optm == 'no_split':
    reit = 1
else:
    reit = round(stg*0.8,0)
sps = split_sol
#pl = 0 # known*.15
pl = known*.15 


# Increment Threshold
ith = 10 #10 #1000
# Optimization Solution Finder ("tier", "random", "mixed", "cost", "inter_route", "min_demand_route")
#osf = "tier" #"random" "mixed"
#osf = 'mixed'

#osf = "random"
#osf = 'cost'
#osf = 'inter_route'
osf = 'min_demand_route'
# Alpha factor for restricted candidate list
rcl = 0.8#0.5 #0.8 #0.8
# rcl = 0.8
# Perturbation percentage
prt = 0.5#0.5 #0.6
# prt = 0.8
# Initial seed (does not apply anymore)
sed = 1
# Interdiction prob (manual or generated--> "None" clause)
iprob = None
iprob = iprob1
# Min no interdiction matrix
min_nint = 1#0.92#1#0.95#0.97 # 0.88 #0.98 #0.95
# Max no interdiction matrix
max_nint = 1#0.92#1 #0.999#0.95#0.97 #0.88 #0.99 #0.99

# Threshold when reaching optimal solution
thres = 0.00001

# Percentage over iterations for no improvement
pert_ct = 0.1
# Local search method ('2-opt', '3-opt', 'segment-reversal', 'random') all include swap-local-search method
#lso = '2-opt'
lso = 'random'
#lso = '3-opt'
#lso = 'segment-reversal'


vrp = VRP(num_vehicles=num_vehicles, num_customers=num_customers, locations=locations, demands=demands, vehicle_capacity=vehicle_capacity, rcl_factor=rcl, iterations=it, local_search_option= lso, stagnation_limit=stg, perturb_percentage=prt,split_penalty= pl, sdd = sed, reintegrate_it=reit, split_sol= sps, min_prob_matrix= min_nint, max_prob_matrix= max_nint, int_prob = iprob, threshold_increment = ith, optimization_solution_finder = osf)
cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = vrp.run()
print('Improvement Time:', improvement_time)
print('Finish Time: ',finish_time)
print('Stag Level: ',sl)
if improvement_time == 1e20:
    diff = "NA"
else:
    diff = str(round(abs((cost/known-1)),2)*100)+'%'
print(improvement_time)
print(finish_time)
if improvement_time == 0  and finish_time == 0:
    pot_impr = str(round((1e10/1e10),2)*100)+'%'   
elif improvement_time == 1e20:
    pot_impr = "NA" 
else:
    pot_impr = str(round((improvement_time/finish_time),2)*100)+'%'
print('Diff_Cost%: ', diff)
print('Pot_Improv%: ', pot_impr)
print("Solution status: ", solution)
# Out:
# Interdiction Probabilities:  [[1.0, 0.9245596093729803, 0.9421224384600982, 0.9281118722090896, 0.9785314546199626, 0.9681146119563971, 0.9601160937637852, 0.9533237169739396, 0.9217886249233886, 0.9581044465882134, 0.979547461445175, 0.977610795183075, 0.9287655278343139, 0.9664321341219351, 0.9803119915077759, 0.9150254450732598, 0.9399681303753511, 0.9757712073838597, 0.9400854762150992, 0.9197061325758853, 0.9787867220324488, 0.9824706939723244, 0.9381160389170244, 0.9793807780421058, 0.9396870296398332, 0.9401673455423657, 0.9814081717202838, 0.9859384753311028, 0.9228217605663368, 0.9337380573517048, 0.9425040877090827, 0.9885802991695554, 0.9452970842338354], [0.9245596093729803, 1.0, 0.9584372833650735, 0.9400140257928693, 0.9299771758359122, 0.9503834264900511, 0.9360898419640802, 0.902380724436002, 0.9660201536071671, 0.9662496655196906, 0.9433889946869619, 0.9345649102346636, 0.9054900573854664, 0.9301369700571391, 0.9695802247486901, 0.9491920980923796, 0.9026029356984477, 0.9855610167531275, 0.9837657379612478, 0.9787974378588218, 0.9042129038318869, 0.9618373105127495, 0.9650092876715939, 0.9515427938067134, 0.9563867110770174, 0.96450652517215, 0.9036634121598764, 0.9787540945917699, 0.907602320523581, 0.9144860741778783, 0.9408579252864454, 0.9855491783510815, 0.9181460514286893], [0.9421224384600982, 0.9584372833650735, 1.0, 0.9264242154819252, 0.9580139296416259, 0.9317593300020401, 0.9518628783973647, 0.9652294185686948, 0.9167030164274126, 0.9647191276508389, 0.9175376081630151, 0.974883661565248, 0.9256949496861441, 0.9599987972914634, 0.9715892121351216, 0.968386356253005, 0.9868663544586418, 0.9460634933276089, 0.9743199792907375, 0.9863164233051496, 0.9019984259505591, 0.950131447112789, 0.9781050951939447, 0.9828010029991583, 0.9086708970654739, 0.9409353154246363, 0.976896359376168, 0.9819180749481291, 0.9513635768476433, 0.9830442119535798, 0.9052016442933383, 0.951941607358771, 0.9043880415124165], [0.9281118722090896, 0.9400140257928693, 0.9264242154819252, 1.0, 0.9637009650561799, 0.9642040350679223, 0.941161618388269, 0.948713188278484, 0.9483414751796131, 0.9898380366151047, 0.927608575314421, 0.9400263455966572, 0.9085915661238244, 0.9813375009858203, 0.9670909137919707, 0.9024051578202773, 0.932492970427768, 0.9389266163243966, 0.9886270145290911, 0.9245891444295257, 0.9043267202967349, 0.9400348895753549, 0.9551019867713755, 0.9400859209013559, 0.9535150028150128, 0.9091030499777119, 0.9302167047399111, 0.9424641171489299, 0.9536640206794328, 0.9188374634994273, 0.970668986905339, 0.9257452689396135, 0.9054353322769534], [0.9785314546199626, 0.9299771758359122, 0.9580139296416259, 0.9637009650561799, 1.0, 0.9640058244061457, 0.9067618278757839, 0.9875464909575913, 0.9359691246305523, 0.963837668746052, 0.9402148687656655, 0.9633637906919923, 0.9014991264393288, 0.9086345998852112, 0.9206772206227004, 0.9755895155614436, 0.9548117979067705, 0.9687064650055403, 0.9842289438769072, 0.9829419864317631, 0.9105843115320451, 0.9781185701506474, 0.9152279303335538, 0.9043520651761386, 0.9655268240126205, 0.9011592745534275, 0.9265703439311508, 0.9553306163153681, 0.9118625438996031, 0.9677891452640103, 0.955982847837417, 0.9827191225313494, 0.9266229054869907], [0.9681146119563971, 0.9503834264900511, 0.9317593300020401, 0.9642040350679223, 0.9640058244061457, 1.0, 0.954641724810021, 0.9715092480110084, 0.9073455543646098, 0.9423115480181214, 0.9513947898178092, 0.9244143004787043, 0.9737919495720608, 0.9002221410882071, 0.9841024606471761, 0.9377528041124721, 0.9651550857286382, 0.9638501535732479, 0.9623855824803988, 0.9457814679308386, 0.9104620519869895, 0.9571447384433396, 0.9682329560093751, 0.9720144384849656, 0.9732432305802801, 0.9418514553832198, 0.9106250339693746, 0.9301935606732554, 0.9160669325979663, 0.9425713711903343, 0.9050762826576827, 0.9892886002608716, 0.9621995830981146], [0.9601160937637852, 0.9360898419640802, 0.9518628783973647, 0.941161618388269, 0.9067618278757839, 0.95464 ...
# Feasible construction solution
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  0 . Cost:  2090.9999037176103
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  1 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  2 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  3 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  4 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  5 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  6 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  7 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  8 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  9 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  10 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  11 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  12 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  13 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  14 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  15 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  16 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  17 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  18 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  19 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  20 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  21 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  22 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  23 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  24 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  25 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  26 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  27 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  28 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  29 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  30 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  31 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  32 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  33 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  34 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  35 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  36 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  37 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  38 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  39 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  40 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  41 . Cost:  1577.3008282344167
# Iteration #  42  out of  500  ( 8.0 %)
# Elapsed time:  48.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  42 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  43 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  44 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  45 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  46 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  47 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  48 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  49 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  50 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  51 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  52 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  53 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  54 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  55 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  56 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  57 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  58 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  59 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  60 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  61 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  62 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  63 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  64 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  65 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  66 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  67 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  68 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  69 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  70 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  71 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  72 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  73 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  74 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  75 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  76 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  77 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  78 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  79 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  80 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  81 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  82 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  83 . Cost:  1493.0699837423356
# Iteration #  84  out of  500  ( 17.0 %)
# Elapsed time:  91.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  84 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  85 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  86 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  87 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  88 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  89 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  90 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  91 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  92 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  93 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  94 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  95 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  96 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  97 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  98 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  99 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  100 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  101 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  102 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  103 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  104 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  105 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  106 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  107 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  108 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  109 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  110 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  111 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  112 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  113 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  114 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  115 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  116 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  117 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  118 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  119 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  120 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  121 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  122 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  123 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  124 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  125 . Cost:  1434.6859558390956
# Iteration #  126  out of  500  ( 25.0 %)
# Elapsed time:  131.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  126 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  127 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  128 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  129 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  130 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  131 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  132 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  133 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  134 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  135 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  136 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  137 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  138 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  139 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  140 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  141 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  142 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  143 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  144 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  145 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  146 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  147 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  148 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  149 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  150 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  151 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  152 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  153 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  154 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  155 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  156 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  157 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  158 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  159 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  160 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  161 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  162 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  163 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  164 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  165 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  166 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  167 . Cost:  1520.0285987153627
# Iteration #  168  out of  500  ( 34.0 %)
# Elapsed time:  187.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  168 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  169 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  170 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  171 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  172 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  173 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  174 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  175 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  176 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  177 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  178 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  179 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  180 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  181 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  182 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  183 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  184 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  185 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  186 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  187 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  188 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  189 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  190 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  191 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  192 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  193 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  194 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  195 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  196 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  197 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  198 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  199 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  200 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  201 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  202 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  203 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  204 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  205 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  206 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  207 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  208 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  209 . Cost:  1616.2055191741592
# Iteration #  210  out of  500  ( 42.0 %)
# Elapsed time:  253.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  210 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  211 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  212 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  213 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  214 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  215 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  216 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  217 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  218 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  219 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  220 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  221 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  222 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  223 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  224 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  225 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  226 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  227 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  228 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  229 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  230 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  231 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  232 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  233 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  234 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  235 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  236 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  237 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  238 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  239 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  240 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  241 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  242 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  243 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  244 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  245 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  246 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  247 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  248 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  249 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  250 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  251 . Cost:  1616.2055191741592
# Iteration #  252  out of  500  ( 50.0 %)
# Elapsed time:  326.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  252 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  253 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  254 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  255 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  256 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  257 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  258 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  259 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  260 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  261 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  262 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  263 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  264 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  265 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  266 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  267 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  268 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  269 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  270 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  271 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  272 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  273 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  274 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  275 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  276 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  277 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  278 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  279 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  280 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  281 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  282 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  283 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  284 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  285 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  286 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  287 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  288 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  289 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  290 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  291 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  292 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  293 . Cost:  1495.792928862868
# Iteration #  294  out of  500  ( 59.0 %)
# Elapsed time:  406.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  294 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  295 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  296 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  297 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  298 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  299 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  300 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  301 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  302 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  303 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  304 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  305 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  306 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  307 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  308 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  309 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  310 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  311 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  312 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  313 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  314 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  315 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  316 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  317 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  318 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  319 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  320 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  321 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  322 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  323 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  324 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  325 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  326 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  327 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  328 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  329 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  330 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  331 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  332 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  333 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  334 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  335 . Cost:  1535.0947177268795
# Iteration #  336  out of  500  ( 67.0 %)
# Elapsed time:  494.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  336 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  337 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  338 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  339 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  340 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  341 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  342 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  343 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  344 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  345 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  346 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  347 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  348 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  349 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  350 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  351 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  352 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  353 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  354 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  355 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  356 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  357 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  358 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  359 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  360 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  361 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  362 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  363 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  364 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  365 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  366 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  367 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  368 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  369 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:
#     Demand serviced by route (0 -> 26 -> 30 -> 23 -> 2 -> 29 -> 16 -> 0): 2853.043290939748
#   Customer 13:
#     Demand serviced by route (0 -> 26 -> 32 -> 9 -> 25 -> 18 -> 1 -> 27 -> 17 -> 13 -> 12 -> 6 -> 5 -> 0): 59.70918540189803
#     Demand serviced by route (0 -> 14 -> 20 -> 22 -> 21 -> 8 -> 10 -> 11 -> 13 -> 3 -> 0): 233.95180459708408
#   Customer 29:
#     Demand serviced by route (0 -> 31 -> 7 -> 29 -> 28 -> 15 -> 4 -> 19 -> 24 -> 0): 52.23771547408257
#     Demand serviced by route (0 -> 26 -> 30 -> 23 -> 2 -> 29 -> 16 -> 0): 497.6391352558029
#
# Customers not served or partially served:
#
# Number of clients with split deliveries: 3
# Number of clients without split deliveries: 29
# Total number of clients: 32
# Improvement Time: 1974.043065071106
# Finish Time:  2285.075987815857
# Stag Level:  No
# 1974.043065071106
# 2285.075987815857
# Diff_Cost%:  137.0%
# Pot_Improv%:  86.0%
# Solution status:  We found a feasible solution

# %% [markdown]
#  ('Combination', 63, 0.8, 0.8, 'demand', 'no', 0)

# %%
# Setting Parameters
# Optimal Value from Data Source
# Number of Iterations
it = 500# 50000 #1000
# Solution with split deliveries
split_sol = 'No'
#split_sol = 'Yes'
# Stagmation parameter
#stg = round(it*0.9,0)
stg = round(it*0.9,0)
if optimal_value == None:
    known = 1e-10
    #known = 18.67292881108081
else:
    known = optimal_value
# Split information from Data Source
if split_sol == 'Yes':
    optm = 'split'
else: 
    optm = 'no_split'
# Logic to reintegrate initial solution by nearest neighbour
if optm == 'no_split':
    reit = 1
else:
    reit = round(stg*0.8,0)
sps = split_sol
pl = 0 # known*.15
#pl = known*.15 


# Increment Threshold
ith = 10 #10 #1000
# Optimization Solution Finder ("tier", "random", "mixed", "cost", "inter_route", "min_demand_route")
#osf = "tier" #"random" "mixed"
#osf = 'mixed'

#osf = "random"
#osf = 'cost'
#osf = 'inter_route'
osf = 'min_demand_route'
# Alpha factor for restricted candidate list
rcl = 0.8#0.5 #0.8 #0.8
# rcl = 0.8
# Perturbation percentage
prt = 0.8#0.5 #0.6
# prt = 0.8
# Initial seed (does not apply anymore)
sed = 1
# Interdiction prob (manual or generated--> "None" clause)
iprob = None
iprob = iprob1
# Min no interdiction matrix
min_nint = 1#0.92#1#0.95#0.97 # 0.88 #0.98 #0.95
# Max no interdiction matrix
max_nint = 1#0.92#1 #0.999#0.95#0.97 #0.88 #0.99 #0.99

# Threshold when reaching optimal solution
thres = 0.00001

# Percentage over iterations for no improvement
pert_ct = 0.1
# Local search method ('2-opt', '3-opt', 'segment-reversal', 'random') all include swap-local-search method
#lso = '2-opt'
lso = 'random'
#lso = '3-opt'
#lso = 'segment-reversal'


vrp = VRP(num_vehicles=num_vehicles, num_customers=num_customers, locations=locations, demands=demands, vehicle_capacity=vehicle_capacity, rcl_factor=rcl, iterations=it, local_search_option= lso, stagnation_limit=stg, perturb_percentage=prt,split_penalty= pl, sdd = sed, reintegrate_it=reit, split_sol= sps, min_prob_matrix= min_nint, max_prob_matrix= max_nint, int_prob = iprob, threshold_increment = ith, optimization_solution_finder = osf)
cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = vrp.run()
print('Improvement Time:', improvement_time)
print('Finish Time: ',finish_time)
print('Stag Level: ',sl)
if improvement_time == 1e20:
    diff = "NA"
else:
    diff = str(round(abs((cost/known-1)),2)*100)+'%'
print(improvement_time)
print(finish_time)
if improvement_time == 0  and finish_time == 0:
    pot_impr = str(round((1e10/1e10),2)*100)+'%'   
elif improvement_time == 1e20:
    pot_impr = "NA" 
else:
    pot_impr = str(round((improvement_time/finish_time),2)*100)+'%'
print('Diff_Cost%: ', diff)
print('Pot_Improv%: ', pot_impr)
print("Solution status: ", solution)
# Out:
# Interdiction Probabilities:  [[1.0, 0.9245596093729803, 0.9421224384600982, 0.9281118722090896, 0.9785314546199626, 0.9681146119563971, 0.9601160937637852, 0.9533237169739396, 0.9217886249233886, 0.9581044465882134, 0.979547461445175, 0.977610795183075, 0.9287655278343139, 0.9664321341219351, 0.9803119915077759, 0.9150254450732598, 0.9399681303753511, 0.9757712073838597, 0.9400854762150992, 0.9197061325758853, 0.9787867220324488, 0.9824706939723244, 0.9381160389170244, 0.9793807780421058, 0.9396870296398332, 0.9401673455423657, 0.9814081717202838, 0.9859384753311028, 0.9228217605663368, 0.9337380573517048, 0.9425040877090827, 0.9885802991695554, 0.9452970842338354], [0.9245596093729803, 1.0, 0.9584372833650735, 0.9400140257928693, 0.9299771758359122, 0.9503834264900511, 0.9360898419640802, 0.902380724436002, 0.9660201536071671, 0.9662496655196906, 0.9433889946869619, 0.9345649102346636, 0.9054900573854664, 0.9301369700571391, 0.9695802247486901, 0.9491920980923796, 0.9026029356984477, 0.9855610167531275, 0.9837657379612478, 0.9787974378588218, 0.9042129038318869, 0.9618373105127495, 0.9650092876715939, 0.9515427938067134, 0.9563867110770174, 0.96450652517215, 0.9036634121598764, 0.9787540945917699, 0.907602320523581, 0.9144860741778783, 0.9408579252864454, 0.9855491783510815, 0.9181460514286893], [0.9421224384600982, 0.9584372833650735, 1.0, 0.9264242154819252, 0.9580139296416259, 0.9317593300020401, 0.9518628783973647, 0.9652294185686948, 0.9167030164274126, 0.9647191276508389, 0.9175376081630151, 0.974883661565248, 0.9256949496861441, 0.9599987972914634, 0.9715892121351216, 0.968386356253005, 0.9868663544586418, 0.9460634933276089, 0.9743199792907375, 0.9863164233051496, 0.9019984259505591, 0.950131447112789, 0.9781050951939447, 0.9828010029991583, 0.9086708970654739, 0.9409353154246363, 0.976896359376168, 0.9819180749481291, 0.9513635768476433, 0.9830442119535798, 0.9052016442933383, 0.951941607358771, 0.9043880415124165], [0.9281118722090896, 0.9400140257928693, 0.9264242154819252, 1.0, 0.9637009650561799, 0.9642040350679223, 0.941161618388269, 0.948713188278484, 0.9483414751796131, 0.9898380366151047, 0.927608575314421, 0.9400263455966572, 0.9085915661238244, 0.9813375009858203, 0.9670909137919707, 0.9024051578202773, 0.932492970427768, 0.9389266163243966, 0.9886270145290911, 0.9245891444295257, 0.9043267202967349, 0.9400348895753549, 0.9551019867713755, 0.9400859209013559, 0.9535150028150128, 0.9091030499777119, 0.9302167047399111, 0.9424641171489299, 0.9536640206794328, 0.9188374634994273, 0.970668986905339, 0.9257452689396135, 0.9054353322769534], [0.9785314546199626, 0.9299771758359122, 0.9580139296416259, 0.9637009650561799, 1.0, 0.9640058244061457, 0.9067618278757839, 0.9875464909575913, 0.9359691246305523, 0.963837668746052, 0.9402148687656655, 0.9633637906919923, 0.9014991264393288, 0.9086345998852112, 0.9206772206227004, 0.9755895155614436, 0.9548117979067705, 0.9687064650055403, 0.9842289438769072, 0.9829419864317631, 0.9105843115320451, 0.9781185701506474, 0.9152279303335538, 0.9043520651761386, 0.9655268240126205, 0.9011592745534275, 0.9265703439311508, 0.9553306163153681, 0.9118625438996031, 0.9677891452640103, 0.955982847837417, 0.9827191225313494, 0.9266229054869907], [0.9681146119563971, 0.9503834264900511, 0.9317593300020401, 0.9642040350679223, 0.9640058244061457, 1.0, 0.954641724810021, 0.9715092480110084, 0.9073455543646098, 0.9423115480181214, 0.9513947898178092, 0.9244143004787043, 0.9737919495720608, 0.9002221410882071, 0.9841024606471761, 0.9377528041124721, 0.9651550857286382, 0.9638501535732479, 0.9623855824803988, 0.9457814679308386, 0.9104620519869895, 0.9571447384433396, 0.9682329560093751, 0.9720144384849656, 0.9732432305802801, 0.9418514553832198, 0.9106250339693746, 0.9301935606732554, 0.9160669325979663, 0.9425713711903343, 0.9050762826576827, 0.9892886002608716, 0.9621995830981146], [0.9601160937637852, 0.9360898419640802, 0.9518628783973647, 0.941161618388269, 0.9067618278757839, 0.95464 ...
# Feasible construction solution
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  0 . Cost:  1715.2499037176106
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  1 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  2 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  3 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  4 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  5 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  6 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  7 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  8 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  9 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  10 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  11 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  12 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  13 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  14 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  15 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  16 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  17 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  18 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  19 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  20 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  21 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  22 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  23 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  24 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  25 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  26 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  27 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  28 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  29 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  30 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  31 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  32 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  33 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  34 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  35 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  36 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  37 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  38 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  39 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  40 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  41 . Cost:  1577.3008282344167
# Iteration #  42  out of  500  ( 8.0 %)
# Elapsed time:  34.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  42 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  43 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  44 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  45 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  46 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  47 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  48 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  49 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  50 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  51 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  52 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  53 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  54 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  55 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  56 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  57 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  58 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  59 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  60 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  61 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  62 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  63 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  64 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  65 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  66 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  67 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  68 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  69 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  70 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  71 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  72 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  73 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  74 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  75 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  76 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  77 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  78 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  79 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  80 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  81 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  82 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  83 . Cost:  1495.792928862868
# Iteration #  84  out of  500  ( 17.0 %)
# Elapsed time:  71.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  84 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  85 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  86 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  87 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  88 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  89 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  90 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  91 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  92 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  93 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  94 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  95 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  96 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  97 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  98 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  99 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  100 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  101 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  102 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  103 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  104 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  105 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  106 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  107 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  108 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  109 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  110 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  111 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  112 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  113 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  114 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  115 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  116 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  117 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  118 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  119 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  120 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  121 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  122 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  123 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  124 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  125 . Cost:  1411.2621207214222
# Iteration #  126  out of  500  ( 25.0 %)
# Elapsed time:  129.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  126 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  127 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  128 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  129 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  130 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  131 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  132 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  133 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  134 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  135 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  136 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  137 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  138 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  139 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  140 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  141 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  142 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  143 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  144 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  145 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  146 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  147 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  148 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  149 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  150 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  151 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  152 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  153 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  154 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  155 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  156 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  157 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  158 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  159 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  160 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  161 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  162 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  163 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  164 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  165 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  166 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  167 . Cost:  1641.9997780225265
# Iteration #  168  out of  500  ( 34.0 %)
# Elapsed time:  189.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  168 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  169 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  170 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  171 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  172 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  173 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  174 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  175 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  176 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  177 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  178 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  179 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  180 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  181 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  182 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  183 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  184 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  185 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  186 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  187 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  188 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  189 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  190 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  191 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  192 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  193 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  194 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  195 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  196 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  197 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  198 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  199 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  200 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  201 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  202 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  203 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  204 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  205 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  206 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  207 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  208 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  209 . Cost:  1495.792928862868
# Iteration #  210  out of  500  ( 42.0 %)
# Elapsed time:  251.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  210 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  211 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  212 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  213 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  214 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  215 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  216 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  217 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  218 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  219 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  220 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  221 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  222 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  223 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  224 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  225 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  226 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  227 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  228 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  229 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  230 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  231 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  232 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  233 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  234 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  235 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  236 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  237 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  238 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  239 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  240 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  241 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  242 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  243 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  244 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  245 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  246 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  247 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  248 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  249 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  250 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  251 . Cost:  1616.2055191741592
# Iteration #  252  out of  500  ( 50.0 %)
# Elapsed time:  319.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  252 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  253 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  254 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  255 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  256 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  257 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  258 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  259 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  260 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  261 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  262 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  263 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  264 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  265 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  266 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  267 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  268 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  269 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  270 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  271 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  272 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  273 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  274 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  275 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  276 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  277 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  278 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  279 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  280 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  281 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  282 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  283 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  284 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  285 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  286 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  287 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  288 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  289 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  290 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  291 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  292 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  293 . Cost:  1641.9997780225265
# Iteration #  294  out of  500  ( 59.0 %)
# Elapsed time:  374.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  294 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  295 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  296 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  297 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  298 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  299 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  300 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  301 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  302 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  303 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  304 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  305 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  306 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  307 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  308 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  309 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  310 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  311 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  312 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  313 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  314 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  315 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  316 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  317 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  318 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  319 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  320 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  321 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  322 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  323 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  324 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  325 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  326 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  327 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  328 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  329 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  330 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  331 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  332 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  333 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  334 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  335 . Cost:  1618.328362403674
# Iteration #  336  out of  500  ( 67.0 %)
# Elapsed time:  446.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  336 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  337 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  338 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  339 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  340 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  341 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  342 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  343 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  344 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  345 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  346 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  347 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  348 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  349 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  350 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  351 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  352 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  353 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  354 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  355 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  356 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  357 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  358 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  359 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  360 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  361 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  362 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  363 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  364 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  365 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  366 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  367 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  368 . Cost:  1616.2055191741592
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  369 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  370 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  371 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  372 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  373 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  374 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  375 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  376 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  377 . Cost:  1531.9666910602145
# Iteration #  378  out of  500  ( 76.0 %)
# Elapsed time:  511.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  378 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:
. Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  75 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  76 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  77 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  78 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  79 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  80 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  81 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  82 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  83 . Cost:  1478.5942299967937
# Iteration #  84  out of  250  ( 34.0 %)
# Elapsed time:  130.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  84 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  85 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  86 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  87 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  88 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  89 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  90 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  91 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  92 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  93 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  94 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  95 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  96 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  97 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  98 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  99 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  100 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  101 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  102 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  103 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  104 . Cost:  1564.0585660182714
# Iteration #  105  out of  250  ( 42.0 %)
# Elapsed time:  158.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  105 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  106 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  107 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  108 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  109 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  110 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  111 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  112 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  113 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  114 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  115 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  116 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  117 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  118 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  119 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  120 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  121 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  122 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  123 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  124 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  125 . Cost:  1447.1549872351115
# Iteration #  126  out of  250  ( 50.0 %)
# Elapsed time:  190.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  126 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  127 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  128 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  129 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  130 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  131 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  132 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  133 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  134 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  135 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  136 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  137 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  138 . Cost:  1615.8444190320888
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  139 . Cost:  1592.6829090728302
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  140 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  141 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  142 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  143 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  144 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  145 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  146 . Cost:  1616.2055191741592
# Iteration #  147  out of  250  ( 59.0 %)
# Elapsed time:  220.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  147 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  148 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  149 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  150 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  151 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  152 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  153 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  154 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  155 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  156 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  157 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  158 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  159 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  160 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  161 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  162 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  163 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  164 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  165 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  166 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  167 . Cost:  1506.6799080126375
# Iteration #  168  out of  250  ( 67.0 %)
# Elapsed time:  248.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  168 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  169 . Cost:  1434.6859558390956
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  170 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  171 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  172 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  173 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  174 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  175 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  176 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  177 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  178 . Cost:  1703.8424385668152
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  179 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  180 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  181 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  182 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  183 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  184 . Cost:  1605.115998988514
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  185 . Cost:  1447.1549872351115
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  186 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  187 . Cost:  1411.2621207214222
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  188 . Cost:  1605.115998988514
# Iteration #  189  out of  250  ( 76.0 %)
# Elapsed time:  278.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  189 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  190 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  191 . Cost:  1495.792928862868
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  192 . Cost:  1535.0947177268795
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  193 . Cost:  1676.7275022833298
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  194 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  195 . Cost:  1564.0585660182714
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  196 . Cost:  1713.2774484751808
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  197 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  198 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  199 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  200 . Cost:  1722.617201650479
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  201 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  202 . Cost:  1641.9997780225265
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  203 . Cost:  1647.0281002546062
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  204 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  205 . Cost:  1659.1399593576684
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  206 . Cost:  1492.487481053387
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  207 . Cost:  1618.328362403674
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  208 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  209 . Cost:  1722.617201650479
# Iteration #  210  out of  250  ( 84.0 %)
# Elapsed time:  307.0  seconds.
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  210 . Cost:  1520.0285987153627
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  211 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  212 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  213 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  214 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  215 . Cost:  1493.0699837423356
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  216 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  217 . Cost:  1531.9666910602145
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  218 . Cost:  1577.3008282344167
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  219 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  220 . Cost:  1478.5942299967937
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  221 . Cost:  1709.30084397434
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  222 . Cost:  1605.79046734136
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  223 . Cost:  1506.6799080126375
# This is a candidate for VRPI
# Total errors: 0
# Message 2:  we did not find a candidate
# Iteration:  224 . Cost:  1641.9997780225265
# Early termination due to stagnation.
#
# Number of clients with split deliveries: NA
# Number of clients without split deliveries: NA
# Total number of clients: NA
# Improvement Time: 1e+20
# Finish Time:  324.54728293418884
# Stag Level:  Yes
# 1e+20
# 324.54728293418884
# Diff_Cost%:  NA
# Pot_Improv%:  NA
# Solution status:  We did not find a feasible solution
