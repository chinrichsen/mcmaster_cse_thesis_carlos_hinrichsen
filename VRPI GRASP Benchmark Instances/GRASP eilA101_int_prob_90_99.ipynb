# %% [markdown]
# #### Reading the instances

# %%
#import os
#os.environ["OMP_NUM_THREADS"] = '1'

# %%
iterations_to_run = 100
# Timeout time in minutes
tmot = 30

# %%
import pandas as pd
# Step 1: Read the text file and store its lines in a list.
#name = 'ct_7_n_4_k10_t_80_no_inter.txt'
name = 'eilA101.txt'
with open(name, 'r') as f:
    lines = f.readlines()

# Step 2: Extract necessary information from the list.
num_vehicles = None
vehicle_capacity = None
optimal_value = None
split_sol = None
demands = []
locations = []

for i, line in enumerate(lines):
    if "Min no of trucks" in line or "Optimal value" in line or "Split" in line:
        num_vehicles = int(line.split("Min no of trucks:")[1].split(",")[0].strip())
        optimal_value = float(line.split("Optimal value:")[1].split(",")[0].strip())
        split_sol = line.split("Split:")[1].split(")")[0].strip()
    elif "CAPACITY" in line:
        vehicle_capacity = int(line.split(":")[1].strip())
    elif "NODE_COORD_SECTION" in line:
        j = i + 1
        while lines[j].strip() != "DEMAND_SECTION":
            _, x, y = map(float, lines[j].split())
            locations.append((x, y))
            j += 1
    elif "DEMAND_SECTION" in line:
        j = i + 1
        while lines[j].strip() != "DEPOT_SECTION":
            _, demand = map(float, lines[j].split())
            demands.append(demand)
            j += 1

# Removing the depot's demand, which is always 0
demands.pop(0)
num_customers = len(demands)

# Step 3: Use the extracted information to generate the desired Python output.
print("# Given data")
print(f"num_vehicles = {num_vehicles}")
print(f"num_customers = {num_customers}")
print(f"vehicle_capacity = {vehicle_capacity}")
print(f"optimal_value = {optimal_value}")
print(f"split_sol = {split_sol}")
print(f"demands = {demands}")
print("\nlocations = [")
for i, (x, y) in enumerate(locations):
    if i == 0:
        print(f"    ({x}, {y}),  # depot")
    else:
        print(f"    ({x}, {y}),  # customer {i}")
print("]")
# Out:
# # Given data
# num_vehicles = 8
# num_customers = 100
# vehicle_capacity = 200
# optimal_value = 817.0
# split_sol = No
# demands = [10.0, 7.0, 13.0, 19.0, 26.0, 3.0, 5.0, 9.0, 16.0, 16.0, 12.0, 19.0, 23.0, 20.0, 8.0, 19.0, 2.0, 12.0, 17.0, 9.0, 11.0, 18.0, 29.0, 3.0, 6.0, 17.0, 16.0, 16.0, 9.0, 21.0, 27.0, 23.0, 11.0, 14.0, 8.0, 5.0, 8.0, 16.0, 31.0, 9.0, 5.0, 5.0, 7.0, 18.0, 16.0, 1.0, 27.0, 36.0, 30.0, 13.0, 10.0, 9.0, 14.0, 18.0, 2.0, 6.0, 7.0, 18.0, 28.0, 3.0, 13.0, 19.0, 10.0, 9.0, 20.0, 25.0, 25.0, 36.0, 6.0, 5.0, 15.0, 25.0, 9.0, 8.0, 18.0, 13.0, 14.0, 3.0, 23.0, 6.0, 26.0, 16.0, 11.0, 7.0, 41.0, 35.0, 26.0, 9.0, 15.0, 3.0, 1.0, 2.0, 22.0, 27.0, 20.0, 11.0, 12.0, 10.0, 9.0, 17.0]
#
# locations = [
#     (35.0, 35.0),  # depot
#     (41.0, 49.0),  # customer 1
#     (35.0, 17.0),  # customer 2
#     (55.0, 45.0),  # customer 3
#     (55.0, 20.0),  # customer 4
#     (15.0, 30.0),  # customer 5
#     (25.0, 30.0),  # customer 6
#     (20.0, 50.0),  # customer 7
# ...

# %% [markdown]
# Preparing for BIG Instances

# %% [markdown]
# 1. Precompute and store all pairwise distances in a matrix instead of calculating them on-the-fly.

# %% [markdown]
# 1. Precompute and store all pairwise distances in a matrix instead of calculating them on-the-fly. +
# 2. Use efficient data structures, such as numpy arrays (from the numpy library), to handle matrix operations.

# %% [markdown]
# 1. Precompute and store all pairwise distances in a matrix instead of calculating them on-the-fly. +
# 2. Use efficient data structures, such as numpy arrays (from the numpy library), to handle matrix operations. +
# 3. Implement a dynamic size for the Restricted Candidate List based on a percentage of the remaining nodes or some other heuristic

# %% [markdown]
# 1. Precompute and store all pairwise distances in a matrix instead of calculating them on-the-fly. +
# 2. Use efficient data structures, such as numpy arrays (from the numpy library), to handle matrix operations. +
# 3. Implement a dynamic size for the Restricted Candidate List based on a percentage of the remaining nodes or some other heuristic +
# 4. Memory Efficiency: Be cautious about storing large numbers of routes in memory. Store only necessary information. Set grasp iterations as parameter at the beginning of code

# %% [markdown]
# 1. Precompute and store all pairwise distances in a matrix instead of calculating them on-the-fly. +
# 2. Use efficient data structures, such as numpy arrays (from the numpy library), to handle matrix operations. +
# 3. Implement a dynamic size for the Restricted Candidate List based on a percentage of the remaining nodes or some other heuristic +
# 4. Memory Efficiency: Be cautious about storing large numbers of routes in memory. Store only necessary information. Set grasp iterations as parameter at the beginning of code +
# 5. Implement additionally more efficient local search techniques like 3-opt or use segment reversal instead of pure swaps. The use of the techniques can be set up as parameters at the beginning of code (fixed or randomly)

# %% [markdown]
# 1. Precompute and store all pairwise distances in a matrix instead of calculating them on-the-fly. +
# 2. Use efficient data structures, such as numpy arrays (from the numpy library), to handle matrix operations. +
# 3. Implement a dynamic size for the Restricted Candidate List based on a percentage of the remaining nodes or some other heuristic +
# 4. Memory Efficiency: Be cautious about storing large numbers of routes in memory. Store only necessary information. Set grasp iterations as parameter at the beginning of code +
# 5. Implement additionally more efficient local search techniques like 3-opt or use segment reversal instead of pure swaps. The use of the techniques can be set up as parameters at the beginning of code (fixed or randomly) +
# 6. Add printing info about split deliveries

# %% [markdown]
# 1. Precompute and store all pairwise distances in a matrix instead of calculating them on-the-fly. +
# 2. Use efficient data structures, such as numpy arrays (from the numpy library), to handle matrix operations. +
# 3. Implement a dynamic size for the Restricted Candidate List based on a percentage of the remaining nodes or some other heuristic +
# 4. Memory Efficiency: Be cautious about storing large numbers of routes in memory. Store only necessary information. Set grasp iterations as parameter at the beginning of code +
# 5. Implement additionally more efficient local search techniques like 3-opt or use segment reversal instead of pure swaps. The use of the techniques can be set up as parameters at the beginning of code (fixed or randomly) +
# 6. Add printing info about split deliveries +
# 7. Add printing info about customers not being served totally or partially

# %% [markdown]
# 1. Precompute and store all pairwise distances in a matrix instead of calculating them on-the-fly. +
# 2. Use efficient data structures, such as numpy arrays (from the numpy library), to handle matrix operations. +
# 3. Implement a dynamic size for the Restricted Candidate List based on a percentage of the remaining nodes or some other heuristic +
# 4. Memory Efficiency: Be cautious about storing large numbers of routes in memory. Store only necessary information. Set grasp iterations as parameter at the beginning of code +
# 5. Implement additionally more efficient local search techniques like 3-opt or use segment reversal instead of pure swaps. The use of the techniques can be set up as parameters at the beginning of code (fixed or randomly) +
# 6. Add printing info about split deliveries +
# 7. Add printing info about customers not being served totally or partially +
# 8. Transform into modular code

# %% [markdown]
# 1. Precompute and store all pairwise distances in a matrix instead of calculating them on-the-fly. +
# 2. Use efficient data structures, such as numpy arrays (from the numpy library), to handle matrix operations. +
# 3. Implement a dynamic size for the Restricted Candidate List based on a percentage of the remaining nodes or some other heuristic +
# 4. Memory Efficiency: Be cautious about storing large numbers of routes in memory. Store only necessary information. Set grasp iterations as parameter at the beginning of code +
# 5. Implement additionally more efficient local search techniques like 3-opt or use segment reversal instead of pure swaps. The use of the techniques can be set up as parameters at the beginning of code (fixed or randomly) +
# 6. Add printing info about split deliveries +
# 7. Add printing info about customers not being served totally or partially +
# 8. Transform into modular code +
# 9. Print cost per iteration

# %% [markdown]
# 1. Precompute and store all pairwise distances in a matrix instead of calculating them on-the-fly. +
# 2. Use efficient data structures, such as numpy arrays (from the numpy library), to handle matrix operations. +
# 3. Implement a dynamic size for the Restricted Candidate List based on a percentage of the remaining nodes or some other heuristic +
# 4. Memory Efficiency: Be cautious about storing large numbers of routes in memory. Store only necessary information. Set grasp iterations as parameter at the beginning of code +
# 5. Implement additionally more efficient local search techniques like 3-opt or use segment reversal instead of pure swaps. The use of the techniques can be set up as parameters at the beginning of code (fixed or randomly) +
# 6. Add printing info about split deliveries +
# 7. Add printing info about customers not being served totally or partially +
# 8. Transform into modular code +
# 9. Print cost per iteration +
# 10. Add conditions for early termination if the solution quality hasn't improved for a certain number of iterations (stagnation)

# %% [markdown]
# 1. Precompute and store all pairwise distances in a matrix instead of calculating them on-the-fly. +
# 2. Use efficient data structures, such as numpy arrays (from the numpy library), to handle matrix operations. +
# 3. Implement a dynamic size for the Restricted Candidate List based on a percentage of the remaining nodes or some other heuristic +
# 4. Memory Efficiency: Be cautious about storing large numbers of routes in memory. Store only necessary information. Set grasp iterations as parameter at the beginning of code +
# 5. Implement additionally more efficient local search techniques like 3-opt or use segment reversal instead of pure swaps. The use of the techniques can be set up as parameters at the beginning of code (fixed or randomly) +
# 6. Add printing info about split deliveries +
# 7. Add printing info about customers not being served totally or partially +
# 8. Transform into modular code +
# 9. Print cost per iteration +
# 10. Add conditions for early termination if the solution quality hasn't improved for a certain number of iterations (stagnation) +
# 11. Perturbation: After constructing a solution, you can apply slight random perturbations to it. For instance, remove a few customers from their routes and reinsert them using greedy or random criteria. This can diversify the search space before the local search

# %% [markdown]
# #### nearest neighbour construct solution

# %% [markdown]
# #### running more with nearest neighbor

# %% [markdown]
# #### split delivery penalty

# %% [markdown]
# #### Adding split deliveries statistics

# %% [markdown]
#  #### Adding the Swap-Based Local Search (SLS)

# %% [markdown]
# Saving the time of best solution

# %% [markdown]
# Nearest neighbour solution saved

# %% [markdown]
# Fixed seed changed again to random seed

# %% [markdown]
# Nearest neighbour flexibility to allow split demand in initial solution

# %% [markdown]
# Optimal value extracted from txt file

# %% [markdown]
# sdvrp check before and after local search

# %% [markdown]
# interdiction matrix added

# %% [markdown]
# Conditions over revised demands for feasibility

# %% [markdown]
# Adding lowest interdiction route logic

# %% [markdown]
# Adding combinations to find feasible solution moving expected demands (pending)

# %% [markdown]
# Adding lowest interdiction route logic (3 opt)

# %% [markdown]
# Adding lowest interdiction route logic (segment-reversal)

# %% [markdown]
# Adding combinations to find feasible solution moving expected demands (working on it)

# %%
import random
import numpy as np
import copy
import pandas as pd
import time
import itertools
from sklearn.cluster import KMeans
from itertools import product
import math
import sys
import threading
from queue import Queue, Empty


class VRP:
    def __init__(self, num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl_factor=0.98, iterations=10000, local_search_option='2-opt', stagnation_limit=50, perturb_percentage=0.1, split_penalty=1000, sdd = 1, reintegrate_it=1000, split_sol = 'Yes', min_prob_matrix = 1.0, max_prob_matrix = 1.0, int_prob = None, threshold_increment = 5, optimization_solution_finder = "tier"): #, dem_increment = 0.25):
        #random.seed(sdd)
        random.seed()
        #np.random.seed(sdd)
        np.random.seed()
        self.depot_id = 0
        self.number_vehicle = num_vehicles
        self.number_customers = num_customers
        self.number_nodes = num_customers + 1
        self.coordinates = locations
        self.demands = [0] + demands
        self.vehicle_capacity = vehicle_capacity
        self.reintegrate_it = reintegrate_it
        self.saved_initial_solution_split = None
        self.saved_initial_solution_no_split = None
        self.split_sol = split_sol
        self.int_prob = int_prob
        self.optimization_solution_finder = optimization_solution_finder
        #self.dem_increment = dem_increment

        # Set hyperparameters
        self.rcl_factor = rcl_factor
        self.iterations = iterations
        self.local_search_option = local_search_option
        self.stagnation_limit = stagnation_limit
        self.perturb_percentage = perturb_percentage
        self.split_penalty = split_penalty
        self.sdd = sdd
        self.min_prob_matrix = min_prob_matrix
        self.max_prob_matrix = max_prob_matrix
        self.threshold_increment = threshold_increment
        

        self.coordinates_np = np.array(self.coordinates)
        self.demands = np.array(self.demands)
        diff = self.coordinates_np[:, np.newaxis, :] - self.coordinates_np
        self.distance_matrix = np.sqrt((diff**2).sum(axis=2))

    def cluster_based_init(self, n_clusters=None):
        if n_clusters is None:
            n_clusters = self.number_vehicle  # Or use a heuristic to determine the number of clusters
        # Apply clustering on customer locations only
        customer_coords = np.array(self.coordinates[1:])  # Exclude depot
        kmeans = KMeans(n_clusters=n_clusters, random_state=self.sdd).fit(customer_coords)
        clusters = kmeans.labels_

        remaining_demands = self.demands.copy()
        routes = []

        for cluster_id in range(n_clusters):
            cluster_customers = [i+1 for i, cluster in enumerate(clusters) if cluster == cluster_id and remaining_demands[i+1] > 0]
            # Apply nearest neighbor within each cluster
            cluster_routes, cluster_remaining_demands = self.nearest_neighbor_within_cluster(cluster_customers, remaining_demands)
            routes.extend(cluster_routes)
            remaining_demands = cluster_remaining_demands

        return routes, remaining_demands

    def nearest_neighbor_within_cluster(self, cluster_customers, remaining_demands):
        cluster_routes = []
        demands_copy = remaining_demands.copy()

        while any(demands_copy[customer] > 0 for customer in cluster_customers):
            route = [self.depot_id]
            current_load = 0
            current_location = self.depot_id

            while current_load < self.vehicle_capacity:
                nearest_customer = None
                nearest_distance = float('inf')

                for customer in cluster_customers:
                    if demands_copy[customer] > 0 and customer not in route:
                        distance = self.distance_matrix[current_location][customer]
                        if distance < nearest_distance and current_load + demands_copy[customer] <= self.vehicle_capacity:
                            nearest_distance = distance
                            nearest_customer = customer

                if nearest_customer is None:
                    break  # No more customers can be added without exceeding capacity

                current_load += demands_copy[nearest_customer]
                demands_copy[nearest_customer] = 0
                route.append(nearest_customer)
                current_location = nearest_customer

            route.append(self.depot_id)
            cluster_routes.append(route)

        return cluster_routes, demands_copy


    def nearest_neighbor(self):
        remaining_demands = self.demands.copy()
        routes = []
        fes_cond = None

        for _ in range(self.number_vehicle):
            current_load = 0
            current_location = self.depot_id
            route = [self.depot_id]

            while current_load < self.vehicle_capacity:
                nearest_customer = None
                nearest_distance = float('inf')

                for i in range(1, self.number_customers + 1):
                    if remaining_demands[i] > 0 and i not in route:
                        distance = self.distance_matrix[current_location][i]
                        if distance < nearest_distance and current_load + remaining_demands[i] <= self.vehicle_capacity:
                            nearest_distance = distance
                            nearest_customer = i

                if nearest_customer is None:
                    break

                current_load += remaining_demands[nearest_customer]
                remaining_demands[nearest_customer] = 0
                route.append(nearest_customer)
                current_location = nearest_customer

            route.append(self.depot_id)
            routes.append(route)
            serviced_demands = []
            for route in routes:
                route_demands = {}
                for customer in route[1:-1]:  # Exclude the depot
                    route_demands[customer] = self.demands[customer]
                serviced_demands.append(route_demands)
        # Check if initial solution is feasible
        # Flatten the list
        flat_list = [item for sublist in routes for item in sublist]

        # Convert the flat list to a set to get unique elements
        unique_elements = set(flat_list)

        # Count the number of unique elements
        count_unique = len(unique_elements)
        if num_customers+1 != count_unique:
            fes_cond = 'Infeasible'
            print("Infeasible construction solution")
        else:
            fes_cond = 'Feasible'
            print("Feasible construction solution")
        if self.saved_initial_solution_no_split is None:# and fes_cond == 'Feasible':
            # Save the initial solution right after it's generated, ensuring no split deliveries
            self.saved_initial_solution_no_split = (copy.deepcopy(routes), copy.deepcopy(remaining_demands), copy.deepcopy(serviced_demands), copy.deepcopy(fes_cond))

        return routes, remaining_demands, serviced_demands, fes_cond

    def nearest_neighbor_with_split_demands(self):
        remaining_demands = self.demands.copy()
        routes = []
        serviced_demands = []
        fes_cond = None

        for _ in range(self.number_vehicle):
            current_load = 0
            current_location = self.depot_id
            route = [self.depot_id]
            route_demands = {}

            while current_load < self.vehicle_capacity:
                nearest_customer = None
                nearest_distance = float('inf')

                for i in range(1, self.number_customers + 1):
                    if remaining_demands[i] > 0 and i not in route:
                        distance = self.distance_matrix[current_location][i]
                        if distance < nearest_distance:
                            nearest_distance = distance
                            nearest_customer = i

                if nearest_customer is None:
                    break

                # Determine how much of the demand can be fulfilled by this vehicle
                demand_to_fulfill = min(remaining_demands[nearest_customer], self.vehicle_capacity - current_load)
                if demand_to_fulfill > 0:  # If there's some demand that can be fulfilled
                    current_load += demand_to_fulfill
                    remaining_demands[nearest_customer] -= demand_to_fulfill
                    route_demands[nearest_customer] = demand_to_fulfill

                    if nearest_customer not in route:  # Add to route if not already added
                        route.append(nearest_customer)
                        current_location = nearest_customer

            route.append(self.depot_id)
            routes.append(route)
            serviced_demands.append(route_demands)

        # Prepare the serviced demands in the desired format
        combined_serviced_demands = []
        for route_demands in serviced_demands:
            combined_serviced_demands.append(route_demands)

        # Flatten the list
        flat_list = [item for sublist in routes for item in sublist]

        # Convert the flat list to a set to get unique elements
        unique_elements = set(flat_list)

        # Count the number of unique elements
        count_unique = len(unique_elements)
        if num_customers+1 != count_unique:
            fes_cond = 'Infeasible'
        else:
            fes_cond = 'Feasible'
        
        if self.saved_initial_solution_split is None:# and fes_cond == 'Feasible':
            # Save the initial solution right after it's generated, allowing for split deliveries
            self.saved_initial_solution_split = (copy.deepcopy(routes), copy.deepcopy(remaining_demands), copy.deepcopy(combined_serviced_demands), copy.deepcopy(fes_cond))

        return routes, remaining_demands, combined_serviced_demands, fes_cond    


    def farthest_customer_init(self):
        remaining_demands = self.demands.copy()
        routes = []

        while np.any(remaining_demands[1:] > 0):  # Check if there's any customer demand left
            route = [self.depot_id]
            current_load = 0
            distances_to_depot = self.distance_matrix[self.depot_id][1:]  # Excludes depot itself

            # Prioritize customers based on distance, but consider only those that can be added without exceeding capacity
            eligible_customers = [(i+1, dist) for i, dist in enumerate(distances_to_depot) if remaining_demands[i+1] > 0 and remaining_demands[i+1] <= self.vehicle_capacity - current_load]
            if not eligible_customers:
                break  # If no eligible customers, break

            # Sort eligible customers by distance in descending order (farthest first)
            farthest_customer = sorted(eligible_customers, key=lambda x: x[1], reverse=True)[0][0]

            # Add farthest customer as the first customer of the route
            current_load += remaining_demands[farthest_customer]
            remaining_demands[farthest_customer] = 0
            route.append(farthest_customer)

            while current_load < self.vehicle_capacity:
                nearest_customer = None
                nearest_distance = float('inf')

                for i in range(1, self.number_customers + 1):
                    if remaining_demands[i] > 0 and i not in route:
                        distance = self.distance_matrix[route[-1]][i]  # Distance from the last customer added to potential next customer
                        if distance < nearest_distance and current_load + remaining_demands[i] <= self.vehicle_capacity:
                            nearest_distance = distance
                            nearest_customer = i

                if nearest_customer is None:
                    break  # No more customers can be added without exceeding capacity

                current_load += remaining_demands[nearest_customer]
                remaining_demands[nearest_customer] = 0
                route.append(nearest_customer)

            route.append(self.depot_id)
            routes.append(route)

        return routes, remaining_demands


    def count_split_deliveries(self, routes, route_demands):
        """ Count the number of split deliveries for the given routes and demands. """
        split_count = 0
        deliveries = {}

        for i, demands_dict in enumerate(route_demands):
            for customer, demand in demands_dict.items():
                if customer not in deliveries:
                    deliveries[customer] = 0
                deliveries[customer] += 1

        for customer, delivery_count in deliveries.items():
            if delivery_count > 1:
                split_count += delivery_count - 1  # We add (delivery_count - 1) because if a customer is served by 2 routes, then there is 1 split delivery for that customer.

        return split_count

    def greedy_cost(self, customer_id, current_load):
        return self.demands[customer_id] / (self.distance_matrix[self.depot_id, customer_id] + 1e-5)




    def construct_solution(self, reintegrate=False):
        #print(split_sol)
        # --> name of method: nearest_neighbor_with_split_demands
        if reintegrate:
        # Reintegrate the saved initial solution without modifications
            if split_sol == 'No':
                routes, remaining_demands, serviced_demands, fes_cond = copy.deepcopy(self.saved_initial_solution_no_split)
            else:
                routes, remaining_demands, serviced_demands, fes_cond = copy.deepcopy(self.saved_initial_solution_split)
        else:
            if split_sol == 'No':
                routes, remaining_demands, serviced_demands, fes_cond = self.nearest_neighbor()
                
            else:
                routes, remaining_demands, serviced_demands, fes_cond = self.nearest_neighbor_with_split_demands()

        # Generate a new solution using nearest_neighbor or another method intended for new solutions
            
            #print(routes)
            #print(remaining_demands)
            #print(serviced_demands)

        # First, we use the nearest neighbor method to get the initial routes.
        #routes, remaining_demands, serviced_demands = self.nearest_neighbor()
        #routes, remaining_demands = self.farthest_customer_init()
        #routes, remaining_demands = self.cluster_based_init()
        #print("Routes after cluster solution: ", routes)
        #print("Remaining demands after cluster solution: ", remaining_demands)
        #print("Serviced demands after cluster solution: ", serviced_demands)
        #print(routes)
        #print(remaining_demands)
            serviced_demands = []

            for route in routes:
                route_demands = {}
                for customer in route[1:-1]:  # Exclude the depot
                    route_demands[customer] = self.demands[customer]
                serviced_demands.append(route_demands)

            remaining_demands = self.demands.copy()
            routes = []
            serviced_demands = []

            for _ in range(self.number_vehicle):
                current_load = 0
                route = [self.depot_id]
                route_demands = {}
                while current_load < self.vehicle_capacity:
                    costs = [(i, self.greedy_cost(i, current_load)) for i in range(1, self.number_customers + 1) if remaining_demands[i] > 0 and i not in route]
                    costs.sort(key=lambda x: x[1], reverse=True)
                    rcl_size = max(1, int(len(costs) * self.rcl_factor))
                    rcl = [c[0] for c in costs[:rcl_size]]

                    if not rcl:
                        break

                    random.seed(10)

                    chosen_customer = random.choice(rcl)
                    delivery = min(self.vehicle_capacity - current_load, remaining_demands[chosen_customer])
                    if chosen_customer not in route_demands:
                        route_demands[chosen_customer] = 0
                    route_demands[chosen_customer] += delivery
                    remaining_demands[chosen_customer] -= delivery
                    current_load += delivery
                    route.append(chosen_customer)
                    if current_load == self.vehicle_capacity:
                        break

                route.append(self.depot_id)
                routes.append(route)
                serviced_demands.append(route_demands)

            
        return routes, serviced_demands, remaining_demands

    def is_route_valid(self, route, route_demands):
        total_demand = sum([route_demands[customer] for customer in route if customer in route_demands])
        return total_demand <= self.vehicle_capacity
    
    def filter_demands(self, route_demands, demands):
        # Convert route_demands keys to a set for faster lookup
        route_customers = set(route_demands.keys())
        
        # Filter demands based on route_customers
        filtered_demands = [demand for index, demand in enumerate(demands, start=1) if index in route_customers]
        
        return filtered_demands
    
    # Function to calculate the required values
    def calculate_demands_for_capacity_check(self, demands_list):
        total_demand_by_route = []
        total_demand = 0

        for route_demands in demands_list:
            route_total = sum(route_demands.values())
            total_demand_by_route.append(route_total)
            total_demand += route_total

        number_of_routes = len(demands_list)
        
        return total_demand_by_route, number_of_routes, total_demand

    def swap_local_search(self, routes, route_demands, interdiction_probabilities, iter_num, tier_1_it, tier_2_it):
        improvement_found = True
        it_number = iter_num+1
        
        osf_swl = self.optimization_solution_finder
                                    
        c_it = 1
        while improvement_found:
            # print("Improvement Found in SWAP: ", improvement_found)
            improvement_found = False
            for i in range(len(routes)):
                for j in range(i + 1, len(routes)):
                    for customer_i in routes[i][1:-1]:  # Exclude depot
                        for customer_j in routes[j][1:-1]:  # Exclude depot
                            # Check if customers are not repeated within their new routes before swap
                            c_it = c_it+1
                            # check_time = time.time() - start_time
                            # print("Check Time:", check_time)
                            # if check_time >= self.maximus_time:
                            #     sys.exit()
                                        
                            if customer_i not in routes[j] and customer_j not in routes[i]:
                                # Prepare for swap
                                new_route_i = routes[i].copy()
                                new_route_j = routes[j].copy()

                                # Safely get demands or 0 if not found
                                demand_i = route_demands[i].get(customer_i, 0)
                                demand_j = route_demands[j].get(customer_j, 0)

                                # Perform swap
                                new_route_i[new_route_i.index(customer_i)] = customer_j
                                new_route_j[new_route_j.index(customer_j)] = customer_i
                                
                                # Swap demands
                                new_demands_i = route_demands[i].copy()
                                new_demands_j = route_demands[j].copy()
                                new_demands_i[customer_j] = demand_j
                                new_demands_j[customer_i] = demand_i
                                
                                if customer_i in new_demands_i: del new_demands_i[customer_i]
                                if customer_j in new_demands_j: del new_demands_j[customer_j]

                                
                                a1 = self.calculate_cumulative_probabilities_for_routes(routes[i], interdiction_probabilities)
                                a2 = self.calculate_cumulative_probabilities_for_routes(routes[j], interdiction_probabilities)
                                a3 = self.calculate_cumulative_probabilities_for_routes(new_route_i, interdiction_probabilities)
                                a4 = self.calculate_cumulative_probabilities_for_routes(new_route_j, interdiction_probabilities)
                                
                                route_old_i = routes[i]
                                route_old_j = routes[j]
                                route_new_i = new_route_i
                                route_new_j = new_route_j
                                route_demands_old_i = route_demands[i]
                                route_demands_old_j = route_demands[j]
                                route_demands_new_i = new_demands_i
                                route_demands_new_j = new_demands_j

                                
                                route_old_i = self.check_and_transform_path(route_old_i)
                                route_old_j = self.check_and_transform_path(route_old_j)
                                route_new_i = self.check_and_transform_path(route_new_i)
                                route_new_j = self.check_and_transform_path(route_new_j)

                                route_demands_old_i = self.check_and_transform_demands(route_demands_old_i)
                                route_demands_old_j = self.check_and_transform_demands(route_demands_old_j)
                                route_demands_new_i = self.check_and_transform_demands(route_demands_new_i)
                                route_demands_new_j = self.check_and_transform_demands(route_demands_new_j)

                                route_demands_old_i = self.reorder_demands_by_route(route_old_i, route_demands_old_i)
                                route_demands_old_j = self.reorder_demands_by_route(route_old_j, route_demands_old_j)
                                route_demands_new_i = self.reorder_demands_by_route(route_new_i, route_demands_new_i)
                                route_demands_new_j = self.reorder_demands_by_route(route_new_j, route_demands_new_j)

                                
                            
                                # Subset of data source demands to apply vrpi check for 2-opt
                                source_demands_filtered_route_old_i = self.filter_demands(route_demands_old_i[0], demands)
                                source_demands_filtered_route_old_j = self.filter_demands(route_demands_old_j[0], demands)
                                source_demands_filtered_route_new_i = self.filter_demands(route_demands_new_i[0], demands)
                                source_demands_filtered_route_new_j = self.filter_demands(route_demands_new_j[0], demands)

                                
                                revised_demands_old_route_i = self.calculate_revised_demands_for_routes(route_old_i, route_demands_old_i, interdiction_probabilities)
                                revised_demands_old_route_j = self.calculate_revised_demands_for_routes(route_old_j, route_demands_old_j, interdiction_probabilities)
                                revised_demands_new_route_i = self.calculate_revised_demands_for_routes(route_new_i, route_demands_new_i, interdiction_probabilities)
                                revised_demands_new_route_j = self.calculate_revised_demands_for_routes(route_new_j, route_demands_new_j, interdiction_probabilities)
                                
                                all_cumulative_probabilities_old_route_i = self.calculate_cumulative_probabilities_for_routes(route_old_i, interdiction_probabilities)
                                all_cumulative_probabilities_old_route_j = self.calculate_cumulative_probabilities_for_routes(route_old_j, interdiction_probabilities)
                                all_cumulative_probabilities_new_route_i = self.calculate_cumulative_probabilities_for_routes(route_new_i, interdiction_probabilities)
                                all_cumulative_probabilities_new_route_j = self.calculate_cumulative_probabilities_for_routes(route_new_j, interdiction_probabilities)

                                expected_demands_old_route_i = self.calculate_expected_demand_serviced(revised_demands_old_route_i, all_cumulative_probabilities_old_route_i)
                                expected_demands_old_route_j = self.calculate_expected_demand_serviced(revised_demands_old_route_j, all_cumulative_probabilities_old_route_j)
                                expected_demands_new_route_i = self.calculate_expected_demand_serviced(revised_demands_new_route_i, all_cumulative_probabilities_new_route_i)
                                expected_demands_new_route_j = self.calculate_expected_demand_serviced(revised_demands_new_route_j, all_cumulative_probabilities_new_route_j)
                                
                                

                                num_vehicles_old_route_i = sum(1 for item in route_old_i if isinstance(item, list))
                                num_vehicles_old_route_j = sum(1 for item in route_old_j if isinstance(item, list))
                                num_vehicles_new_route_i = sum(1 for item in route_new_i if isinstance(item, list))
                                num_vehicles_new_route_j = sum(1 for item in route_new_j if isinstance(item, list))

                                # Calculate the demands
                                total_demand_by_route_check_old_route_i, number_of_routes_check_old_route_i, total_demand_check_old_route_i = self.calculate_demands_for_capacity_check(revised_demands_old_route_i)
                                
                                total_demand_by_route_check_old_route_j, number_of_routes_check_old_route_j, total_demand_check_old_route_j = self.calculate_demands_for_capacity_check(revised_demands_old_route_j)
                                
                                total_demand_by_route_check_new_route_i, number_of_routes_check_new_route_i, total_demand_check_new_route_i = self.calculate_demands_for_capacity_check(revised_demands_new_route_i)
                                
                                total_demand_by_route_check_new_route_j, number_of_routes_check_new_route_j, total_demand_check_new_route_j = self.calculate_demands_for_capacity_check(revised_demands_new_route_j)
                                
                                # print("Self Route 1 is valid: ", self.is_route_valid(new_route_i, new_demands_i))
                                # print("Self Route 2 is valid: ", self.is_route_valid(new_route_j, new_demands_j))

                                # Check if swap is valid
                                if self.is_route_valid(new_route_i, new_demands_i) and self.is_route_valid(new_route_j, new_demands_j):
                                    cost_before = self.route_cost(routes[i]) + self.route_cost(routes[j])
                                    cost_after = self.route_cost(new_route_i) + self.route_cost(new_route_j)

                                    if osf_swl == "cost":
                                        if cost_after < cost_before:
                                            routes[i], routes[j] = new_route_i, new_route_j
                                            route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                            improvement_found = True

                                    elif osf_swl == "inter_route":
                                        if (a4[0][0]+a3[0][0]<a2[0][0]+a1[0][0]):
                                            routes[i], routes[j] = new_route_i, new_route_j
                                            route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                            improvement_found = True
                                            
                                    elif osf_swl == "min_demand_route":
                                        if ((round(total_demand_check_new_route_i + total_demand_check_new_route_j,1) < round(total_demand_check_old_route_i + total_demand_check_old_route_j,1) )): 
                                            routes[i], routes[j] = new_route_i, new_route_j
                                            route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                            improvement_found = True
                                            
                                    elif osf_swl == "tier":
                                        if it_number <= tier_1_it:
                                            if ((round(total_demand_check_new_route_i + total_demand_check_new_route_j,1) < round(total_demand_check_old_route_i + total_demand_check_old_route_j,1) )): 
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                        elif it_number > tier_1_it and it_number <= tier_2_it:
                                            if (a4[0][0]+a3[0][0]<a2[0][0]+a1[0][0]): 
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                        elif it_number > tier_2_it:
                                            if ((cost_after < cost_before)):
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True

                                    elif osf_swl == "random":
                                        a = random.uniform(0, 1)
                                        if a <= 0.33:
                                            if ((round(total_demand_check_new_route_i + total_demand_check_new_route_j,1) < round(total_demand_check_old_route_i + total_demand_check_old_route_j,1) )): 
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                        elif a > 0.33 and a <= 0.66:
                                            if (a4[0][0]+a3[0][0]<a2[0][0]+a1[0][0]): 
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                        elif a > 0.66:
                                            if ((cost_after < cost_before)):
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True

                                    elif osf_swl == "mixed":
                                        b = random.uniform(0, 1)
                                        if it_number <= tier_1_it and b <= 0.33:
                                            if ((round(total_demand_check_new_route_i + total_demand_check_new_route_j,1) < round(total_demand_check_old_route_i + total_demand_check_old_route_j,1) )): 
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                        elif it_number > tier_1_it and it_number <= tier_2_it and b <= 0.33:
                                            if (a4[0][0]+a3[0][0]<a2[0][0]+a1[0][0]): 
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                        elif it_number > tier_2_it and b <= 0.33:
                                            if ((cost_after < cost_before)):
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                        elif it_number <= tier_1_it and b > 0.33 and b <= 0.66:
                                            if ((round(total_demand_check_new_route_i + total_demand_check_new_route_j,1) < round(total_demand_check_old_route_i + total_demand_check_old_route_j,1) )): 
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                        elif it_number > tier_1_it and it_number <= tier_2_it and b > 0.33 and b <= 0.66:
                                            if (a4[0][0]+a3[0][0]<a2[0][0]+a1[0][0]): 
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                        elif it_number > tier_2_it and b > 0.33 and b <= 0.66:
                                            if ((cost_after < cost_before)):
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                        elif it_number <= tier_1_it and b > 0.66:
                                            if ((round(total_demand_check_new_route_i + total_demand_check_new_route_j,1) < round(total_demand_check_old_route_i + total_demand_check_old_route_j,1) )): 
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                                
                                        elif it_number > tier_1_it and it_number <= tier_2_it and b > 0.66:
                                            
                                            if (a4[0][0]+a3[0][0]<a2[0][0]+a1[0][0]): 
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                                
                                        elif it_number > tier_2_it and b > 0.66:
                                            if ((cost_after < cost_before)):
                                                routes[i], routes[j] = new_route_i, new_route_j
                                                route_demands[i], route_demands[j] = new_demands_i, new_demands_j
                                                improvement_found = True
                                                
                                            
                            



    def two_opt(self, route, route_demands, interdiction_probabilities, iter_num, tier_1_it, tier_2_it):
        best_route = route[:]
        improved = True
        it_number = iter_num+1
        
        osf_swl = self.optimization_solution_finder
        while improved:
            improved = False
            for i in range(1, len(route) - 2):
                for j in range(i + 1, len(route) - 1):
                    c1 = self.calculate_cumulative_probabilities_for_routes(route[:i] + list(reversed(route[i:j+1])) + route[j+1:], interdiction_probabilities)
                    c2 = self.calculate_cumulative_probabilities_for_routes(route[:i] + list((route[i:j+1])) + route[j+1:], interdiction_probabilities)
                    new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                    old_route = route[:i] + list((route[i:j+1])) + route[j+1:]
                    old_demands = route_demands

                    new_route = self.check_and_transform_path(new_route)
                    old_route = self.check_and_transform_path(old_route)
                    old_demands = self.check_and_transform_demands(old_demands)
                    
                    new_demands = self.reorder_demands_by_route(new_route, old_demands)
                    new_demands = self.check_and_transform_demands(new_demands)
                
                    
                    # Subset of data source demands to apply vrpi check for 2-opt
                    source_demands_filtered = self.filter_demands(route_demands, demands)
                    
                    revised_demands_old_route = self.calculate_revised_demands_for_routes(old_route, old_demands, interdiction_probabilities)
                    revised_demands_new_route = self.calculate_revised_demands_for_routes(new_route, new_demands, interdiction_probabilities)
                    all_cumulative_probabilities_old_route = self.calculate_cumulative_probabilities_for_routes(old_route, interdiction_probabilities)
                    all_cumulative_probabilities_new_route = self.calculate_cumulative_probabilities_for_routes(new_route, interdiction_probabilities)
                    
                    expected_demands_old_route = self.calculate_expected_demand_serviced(revised_demands_old_route, all_cumulative_probabilities_old_route)
                    
                    expected_demands_new_route = self.calculate_expected_demand_serviced(revised_demands_new_route, all_cumulative_probabilities_new_route)
                    
                    # Calculate the demands
                    total_demand_by_route_check_old_route, number_of_routes_check_old_route, total_demand_check_old_route = self.calculate_demands_for_capacity_check(revised_demands_old_route)
                    
                    total_demand_by_route_check_new_route, number_of_routes_check_new_route, total_demand_check_new_route = self.calculate_demands_for_capacity_check(revised_demands_new_route)
                    
                    if osf_swl == "tier":
                        if it_number <= tier_1_it:
                            if round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1):
                            
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True

                        elif it_number > tier_1_it and it_number <= tier_2_it:
                            if c1[0][0] < c2[0][0]:
                            
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True
                        
                        elif it_number > tier_2_it :
                            if (self.distance_matrix[route[i-1], route[i]] + self.distance_matrix[route[j], route[j+1]] > 
                         self.distance_matrix[route[i-1], route[j]] + self.distance_matrix[route[i], route[j+1]]):
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True

                    elif osf_swl == "cost":
                        if (self.distance_matrix[route[i-1], route[i]] + self.distance_matrix[route[j], route[j+1]] > 
                         self.distance_matrix[route[i-1], route[j]] + self.distance_matrix[route[i], route[j+1]]):
                            new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                            if self.is_route_valid(new_route, route_demands):
                                route = new_route
                                    
                                improved = True

                    elif osf_swl == "inter_route":
                        if c1[0][0] < c2[0][0]:
                            new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                            if self.is_route_valid(new_route, route_demands):
                                route = new_route
                                    
                                improved = True

                    elif osf_swl == "min_demand_route":
                        if round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1):
                            new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                            if self.is_route_valid(new_route, route_demands):
                                route = new_route
                                    
                                improved = True
                    
                    elif osf_swl == "random":
                        a = random.uniform(0, 1)
                        if a <= 0.33:
                            if round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1):
                            
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True

                        elif a > 0.33 and a <= 0.66:
                            if c1[0][0] < c2[0][0]:
                            
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True
                        
                        elif a > 0.66:
                            if (self.distance_matrix[route[i-1], route[i]] + self.distance_matrix[route[j], route[j+1]] > 
                         self.distance_matrix[route[i-1], route[j]] + self.distance_matrix[route[i], route[j+1]]):
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True

                    elif osf_swl == "mixed":
                        b = random.uniform(0, 1)
                        if it_number <= tier_1_it and b <= 0.33:
                            if round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1):
                            
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True

                        elif it_number > tier_1_it and it_number <= tier_2_it and b <= 0.33:
                            if c1[0][0] < c2[0][0]:
                            
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True
                        
                        elif it_number > tier_2_it and b <= 0.33:
                            if (self.distance_matrix[route[i-1], route[i]] + self.distance_matrix[route[j], route[j+1]] > 
                         self.distance_matrix[route[i-1], route[j]] + self.distance_matrix[route[i], route[j+1]]):
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True

                        elif it_number <= tier_1_it and (b > 0.33 and b <= 0.66):
                            if round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1):
                            
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True

                        elif it_number > tier_1_it and it_number <= tier_2_it and (b > 0.33 and b <= 0.66):
                            if c1[0][0] < c2[0][0]:
                            
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True
                        
                        elif it_number > tier_2_it and (b > 0.33 and b <= 0.66):
                            if (self.distance_matrix[route[i-1], route[i]] + self.distance_matrix[route[j], route[j+1]] > 
                         self.distance_matrix[route[i-1], route[j]] + self.distance_matrix[route[i], route[j+1]]):
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True

                        elif it_number <= tier_1_it and b > 0.66:
                            if round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1):
                            
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True

                        elif it_number > tier_1_it and it_number <= tier_2_it and b > 0.66:
                            if c1[0][0] < c2[0][0]:
                            
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True
                        
                        elif it_number > tier_2_it and b > 0.66:
                            if (self.distance_matrix[route[i-1], route[i]] + self.distance_matrix[route[j], route[j+1]] > 
                         self.distance_matrix[route[i-1], route[j]] + self.distance_matrix[route[i], route[j+1]]):
                                new_route = route[:i] + list(reversed(route[i:j+1])) + route[j+1:]
                                if self.is_route_valid(new_route, route_demands):
                                    route = new_route
                                        
                                    improved = True

         
        return route

    def three_opt(self, route, route_demands , interdiction_probabilities, iter_num, tier_1_it, tier_2_it):
        best_route = route[:]
        best_distance = self.route_cost(route)
        it_number = iter_num+1
        
        osf_swl = self.optimization_solution_finder
        for i in range(1, len(route) - 2):
            for j in range(i + 1, len(route) - 1):
                for k in range(j + 1, len(route)):
                    new_routes = [
                        route[:i] + route[j:k] + route[i:j] + route[k:],
                        route[:i] + list(reversed(route[i:j])) + route[j:k] + route[k:],
                        route[:i] + route[j:k] + list(reversed(route[i:j])) + route[k:]
                    ]
                    for new_route in new_routes:
                        
                        
                        old_route = best_route
                        old_demands = route_demands

                        new_route_bu = new_route

                        new_route = self.check_and_transform_path(new_route_bu)
                        old_route = self.check_and_transform_path(old_route)
                        old_demands = self.check_and_transform_demands(old_demands)
                        
                        new_demands = self.reorder_demands_by_route(new_route, old_demands)
                        new_demands_bu = new_demands
                        new_demands = self.check_and_transform_demands(new_demands)

                        
                        revised_demands_old_route = self.calculate_revised_demands_for_routes(old_route, old_demands, interdiction_probabilities)
                        revised_demands_new_route = self.calculate_revised_demands_for_routes(new_route, new_demands, interdiction_probabilities)
                        all_cumulative_probabilities_old_route = self.calculate_cumulative_probabilities_for_routes(old_route, interdiction_probabilities)
                        all_cumulative_probabilities_new_route = self.calculate_cumulative_probabilities_for_routes(new_route, interdiction_probabilities)
                        
                        expected_demands_old_route = self.calculate_expected_demand_serviced(revised_demands_old_route, all_cumulative_probabilities_old_route)
                        
                        expected_demands_new_route = self.calculate_expected_demand_serviced(revised_demands_new_route, all_cumulative_probabilities_new_route)
                        c1 = self.calculate_cumulative_probabilities_for_routes(best_route, interdiction_probabilities)
                        c2 = self.calculate_cumulative_probabilities_for_routes(new_route_bu, interdiction_probabilities)
                        

                        total_demand_by_route_check_old_route, number_of_routes_check_old_route, total_demand_check_old_route = self.calculate_demands_for_capacity_check(revised_demands_old_route)
                        
                        total_demand_by_route_check_new_route, number_of_routes_check_new_route, total_demand_check_new_route = self.calculate_demands_for_capacity_check(revised_demands_new_route)
                        
                        new_route = new_route_bu
                        current_distance = self.route_cost(new_route_bu)

                        total_demand_check_new_route < total_demand_check_old_route
                        route_demands = new_demands_bu
                        
                        if osf_swl == "tier":
                            if it_number <= tier_1_it:
                                if ((round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1)) and self.is_route_valid(new_route_bu, route_demands)):
                                    
                                    best_route = new_route[:]
                                

                            elif it_number > tier_1_it and it_number <= tier_2_it:
                                if (c2[0][0] < c1[0][0]) and self.is_route_valid(new_route_bu, route_demands):
                                    best_route = new_route[:]
                                
                            
                            elif it_number > tier_2_it :
                                if current_distance < best_distance and self.is_route_valid(new_route_bu, route_demands):
                                    best_distance = current_distance
                                    best_route = new_route[:]
                               
                        elif osf_swl == "cost":
                            if current_distance < best_distance and self.is_route_valid(new_route_bu, route_demands):
                                best_distance = current_distance
                                best_route = new_route[:]

                        elif osf_swl == "inter_route":
                            if (c2[0][0] < c1[0][0]) and self.is_route_valid(new_route_bu, route_demands):
                                best_route = new_route[:]

                        elif osf_swl == "min_demand_route":
                            if ((round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1)) and self.is_route_valid(new_route_bu, route_demands)):
                                best_route = new_route[:]
                        
                        elif osf_swl == "random":
                            a = random.uniform(0, 1)
                            if a <= 0.33:
                                if ((round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1)) and self.is_route_valid(new_route_bu, route_demands)):
                                    best_route = new_route[:]
                                

                            elif a > 0.33 and a <= 0.66:
                                if (c2[0][0] < c1[0][0]) and self.is_route_valid(new_route_bu, route_demands):
                                    best_route = new_route[:]
                                
                            
                            elif a > 0.66:
                                if current_distance < best_distance and self.is_route_valid(new_route_bu, route_demands):
                                    best_distance = current_distance
                                    best_route = new_route[:]
                                

                        elif osf_swl == "mixed":
                            b = random.uniform(0, 1)
                            if it_number <= tier_1_it and b <= 0.33:
                                if ((round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1)) and self.is_route_valid(new_route_bu, route_demands)):
                                    best_route = new_route[:]
                                

                            elif it_number > tier_1_it and it_number <= tier_2_it and b <= 0.33:
                                if (c2[0][0] < c1[0][0]) and self.is_route_valid(new_route_bu, route_demands):
                                    best_route = new_route[:]
                                
                            
                            elif it_number > tier_2_it and b <= 0.33:
                                if current_distance < best_distance and self.is_route_valid(new_route_bu, route_demands):
                                    best_distance = current_distance
                                    best_route = new_route[:]
                                

                            elif it_number <= tier_1_it and (b > 0.33 and b <= 0.66):
                                if ((round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1)) and self.is_route_valid(new_route_bu, route_demands)):
                                    best_route = new_route[:]
                                

                            elif it_number > tier_1_it and it_number <= tier_2_it and (b > 0.33 and b <= 0.66):
                                if (c2[0][0] < c1[0][0]) and self.is_route_valid(new_route_bu, route_demands):
                                    best_route = new_route[:]
                                
                            
                            elif it_number > tier_2_it and (b > 0.33 and b <= 0.66):
                                if current_distance < best_distance and self.is_route_valid(new_route_bu, route_demands):
                                    best_distance = current_distance
                                    best_route = new_route[:]
                                
                                

                            elif it_number <= tier_1_it and b > 0.66:
                                if ((round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1)) and self.is_route_valid(new_route_bu, route_demands)):
                                    best_route = new_route[:]
                                

                            elif it_number > tier_1_it and it_number <= tier_2_it and b > 0.66:
                                if (c2[0][0] < c1[0][0]) and self.is_route_valid(new_route_bu, route_demands):
                                    best_route = new_route[:]
                                
                            
                            elif it_number > tier_2_it and b > 0.66:
                                if current_distance < best_distance and self.is_route_valid(new_route_bu, route_demands):
                                    best_distance = current_distance
                                    best_route = new_route[:]
                                

        return best_route

    def segment_reversal(self, route, route_demands , interdiction_probabilities, iter_num, tier_1_it, tier_2_it):
        best_route = route[:]
        best_distance = self.route_cost(route)
        it_number = iter_num+1
        
        osf_swl = self.optimization_solution_finder
        
        for i in range(1, len(route) - 2):
            for j in range(i + 1, len(route)):
                c1 = self.calculate_cumulative_probabilities_for_routes(best_route, interdiction_probabilities)
                new_route = route[:i] + list(reversed(route[i:j])) + route[j:]
                new_route_backup = new_route
                c2 = self.calculate_cumulative_probabilities_for_routes(new_route, interdiction_probabilities)
                current_distance = self.route_cost(new_route)

                old_route = best_route
                old_demands = route_demands

                new_route = self.check_and_transform_path(new_route)
                old_route = self.check_and_transform_path(old_route)
                old_demands = self.check_and_transform_demands(old_demands)
                  
                new_demands = self.reorder_demands_by_route(new_route, old_demands)
                new_demands_bu = new_demands  
                
                new_demands = self.check_and_transform_demands(new_demands)

            
                revised_demands_old_route = self.calculate_revised_demands_for_routes(old_route, old_demands, interdiction_probabilities)
                revised_demands_new_route = self.calculate_revised_demands_for_routes(new_route, new_demands, interdiction_probabilities)
                all_cumulative_probabilities_old_route = self.calculate_cumulative_probabilities_for_routes(old_route, interdiction_probabilities)
                all_cumulative_probabilities_new_route = self.calculate_cumulative_probabilities_for_routes(new_route, interdiction_probabilities)
                
                expected_demands_old_route = self.calculate_expected_demand_serviced(revised_demands_old_route, all_cumulative_probabilities_old_route)
                
                expected_demands_new_route = self.calculate_expected_demand_serviced(revised_demands_new_route, all_cumulative_probabilities_new_route)
                
                # Calculate the demands
                total_demand_by_route_check_old_route, number_of_routes_check_old_route, total_demand_check_old_route = self.calculate_demands_for_capacity_check(revised_demands_old_route)
                
                total_demand_by_route_check_new_route, number_of_routes_check_new_route, total_demand_check_new_route = self.calculate_demands_for_capacity_check(revised_demands_new_route)
                
                total_demand_check_new_route < total_demand_check_old_route
                route_demands = new_demands_bu
                
                if osf_swl == "tier":
                    if it_number <= tier_1_it:
                        if (round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1)) and self.is_route_valid(new_route_backup, route_demands):
                            
                            best_route = new_route_backup[:]
                                

                    elif it_number > tier_1_it and it_number <= tier_2_it:
                        if (c2[0][0] < c1[0][0]) and self.is_route_valid(new_route_backup, route_demands):
                            
                            best_route = new_route_backup[:]
                                
                            
                    elif it_number > tier_2_it :
                        if current_distance < best_distance and self.is_route_valid(new_route_backup, route_demands):
                            best_distance = current_distance
                            best_route = new_route_backup[:]
                               

                elif osf_swl == "cost":
                    if current_distance < best_distance and self.is_route_valid(new_route_backup, route_demands):
                        best_distance = current_distance
                        best_route = new_route_backup[:]

                elif osf_swl == "inter_route":
                    if (c2[0][0] < c1[0][0]) and self.is_route_valid(new_route_backup, route_demands):
                        
                        best_route = new_route_backup[:]
                
                elif osf_swl == "min_demand_route":
                    if (round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1)) and self.is_route_valid(new_route_backup, route_demands):
                        
                        best_route = new_route_backup[:]
                
                elif osf_swl == "random":
                    a = random.uniform(0, 1)
                    if a <= 0.33:
                        if (round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1)) and self.is_route_valid(new_route_backup, route_demands):
                            
                            best_route = new_route_backup[:]
                                

                    elif a > 0.33 and a <= 0.66:
                        if (c2[0][0] < c1[0][0]) and self.is_route_valid(new_route_backup, route_demands):
                            
                            best_route = new_route_backup[:]
                                
                            
                    elif a > 0.66:
                        if current_distance < best_distance and self.is_route_valid(new_route_backup, route_demands):
                            best_distance = current_distance
                            best_route = new_route_backup[:]
                                

                elif osf_swl == "mixed":
                    b = random.uniform(0, 1)
                    if it_number <= tier_1_it and b <= 0.33:
                        if (round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1)) and self.is_route_valid(new_route_backup, route_demands):
                            
                            best_route = new_route_backup[:]
                                

                    elif it_number > tier_1_it and it_number <= tier_2_it and b <= 0.33:
                        if (c2[0][0] < c1[0][0]) and self.is_route_valid(new_route_backup, route_demands):
                            
                            best_route = new_route_backup[:]
                                
                            
                    elif it_number > tier_2_it and b <= 0.33:
                        if current_distance < best_distance and self.is_route_valid(new_route_backup, route_demands):
                            best_distance = current_distance
                            best_route = new_route_backup[:]
                                

                    elif it_number <= tier_1_it and (b > 0.33 and b <= 0.66):
                        if (round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1)) and self.is_route_valid(new_route_backup, route_demands):
                            best_route = new_route_backup[:]
                                

                    elif it_number > tier_1_it and it_number <= tier_2_it and (b > 0.33 and b <= 0.66):
                        if (c2[0][0] < c1[0][0]) and self.is_route_valid(new_route_backup, route_demands):
                            best_route = new_route_backup[:]
                                
                            
                    elif it_number > tier_2_it and (b > 0.33 and b <= 0.66):
                        if current_distance < best_distance and self.is_route_valid(new_route_backup, route_demands):
                            best_distance = current_distance
                            best_route = new_route_backup[:]
                                

                    elif it_number <= tier_1_it and b > 0.66:
                        if (round(total_demand_check_new_route,1) < round(total_demand_check_old_route,1)) and self.is_route_valid(new_route_backup, route_demands):
                            best_route = new_route_backup[:]
                                

                    elif it_number > tier_1_it and it_number <= tier_2_it and b > 0.66:
                        if (c2[0][0] < c1[0][0]) and self.is_route_valid(new_route_backup, route_demands):
                            best_route = new_route_backup[:]
                                
                            
                    elif it_number > tier_2_it and b > 0.66:
                        if current_distance < best_distance and self.is_route_valid(new_route_backup, route_demands):
                            best_distance = current_distance
                            best_route = new_route_backup[:]

        return best_route

    def local_search(self, routes, route_demands, interdiction_probabilities, iter_num, tier_1_it, tier_2_it):
        
        for idx, route in enumerate(routes):

            if self.local_search_option == '2-opt':
                routes[idx] = self.two_opt(route, route_demands[idx], interdiction_probabilities, iter_num, tier_1_it, tier_2_it)
                
            elif self.local_search_option == '3-opt':
                routes[idx] = self.three_opt(route, route_demands[idx] , interdiction_probabilities, iter_num, tier_1_it, tier_2_it)
            elif self.local_search_option == 'segment-reversal':
                routes[idx] = self.segment_reversal(route, route_demands[idx] , interdiction_probabilities, iter_num, tier_1_it, tier_2_it)
            elif self.local_search_option == 'random':
                random_choice = random.choice(['2-opt', '3-opt', 'segment-reversal'])
                if random_choice == '2-opt':
                    # print("ENTERING 2-opt")
                    routes[idx] = self.two_opt(route, route_demands[idx] , interdiction_probabilities, iter_num, tier_1_it, tier_2_it)
                    # print("FINISHING 2-opt")
                elif random_choice == '3-opt':
                    # print("ENTERING 3-opt")
                    routes[idx] = self.three_opt(route, route_demands[idx] , interdiction_probabilities, iter_num, tier_1_it, tier_2_it)
                    # print("FINISHING 3-opt")
                elif random_choice == 'segment-reversal':
                    # print("ENTERING segment-reversal")
                    routes[idx] = self.segment_reversal(route, route_demands[idx] , interdiction_probabilities, iter_num, tier_1_it, tier_2_it)
                    # print("FINISHING segment-reversal")
            check_time = time.time() - start_time
            # print("Check Time:", check_time)
            # if check_time >= self.maximus_time:
            #     sys.exit()
        # Apply swap-based local search after other local searches
        ordered_demands = self.reorder_demands_by_route(routes, route_demands)
        route_demands = ordered_demands
        
        # print("ENTERING swap")
        # print("Routes before swap: ", routes)
        # print("Demands before swap: ", route_demands)
        # print("Iter Num before swap: ", iter_num)
        # print("Tier 1 before swap: ", tier_1_it)
        # print("Tier 2 before swap: ", tier_2_it)
        self.swap_local_search(routes, route_demands, interdiction_probabilities, iter_num, tier_1_it, tier_2_it)
        # print("FINISHING swap")
        return routes, route_demands
        
    # Function to reorder demands to match the route order
    def reorder_demands_by_route(self, routes, demands):
        ordered_demands = []
        for route, demand in zip(routes, demands):
            ordered_route_demands = {}
            # Skip the first and last element assuming they're the depot (0)
            for node in route[1:-1]:
                if node in demand:
                    ordered_route_demands[node] = demand[node]
            ordered_demands.append(ordered_route_demands)
        return ordered_demands

    def route_cost(self, route):
        total_distance = sum(self.distance_matrix[route[i], route[i+1]] for i in range(len(route)-1))
        # We'll apply the penalty in the grasp function when summing up all routes cost
        return total_distance
    
    # Function to check and transform path
    def check_and_transform_path(self, path):
        if isinstance(path, list) and all(isinstance(item, list) for item in path):
            # path is already a list of lists
            return path
        elif isinstance(path, list):
            # path is a single list
            return [path]
        else:
            raise ValueError("path is not in the expected format")

    # Function to check and transform demands_list
    def check_and_transform_demands(self, demands_list):
        if isinstance(demands_list, list) and all(isinstance(item, dict) for item in demands_list):
            # demands_list is already a list of dictionaries
            return demands_list
        elif isinstance(demands_list, dict):
            # demands_list is a single dictionary
            return [demands_list]
        else:
            raise ValueError("demands_list is not in the expected format")
    
    
    def check_sdvrp_feasibility(self, routes, serviced_demands, demands, num_vehicles, vehicle_capacity):
        num_customers = len(demands)
        total_demands_satisfied = {i+1: 0 for i in range(num_customers)}
        customers_serviced = set()

        # Condition 2: Check if number of routes matches number of vehicles
        if len(routes) != num_vehicles:
            return False, "The number of routes does not match the number of vehicles."

        for vehicle, route_demands in enumerate(serviced_demands):
            route_load = 0  # Total load on the current route

            for customer, amount in route_demands.items():
                route_load += amount
                total_demands_satisfied[customer] += amount
                customers_serviced.add(customer)  # Track which customers are serviced

                # Condition 4: Check if any delivery to a customer exceeds vehicle capacity
                if amount > vehicle_capacity:
                    return False, f"Delivery to customer {customer} exceeds vehicle capacity on route {vehicle+1}."

            # Condition 1: Check if total demand on route exceeds vehicle capacity
            if route_load > vehicle_capacity:
                return False, f"Total demand on route {vehicle+1} exceeds vehicle capacity."

        # Condition 3: Check if all customers are serviced
        if len(customers_serviced) != num_customers:
            return False, "Not all customers are serviced."

        # Condition 5: Check if all demands are met or exceeded
        for customer, demand in enumerate(demands, start=1):
            if total_demands_satisfied[customer] < demand:
                return False, f"Customer {customer}'s total received demand {total_demands_satisfied[customer]} is less than required {demand}."

        return True, "All conditions satisfied."
    
    def check_vrpi_feasibility(self, routes, revised_demands, expected_demands, demands, num_vehicles, vehicle_capacity):
        num_customers = len(demands)
        total_demands_satisfied = {i+1: 0 for i in range(num_customers)}
        customers_serviced = set()

        # Condition 2: Check if number of routes matches number of vehicles
        if len(routes) != num_vehicles:
            return False, "The number of routes does not match the number of vehicles."

        for vehicle, route_demands in enumerate(revised_demands):
            route_load = 0  # Total load on the current route

            for customer, amount in route_demands.items():
                route_load += amount
                total_demands_satisfied[customer] += amount
                customers_serviced.add(customer)  # Track which customers are serviced

                # Condition 4: Check if any delivery to a customer exceeds vehicle capacity
                if amount > vehicle_capacity:
                    return False, f"Delivery to customer {customer} exceeds vehicle capacity on route {vehicle+1}."

            # Condition 1: Check if total demand on route exceeds vehicle capacity
            if route_load > vehicle_capacity:
                return False, f"Total demand on route {vehicle+1} exceeds vehicle capacity."

        # Condition 3: Check if all customers are serviced
        if len(customers_serviced) != num_customers:
            return False, "Not all customers are serviced."

        # Condition 5: Check if all demands are met or exceeded
        # Iterate over the demands list with index (1-based)
        for index, demand in enumerate(demands, start=1):
            expected_demand = expected_demands.get(index, 0)  # Get expected demand or 0 if not found
            # Check if the expected demand meets or exceeds the specified demand
            if expected_demand < demand:
                return False, f"Expected demand for customer {index} is {expected_demand}, which is less than required {demand}."

        return True, "All conditions satisfied."

    def calculate_increments(self, total_demand, increment_threshold):
        increment = total_demand / increment_threshold
        return [i * increment for i in range(increment_threshold + 1)]

    def generate_combinations(self, routes, demands, increment_threshold, interdiction_probabilities, input_demands):
        # Identify customers with split deliveries and calculate their total demands
        split_customers = {}
        total_demands = {}

        
        for route_idx, route in enumerate(routes):
            for customer in route[1:-1]:  # Exclude the depot (0)
                #print(route[1:-1])
                if customer not in total_demands:
                    total_demands[customer] = 0
                total_demands[customer] += demands[route_idx].get(customer, 0)

        for customer, total_demand in total_demands.items():
            route_indices = [route_idx for route_idx, route in enumerate(routes) if customer in demands[route_idx]]
            if len(route_indices) > 1:
                split_customers[customer] = (total_demand, route_indices)
        
        # Generate demand increments for each split customer
        customer_combinations = {}
        for customer, (total_demand, route_indices) in split_customers.items():
            increments = self.calculate_increments(total_demand, increment_threshold)
            customer_combinations[customer] = list(itertools.product(increments, repeat=len(route_indices)))
            # Filter out combinations that don't sum up to the total demand
            customer_combinations[customer] = [comb for comb in customer_combinations[customer] if abs(sum(comb) - total_demand) <= 1e-6]
        
        # Generate all possible combinations
        all_combinations = list(itertools.product(*customer_combinations.values()))
        
        # Initialize error count
        error_count = 0

        
        
        # Process each combination
        for combination_set in all_combinations:
            combination_demands = [{k: v for k, v in route.items()} for route in demands]
            
            for idx, (customer, (total_demand, route_indices)) in enumerate(split_customers.items()):
                combination = combination_set[idx]
                for route_idx, demand in zip(route_indices, combination):
                    combination_demands[route_idx][customer] = demand
            
            all_cumulative_probabilities = self.calculate_cumulative_probabilities_for_routes(routes, interdiction_probabilities)
            revised_demands = self.calculate_revised_demands_for_routes(routes, combination_demands, interdiction_probabilities)
            expected_demands = self.calculate_expected_demand_serviced(revised_demands, all_cumulative_probabilities)
            result_f, message = self.check_vrpi_feasibility(routes, revised_demands, expected_demands, input_demands, num_vehicles, vehicle_capacity)
            total_serviced_demands = {}
            for customer, total_demand in total_demands.items():
                serviced_demand = sum(combination_demands[route_idx].get(customer, 0) for route_idx in range(len(routes)))
                total_serviced_demands[customer] = serviced_demand
                log = True
                if abs(serviced_demand - total_demand) > 1e-6:
                    print(f"Error: Serviced demand for customer {customer} does not match total demand.")
                    print(f"Expected: {total_demand}, Got: {serviced_demand}")
                    error_count += 1
                    log = False
                    
                if any(demand < 0 for demand in (combination_demands[route_idx].get(customer, 0) for route_idx in range(len(routes)))):
                    print(f"Error: Negative demand for customer {customer} in one of the routes.")
                    error_count += 1
                    log = False
            if result_f is True and log is True:
                return "we have a candidate", routes, revised_demands
            
            
        
        print(f"Total errors: {error_count}")
        return "we did not find a candidate", routes, revised_demands    
        
        
    
    def calculate_inverse_cumulative_probability(self, path, interdiction_probabilities):
        cumulative_probabilities = {path[0]: 1}  # Start with depot having a cumulative probability of 1
        for i in range(1, len(path)):
            cumulative_probabilities[path[i]] = cumulative_probabilities[path[i-1]] * interdiction_probabilities[path[i-1]][path[i]]
        inverse_cumulative_probabilities = {node: 1/prob for node, prob in cumulative_probabilities.items() if prob != 0}
        return inverse_cumulative_probabilities

    def calculate_revised_demands_for_routes(self, routes, demands, interdiction_probabilities):
        all_revised_demands = []
        for route, demand_serviced in zip(routes, demands):
            # Calculate inverse cumulative probabilities for the route
            inverse_cumulative_probabilities = self.calculate_inverse_cumulative_probability(route, interdiction_probabilities)
            
            # Calculate revised demands
            revised_demands = {}
            for node, demand in demand_serviced.items():
                if node in inverse_cumulative_probabilities:
                    revised_demands[node] = demand * inverse_cumulative_probabilities[node]
            
            all_revised_demands.append(revised_demands)
        
        return all_revised_demands
    
    def calculate_cumulative_probabilities_for_routes(self, routes, interdiction_probabilities):
        # Ensure that 'routes' is always a list of lists
        if not isinstance(routes[0], list):
            routes = [routes]  # Wrap it in another list if it's not already a list of lists
        
        all_cumulative_probabilities = []
        for path in routes:
            cumulative_probabilities = {path[0]: 1}  # Start with depot having a cumulative probability of 1
            for i in range(1, len(path)):
                # Compute cumulative probability for the current node on the path
                cumulative_probabilities[path[i]] = cumulative_probabilities[path[i-1]] * interdiction_probabilities[path[i-1]][path[i]]
            # Append the calculated cumulative probabilities for this route to the list
            all_cumulative_probabilities.append(cumulative_probabilities)
        return all_cumulative_probabilities
    
    def is_matrix_uniform(self, interdiction_probabilities):
        """Check if the interdiction matrix has all elements as 1."""
        for row in interdiction_probabilities:
            for prob in row:
                if prob != 1:
                    return False
        return True

    
    def calculate_expected_demand_serviced(self, revised_demands, cumulative_probabilities):
    # Dictionary to store the expected demand serviced by each customer
        expected_demand_serviced = {}
        
        # Process each route's data
        for revised, probabilities in zip(revised_demands, cumulative_probabilities):
            for node in revised:
                if node in probabilities:
                    # Calculate expected demand for the node
                    expected_demand = revised[node] * probabilities[node]
                    
                    # Add to existing demand if node appears in multiple routes
                    if node in expected_demand_serviced:
                        expected_demand_serviced[node] += expected_demand
                    else:
                        expected_demand_serviced[node] = expected_demand
        #expected_demand_serviced = {key: value + 1e-10 for key, value in expected_demand_serviced.items()}
        expected_demand_serviced = {key: round(value,2) for key, value in expected_demand_serviced.items()}
        return expected_demand_serviced
    

    def is_square_and_dimensions(self, matrix):
        # Determine the number of rows
        num_rows = len(matrix)
        
        # Determine if all rows have the same length as the number of rows (i.e., it's a square matrix)
        is_square = all(len(row) == num_rows for row in matrix)
        
        # Dimensions are given by the number of rows and the number of columns (assuming it's a square)
        dimensions = (num_rows, num_rows if is_square else None)  # Set columns to None if it's not a square
        
        return is_square, dimensions
    
    def generate_intr_matrix(self, n, a, b):
        # Generate the upper triangle of the matrix with random numbers between min and max
        upper_triangle = np.triu(np.random.uniform(a, b, (n, n)), 1)

        # Create the symmetric matrix by adding the transpose of the upper triangle to itself and the diagonal as 1
        matrix = upper_triangle + upper_triangle.T + np.eye(n)

        # Convert numpy array to a list of lists
        interdiction_probabilities = matrix.tolist()
        return interdiction_probabilities
    
    def is_all_ones(self, matrix, tolerance=1e-9):
        for row in matrix:
            for value in row:
                if abs(value - 1.0) > tolerance:
                    return False
        return True

    def grasp(self):
        start_time = time.time()
        best_routes = None
        best_route_demands = None
        best_cost = float('inf')
        no_improvement_counter = 0
        potential_solution_counter = 0
        sl = 'No'
        if self.int_prob is not None:
            is_square, dimensions = self.is_square_and_dimensions(self.int_prob)
            if dimensions[0] == dimensions [1] and dimensions[0] == num_customers+1:
                interdiction_probabilities = self.int_prob
                print("Interdiction Probabilities: ",interdiction_probabilities)
            else:
                print("The manual interdiction probabilities matrix does not have the right dimensions for this problem")
                print("It was replaced by a matrix full of 1's") 
                interdiction_probabilities = self.generate_intr_matrix(num_customers+1, 1.0, 1.0)
                print(interdiction_probabilities)
        else:
            interdiction_probabilities = self.generate_intr_matrix(num_customers+1, self.min_prob_matrix, self.max_prob_matrix)
            print(interdiction_probabilities)

        tier_1_it = round(self.iterations/3,0)
        tier_2_it = round(self.iterations*2/3,0)
        

        for iter_num in range(self.iterations):
            if iter_num != 0 and iter_num >= self.reintegrate_it:
                # Reintegrate the saved initial solution
                routes, route_demands, remaining_demands = self.construct_solution(reintegrate=True)
                
            else:
                # Normal solution generation
                routes, route_demands, remaining_demands = self.construct_solution()
                
            # print("ENTERING LOCAL SEARCH")
            routes, route_demands = self.local_search(routes, route_demands, interdiction_probabilities, iter_num, tier_1_it, tier_2_it)
            
            revised_demands = self.calculate_revised_demands_for_routes(routes, route_demands, interdiction_probabilities)
            all_cumulative_probabilities = self.calculate_cumulative_probabilities_for_routes(routes, interdiction_probabilities)
            
            input_demands = demands
            
            

            result_matrix = self.is_all_ones(interdiction_probabilities)
            
            if result_matrix is True:
                result_f, message = self.check_sdvrp_feasibility(routes, route_demands, demands, num_vehicles, vehicle_capacity)
                print("This is a candidate for SDVRP")
            elif result_matrix is False:
                expected_demands = self.calculate_expected_demand_serviced(revised_demands, all_cumulative_probabilities)
                result_f, message = self.check_vrpi_feasibility(routes, revised_demands, expected_demands, demands, num_vehicles, vehicle_capacity)
                print("This is a candidate for VRPI")

            

            if result_f is False:
                message2, routes, route_demands = self.generate_combinations(routes, route_demands, self.threshold_increment, interdiction_probabilities, input_demands)
                print("Message 2: ", message2)
                # if message == "we have a candidate":
                if message2 == "we have a candidate":
                    result_f = True
                    revised_demands = route_demands
                else:
                    result_f = False
                    revised_demands = revised_demands
            else:
                print("No need to generate combinations")
                
            

            split_deliveries = self.count_split_deliveries(routes, revised_demands)
            cost = sum(self.route_cost(route) for route in routes) + split_deliveries * self.split_penalty
            print("Iteration: ", iter_num, ". Cost: ", cost)
            #print((cost/known-1), '-->', thres)
            div = round(self.iterations/12,0)
            if (iter_num+1) % div == 0:
                print('Iteration # ', iter_num+1, ' out of ', self.iterations,
                  ' (', round((iter_num+1)/self.iterations,2)*100, '%)')
                print('Elapsed time: ', round(time.time() - start_time,0), ' seconds.')

            if ((cost < known) and (result_f is True or message2 == "we have a candidate")) or (((cost/known-1) <= thres) and (result_f is True or message2 == "we have a candidate")):
            #if (cost < known) or (((cost/known-1) <= thres)):
                #print('True: ', (cost/known-1) )
                improvement_time = time.time() - start_time
                trigger = cost/known-1
                best_cost = cost
                best_routes = routes
                best_route_demands = revised_demands
                potential_solution_counter += 1
                if cost < known and result_f is True:
                    print("Early finish, best cost found was lower than known value. Best cost: ", best_cost, ", and known cost is: ", known)
                else:
                    print("Early finish, difference between known value and best cost was: ", str(trigger*100)+'%',
                 ', which is less than the threshold: ', str(thres*100)+'%')
                break
            #print("Cost is ",cost, ", and Best Cost is ", best_cost)
            if cost < best_cost and (result_f is True or message2 == "we have a candidate"):
                improvement_time = time.time() - start_time
                best_cost = cost
                best_routes = routes
                best_route_demands = revised_demands
                no_improvement_counter = 0
                potential_solution_counter += 1
            else:
                no_improvement_counter += 1

            if no_improvement_counter == int(self.iterations * pert_ct):
                self.perturb(routes)

            if no_improvement_counter >= self.stagnation_limit:
                print("Early termination due to stagnation.")
                sl = 'Yes'
                break

        finish_time = time.time() - start_time

        
        if potential_solution_counter >0:
            improvement_time = improvement_time
        else:
            improvement_time = 1e20
            best_routes = "NA"
            best_cost = "NA"
            best_route_demands = "NA"
            remaining_demands = "NA"

    

        return best_routes, best_cost, best_route_demands, remaining_demands, improvement_time, finish_time, sl

    def perturb(self, routes):
        k = int(self.number_customers * self.perturb_percentage)
        perturbed_customers = random.sample(range(1, self.number_customers + 1), k)
        #print('pert customers',perturbed_customers)

        for customer in perturbed_customers:
            for route in routes:
                if customer in route:
                    route.remove(customer)

        for customer in perturbed_customers:
            insertion_route = random.choice(routes)
            insertion_position = random.randint(1, len(insertion_route) - 1)
            #print('inst route', insertion_route)
            #print('inst pos', insertion_position)
            insertion_route.insert(insertion_position, customer)


    def print_results(self, best_routes, best_cost, best_route_demands, remaining_demands):
        for i, route in enumerate(best_routes):
            print(f"Route {i + 1}: {' -> '.join(map(str, route))}")
            print(f"Cost: {self.route_cost(route):.2f}")

        print("Total cost:", best_cost)

        print("\nServiced demands for each route:")
        #print("Best routes demands: ",best_route_demands)
        for i, demands_dict in enumerate(best_route_demands):
            print(f"Route {i + 1} Total Demand Serviced: {sum(demands_dict.values())}")
            for customer in best_routes[i][1:-1]:
                if customer in demands_dict:
                    print(f"   Customer {customer}: {demands_dict[customer]}")

        print("\nCustomers with split delivery:")

        split_deliveries = {}
        for i, demands_dict in enumerate(best_route_demands):
            for customer, demand in demands_dict.items():
                if customer not in split_deliveries:
                    split_deliveries[customer] = []
                split_deliveries[customer].append((best_routes[i], demand))

        for customer, deliveries in split_deliveries.items():
            if len(deliveries) > 1:
                print(f"  Customer {customer}:")
                for delivery in deliveries:
                    route_str = " -> ".join(map(str, delivery[0]))
                    print(f"    Demand serviced by route ({route_str}): {delivery[1]}")

        # Identify and print customers who were not served (either partially or totally)
        print("\nCustomers not served or partially served:")
        for customer_id, rem_demand in enumerate(remaining_demands):
            if rem_demand > 0 and customer_id != 0:  # Exclude the depot with customer_id = 0
                print(f"  Customer {customer_id}: Unserved Demand {rem_demand}")

        # Count clients with split delivery
        split_clients = [cust for cust, deliveries in split_deliveries.items() if len(deliveries) > 1]
        num_split_clients = len(split_clients)

        # Count total clients and clients without split delivery
        total_clients = self.number_customers
        num_non_split_clients = total_clients - num_split_clients

        return num_split_clients, num_non_split_clients, total_clients

    def run(self):
        best_routes, best_cost, best_route_demands, remaining_demands, improvement_time, finish_time, sl = self.grasp()
        if best_routes == "NA":
            num_split_clients = "NA"
            num_non_split_clients = "NA"
            total_clients = "NA"
            solution = "We did not find a feasible solution"
        else:
            num_split_clients, num_non_split_clients, total_clients = self.print_results(best_routes, best_cost, best_route_demands, remaining_demands)
            solution = "We found a feasible solution"

        print(f"\nNumber of clients with split deliveries: {num_split_clients}")
        print(f"Number of clients without split deliveries: {num_non_split_clients}")
        print(f"Total number of clients: {total_clients}")

        return best_cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution  # Ensure you return the best_cost along with the counts
    
    # Wrapper function to run the VRP run method
    def run_vrp(self, queue, num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf):
        vrp = VRP(num_vehicles=num_vehicles, num_customers=num_customers, locations=locations, demands=demands, vehicle_capacity=vehicle_capacity, rcl_factor=rcl, iterations=it, local_search_option= lso, stagnation_limit=stg, perturb_percentage=prt, split_penalty= pl, sdd = sed, reintegrate_it=reit, split_sol= sps, min_prob_matrix= min_nint, max_prob_matrix= max_nint, int_prob = iprob, threshold_increment = ith, optimization_solution_finder = osf)
        result = vrp.run()
        queue.put(result)

    # Function to run with a timeout
    def run_with_timeout(self, target, timeout, args):
        queue = Queue()
        thread = threading.Thread(target=target, args=(queue, *args))
        thread.start()
        thread.join(timeout)
        if thread.is_alive():
            print(f"Code execution exceeded {timeout} seconds and was terminated.")
            return None
        try:
            return queue.get_nowait()
        except Empty:
            return None

# %% [markdown]
# Setting Parameters and Running

# %% [markdown]
# Interdiction Probability Matrix

# %%
iprob1 =[[1.0,
  0.9507679535949476,
  0.9171009531226609,
  0.9816929252010751,
  0.9556031383837665,
  0.9119915331443227,
  0.9686085611421599,
  0.9404912632070668,
  0.9793768398982458,
  0.9145446609142734,
  0.9222895634918089,
  0.9233556411534923,
  0.9605759499366471,
  0.9389023090852183,
  0.9738191058696316,
  0.9329665288561366,
  0.9734051928422213,
  0.9814347642098326,
  0.9053115218539525,
  0.969547716443647,
  0.9736094840670293,
  0.9818346933236656,
  0.9051386494708944,
  0.9080345461646157,
  0.9477124125489895,
  0.9054380000443489,
  0.908945043426306,
  0.9710528534934019,
  0.9575770991397257,
  0.9097881238682727,
  0.9327654549911849,
  0.9760133937241467,
  0.9340064716575198,
  0.9450098846028525,
  0.9170790724049441,
  0.9533083877322311,
  0.944362216333655,
  0.9174397639787502,
  0.9682302046709592,
  0.9488748594634031,
  0.9249094594856685,
  0.9782960234441811,
  0.9492841523475114,
  0.9581481149636056,
  0.9894381485426307,
  0.9058649423758312,
  0.9845333486395769,
  0.9850692661904662,
  0.9754081333453845,
  0.9764157082837631,
  0.9878151664178915,
  0.9552459472516684,
  0.955635909837696,
  0.921841973333169,
  0.9034800161729732,
  0.9584335557969397,
  0.9110312953641584,
  0.9294602186419905,
  0.9684218598724614,
  0.9704039194467989,
  0.9060093497770917,
  0.903804444878008,
  0.9472258435016989,
  0.9845428460923785,
  0.9660058630717843,
  0.9035740507712138,
  0.921882565300697,
  0.9846667314238203,
  0.9268993980003662,
  0.9004409161068476,
  0.9520208786210711,
  0.920529974243873,
  0.9014916880800823,
  0.9383760747475616,
  0.9207211559760083,
  0.9224474642052818,
  0.9522928188114389,
  0.9199961525121685,
  0.9632044157114901,
  0.9491542612356813,
  0.9337984090384096,
  0.9484291964555271,
  0.9846609414768962,
  0.9104546030167203,
  0.9837140385340799,
  0.9291905123876091,
  0.986081161031118,
  0.915232467599517,
  0.9197834845596761,
  0.9688850176606381,
  0.9564990944102124,
  0.969961532534186,
  0.9489810228663218,
  0.9592214752534944,
  0.9394374916621978,
  0.9746635307179137,
  0.9875432694044755,
  0.9749877834724527,
  0.9187018485443904,
  0.9169419557537821,
  0.9247271830715339],
 [0.9507679535949476,
  1.0,
  0.9685950337938571,
  0.9573520721917992,
  0.9575558724659508,
  0.9144397036715619,
  0.9477018150408755,
  0.9821546626190931,
  0.9216587824209882,
  0.9351787507316575,
  0.9158265732008772,
  0.9424233101007662,
  0.9663802205910321,
  0.9748306908705733,
  0.9142280532555729,
  0.9236293232129404,
  0.9519579346967463,
  0.939443953487365,
  0.9528069207053046,
  0.9868853706921605,
  0.9640232486049262,
  0.9182021259290959,
  0.9781750209121028,
  0.9034498942071563,
  0.9012096878951947,
  0.9048796018721996,
  0.9612733570909032,
  0.9704542041943749,
  0.9013043801734549,
  0.9658791461024384,
  0.9646971798618564,
  0.9274730452211477,
  0.980040298810096,
  0.9849486056522327,
  0.94910414198058,
  0.9631469962829345,
  0.9610991450513616,
  0.9898299901371567,
  0.9103626405245295,
  0.963422498101482,
  0.9729979692440585,
  0.9780886712626243,
  0.9013454116168588,
  0.9150019712881291,
  0.9151414691052862,
  0.9229226728629186,
  0.9211276218133329,
  0.9456295020608955,
  0.9060945870733594,
  0.9829866726269613,
  0.9149204067248345,
  0.9842634613387651,
  0.987775993972614,
  0.9874464334687996,
  0.9484647766270315,
  0.912685620611116,
  0.9768327010735213,
  0.9047837041138609,
  0.9103712307086982,
  0.9591023014656332,
  0.9837427076997235,
  0.9231851206424307,
  0.9335610605655829,
  0.9567471276673094,
  0.9817350012183479,
  0.9113020210777063,
  0.960600489660732,
  0.97536700033498,
  0.9889135341850649,
  0.9766113099611357,
  0.9671525122462152,
  0.9297399580321839,
  0.9141226593018361,
  0.9701726265057271,
  0.9027885926999124,
  0.9779636257905121,
  0.9620240999325361,
  0.9479440166369044,
  0.9468702029322017,
  0.9554307151114116,
  0.9040827500385848,
  0.9673668404459292,
  0.9210423368590352,
  0.9210675966330805,
  0.9483937372430169,
  0.9781771252696233,
  0.9157690587671056,
  0.9530568742319269,
  0.9838542591840752,
  0.9022113693025251,
  0.9830014938144935,
  0.9456415452699569,
  0.9705002514715124,
  0.9622104038780451,
  0.9139227733076694,
  0.9052512048298385,
  0.9650552874307947,
  0.9710152660824791,
  0.9600075381184601,
  0.9089848178817389,
  0.9005337438623175],
 [0.9171009531226609,
  0.9685950337938571,
  1.0,
  0.9580327292491851,
  0.9524337006062189,
  0.9493122268348286,
  0.9852141898765279,
  0.9015218159874225,
  0.9277016985228568,
  0.9798056051598,
  0.9898489575291664,
  0.9294007450709355,
  0.9279642185888454,
  0.9869893555078737,
  0.9497560673892644,
  0.9716563553789683,
  0.957356087130623,
  0.9028981364976314,
  0.9686448583107592,
  0.9079809658392768,
  0.9091885091815298,
  0.9583957674560178,
  0.956517596913375,
  0.9178468517097379,
  0.9501009810078471,
  0.9422443866792732,
  0.9444441424188258,
  0.9452904009422247,
  0.971071769442789,
  0.9298254391076906,
  0.9109571387785705,
  0.9719828617400531,
  0.9210874517460196,
  0.9205787965687502,
  0.9084441903679303,
  0.9500506283660276,
  0.91837608317463,
  0.9549743536232109,
  0.9253006479093149,
  0.9145263390701027,
  0.91799951906019,
  0.9567405624676072,
  0.9849601927621102,
  0.9790453575916935,
  0.9391067921596826,
  0.9813929833940949,
  0.9153856974313589,
  0.9217551607832569,
  0.9118961598979952,
  0.9118816328948072,
  0.9212447223693084,
  0.9499258691176985,
  0.9862114039277184,
  0.9142094835121425,
  0.9671127552902905,
  0.9711427631405136,
  0.9753592822394052,
  0.9507674239516807,
  0.9615260171235637,
  0.9717175428782927,
  0.905610234295763,
  0.9073679886376456,
  0.9515587569323476,
  0.9198998396344072,
  0.9791252675971364,
  0.9758048378164754,
  0.9677104674204046,
  0.9119597024698604,
  0.932766716491513,
  0.9048852689284461,
  0.9001607922923942,
  0.9264358550640237,
  0.9152947987378248,
  0.9024386151391303,
  0.9061756677960288,
  0.9081997342899152,
  0.9373906164533262,
  0.9872880272549558,
  0.9485632208318525,
  0.9293792382472923,
  0.9437450466602555,
  0.9130148580787044,
  0.9409353410196135,
  0.9577292704481413,
  0.9433029530319824,
  0.9513039091272953,
  0.954332050416287,
  0.9295552211319354,
  0.9548394050351378,
  0.9529639991404897,
  0.9720439492666926,
  0.9834240546246776,
  0.9252675228855638,
  0.9082172150910793,
  0.9198488844281028,
  0.9667101260440565,
  0.9275926054229632,
  0.9794632014532665,
  0.9416492140091738,
  0.9337638599494841,
  0.9474936754328233],
 [0.9816929252010751,
  0.9573520721917992,
  0.9580327292491851,
  1.0,
  0.9425821725900646,
  0.9315632929533326,
  0.9779314856994513,
  0.9309787278783571,
  0.9427094482972435,
  0.9449380980008354,
  0.9057034647854525,
  0.9027413611672136,
  0.9776204251324813,
  0.940844100589605,
  0.9265217506795237,
  0.9076101298840475,
  0.9071567500439668,
  0.9348694534160109,
  0.9573601546954871,
  0.9299483090391187,
  0.9485586822160303,
  0.9116004047542408,
  0.9666243094182912,
  0.9852685368163906,
  0.9161597622805658,
  0.982760990202555,
  0.9896424248801095,
  0.9427619149314074,
  0.9218498742888964,
  0.9234359271669259,
  0.9821190848073885,
  0.9627412851237064,
  0.9221584145567172,
  0.9641184165214987,
  0.9422651115073315,
  0.9228959368391452,
  0.971437437845309,
  0.9423095567457448,
  0.9457362031483681,
  0.9890727866594056,
  0.9894204293984115,
  0.9062091125176988,
  0.9886921037426198,
  0.9236507800705153,
  0.9833008260002537,
  0.9629426464721298,
  0.922228499882775,
  0.9171160389790285,
  0.977923361982207,
  0.9220456597801203,
  0.9869168078927089,
  0.9003411933934643,
  0.9822825451375078,
  0.9095313694165815,
  0.9778531272684624,
  0.9091811790913628,
  0.9723954894720844,
  0.9112180417438788,
  0.9383258392226326,
  0.9181214797634507,
  0.9284200624486754,
  0.9260739202812406,
  0.9161822265529403,
  0.9005509563483051,
  0.9198480721575102,
  0.9687359961024435,
  0.9564192992115033,
  0.929704478655797,
  0.9671636923944399,
  0.9577439210253087,
  0.9265257925670599,
  0.9151275443497547,
  0.9423689113805728,
  0.96480892824423,
  0.9212798969026689,
  0.9206253067684917,
  0.9336880019099314,
  0.9383216246771582,
  0.9730465866243213,
  0.986242467041733,
  0.9856255324050301,
  0.9180899057703888,
  0.9226247847468302,
  0.9221934131949906,
  0.9049783209673271,
  0.9773556405528409,
  0.9113874833823531,
  0.9377111091567681,
  0.957602051471542,
  0.9884613668974102,
  0.9852446561192079,
  0.95346482865546,
  0.9419224896898969,
  0.9510585858234081,
  0.9422342113196825,
  0.9708547729912261,
  0.9663861354478775,
  0.9674099196587453,
  0.9180976439309915,
  0.902430063076905,
  0.9048691949312988],
 [0.9556031383837665,
  0.9575558724659508,
  0.9524337006062189,
  0.9425821725900646,
  1.0,
  0.9681638896776911,
  0.9185500290607711,
  0.926624612824625,
  0.9240129322999189,
  0.934423504923304,
  0.9552224760085367,
  0.9510768037612823,
  0.9053067039194975,
  0.9069575360743056,
  0.9737624137204715,
  0.9510293881494004,
  0.9564972383941317,
  0.9154173423486619,
  0.9140301812142803,
  0.9235165638618998,
  0.9243649958347302,
  0.9096443915796174,
  0.9532466043370578,
  0.9190587775003183,
  0.91634701231457,
  0.9326326160327065,
  0.9610190137150839,
  0.963879300541458,
  0.9422184062923844,
  0.9677691644903007,
  0.9695707198809272,
  0.9339259719329717,
  0.9050087273886931,
  0.9681906357219405,
  0.914581543598181,
  0.9720723738034187,
  0.9756596926287093,
  0.9455205588400628,
  0.9583382371170203,
  0.97973658730127,
  0.9117207003424288,
  0.9797346729303322,
  0.9635739293268811,
  0.9682246560257461,
  0.9770263607581904,
  0.961593674872201,
  0.9039531719904984,
  0.9066967224735507,
  0.9262906805129815,
  0.9768756189337748,
  0.9023521750069099,
  0.9823515971772948,
  0.9183794696844674,
  0.9023603030737111,
  0.9824823798180882,
  0.9170402649613297,
  0.9064917806325253,
  0.9864970338768195,
  0.9342213117089339,
  0.9423510632301931,
  0.9115519609143249,
  0.9599181240723957,
  0.9377763889084434,
  0.9261539962693213,
  0.9238589056494474,
  0.9751668256090502,
  0.9351958489324155,
  0.9713518186558754,
  0.9387992629957871,
  0.9131015574098298,
  0.9540231084958383,
  0.9091394625860935,
  0.9390155126312201,
  0.9142356381473113,
  0.9231794639908991,
  0.9746291208750921,
  0.9883022716043659,
  0.9110791584650055,
  0.9438891134124272,
  0.9113553033450963,
  0.9582324018486614,
  0.9311885979750019,
  0.9526287185555448,
  0.9653198681988948,
  0.9804401222534213,
  0.9388396957976104,
  0.9407027296702644,
  0.9317919224042623,
  0.9139198754743347,
  0.9108342942078465,
  0.9533609796960338,
  0.9672191181244569,
  0.9467804489650743,
  0.9121730211585821,
  0.9112913818662507,
  0.9784594035800734,
  0.9734914809782923,
  0.9208954980685825,
  0.9431787048581922,
  0.9583641046553162,
  0.9184994137978334],
 [0.9119915331443227,
  0.9144397036715619,
  0.9493122268348286,
  0.9315632929533326,
  0.9681638896776911,
  1.0,
  0.9738860780475094,
  0.9896248790837169,
  0.9126810516917617,
  0.9039232087769224,
  0.9897252817247676,
  0.9772507901065239,
  0.9770485055240478,
  0.9752851218689548,
  0.9665296024004181,
  0.9800264932862615,
  0.9582795624174147,
  0.9652085698605304,
  0.9606717688732676,
  0.9154394073691249,
  0.9689350347796976,
  0.9054291914125326,
  0.9651984036900979,
  0.9811089505715891,
  0.9174318427485537,
  0.9341582178154713,
  0.948643426818457,
  0.9463676093104898,
  0.9413050943890464,
  0.9162168239419658,
  0.9800447722255011,
  0.9817736968761938,
  0.9301474860773009,
  0.9841749951943738,
  0.9518762596636177,
  0.9284472867778586,
  0.9644938234220056,
  0.9582928121809388,
  0.9050443252102934,
  0.9768499065231186,
  0.9515724807467428,
  0.9326846790686593,
  0.9716779601447143,
  0.9553464471341679,
  0.9713314843729914,
  0.9646139984352479,
  0.9372769155161923,
  0.9051541205601654,
  0.9158384705773109,
  0.93386171306787,
  0.9182272599078273,
  0.9344367010616074,
  0.9871465933450522,
  0.9020051209928865,
  0.9150707885310018,
  0.9065859665210574,
  0.9219157379627366,
  0.9815913536146591,
  0.9515615364087473,
  0.925704790769791,
  0.9866955961453625,
  0.9146534522901809,
  0.9135066894448596,
  0.9019794546948293,
  0.9795898012505801,
  0.9066389911365658,
  0.9031557818206761,
  0.9681246333114856,
  0.9006915287211226,
  0.9279523036702522,
  0.9011693596172063,
  0.9108875338259299,
  0.9003386051718733,
  0.9428252987386015,
  0.9476867918598955,
  0.94784689238068,
  0.9265576708111933,
  0.9786340817816828,
  0.9813811561624751,
  0.9710091031200823,
  0.9202244497934501,
  0.9823363478576825,
  0.9394610206325801,
  0.9662518197929026,
  0.9285701188769739,
  0.9587361913614733,
  0.9366547224083744,
  0.9396697665140386,
  0.9211599876320072,
  0.9144610480776421,
  0.9275317936627363,
  0.9625264002165742,
  0.9164523861060092,
  0.961451995304374,
  0.9697556902254334,
  0.9578876426634878,
  0.9706080772443023,
  0.9894108579487654,
  0.9823420510488757,
  0.9304266836861865,
  0.9379357337277883],
 [0.9686085611421599,
  0.9477018150408755,
  0.9852141898765279,
  0.9779314856994513,
  0.9185500290607711,
  0.9738860780475094,
  1.0,
  0.9362554232310046,
  0.9087012292880878,
  0.9337958138699078,
  0.9300741584663934,
  0.9098812936565261,
  0.9632850981753748,
  0.9482364411556582,
  0.9676455217389299,
  0.9362169631474279,
  0.9378097746936687,
  0.9128776036592458,
  0.9633106382565568,
  0.936866413556033,
  0.9370581618745443,
  0.9039110220177523,
  0.9570163052510152,
  0.9605061333642251,
  0.9894757169042954,
  0.923702963641654,
  0.9753762761820293,
  0.9762235297584606,
  0.9896769281923252,
  0.9814914740676662,
  0.9569953710854686,
  0.9868436486315141,
  0.9062095312009385,
  0.9602824530910115,
  0.9657136739747169,
  0.9657342277586229,
  0.916389904472661,
  0.9022017642001472,
  0.9199649059296433,
  0.9186238092067197,
  0.9580236515970312,
  0.915345139746792,
  0.9474366827210018,
  0.938172809392428,
  0.9246992378116999,
  0.9258581375790175,
  0.9762491314130113,
  0.9860441226268034,
  0.931642610525704,
  0.9080412364954606,
  0.9286681609016767,
  0.9896601131303604,
  0.9725301530103764,
  0.9571547791614186,
  0.9653682834231404,
  0.9749873998064194,
  0.9671757463739045,
  0.9728863899797361,
  0.9183142749221068,
  0.9192954502885795,
  0.9009877385097945,
  0.9103208214660502,
  0.9034773170817848,
  0.9591442686573103,
  0.9350582892607129,
  0.9228800291272228,
  0.9805583273983066,
  0.9714006117215237,
  0.9502515406873407,
  0.9628923140035653,
  0.9469136974667663,
  0.9151149473335013,
  0.9107871783133793,
  0.9453303935582661,
  0.9834587191374877,
  0.9315995871595166,
  0.9101504135120534,
  0.9562678676286002,
  0.9617000540968607,
  0.9217858915974388,
  0.9396462786454763,
  0.9689218096163301,
  0.944193134007439,
  0.9857393820832754,
  0.9081114669261903,
  0.9179277611222224,
  0.9749206115663465,
  0.9634296829049244,
  0.926920786641035,
  0.9311243781398391,
  0.9212472182668917,
  0.9457515797808117,
  0.9223843377813329,
  0.961458082596444,
  0.9638502669405773,
  0.9713894824003098,
  0.9755077459677062,
  0.9384260300600941,
  0.9786974327474048,
  0.9158296688084018,
  0.9615644918557574],
 [0.9404912632070668,
  0.9821546626190931,
  0.9015218159874225,
  0.9309787278783571,
  0.926624612824625,
  0.9896248790837169,
  0.9362554232310046,
  1.0,
  0.950808464203737,
  0.9746015696154177,
  0.9412500638720008,
  0.9443612524079201,
  0.9084608152017325,
  0.9257863005059687,
  0.9248616121376831,
  0.9299544375565255,
  0.9574719242901792,
  0.9221098355632779,
  0.978756467503872,
  0.96157593357224,
  0.9822669508630637,
  0.9457212038622174,
  0.9002518672749799,
  0.9878366917084107,
  0.9620572311394519,
  0.9476568797691075,
  0.9473229211213705,
  0.918506257218007,
  0.9006399829470806,
  0.9887766553117238,
  0.9107058421161262,
  0.9369703005421939,
  0.9505584009916596,
  0.9060132084020885,
  0.9758142194964848,
  0.9681153908728678,
  0.9356789571004216,
  0.901634498035805,
  0.9746565506177122,
  0.9779960353453423,
  0.9271945377983373,
  0.9742302537150359,
  0.952445973746511,
  0.9018403428950181,
  0.9385962429943434,
  0.9393526006284,
  0.9573800899844416,
  0.9269860589483515,
  0.9452000459708917,
  0.9858425444847976,
  0.9677565861866433,
  0.9423977484478979,
  0.9882449938020559,
  0.983271265381192,
  0.9807914550588809,
  0.9070955181247258,
  0.9897883669720098,
  0.9832160033989725,
  0.9033839914716351,
  0.9439806141782093,
  0.9796177481873043,
  0.9809196260395019,
  0.9096159373030192,
  0.9350906789301028,
  0.9450075098446773,
  0.9875487741567925,
  0.9217302720697675,
  0.9315476485927286,
  0.9120012207392345,
  0.9016288815172862,
  0.9662458602320306,
  0.9757931437088018,
  0.978124796947596,
  0.9277440455704472,
  0.9840450203575659,
  0.9081140020871284,
  0.967134051655747,
  0.9238542919728423,
  0.9345327097560583,
  0.9110728305469357,
  0.9255235569913431,
  0.9419511953108008,
  0.9563258050852578,
  0.9157470478798622,
  0.9626837524582719,
  0.9375588646533515,
  0.9345842593255442,
  0.9140164878242837,
  0.910795918033516,
  0.9295550828434405,
  0.926360665187761,
  0.9493895908474382,
  0.9599806706163636,
  0.9725866991881403,
  0.9416063517819685,
  0.9765232539323693,
  0.9764084368461006,
  0.9622159237419832,
  0.9755725508403259,
  0.9705474331723195,
  0.9615439009296021],
 [0.9793768398982458,
  0.9216587824209882,
  0.9277016985228568,
  0.9427094482972435,
  0.9240129322999189,
  0.9126810516917617,
  0.9087012292880878,
  0.950808464203737,
  1.0,
  0.9028912406124414,
  0.9565274477263714,
  0.9242915346763327,
  0.9639746376078266,
  0.9690166937334714,
  0.9021952267209532,
  0.9121117857658484,
  0.977142985395195,
  0.927109662089134,
  0.9416584840218405,
  0.9831468755478157,
  0.9094544991811673,
  0.9512174163897218,
  0.9769285481061646,
  0.9863923510425361,
  0.9679302978378224,
  0.9893100150815382,
  0.9332493065165902,
  0.9131531763342794,
  0.9512331240364118,
  0.9250632687068817,
  0.9757145832759772,
  0.9289952498557542,
  0.9226535256301345,
  0.9449077140924528,
  0.9200287888284219,
  0.9791517294991658,
  0.9319357522089441,
  0.9745891852527221,
  0.9074685983670032,
  0.9702989247579388,
  0.9038878832354588,
  0.9134385637350376,
  0.9341385871926172,
  0.914759124800901,
  0.9558423350201288,
  0.9549772169176806,
  0.9760656712238863,
  0.9228966223020122,
  0.9377432321891607,
  0.967008252883598,
  0.9307444869704902,
  0.9286099014332403,
  0.9046030341667046,
  0.9509280750188817,
  0.9320635847709857,
  0.9759859807746256,
  0.9242047049282516,
  0.9357611860378588,
  0.9677980261519437,
  0.939877719848343,
  0.9055900113320402,
  0.9447564363692482,
  0.9676254205560161,
  0.9730211300594441,
  0.9464975267169952,
  0.950241693376005,
  0.9425171000972773,
  0.9503763997844038,
  0.9616845711174578,
  0.9316512635149284,
  0.9517753392536629,
  0.9176414584372817,
  0.9164079169959609,
  0.9607873424103748,
  0.9029134673365237,
  0.9355860302202691,
  0.9719422966380592,
  0.9464736027560853,
  0.924158425430106,
  0.9312611966249718,
  0.9262873922048747,
  0.9370998934510114,
  0.9046475684138413,
  0.9508717441179884,
  0.9313788433936824,
  0.9001879019906361,
  0.9270681853403947,
  0.9882627652678686,
  0.9798222939597364,
  0.9005416168014148,
  0.9685449130335967,
  0.9447634939028591,
  0.9814800905985602,
  0.9372285402879951,
  0.9197042379762259,
  0.9592997177688566,
  0.9866264019677111,
  0.9568830922482185,
  0.9866320722265403,
  0.9552716220126036,
  0.9338417013012185],
 [0.9145446609142734,
  0.9351787507316575,
  0.9798056051598,
  0.9449380980008354,
  0.934423504923304,
  0.9039232087769224,
  0.9337958138699078,
  0.9746015696154177,
  0.9028912406124414,
  1.0,
  0.9006152838183318,
  0.9061459399438013,
  0.9271064875118166,
  0.9302791401361634,
  0.9406124534532364,
  0.9428675965560501,
  0.9203682751477305,
  0.9754412428768304,
  0.9216880839070932,
  0.9777862925934742,
  0.9035359370499098,
  0.9279754919703016,
  0.9003569259864178,
  0.9832902688986745,
  0.9185607668871878,
  0.9776282204395277,
  0.9634768148130531,
  0.9624449099740828,
  0.9853224310436616,
  0.9573821921961725,
  0.9513599698335375,
  0.9598081175496515,
  0.968670889684958,
  0.9202522651291314,
  0.971304975854325,
  0.9515183565978699,
  0.9783554965811034,
  0.9072604571581975,
  0.9884343159105917,
  0.9090924179904095,
  0.9074405766885866,
  0.9102755551122621,
  0.9010325285224303,
  0.9011668683437973,
  0.9832633003126863,
  0.9400426671315094,
  0.9166484014788134,
  0.922141403164274,
  0.9078660546957482,
  0.968984066362226,
  0.9017937584535801,
  0.9367293035743863,
  0.9136235582737445,
  0.944889552751944,
  0.9405690519047505,
  0.918652189445807,
  0.9274587245393997,
  0.9610825621667651,
  0.9452595810520654,
  0.9801786010329067,
  0.9369052133932714,
  0.9726272084880452,
  0.9102514465696635,
  0.9753255454912997,
  0.958689360071985,
  0.9571879662449745,
  0.9788219030908831,
  0.9754071974760246,
  0.9153027070486183,
  0.9005762701577246,
  0.9141580169966409,
  0.926942468506696,
  0.9831557571096696,
  0.9352235184376305,
  0.9393789635206498,
  0.9413672187993523,
  0.9392186311750882,
  0.9801362638040084,
  0.9246239865509539,
  0.933837716106758,
  0.9449445202098778,
  0.9348103674027415,
  0.9567863914224574,
  0.9402583449587366,
  0.9372047891548749,
  0.9709133247625905,
  0.9122976472996416,
  0.9391340003864534,
  0.9345186489236844,
  0.9308739896132155,
  0.9107132820052632,
  0.912104050183933,
  0.9134025727188986,
  0.9713123798677095,
  0.9705037479047063,
  0.9418294502189787,
  0.9417946715987244,
  0.9148630091254671,
  0.9460647170170281,
  0.9359310438687916,
  0.9504841828158912],
 [0.9222895634918089,
  0.9158265732008772,
  0.9898489575291664,
  0.9057034647854525,
  0.9552224760085367,
  0.9897252817247676,
  0.9300741584663934,
  0.9412500638720008,
  0.9565274477263714,
  0.9006152838183318,
  1.0,
  0.9566374691690099,
  0.9571568751002816,
  0.916151396966687,
  0.90374434676382,
  0.9056176779020021,
  0.915187611380954,
  0.9772948087234191,
  0.9395019385353021,
  0.913866062234469,
  0.940011330886468,
  0.9240762863187955,
  0.9452607045614995,
  0.9252868452418973,
  0.9356631296214298,
  0.9298616759825272,
  0.9284439878726669,
  0.9494336204687823,
  0.9355519481265836,
  0.9770216535977626,
  0.9293675942159906,
  0.9830469295355209,
  0.910579684039958,
  0.9245548971498645,
  0.9595175504225703,
  0.97748044959379,
  0.9635378983632727,
  0.9661152770594729,
  0.9204931396842726,
  0.9343466361886075,
  0.9642163962685404,
  0.9526924145058486,
  0.9089118195911293,
  0.9329376179122547,
  0.9274494437559464,
  0.9666143070943686,
  0.9282756921349592,
  0.9304691383235166,
  0.9356012787933308,
  0.9217172177362424,
  0.9345283881451116,
  0.9359329712385065,
  0.9367244738454993,
  0.9246328869050305,
  0.9011996809291605,
  0.9459813452433076,
  0.9508485185313837,
  0.9466676754175656,
  0.902953305606489,
  0.9169931287401188,
  0.9285308809873263,
  0.9257777025161225,
  0.9504704131645786,
  0.9448379902949215,
  0.9833362521688194,
  0.9180064023376172,
  0.9496246124656673,
  0.928202075286651,
  0.9481786415626828,
  0.9710245961393918,
  0.9647793062549463,
  0.9143718880326491,
  0.9127682917333592,
  0.9148075353351092,
  0.9700309297033196,
  0.9044277297196823,
  0.9317042484482284,
  0.9415625952943784,
  0.9423019515388917,
  0.9247776286910833,
  0.9096398729535121,
  0.9530413277467168,
  0.9731978459818708,
  0.9217444980486076,
  0.9601045607101693,
  0.9243167716777986,
  0.9338501079351269,
  0.9799761234457907,
  0.9574421383181161,
  0.971595675433933,
  0.9578088680491942,
  0.9041571652930454,
  0.9569849613155189,
  0.953159624930583,
  0.9180904900161252,
  0.9893424043119107,
  0.979145281243226,
  0.9708805500916725,
  0.9011703169671622,
  0.9295629235799205,
  0.972497802643929],
 [0.9233556411534923,
  0.9424233101007662,
  0.9294007450709355,
  0.9027413611672136,
  0.9510768037612823,
  0.9772507901065239,
  0.9098812936565261,
  0.9443612524079201,
  0.9242915346763327,
  0.9061459399438013,
  0.9566374691690099,
  1.0,
  0.970645468515617,
  0.984460466296893,
  0.9425774262007143,
  0.9401647945803555,
  0.9286386048097662,
  0.9768806489100823,
  0.9011548706299529,
  0.9340265218459584,
  0.9786356276567357,
  0.9864186818198861,
  0.9771865076397849,
  0.9390625393319197,
  0.9527279336936372,
  0.9237847432410831,
  0.948904603943345,
  0.9271077475884667,
  0.9150730476135466,
  0.91876656235632,
  0.9590191957239278,
  0.9223307940567215,
  0.9771487662015514,
  0.9297686881509604,
  0.9070067961200086,
  0.9403716552443916,
  0.9786906883637714,
  0.957486466925426,
  0.9489471218745817,
  0.9652249896271967,
  0.9431781346138649,
  0.9271052243905187,
  0.9768427968253309,
  0.9788408101105013,
  0.9387738176345293,
  0.9825237963124682,
  0.9021530389161176,
  0.967837435511313,
  0.9043328754167516,
  0.9165912869347973,
  0.9367817076246243,
  0.9410889917775944,
  0.9005570714054841,
  0.9890710731751513,
  0.9058601641163471,
  0.9085763210066644,
  0.9733120603801129,
  0.9761231650631921,
  0.9135514648956435,
  0.9853623099894644,
  0.9396032045925142,
  0.9121958759408761,
  0.9589578468321681,
  0.933296856896945,
  0.982643433039222,
  0.9203035577672971,
  0.9761350408287369,
  0.9847187097459151,
  0.9449055800037474,
  0.9634795828766398,
  0.9300262173937418,
  0.9451168407667827,
  0.9319036343097968,
  0.9021135238336664,
  0.9397905205201161,
  0.9891817237189608,
  0.9830092286359375,
  0.9096722622001644,
  0.9285346670779067,
  0.9580061821367594,
  0.9456254226479763,
  0.9576387599953516,
  0.9694512876921514,
  0.9854621826560133,
  0.9360644283787163,
  0.9090963268614349,
  0.902042972955073,
  0.9512301852630274,
  0.9779139130187506,
  0.9357273636776446,
  0.9779807220275347,
  0.948402779276762,
  0.9534904890397691,
  0.9876833139387285,
  0.9006235065093822,
  0.9799136345092502,
  0.9002173143469614,
  0.941273754888333,
  0.9706503392069625,
  0.9173372137778976,
  0.944486661282334],
 [0.9605759499366471,
  0.9663802205910321,
  0.9279642185888454,
  0.9776204251324813,
  0.9053067039194975,
  0.9770485055240478,
  0.9632850981753748,
  0.9084608152017325,
  0.9639746376078266,
  0.9271064875118166,
  0.9571568751002816,
  0.970645468515617,
  1.0,
  0.930598912819671,
  0.914284004951865,
  0.9720958378242261,
  0.9496070451276468,
  0.9463817978764427,
  0.9595310926128646,
  0.9364532850563088,
  0.9779879258415602,
  0.9789880633694232,
  0.9698671946495215,
  0.9879309260690423,
  0.912107286846636,
  0.9755454463917337,
  0.9222285018406158,
  0.9731109929255668,
  0.9248962913259252,
  0.929189819563263,
  0.96320099902037,
  0.9017167870906576,
  0.9529639781261916,
  0.9003270095367861,
  0.9336630171598072,
  0.9332884270712664,
  0.9347172202711544,
  0.9095704656907776,
  0.9790588011404842,
  0.906994654616203,
  0.9239360424482748,
  0.9051578855278399,
  0.9640776195813542,
  0.9735924241072871,
  0.949544330418693,
  0.9829400216751712,
  0.9657284476935839,
  0.9344611318757099,
  0.9876851123177772,
  0.949497279244488,
  0.9879146332639162,
  0.9776234536214853,
  0.9164438958005574,
  0.9292995689130551,
  0.9213458421791484,
  0.9095090608814712,
  0.964666070991447,
  0.9582096428055503,
  0.9871634935539505,
  0.9228027893576202,
  0.9019858171979469,
  0.9155581482208456,
  0.9228506144525364,
  0.9583438634425494,
  0.9624155354695314,
  0.962899343304684,
  0.9573635884450686,
  0.9245857310001506,
  0.9300088686202396,
  0.9461636399091266,
  0.9070687889196107,
  0.9552951949423124,
  0.9204279421833247,
  0.981565408938178,
  0.9230652909689646,
  0.9473921024485125,
  0.9597032014071897,
  0.9434893298045298,
  0.9758748620859604,
  0.9635565751852145,
  0.9291694097920242,
  0.9172657892733536,
  0.9499269279894499,
  0.9550587689899612,
  0.9803151229033447,
  0.9863699510611169,
  0.9601210747995981,
  0.9037984080864863,
  0.9008955121440656,
  0.9170828739452104,
  0.9896138794776023,
  0.9519597663259595,
  0.9121247946168879,
  0.9105942453209633,
  0.9279821421691672,
  0.9532626192106376,
  0.911741352096691,
  0.9062895226959804,
  0.9099153321563229,
  0.9170262203166208,
  0.9446667197459618],
 [0.9389023090852183,
  0.9748306908705733,
  0.9869893555078737,
  0.940844100589605,
  0.9069575360743056,
  0.9752851218689548,
  0.9482364411556582,
  0.9257863005059687,
  0.9690166937334714,
  0.9302791401361634,
  0.916151396966687,
  0.984460466296893,
  0.930598912819671,
  1.0,
  0.9478912072822867,
  0.9006002232532573,
  0.9527543453980564,
  0.9551964592905814,
  0.9820766167543304,
  0.9722561576869715,
  0.9786046846442538,
  0.9023423199508557,
  0.9140671273449439,
  0.9003081488256406,
  0.9707786850746584,
  0.962109151301125,
  0.9700948918935203,
  0.9587489457500269,
  0.9855208597608702,
  0.9603594317775022,
  0.9183537374924932,
  0.9341568000454765,
  0.9100996615428842,
  0.9344669796196274,
  0.9644325469058248,
  0.9866611229582704,
  0.9043787393114802,
  0.9547157373221067,
  0.9471450293232038,
  0.9353971252644239,
  0.9878004230790672,
  0.9427918106139986,
  0.9650842576008102,
  0.9040267053324232,
  0.9700828775490685,
  0.929701323268622,
  0.9189000332410536,
  0.9084923187481702,
  0.9251587223203397,
  0.9178350122152157,
  0.9110621391857555,
  0.9792397986345354,
  0.9163406095584101,
  0.9432131847770101,
  0.9666977014279632,
  0.9265832669682856,
  0.9205236800554588,
  0.9360425933844664,
  0.9086126757202931,
  0.9816310585787534,
  0.9483072686630799,
  0.925538534932404,
  0.9595921436678758,
  0.9126531313090028,
  0.9278653273982118,
  0.9190803707238075,
  0.9634905765220347,
  0.9573659635296283,
  0.9550217952982859,
  0.9743270490431731,
  0.9498788733428215,
  0.9507572516055981,
  0.9337749759112804,
  0.9096887915150025,
  0.9536678986572488,
  0.9010266518481136,
  0.9230231471061554,
  0.9268325266083476,
  0.9264664611176879,
  0.9027269268522753,
  0.9223153943160102,
  0.9048165594531055,
  0.968512457759007,
  0.9150833201694224,
  0.9622806732975029,
  0.9830642899068051,
  0.9882136002423153,
  0.9391371446363111,
  0.9508458276099914,
  0.9488910763307484,
  0.9817446041198988,
  0.9208259775264638,
  0.907977662487982,
  0.9549528843956718,
  0.9821535592036157,
  0.937882233185513,
  0.9392618551402059,
  0.9719635552273497,
  0.9005625420179837,
  0.9061063481866285,
  0.9412401104580236],
 [0.9738191058696316,
  0.9142280532555729,
  0.9497560673892644,
  0.9265217506795237,
  0.9737624137204715,
  0.9665296024004181,
  0.9676455217389299,
  0.9248616121376831,
  0.9021952267209532,
  0.9406124534532364,
  0.90374434676382,
  0.9425774262007143,
  0.914284004951865,
  0.9478912072822867,
  1.0,
  0.9234142096513647,
  0.9494260619813375,
  0.9024355491105798,
  0.9182808211640966,
  0.9624433685685461,
  0.9144014898564398,
  0.9219730803815667,
  0.908674536895731,
  0.90473084663179,
  0.9649553660898873,
  0.9540379751158528,
  0.9854336761441569,
  0.9764469986135151,
  0.9209891501684575,
  0.9895901781556404,
  0.9611839779259616,
  0.9757630283339317,
  0.9524884882754056,
  0.9761787430185775,
  0.9064969839225065,
  0.9122635423009745,
  0.9374838183443814,
  0.9508580004244246,
  0.9586797271328892,
  0.9412521209194575,
  0.9064123334019943,
  0.9394362343602781,
  0.9331484627221613,
  0.9291989255238631,
  0.954780846635584,
  0.9742767940595003,
  0.975648289273678,
  0.9672930245885527,
  0.9350457063873638,
  0.9894342042289984,
  0.9879093778734356,
  0.938366610601615,
  0.9808564788531543,
  0.9170301891916652,
  0.9618305089025656,
  0.9683430095187702,
  0.9026023134605975,
  0.9231304843430236,
  0.9433416224099798,
  0.9034570777667842,
  0.9619642649521329,
  0.9205653958382791,
  0.9544759699267958,
  0.916287418689859,
  0.9603785961435997,
  0.9516428067021357,
  0.9358702510280534,
  0.9643804554008676,
  0.981826910151038,
  0.9844483286145627,
  0.9260284524601585,
  0.9540408669650157,
  0.9881421134281245,
  0.9571671821458981,
  0.9328691145001543,
  0.9523044325946745,
  0.950516753319042,
  0.932005432337673,
  0.9288486037872103,
  0.9574910128986589,
  0.9146338327690842,
  0.9672461563734607,
  0.9030926169592485,
  0.9637894052166687,
  0.9787798098239482,
  0.9078117183636217,
  0.9407778130666438,
  0.9876276585666527,
  0.9002757066548722,
  0.9421230580941371,
  0.9813665643890263,
  0.9689513637940246,
  0.9514824385372641,
  0.9830190019107927,
  0.9541709626636532,
  0.9469202557875915,
  0.9176171109334095,
  0.9575827383353805,
  0.919130604374147,
  0.9753038562721309,
  0.9544400953600026],
 [0.9329665288561366,
  0.9236293232129404,
  0.9716563553789683,
  0.9076101298840475,
  0.9510293881494004,
  0.9800264932862615,
  0.9362169631474279,
  0.9299544375565255,
  0.9121117857658484,
  0.9428675965560501,
  0.9056176779020021,
  0.9401647945803555,
  0.9720958378242261,
  0.9006002232532573,
  0.9234142096513647,
  1.0,
  0.9091295514323248,
  0.9653122312733065,
  0.947606377264964,
  0.957819381904011,
  0.9073349795780987,
  0.9867492796120171,
  0.9703147180814014,
  0.9316400868364835,
  0.9420854368191467,
  0.9529017965964808,
  0.9116106882716679,
  0.9124858660469132,
  0.9899476720885779,
  0.9611467791887894,
  0.9155632252870051,
  0.9005978655191511,
  0.9503628934135935,
  0.9039502382328299,
  0.9815411403707662,
  0.9057626848274325,
  0.9832912569632936,
  0.9706883820313067,
  0.9147504117956801,
  0.9097067837100236,
  0.9010159006681893,
  0.9323121657924818,
  0.9143017134643201,
  0.9702597142835487,
  0.9174134271901475,
  0.9186564714591998,
  0.908450151458752,
  0.9216386965432961,
  0.9466643227174327,
  0.9710036522832532,
  0.9175767041347651,
  0.9352994828987473,
  0.9830631669279135,
  0.945483908842535,
  0.948944176968411,
  0.9597647140879249,
  0.9840607736302145,
  0.906475845952058,
  0.9257956174672594,
  0.9233395118453861,
  0.9674440639733652,
  0.9765650752163137,
  0.9456692167963336,
  0.9348186484071915,
  0.9828852525581728,
  0.9481070282778562,
  0.9863983302979652,
  0.9760328554316002,
  0.9466926239460411,
  0.9358159448443818,
  0.9476940548630916,
  0.9024874833665625,
  0.9790710620618954,
  0.9505395408716424,
  0.9887074191597648,
  0.913376398923291,
  0.9203056073496729,
  0.9446542137894907,
  0.9690177745115875,
  0.9445100876957984,
  0.9884069526848746,
  0.9870211405021594,
  0.9057821235185937,
  0.9321003614396561,
  0.9452715832677132,
  0.9073555618992019,
  0.9004696190070574,
  0.9477824544738216,
  0.9880298825334772,
  0.9439287921145288,
  0.9053364250773918,
  0.9735260936553586,
  0.9550675078714875,
  0.9213362161192169,
  0.9234567472701724,
  0.985646423076993,
  0.9846197130298506,
  0.9604078577864346,
  0.970198220823661,
  0.9460587831379966,
  0.9268633008530615],
 [0.9734051928422213,
  0.9519579346967463,
  0.957356087130623,
  0.9071567500439668,
  0.9564972383941317,
  0.9582795624174147,
  0.9378097746936687,
  0.9574719242901792,
  0.977142985395195,
  0.9203682751477305,
  0.915187611380954,
  0.9286386048097662,
  0.9496070451276468,
  0.9527543453980564,
  0.9494260619813375,
  0.9091295514323248,
  1.0,
  0.9408103791166276,
  0.9089973943382996,
  0.9050047645142413,
  0.9184733446672604,
  0.937840548515956,
  0.9327699123620532,
  0.9046023414678186,
  0.9561494974679244,
  0.9862246553346959,
  0.9624873168624205,
  0.9351696544805848,
  0.9238046039222187,
  0.9049678985061084,
  0.977208981693934,
  0.989187436707583,
  0.9884743622973274,
  0.9500634010836526,
  0.9230901561000872,
  0.9813172177499719,
  0.9685745837245654,
  0.9388980172255623,
  0.9297628315053842,
  0.9720750491366102,
  0.9860305357258045,
  0.9321260888078413,
  0.9503034352785961,
  0.9125236905618752,
  0.9476360850795615,
  0.9712565958786664,
  0.9846283361271061,
  0.9885185915919021,
  0.9495424243227759,
  0.9502740204028172,
  0.9616094366935373,
  0.9830580041375079,
  0.9487293544708538,
  0.9605315897438872,
  0.9571631647509455,
  0.9042185611996315,
  0.9048885737563376,
  0.9365037484907488,
  0.975892790282857,
  0.9475791391287711,
  0.9441575931927706,
  0.9270167374689329,
  0.9518035325979108,
  0.9243158422342107,
  0.9288687893066647,
  0.9120551132058118,
  0.9599553063244796,
  0.9203858987469294,
  0.98412128491968,
  0.9880297593669576,
  0.9636025473122334,
  0.9410613837479549,
  0.945469644991721,
  0.9727230653727106,
  0.9865668730312682,
  0.9014912389999395,
  0.9794579990698733,
  0.9774948925122662,
  0.9872858523774659,
  0.930376698738652,
  0.9566366013533673,
  0.9822264598619874,
  0.956034186119812,
  0.980898779184155,
  0.9698413602382628,
  0.9093092250487821,
  0.9618761548446686,
  0.9504548740297386,
  0.9312113772991549,
  0.9642854209226257,
  0.9162349199055619,
  0.91785429356576,
  0.9893781731900874,
  0.9757089595215538,
  0.9042571096392501,
  0.9618307066677394,
  0.9138013339702167,
  0.956141960963595,
  0.9411997747304206,
  0.9451406008547633,
  0.9805457320937786],
 [0.9814347642098326,
  0.939443953487365,
  0.9028981364976314,
  0.9348694534160109,
  0.9154173423486619,
  0.9652085698605304,
  0.9128776036592458,
  0.9221098355632779,
  0.927109662089134,
  0.9754412428768304,
  0.9772948087234191,
  0.9768806489100823,
  0.9463817978764427,
  0.9551964592905814,
  0.9024355491105798,
  0.9653122312733065,
  0.9408103791166276,
  1.0,
  0.9533909090445862,
  0.9436979291377773,
  0.9230518088227793,
  0.9066367770058543,
  0.9426345250765078,
  0.9783599143747936,
  0.9367001770385074,
  0.9804097001485732,
  0.9059394202586821,
  0.9652640195392667,
  0.9309596442377193,
  0.965105001374764,
  0.9421171192966288,
  0.9398207674674806,
  0.9830054277318502,
  0.9384305869097934,
  0.9626450237249313,
  0.9884030701894578,
  0.9124710007621195,
  0.974380532090433,
  0.9573354877762495,
  0.9813149256330895,
  0.9192764836306794,
  0.9426542663957764,
  0.9711057279399596,
  0.9438832160559787,
  0.9449780166159112,
  0.9581536458557921,
  0.9736509434064821,
  0.9166518384869375,
  0.9176531896434224,
  0.9764796372699533,
  0.9037122712123775,
  0.9557663542790068,
  0.9123459881184681,
  0.912533937580846,
  0.9428841529546728,
  0.9531095811119796,
  0.9622789725635628,
  0.9240007437907276,
  0.9732291849735291,
  0.9494930628661656,
  0.9582257579503751,
  0.9483642750481474,
  0.9752139183531321,
  0.9242152908410368,
  0.9269294957124531,
  0.9191798172073066,
  0.9052580570190355,
  0.9107175975979211,
  0.9315863508686167,
  0.9505715119548,
  0.9622412157476401,
  0.9616145590892818,
  0.9045312560588512,
  0.9366700809760453,
  0.9188640530387745,
  0.9334228168473279,
  0.9127663746077742,
  0.9671811806447657,
  0.9424170002504895,
  0.9196337261707582,
  0.9413099456587602,
  0.9043650587850246,
  0.9354970431085607,
  0.9468640246386331,
  0.9568606813742531,
  0.9684535080801877,
  0.9636844910444018,
  0.9108495294181381,
  0.9231248034768038,
  0.9480975973140044,
  0.9118666700069922,
  0.9837768143268515,
  0.9121756712080281,
  0.9279847965772015,
  0.9231663347327608,
  0.9682544376785472,
  0.9619318135001145,
  0.9753811113889825,
  0.9080172262237192,
  0.9347646505565286,
  0.9872077058775133],
 [0.9053115218539525,
  0.9528069207053046,
  0.9686448583107592,
  0.9573601546954871,
  0.9140301812142803,
  0.9606717688732676,
  0.9633106382565568,
  0.978756467503872,
  0.9416584840218405,
  0.9216880839070932,
  0.9395019385353021,
  0.9011548706299529,
  0.9595310926128646,
  0.9820766167543304,
  0.9182808211640966,
  0.947606377264964,
  0.9089973943382996,
  0.9533909090445862,
  1.0,
  0.9151326691440705,
  0.9369196400634126,
  0.952195606565166,
  0.959244136657264,
  0.9519394831576681,
  0.9612606005865533,
  0.9897369805086302,
  0.9762643354379876,
  0.9819175525415027,
  0.9283473375267277,
  0.9894456781263936,
  0.9701989043650632,
  0.9463172950211622,
  0.9212627911640289,
  0.9431659246614884,
  0.9502872694449147,
  0.9748944700096551,
  0.9136258507816499,
  0.9115573336698642,
  0.9204138401591815,
  0.9330098079538551,
  0.944952362665116,
  0.9732199148325337,
  0.9756144329167058,
  0.9200928817173287,
  0.9460163887448698,
  0.9238339537944382,
  0.9219063090424034,
  0.9399860622274285,
  0.955890812833437,
  0.9764481176644846,
  0.9209124807347748,
  0.9330183477615047,
  0.9891596633100076,
  0.9027011328123579,
  0.9363271292694929,
  0.9551704430192417,
  0.9049045680191525,
  0.9824155735597282,
  0.9306178810566567,
  0.9865533314579146,
  0.9326023292133373,
  0.9803821238330203,
  0.9493334256023122,
  0.9839862624542485,
  0.9221037343464389,
  0.9130529872400234,
  0.9021888938463031,
  0.9413816657176999,
  0.9464466698875442,
  0.9159425269761956,
  0.944962695806635,
  0.9890155032304262,
  0.9804117803777981,
  0.973962960445119,
  0.9721383419017633,
  0.9619020927476363,
  0.9551121725390552,
  0.9004962094389087,
  0.9399190198277899,
  0.9701617128365914,
  0.9022229529273156,
  0.9166036560439312,
  0.900578209127893,
  0.9669515152584365,
  0.9062832724189729,
  0.9050358248050643,
  0.9597107087302021,
  0.9878537382265692,
  0.9095360188563819,
  0.9309032938933073,
  0.9120359055005556,
  0.9209784014976867,
  0.9495992465807367,
  0.9658575303708046,
  0.9702287191575983,
  0.9045682690080434,
  0.9616694496519705,
  0.9591212351063234,
  0.9391227108643931,
  0.923014662364758,
  0.9522450578858266],
 [0.969547716443647,
  0.9868853706921605,
  0.9079809658392768,
  0.9299483090391187,
  0.9235165638618998,
  0.9154394073691249,
  0.936866413556033,
  0.96157593357224,
  0.9831468755478157,
  0.9777862925934742,
  0.913866062234469,
  0.9340265218459584,
  0.9364532850563088,
  0.9722561576869715,
  0.9624433685685461,
  0.957819381904011,
  0.9050047645142413,
  0.9436979291377773,
  0.9151326691440705,
  1.0,
  0.964790572266295,
  0.9248638952943647,
  0.9583925335659124,
  0.9785778314669599,
  0.9636131558066793,
  0.9610227280953625,
  0.9549434248690053,
  0.9663957208171892,
  0.9708021785110106,
  0.9519816535865535,
  0.9340973486842006,
  0.9119653339215836,
  0.9706641926732977,
  0.9285404165587391,
  0.9009037266335774,
  0.9633915133978368,
  0.9427488131262263,
  0.9443916013148347,
  0.9805070370806471,
  0.9715676903425681,
  0.9711352311144683,
  0.9286866189459235,
  0.9026173805090348,
  0.9166248042487064,
  0.9848732226365996,
  0.9448216260884625,
  0.9897001635291752,
  0.9679099843048036,
  0.9831427859482122,
  0.95860404769024,
  0.9799497124443822,
  0.9662382897649389,
  0.9576232729985493,
  0.9059009885446688,
  0.9221715730140005,
  0.9796860482094817,
  0.9068009769056344,
  0.9507468034595303,
  0.9425504613627458,
  0.9239205142343634,
  0.9560260567075485,
  0.9001615992762361,
  0.9301410934085133,
  0.9408377806598955,
  0.977807690122358,
  0.9511473229304759,
  0.9221596494695643,
  0.9896076163178434,
  0.9513698131515673,
  0.9271984662768595,
  0.953835866288533,
  0.9782031590168146,
  0.9891047272882112,
  0.947568957177382,
  0.9293306503445962,
  0.9574731060574673,
  0.959688238744434,
  0.9858068574456972,
  0.9495064439189116,
  0.9446067871293174,
  0.9059523685105059,
  0.9341903859946796,
  0.9557430237217872,
  0.9300000665233388,
  0.9732738137184012,
  0.9835129924305277,
  0.9324604499424028,
  0.98167118154414,
  0.9008535756182351,
  0.9842895717440013,
  0.9859703493572681,
  0.9007621532617549,
  0.908864908755223,
  0.9374394161184354,
  0.9688684378479231,
  0.9210853381204925,
  0.9566892972344538,
  0.9728064657683089,
  0.9600463038595628,
  0.9144044280624041,
  0.9590637522804667],
 [0.9736094840670293,
  0.9640232486049262,
  0.9091885091815298,
  0.9485586822160303,
  0.9243649958347302,
  0.9689350347796976,
  0.9370581618745443,
  0.9822669508630637,
  0.9094544991811673,
  0.9035359370499098,
  0.940011330886468,
  0.9786356276567357,
  0.9779879258415602,
  0.9786046846442538,
  0.9144014898564398,
  0.9073349795780987,
  0.9184733446672604,
  0.9230518088227793,
  0.9369196400634126,
  0.964790572266295,
  1.0,
  0.9058838953231676,
  0.9590681202935718,
  0.9349785748080837,
  0.9151655140434294,
  0.9351714871043799,
  0.9720776803365256,
  0.9274588870552047,
  0.9836765011743497,
  0.934352172591522,
  0.9031836106620965,
  0.9180958366904446,
  0.952771412570051,
  0.9541204561598887,
  0.9890406473611009,
  0.9703422249355119,
  0.987798270426217,
  0.9253439630149284,
  0.9462045657445619,
  0.9036594378259061,
  0.9352831917550037,
  0.9193758610866232,
  0.9364400310438228,
  0.9679996967108396,
  0.9324860264623058,
  0.9124048051347616,
  0.9690838052438282,
  0.9746403290292661,
  0.9241045428085022,
  0.9383715713175952,
  0.9430237505846172,
  0.9157412336842886,
  0.9077496662681345,
  0.9453950727377433,
  0.9222487888419588,
  0.9143390704698793,
  0.9440613255403786,
  0.9408771886262681,
  0.9317196201925567,
  0.9045899872603981,
  0.9175813335877416,
  0.959832174226247,
  0.9250721589074201,
  0.9477848433218189,
  0.9375520354363637,
  0.9465727672633422,
  0.954556052935196,
  0.9069584492452153,
  0.928028212426961,
  0.9020524374278306,
  0.939982751208601,
  0.9236993864913353,
  0.9262814686415376,
  0.9560685104134962,
  0.976009698677405,
  0.978414792375773,
  0.9782333122539902,
  0.9438265052742111,
  0.9739819524629753,
  0.9226593045458273,
  0.9303817710791313,
  0.9698641522914164,
  0.9079387738923055,
  0.9757313193894155,
  0.9523511441648641,
  0.947905025132871,
  0.9167023437431103,
  0.9688809750359815,
  0.9700428299355286,
  0.9643769075916235,
  0.9157775099512823,
  0.9509716891293087,
  0.932225100399395,
  0.9084560903311364,
  0.9156665284528166,
  0.9598735889438424,
  0.9884209308799218,
  0.9881084057610078,
  0.9723002162757196,
  0.9789854479358289,
  0.9843762832994367],
 [0.9818346933236656,
  0.9182021259290959,
  0.9583957674560178,
  0.9116004047542408,
  0.9096443915796174,
  0.9054291914125326,
  0.9039110220177523,
  0.9457212038622174,
  0.9512174163897218,
  0.9279754919703016,
  0.9240762863187955,
  0.9864186818198861,
  0.9789880633694232,
  0.9023423199508557,
  0.9219730803815667,
  0.9867492796120171,
  0.937840548515956,
  0.9066367770058543,
  0.952195606565166,
  0.9248638952943647,
  0.9058838953231676,
  1.0,
  0.96833785776773,
  0.9781264185293513,
  0.9715891760951033,
  0.922122075753241,
  0.9012469823179976,
  0.9837318491660475,
  0.902173061759784,
  0.9159223751944717,
  0.9385928437425715,
  0.9015226696841099,
  0.945450568988138,
  0.9225744006921219,
  0.9313428761045298,
  0.9714084564766696,
  0.9750758074592528,
  0.9358350757153642,
  0.9745820181592784,
  0.9713732894405525,
  0.971692459785777,
  0.9783459361300308,
  0.9771282705757971,
  0.9270639529902724,
  0.9804472186818426,
  0.9808273933945363,
  0.9158912586732794,
  0.9173689181508213,
  0.927047700804401,
  0.9660170888293028,
  0.9011889483701314,
  0.989249895284135,
  0.9520959670303174,
  0.973832499455182,
  0.9101646656269015,
  0.9224997402489913,
  0.9090086713558989,
  0.9624022962837471,
  0.908094111492025,
  0.9072675948804665,
  0.9068778858989587,
  0.9320096956318056,
  0.9671423069248354,
  0.9887347367904994,
  0.9117681511624413,
  0.9023862160034423,
  0.9815162484438279,
  0.9262684065443261,
  0.9089930308891099,
  0.9391700899224474,
  0.9476511185038634,
  0.9624279586463627,
  0.9373132241339417,
  0.9617908597129288,
  0.9571637050649575,
  0.9046075349152828,
  0.9419185723442653,
  0.9422967021277732,
  0.9614350908331243,
  0.9077787245852976,
  0.9451250000894256,
  0.9168245773440011,
  0.9529484927227977,
  0.9176221725194796,
  0.9699246160765338,
  0.9123982684930144,
  0.9072670490511148,
  0.951538666759882,
  0.94279883174312,
  0.9306269579995332,
  0.9856720469627873,
  0.9128850686952946,
  0.969263467304254,
  0.9889861933858365,
  0.966533771445169,
  0.9837269031744768,
  0.9743356874605721,
  0.9376183301109005,
  0.9798359835775486,
  0.956648359224659,
  0.9823233637939395],
 [0.9051386494708944,
  0.9781750209121028,
  0.956517596913375,
  0.9666243094182912,
  0.9532466043370578,
  0.9651984036900979,
  0.9570163052510152,
  0.9002518672749799,
  0.9769285481061646,
  0.9003569259864178,
  0.9452607045614995,
  0.9771865076397849,
  0.9698671946495215,
  0.9140671273449439,
  0.908674536895731,
  0.9703147180814014,
  0.9327699123620532,
  0.9426345250765078,
  0.959244136657264,
  0.9583925335659124,
  0.9590681202935718,
  0.96833785776773,
  1.0,
  0.912277977968151,
  0.975237520715416,
  0.9701388678332626,
  0.9535346396021791,
  0.9268405734663802,
  0.914176695689161,
  0.9495300144768656,
  0.9702425282962115,
  0.9210388717565478,
  0.9898075779809679,
  0.9612537742625065,
  0.9708193857838383,
  0.9630890078327009,
  0.9278784264316245,
  0.9489911608610465,
  0.9575020555330657,
  0.9627282357935191,
  0.9040940541539608,
  0.9297931601485337,
  0.9108304675687308,
  0.9227535896865984,
  0.9147696218638162,
  0.9883910890160974,
  0.9299493818410641,
  0.9675741059375799,
  0.9504872994275791,
  0.9434404710085518,
  0.929403915294481,
  0.9176073410664173,
  0.9103719759570461,
  0.9694315823478615,
  0.9114403087133709,
  0.9728214535563806,
  0.9084577518239628,
  0.9236071714299526,
  0.9049617622591888,
  0.983598454053908,
  0.9265622072863282,
  0.9022871035386669,
  0.9570537188466933,
  0.9213660433814655,
  0.9711788479909428,
  0.9173375097576678,
  0.9435642501368844,
  0.9080648364004142,
  0.9033845827725102,
  0.9374876030389986,
  0.9628307560241885,
  0.9553384573187941,
  0.9138543179792803,
  0.9241940993585622,
  0.9284539244276346,
  0.9736414137834416,
  0.9898435003100318,
  0.9653518291955873,
  0.9655370008891004,
  0.9889523601936084,
  0.9859941392997256,
  0.9744439293124526,
  0.9770388046600812,
  0.958472988499714,
  0.9899816023149554,
  0.9246936355899148,
  0.9027635069479992,
  0.9368513017508611,
  0.9074928043339082,
  0.9376957169436735,
  0.915475152220204,
  0.9747274236331107,
  0.9110196834007147,
  0.9538845574122357,
  0.965749271971788,
  0.9703839420474053,
  0.987888657952863,
  0.9045104869965825,
  0.9369767396175926,
  0.9715328863830949,
  0.9540383177945491],
 [0.9080345461646157,
  0.9034498942071563,
  0.9178468517097379,
  0.9852685368163906,
  0.9190587775003183,
  0.9811089505715891,
  0.9605061333642251,
  0.9878366917084107,
  0.9863923510425361,
  0.9832902688986745,
  0.9252868452418973,
  0.9390625393319197,
  0.9879309260690423,
  0.9003081488256406,
  0.90473084663179,
  0.9316400868364835,
  0.9046023414678186,
  0.9783599143747936,
  0.9519394831576681,
  0.9785778314669599,
  0.9349785748080837,
  0.9781264185293513,
  0.912277977968151,
  1.0,
  0.9846041538116141,
  0.9348884032310378,
  0.9308094657946365,
  0.9887690979614125,
  0.9060763284562636,
  0.9306612841659835,
  0.988005325045324,
  0.9175481781018389,
  0.9402870541481447,
  0.92504716543784,
  0.9447528582397177,
  0.9897189354089295,
  0.9181981134325268,
  0.9014870257454848,
  0.9329716743401841,
  0.9262801993037724,
  0.9602555373755266,
  0.9866585188991669,
  0.9783191643739606,
  0.9748301488542308,
  0.9311997909123229,
  0.9264571260128284,
  0.9383187763262312,
  0.97242660964539,
  0.9264755801901546,
  0.9216488385866539,
  0.9400829745822147,
  0.9701327508176382,
  0.9017212205348163,
  0.9140115328195833,
  0.9761694570510011,
  0.9707756767272216,
  0.9378206593679985,
  0.9182761061286907,
  0.9312726966535082,
  0.9342212070797824,
  0.9297397023696924,
  0.9128687688573002,
  0.9330640959625692,
  0.9709514973354936,
  0.9395525790402917,
  0.9593126988521776,
  0.9863740437445104,
  0.9460392517330448,
  0.9494296029786126,
  0.9844683389575082,
  0.9725204649623836,
  0.97252771602574,
  0.9466384081718804,
  0.9686170271005445,
  0.9727298774809903,
  0.9660354320648462,
  0.9789422520162714,
  0.9517560689608162,
  0.9306827014252799,
  0.9620339662075076,
  0.9307645100546135,
  0.9409329135532691,
  0.9431972477844721,
  0.9824685238940627,
  0.9273312512517375,
  0.9066622401794391,
  0.9036043796362732,
  0.9133562943544433,
  0.9310162185040853,
  0.9712021316680354,
  0.9808825953774267,
  0.9379164412171189,
  0.9230485142893241,
  0.966683532810816,
  0.948068295537283,
  0.9392456682684115,
  0.9743277176962821,
  0.9215634639236503,
  0.9248592190301916,
  0.9393683282965594,
  0.9230432144621876],
 [0.9477124125489895,
  0.9012096878951947,
  0.9501009810078471,
  0.9161597622805658,
  0.91634701231457,
  0.9174318427485537,
  0.9894757169042954,
  0.9620572311394519,
  0.9679302978378224,
  0.9185607668871878,
  0.9356631296214298,
  0.9527279336936372,
  0.912107286846636,
  0.9707786850746584,
  0.9649553660898873,
  0.9420854368191467,
  0.9561494974679244,
  0.9367001770385074,
  0.9612606005865533,
  0.9636131558066793,
  0.9151655140434294,
  0.9715891760951033,
  0.975237520715416,
  0.9846041538116141,
  1.0,
  0.9384604340881428,
  0.9117779746822177,
  0.9658781381869368,
  0.9411506335924164,
  0.9422227964370812,
  0.9049417503603132,
  0.9410284400284448,
  0.9648957672702837,
  0.9431372394709874,
  0.9477532583518115,
  0.9030771152204033,
  0.920963553125417,
  0.9720658012874647,
  0.956527553347076,
  0.9597299916070009,
  0.9113504135260241,
  0.98991652249351,
  0.9027620239085872,
  0.9354127805821295,
  0.9746260021309784,
  0.915463797694618,
  0.9724457934974655,
  0.9205577846349859,
  0.9694966448699907,
  0.9899650189341901,
  0.9848970153700111,
  0.9232410418009124,
  0.9313270152199314,
  0.9365693045997343,
  0.9579848990541947,
  0.9051632709473949,
  0.9432735273750646,
  0.9336758757888391,
  0.953607705906638,
  0.9485515931655487,
  0.9387112592955487,
  0.9494834686566028,
  0.9782954617205223,
  0.9823546306385024,
  0.9140694662861987,
  0.9759972745859394,
  0.9311710689293616,
  0.9654657378456806,
  0.9560063544719837,
  0.9826835557800586,
  0.9332764103742979,
  0.9291968675083907,
  0.9891724060655254,
  0.987921175936355,
  0.9675855559934747,
  0.9638606519191045,
  0.9750307658220795,
  0.9118140689721386,
  0.9343379987787273,
  0.9476426892029851,
  0.9127638904163443,
  0.9027368513749251,
  0.9772159145419227,
  0.9075269535794376,
  0.9263623132618012,
  0.9275303948567741,
  0.9442169084176412,
  0.9748662320868607,
  0.9702747164265306,
  0.9736774823671832,
  0.9413925249604959,
  0.9830264447281055,
  0.9371643660867279,
  0.909290328311126,
  0.9103027523194471,
  0.9044626485859255,
  0.9514407266638553,
  0.9444229086890267,
  0.9628509451516944,
  0.9877449373373509,
  0.9370257469014018],
 [0.9054380000443489,
  0.9048796018721996,
  0.9422443866792732,
  0.982760990202555,
  0.9326326160327065,
  0.9341582178154713,
  0.923702963641654,
  0.9476568797691075,
  0.9893100150815382,
  0.9776282204395277,
  0.9298616759825272,
  0.9237847432410831,
  0.9755454463917337,
  0.962109151301125,
  0.9540379751158528,
  0.9529017965964808,
  0.9862246553346959,
  0.9804097001485732,
  0.9897369805086302,
  0.9610227280953625,
  0.9351714871043799,
  0.922122075753241,
  0.9701388678332626,
  0.9348884032310378,
  0.9384604340881428,
  1.0,
  0.9032923556012346,
  0.9451210963302077,
  0.9206651880249491,
  0.9878187893252686,
  0.9732397597130026,
  0.9280942543019693,
  0.9354802181568489,
  0.9763786495485904,
  0.9626423844116464,
  0.9535658610622786,
  0.9663077418429759,
  0.9013986540476869,
  0.934083319573385,
  0.9474164670929079,
  0.9785382852279352,
  0.9799650017972479,
  0.9681496838083374,
  0.9696481880722188,
  0.9082216004628685,
  0.9781276603766489,
  0.9328061476147335,
  0.9370178895372201,
  0.9899749858571844,
  0.9247067205923202,
  0.9246480205110003,
  0.9003719343263843,
  0.92327626642311,
  0.9515277849788472,
  0.9307770971536115,
  0.9809016109819829,
  0.9091209655591155,
  0.9652365904306969,
  0.9771866474596504,
  0.9723552951341822,
  0.9861113653191126,
  0.9801094186664928,
  0.9245813564051181,
  0.9260870625672115,
  0.902762158968427,
  0.9630393481666402,
  0.9849192855191653,
  0.9568724420625799,
  0.9539526713478618,
  0.9891844470708958,
  0.9330685388162236,
  0.9341408247224134,
  0.9899366028456736,
  0.9274238891072343,
  0.9883599045973811,
  0.9791831209288904,
  0.9144596230755967,
  0.9891544751824282,
  0.9348837186389561,
  0.9004700371502267,
  0.9000408228887664,
  0.966966458439488,
  0.9237240712644342,
  0.9260654235574608,
  0.9676426814503961,
  0.9734143791713032,
  0.9274280813836402,
  0.9277474201488176,
  0.9480239639572323,
  0.9115075478300357,
  0.9033235550107561,
  0.9853071213868161,
  0.9532310484866285,
  0.9276159936217653,
  0.9531519496706814,
  0.9121242973424747,
  0.9651604478797615,
  0.901759436433743,
  0.9694168007134838,
  0.9024952960425028,
  0.9370342037110511],
 [0.908945043426306,
  0.9612733570909032,
  0.9444441424188258,
  0.9896424248801095,
  0.9610190137150839,
  0.948643426818457,
  0.9753762761820293,
  0.9473229211213705,
  0.9332493065165902,
  0.9634768148130531,
  0.9284439878726669,
  0.948904603943345,
  0.9222285018406158,
  0.9700948918935203,
  0.9854336761441569,
  0.9116106882716679,
  0.9624873168624205,
  0.9059394202586821,
  0.9762643354379876,
  0.9549434248690053,
  0.9720776803365256,
  0.9012469823179976,
  0.9535346396021791,
  0.9308094657946365,
  0.9117779746822177,
  0.9032923556012346,
  1.0,
  0.9543553813110548,
  0.9888076356251119,
  0.9581973383021565,
  0.9292673383187589,
  0.9761040693783731,
  0.9578748067380778,
  0.9689703158190359,
  0.9451641256066909,
  0.9371926383810543,
  0.9426709156115446,
  0.9787165464104542,
  0.9207034963307464,
  0.9336551425856012,
  0.959137520707047,
  0.9305443959794489,
  0.923651494912914,
  0.9366361998526267,
  0.9201357314442691,
  0.94431600174029,
  0.9576856911806125,
  0.9305659340604365,
  0.975803297462198,
  0.9256689836067297,
  0.951184545022638,
  0.9668907712387825,
  0.9052891341361768,
  0.9525499865892126,
  0.9048752415547175,
  0.976789048503999,
  0.9725154648933789,
  0.9682469406520569,
  0.9743842510532102,
  0.9424003866756865,
  0.9354982816157853,
  0.9546352547011815,
  0.9677180890774575,
  0.9423006768687096,
  0.947407062387088,
  0.9306077331071778,
  0.9116071091043699,
  0.9294481946524573,
  0.9051711926761089,
  0.9630278473403997,
  0.9506227893773274,
  0.9199107220829128,
  0.960620535037708,
  0.9791252236135584,
  0.9395233252816144,
  0.955739726002146,
  0.9704208648857797,
  0.9007435822482046,
  0.9636803189546249,
  0.9124984208255341,
  0.9545895049882293,
  0.9072322842266999,
  0.9489296532999523,
  0.9513389125696444,
  0.988936423872484,
  0.9067807427313819,
  0.9851193090505271,
  0.9152972037176089,
  0.9442305237250873,
  0.9405407899179122,
  0.935241475581954,
  0.9376761039049227,
  0.9855615392940328,
  0.9185859240126931,
  0.977828336096316,
  0.9637640550080117,
  0.9680753812547446,
  0.9059311511470918,
  0.9868824458681537,
  0.9528589547597666,
  0.9850449599487191],
 [0.9710528534934019,
  0.9704542041943749,
  0.9452904009422247,
  0.9427619149314074,
  0.963879300541458,
  0.9463676093104898,
  0.9762235297584606,
  0.918506257218007,
  0.9131531763342794,
  0.9624449099740828,
  0.9494336204687823,
  0.9271077475884667,
  0.9731109929255668,
  0.9587489457500269,
  0.9764469986135151,
  0.9124858660469132,
  0.9351696544805848,
  0.9652640195392667,
  0.9819175525415027,
  0.9663957208171892,
  0.9274588870552047,
  0.9837318491660475,
  0.9268405734663802,
  0.9887690979614125,
  0.9658781381869368,
  0.9451210963302077,
  0.9543553813110548,
  1.0,
  0.9233851286020544,
  0.9431014076011555,
  0.9434728052405444,
  0.9585394695776215,
  0.9597653163264649,
  0.9794510482395198,
  0.9520526183582381,
  0.9222937577910346,
  0.9261518270413112,
  0.9012506741289099,
  0.9147746361140489,
  0.9278938475003436,
  0.9002306764339902,
  0.9666034949438029,
  0.9391896419545238,
  0.9738820950663429,
  0.9579543846640228,
  0.9312491433224347,
  0.9369023927008487,
  0.9125326449314352,
  0.9721578966435814,
  0.9778581550415777,
  0.9518364816989692,
  0.9701944749242454,
  0.9492807197706262,
  0.9067463967500193,
  0.9044283079277801,
  0.931474474121141,
  0.9773185471830764,
  0.9796796470902069,
  0.9140721010374661,
  0.924881898740067,
  0.9180378994640074,
  0.9005216712706419,
  0.9217383156811401,
  0.9436727256564985,
  0.9574111021134314,
  0.9121193016371205,
  0.9484234779860142,
  0.9612181019874416,
  0.9232496302927643,
  0.9102385993010189,
  0.903283446620705,
  0.9386114736164105,
  0.9816878752294742,
  0.9453932821479271,
  0.9319925592263659,
  0.9195523820047743,
  0.9313283698118486,
  0.9414282037480969,
  0.9445674062708606,
  0.9015751775581216,
  0.9253833356940919,
  0.9560358095035252,
  0.9671221980143467,
  0.9555791799183185,
  0.9585746909715853,
  0.9389402846342957,
  0.9897634708264751,
  0.9043837057569254,
  0.9835867987026576,
  0.9062848638430008,
  0.9347467085997985,
  0.9623087248962476,
  0.9121873823979911,
  0.9351971306343693,
  0.9608997905275349,
  0.9436778317337786,
  0.9046611039055434,
  0.9159479064742024,
  0.9061123737361891,
  0.954432267570153,
  0.97454108962601],
 [0.9575770991397257,
  0.9013043801734549,
  0.971071769442789,
  0.9218498742888964,
  0.9422184062923844,
  0.9413050943890464,
  0.9896769281923252,
  0.9006399829470806,
  0.9512331240364118,
  0.9853224310436616,
  0.9355519481265836,
  0.9150730476135466,
  0.9248962913259252,
  0.9855208597608702,
  0.9209891501684575,
  0.9899476720885779,
  0.9238046039222187,
  0.9309596442377193,
  0.9283473375267277,
  0.9708021785110106,
  0.9836765011743497,
  0.902173061759784,
  0.914176695689161,
  0.9060763284562636,
  0.9411506335924164,
  0.9206651880249491,
  0.9888076356251119,
  0.9233851286020544,
  1.0,
  0.9863141250644368,
  0.987877361217253,
  0.9177928243639042,
  0.9386262296114141,
  0.9384600475704282,
  0.9248120756797473,
  0.9404656562175904,
  0.9341673564141951,
  0.983857474859327,
  0.9417972338593544,
  0.9799449785476627,
  0.952430568151306,
  0.9197782200574667,
  0.9326581027448185,
  0.9263199259188165,
  0.9803065450196897,
  0.9434842414192147,
  0.9077640753115421,
  0.9306403439824321,
  0.9415913048541359,
  0.9797791844667418,
  0.9444313923970371,
  0.9512097544684973,
  0.9893912784417378,
  0.9050408026991345,
  0.9578424616383161,
  0.9609893859508152,
  0.9773623880323776,
  0.9849396931298992,
  0.9669521182797719,
  0.920268066681301,
  0.9271725467483833,
  0.9883211711912998,
  0.9412677612182074,
  0.9269478737129756,
  0.9439766701656453,
  0.9585373196918844,
  0.9332334502623841,
  0.9129288300777645,
  0.9390271862222076,
  0.9840402344609838,
  0.9060058773136823,
  0.9632469481733504,
  0.9780986523402674,
  0.9060002618010747,
  0.9608384940774058,
  0.9487503045442347,
  0.9528750483624959,
  0.9780541747598428,
  0.940505990779442,
  0.911549384958575,
  0.9854493864471257,
  0.9439664696020329,
  0.9524447418756639,
  0.9456629907342652,
  0.9072605494668003,
  0.9015712510647345,
  0.9396516923065713,
  0.9694548341034465,
  0.9762345267020659,
  0.9227796551903896,
  0.9156342069824874,
  0.9690158477590964,
  0.9576644262545283,
  0.9012545800617208,
  0.9516303824411829,
  0.9169130755475885,
  0.918736292473787,
  0.9875367160961837,
  0.9690233164363206,
  0.9002236823117465,
  0.9220494540230287],
 [0.9097881238682727,
  0.9658791461024384,
  0.9298254391076906,
  0.9234359271669259,
  0.9677691644903007,
  0.9162168239419658,
  0.9814914740676662,
  0.9887766553117238,
  0.9250632687068817,
  0.9573821921961725,
  0.9770216535977626,
  0.91876656235632,
  0.929189819563263,
  0.9603594317775022,
  0.9895901781556404,
  0.9611467791887894,
  0.9049678985061084,
  0.965105001374764,
  0.9894456781263936,
  0.9519816535865535,
  0.934352172591522,
  0.9159223751944717,
  0.9495300144768656,
  0.9306612841659835,
  0.9422227964370812,
  0.9878187893252686,
  0.9581973383021565,
  0.9431014076011555,
  0.9863141250644368,
  1.0,
  0.9361987330436616,
  0.9312443739514801,
  0.9790497694657596,
  0.9256261059506122,
  0.9706990027888849,
  0.9872672643822565,
  0.9590724949932444,
  0.9077084489768715,
  0.9653700087636201,
  0.9804269987826664,
  0.930513524392509,
  0.9889843403956563,
  0.9192320977764474,
  0.9339351104878715,
  0.9734655175480991,
  0.9633679411272806,
  0.9765698974151684,
  0.9037074081859584,
  0.9332748682450709,
  0.9701298021395716,
  0.9370596536263406,
  0.9664249223718071,
  0.9597490735945919,
  0.9096680339556316,
  0.967854519976362,
  0.921590830237221,
  0.9265325387895866,
  0.9181793092931456,
  0.9372641480264886,
  0.9574437662480165,
  0.987775773605956,
  0.9820568022066894,
  0.9384015898895337,
  0.9272306271568689,
  0.9720590226044414,
  0.9435454874524748,
  0.9637006277343629,
  0.9847149521897126,
  0.9611943114883049,
  0.9317736974271651,
  0.9640738837624536,
  0.9442795792908956,
  0.9435854069392487,
  0.9282948497827538,
  0.9195868953089018,
  0.9602970592937878,
  0.934348277425682,
  0.9638073288619897,
  0.9380566311645717,
  0.9196482795397307,
  0.9190191021499637,
  0.9023471129696665,
  0.9244330091967284,
  0.9083528492484522,
  0.9271469290103598,
  0.9435782065136344,
  0.9012960093157669,
  0.9763756829896254,
  0.9019478076985454,
  0.9083511115891132,
  0.9626538724044805,
  0.9776893174458814,
  0.9413209189532267,
  0.9793546939555673,
  0.9058030525950205,
  0.9068712568166498,
  0.9635274491082683,
  0.9077050772097138,
  0.9676358379573112,
  0.9564322826501916,
  0.9869887875351231],
 [0.9327654549911849,
  0.9646971798618564,
  0.9109571387785705,
  0.9821190848073885,
  0.9695707198809272,
  0.9800447722255011,
  0.9569953710854686,
  0.9107058421161262,
  0.9757145832759772,
  0.9513599698335375,
  0.9293675942159906,
  0.9590191957239278,
  0.96320099902037,
  0.9183537374924932,
  0.9611839779259616,
  0.9155632252870051,
  0.977208981693934,
  0.9421171192966288,
  0.9701989043650632,
  0.9340973486842006,
  0.9031836106620965,
  0.9385928437425715,
  0.9702425282962115,
  0.988005325045324,
  0.9049417503603132,
  0.9732397597130026,
  0.9292673383187589,
  0.9434728052405444,
  0.987877361217253,
  0.9361987330436616,
  1.0,
  0.9319275428787264,
  0.9064592494071397,
  0.9747554107838502,
  0.9238658036593308,
  0.9246480789016538,
  0.9571754582838646,
  0.9016793525599238,
  0.9370920755475166,
  0.939015764498425,
  0.9030566104527697,
  0.9255533586390811,
  0.9786593555250231,
  0.9187389825066733,
  0.9261138746184806,
  0.9149980402774975,
  0.9651679131604007,
  0.9516709577277481,
  0.9853774574526997,
  0.9040352613543587,
  0.9368400394025407,
  0.9551917370672348,
  0.9602407145845232,
  0.9356206318859132,
  0.9179856536430298,
  0.9170417416896106,
  0.9264778560424616,
  0.9416396804830368,
  0.9772430957761564,
  0.953027483747065,
  0.9388340011271605,
  0.9822443147773743,
  0.9467258088820016,
  0.9738393986714302,
  0.9180171132934499,
  0.9028843787054088,
  0.9217476807429169,
  0.9026071652665768,
  0.9655990565776351,
  0.9480188702253247,
  0.9276178875795509,
  0.9319430452596229,
  0.9765775794482435,
  0.9753473662152662,
  0.9713564847112728,
  0.9392432968374687,
  0.9071211152001852,
  0.9646185025389106,
  0.9245433481798372,
  0.9218634603721533,
  0.931838202292004,
  0.9692679275240244,
  0.967713706190998,
  0.9099147892322917,
  0.9401335874051009,
  0.9203909773539549,
  0.9079326474899669,
  0.952216841214409,
  0.9196300045452267,
  0.9816279308940118,
  0.9423398542726112,
  0.9353129203441322,
  0.9436405758069657,
  0.9381562749052458,
  0.9558982529564272,
  0.9076647543192344,
  0.9176792463802924,
  0.9182429031222206,
  0.9565034507314498,
  0.9389910017644532,
  0.9242389006244203],
 [0.9760133937241467,
  0.9274730452211477,
  0.9719828617400531,
  0.9627412851237064,
  0.9339259719329717,
  0.9817736968761938,
  0.9868436486315141,
  0.9369703005421939,
  0.9289952498557542,
  0.9598081175496515,
  0.9830469295355209,
  0.9223307940567215,
  0.9017167870906576,
  0.9341568000454765,
  0.9757630283339317,
  0.9005978655191511,
  0.989187436707583,
  0.9398207674674806,
  0.9463172950211622,
  0.9119653339215836,
  0.9180958366904446,
  0.9015226696841099,
  0.9210388717565478,
  0.9175481781018389,
  0.9410284400284448,
  0.9280942543019693,
  0.9761040693783731,
  0.9585394695776215,
  0.9177928243639042,
  0.9312443739514801,
  0.9319275428787264,
  1.0,
  0.9104033636750467,
  0.9239690246579005,
  0.9368877489654341,
  0.9561669609494464,
  0.9002764566232913,
  0.9748117397542949,
  0.964720014040716,
  0.9204715475863022,
  0.9440333790867608,
  0.962048669003359,
  0.9107657600028635,
  0.942280350473256,
  0.9700718535040126,
  0.9069280273020832,
  0.951474550080156,
  0.9678974715197723,
  0.9400888561201496,
  0.9008983796576611,
  0.9524554528446534,
  0.9026411452708629,
  0.9806034444721657,
  0.9273571306452513,
  0.978457034030403,
  0.9229988364723577,
  0.9636866582733926,
  0.9598617165001928,
  0.9499453344319407,
  0.9690462248933118,
  0.9667379375225416,
  0.9200415595716506,
  0.9136872461276871,
  0.9053942403619089,
  0.984029441379178,
  0.9496589671329935,
  0.9454515685443048,
  0.9426789973035251,
  0.915991534863954,
  0.91991764984235,
  0.9771441971764647,
  0.9518365129059458,
  0.964212992406499,
  0.9326098015585517,
  0.9278395687446399,
  0.9265985799894642,
  0.9654198522453556,
  0.9551159864154386,
  0.9222205304076141,
  0.9435786272519502,
  0.919151092647737,
  0.9507730033627284,
  0.9825088152880594,
  0.912857648162201,
  0.9299139371535382,
  0.9437257828742676,
  0.9263538357359808,
  0.9871032466141402,
  0.9631437575035667,
  0.968543578981093,
  0.955747332340625,
  0.9346896445736259,
  0.919039209915643,
  0.9414667991159787,
  0.9039859327957729,
  0.9844496310753473,
  0.981085000973762,
  0.9728834911832382,
  0.9230839859514539,
  0.9187628751861977,
  0.9680235054622467],
 [0.9340064716575198,
  0.980040298810096,
  0.9210874517460196,
  0.9221584145567172,
  0.9050087273886931,
  0.9301474860773009,
  0.9062095312009385,
  0.9505584009916596,
  0.9226535256301345,
  0.968670889684958,
  0.910579684039958,
  0.9771487662015514,
  0.9529639781261916,
  0.9100996615428842,
  0.9524884882754056,
  0.9503628934135935,
  0.9884743622973274,
  0.9830054277318502,
  0.9212627911640289,
  0.9706641926732977,
  0.952771412570051,
  0.945450568988138,
  0.9898075779809679,
  0.9402870541481447,
  0.9648957672702837,
  0.9354802181568489,
  0.9578748067380778,
  0.9597653163264649,
  0.9386262296114141,
  0.9790497694657596,
  0.9064592494071397,
  0.9104033636750467,
  1.0,
  0.9178586877005473,
  0.9778676520062375,
  0.9752772275021773,
  0.934605584448734,
  0.9118344148977677,
  0.9330142767263588,
  0.9729857502682399,
  0.907840043420187,
  0.9774851274423552,
  0.9781495866352731,
  0.9646701350846218,
  0.9654351265017755,
  0.9819091541631337,
  0.9867953015956502,
  0.9385464505666282,
  0.9614654479748004,
  0.9341060604017697,
  0.9664205526423545,
  0.9295102368844411,
  0.9406267594948013,
  0.9175952374869404,
  0.9753426915945433,
  0.9289176093546095,
  0.9232660809526109,
  0.9574000867181208,
  0.9057317564623266,
  0.96312462528355,
  0.9252829829580926,
  0.9456893366578896,
  0.9441357726868678,
  0.927053418573171,
  0.9417686446357533,
  0.9108010795046037,
  0.9108642287688368,
  0.9654208201183261,
  0.9140807050881693,
  0.9301256186469729,
  0.9891278695030696,
  0.9555304070384875,
  0.9432539998569758,
  0.9152978188678879,
  0.9422212366235045,
  0.9696464693481887,
  0.9764849780051237,
  0.9643632741982497,
  0.9454615134192406,
  0.9821661530225735,
  0.9811818309434606,
  0.9632858080800953,
  0.9584006334387275,
  0.9502514352380262,
  0.9295130180919544,
  0.9048181489808992,
  0.9784121232943276,
  0.9021688395745193,
  0.9674766605514712,
  0.9315506877657892,
  0.9544062822098162,
  0.9504960075013804,
  0.9293584841509297,
  0.9201084719577257,
  0.9117381974381333,
  0.9230376556165956,
  0.9814991452833528,
  0.9224080816188539,
  0.9453478298355816,
  0.9357849364103452,
  0.9340811897514321],
 [0.9450098846028525,
  0.9849486056522327,
  0.9205787965687502,
  0.9641184165214987,
  0.9681906357219405,
  0.9841749951943738,
  0.9602824530910115,
  0.9060132084020885,
  0.9449077140924528,
  0.9202522651291314,
  0.9245548971498645,
  0.9297686881509604,
  0.9003270095367861,
  0.9344669796196274,
  0.9761787430185775,
  0.9039502382328299,
  0.9500634010836526,
  0.9384305869097934,
  0.9431659246614884,
  0.9285404165587391,
  0.9541204561598887,
  0.9225744006921219,
  0.9612537742625065,
  0.92504716543784,
  0.9431372394709874,
  0.9763786495485904,
  0.9689703158190359,
  0.9794510482395198,
  0.9384600475704282,
  0.9256261059506122,
  0.9747554107838502,
  0.9239690246579005,
  0.9178586877005473,
  1.0,
  0.9765407568945965,
  0.9637572226757887,
  0.9108535541140692,
  0.9568208438633037,
  0.9588037506370231,
  0.9859572632708858,
  0.9786573450459063,
  0.9683738275883159,
  0.9550694159072088,
  0.9668206868029038,
  0.9221161812085295,
  0.9306709770490765,
  0.9150620388205954,
  0.9342853401954241,
  0.9716323056763252,
  0.9455514792415572,
  0.93307047377446,
  0.9828895899335733,
  0.935550481367659,
  0.9358932408994133,
  0.9568039333051016,
  0.96419706534626,
  0.9515784499572945,
  0.9478540327608813,
  0.9805861314691794,
  0.9255140481648915,
  0.9490457775340445,
  0.912202773454356,
  0.9235697840163213,
  0.9790495310952364,
  0.9433915535939124,
  0.9548003768738218,
  0.9820511413538218,
  0.9264085694559094,
  0.9482107108179628,
  0.9513123942035896,
  0.9266493311422243,
  0.9313186211145864,
  0.9157312131141021,
  0.9100586217274973,
  0.9470506023550475,
  0.9269250537089772,
  0.9594482029477,
  0.9475368502174926,
  0.9784380121037084,
  0.9651103976940834,
  0.958577984929933,
  0.9855477792227614,
  0.9682552031150536,
  0.9684687699996991,
  0.9495741466212028,
  0.9229916422189552,
  0.9758025997687939,
  0.9258230647068234,
  0.9433053066956704,
  0.9025242837921388,
  0.9210256608578115,
  0.9062579965458616,
  0.971536401325152,
  0.9873552281841033,
  0.9812593100781939,
  0.9778945399088116,
  0.9480970102448724,
  0.913184850938815,
  0.9704592329529649,
  0.9461661413818909,
  0.9422418214500403],
 [0.9170790724049441,
  0.94910414198058,
  0.9084441903679303,
  0.9422651115073315,
  0.914581543598181,
  0.9518762596636177,
  0.9657136739747169,
  0.9758142194964848,
  0.9200287888284219,
  0.971304975854325,
  0.9595175504225703,
  0.9070067961200086,
  0.9336630171598072,
  0.9644325469058248,
  0.9064969839225065,
  0.9815411403707662,
  0.9230901561000872,
  0.9626450237249313,
  0.9502872694449147,
  0.9009037266335774,
  0.9890406473611009,
  0.9313428761045298,
  0.9708193857838383,
  0.9447528582397177,
  0.9477532583518115,
  0.9626423844116464,
  0.9451641256066909,
  0.9520526183582381,
  0.9248120756797473,
  0.9706990027888849,
  0.9238658036593308,
  0.9368877489654341,
  0.9778676520062375,
  0.9765407568945965,
  1.0,
  0.9792147092031193,
  0.9712453629750355,
  0.9390616519448866,
  0.9724341080387684,
  0.9138176908497211,
  0.9409568316689766,
  0.9587769122247825,
  0.9611367376928717,
  0.9443759799899545,
  0.9076324519553095,
  0.9511346836253555,
  0.9709718391764465,
  0.9402660501067204,
  0.950781021892456,
  0.9176848318450407,
  0.9528551405211219,
  0.9756058165617683,
  0.9883722163230542,
  0.9729583697572011,
  0.9421685772916021,
  0.954481816423282,
  0.957454684536379,
  0.9201308262119192,
  0.9694674688691238,
  0.9507662590648065,
  0.9002151646954828,
  0.9590754725515257,
  0.9885161281070769,
  0.9673885160852689,
  0.9855679603396413,
  0.965542600283203,
  0.9182580096514843,
  0.9661159994838591,
  0.9819360107344499,
  0.9674118258177999,
  0.9521274632942216,
  0.9295621241239805,
  0.9222708612130803,
  0.9358724739690978,
  0.9847515688682352,
  0.9174655728616894,
  0.9063406550177063,
  0.9094908974545218,
  0.9152493993813204,
  0.9757579941789584,
  0.9833954565101548,
  0.9163591822374421,
  0.9086657795295059,
  0.9581481787534554,
  0.9768228659850717,
  0.9350510982280111,
  0.9605878149986246,
  0.940605328452071,
  0.9368785777243221,
  0.9485512344987436,
  0.9576630950265361,
  0.9616026720184588,
  0.978080181450719,
  0.9740806497086981,
  0.9831643868522509,
  0.9310929240108063,
  0.9767450555189859,
  0.982616840537816,
  0.9699272546673201,
  0.9192523138721469,
  0.9400322495396499],
 [0.9533083877322311,
  0.9631469962829345,
  0.9500506283660276,
  0.9228959368391452,
  0.9720723738034187,
  0.9284472867778586,
  0.9657342277586229,
  0.9681153908728678,
  0.9791517294991658,
  0.9515183565978699,
  0.97748044959379,
  0.9403716552443916,
  0.9332884270712664,
  0.9866611229582704,
  0.9122635423009745,
  0.9057626848274325,
  0.9813172177499719,
  0.9884030701894578,
  0.9748944700096551,
  0.9633915133978368,
  0.9703422249355119,
  0.9714084564766696,
  0.9630890078327009,
  0.9897189354089295,
  0.9030771152204033,
  0.9535658610622786,
  0.9371926383810543,
  0.9222937577910346,
  0.9404656562175904,
  0.9872672643822565,
  0.9246480789016538,
  0.9561669609494464,
  0.9752772275021773,
  0.9637572226757887,
  0.9792147092031193,
  1.0,
  0.9883135520692451,
  0.9119235359294237,
  0.9581855173725538,
  0.9174237979330853,
  0.9559108916458673,
  0.9545362317922151,
  0.988099502520974,
  0.9426195219564093,
  0.9200285734951299,
  0.9800383136225335,
  0.9678539715430302,
  0.9462778905698923,
  0.9319582738129699,
  0.9569270626079627,
  0.9340904184226584,
  0.9458324885634006,
  0.9772504433955429,
  0.9525127033017655,
  0.9036226818396015,
  0.9174595223850338,
  0.9052253134909815,
  0.9055578851235477,
  0.9388356275548364,
  0.9480792832374644,
  0.9246197280433714,
  0.983786984426102,
  0.9117426723690548,
  0.9125383748504166,
  0.9067744108075164,
  0.9598913368072753,
  0.9252933617565834,
  0.9040675738764664,
  0.963410339452135,
  0.9417994110034347,
  0.9065267861174209,
  0.9829510693025544,
  0.956990703052428,
  0.9362540355923308,
  0.972860531209726,
  0.9101676290864618,
  0.9569614148685907,
  0.9733082162478744,
  0.9274051513020085,
  0.9250055657502904,
  0.9540637948237166,
  0.9841671431892753,
  0.9019314839944551,
  0.9584613647806689,
  0.9571238690868347,
  0.9444172969153816,
  0.9239748088960238,
  0.9347445187415141,
  0.9722386322583377,
  0.9301557181901969,
  0.9186560646604337,
  0.9135359215657993,
  0.9563292211015215,
  0.9452355912496085,
  0.9795561322327064,
  0.9753733649661233,
  0.9345672538471326,
  0.9358859775230554,
  0.981999664824497,
  0.9598641609629828,
  0.9071839984991587],
 [0.944362216333655,
  0.9610991450513616,
  0.91837608317463,
  0.971437437845309,
  0.9756596926287093,
  0.9644938234220056,
  0.916389904472661,
  0.9356789571004216,
  0.9319357522089441,
  0.9783554965811034,
  0.9635378983632727,
  0.9786906883637714,
  0.9347172202711544,
  0.9043787393114802,
  0.9374838183443814,
  0.9832912569632936,
  0.9685745837245654,
  0.9124710007621195,
  0.9136258507816499,
  0.9427488131262263,
  0.987798270426217,
  0.9750758074592528,
  0.9278784264316245,
  0.9181981134325268,
  0.920963553125417,
  0.9663077418429759,
  0.9426709156115446,
  0.9261518270413112,
  0.9341673564141951,
  0.9590724949932444,
  0.9571754582838646,
  0.9002764566232913,
  0.934605584448734,
  0.9108535541140692,
  0.9712453629750355,
  0.9883135520692451,
  1.0,
  0.985212677031887,
  0.9589524342065309,
  0.9890809439141478,
  0.9066550294790147,
  0.9799667593752311,
  0.9246624044114251,
  0.9066466383560179,
  0.9248757042980768,
  0.9693773005887605,
  0.9294116719388701,
  0.9628918545821094,
  0.9292248675637883,
  0.9149737981493178,
  0.9775750558665393,
  0.9294825629742306,
  0.9845246166510078,
  0.9482324346771828,
  0.9016338299316775,
  0.9368628671914544,
  0.9556436325675077,
  0.9565652465543235,
  0.9393242239143973,
  0.9896664637653843,
  0.9028469568290848,
  0.9697235444281006,
  0.90649956371304,
  0.9572244198592639,
  0.9292353803175238,
  0.9416631211669358,
  0.9272184825447007,
  0.9773361355906452,
  0.9475250787921726,
  0.9362750881350376,
  0.9686126817452639,
  0.9511611000297789,
  0.912607614587836,
  0.9398889915039146,
  0.9176463087448967,
  0.9139971369676325,
  0.9335728867300609,
  0.9880292147440937,
  0.9565770897859128,
  0.9171754083080405,
  0.9338938621739913,
  0.9242955001353036,
  0.9531710569474247,
  0.9589388004552564,
  0.9595322355062279,
  0.9096971846278562,
  0.9888706754290275,
  0.978718148009521,
  0.915386890978162,
  0.948983060567938,
  0.9081676941950033,
  0.9001092234385183,
  0.9362487278095785,
  0.9844101925720411,
  0.9229792790150839,
  0.9562996483863645,
  0.933073887647953,
  0.916977042063248,
  0.9112961188210413,
  0.9331007293606018,
  0.9875278612175764],
 [0.9174397639787502,
  0.9898299901371567,
  0.9549743536232109,
  0.9423095567457448,
  0.9455205588400628,
  0.9582928121809388,
  0.9022017642001472,
  0.901634498035805,
  0.9745891852527221,
  0.9072604571581975,
  0.9661152770594729,
  0.957486466925426,
  0.9095704656907776,
  0.9547157373221067,
  0.9508580004244246,
  0.9706883820313067,
  0.9388980172255623,
  0.974380532090433,
  0.9115573336698642,
  0.9443916013148347,
  0.9253439630149284,
  0.9358350757153642,
  0.9489911608610465,
  0.9014870257454848,
  0.9720658012874647,
  0.9013986540476869,
  0.9787165464104542,
  0.9012506741289099,
  0.983857474859327,
  0.9077084489768715,
  0.9016793525599238,
  0.9748117397542949,
  0.9118344148977677,
  0.9568208438633037,
  0.9390616519448866,
  0.9119235359294237,
  0.985212677031887,
  1.0,
  0.9065295588789496,
  0.9332943438245713,
  0.9093324161074036,
  0.9504407716678267,
  0.9751096673123979,
  0.9097899475562069,
  0.9153123759039906,
  0.9196820962106004,
  0.9541076201149558,
  0.908685842348331,
  0.963671883877471,
  0.9466407543763561,
  0.9883581956408809,
  0.9001373673001043,
  0.926730025923766,
  0.9506723588968059,
  0.9561022339030896,
  0.912315121355287,
  0.9530567676563519,
  0.9676791726678806,
  0.9158130736502174,
  0.989385098899101,
  0.9491407656218035,
  0.9290065889852555,
  0.9836641832031843,
  0.9643889418866988,
  0.9106149620204423,
  0.9882394077958236,
  0.9778481167216169,
  0.9143606706169136,
  0.9690064091415542,
  0.9323948719534308,
  0.9462908468088544,
  0.9712603986994979,
  0.9873526965953849,
  0.9655986042249383,
  0.9146801723117939,
  0.9195514557347286,
  0.9636992320950637,
  0.9072014000741044,
  0.9448497598712553,
  0.9075270719973489,
  0.9332522757739061,
  0.9347427193204959,
  0.924507897638919,
  0.9706996353892967,
  0.919295836456497,
  0.9463174205790521,
  0.9412002071929979,
  0.9053100990689059,
  0.9566576071105366,
  0.9214115973479562,
  0.9427935359668701,
  0.940111480545694,
  0.9493403490533893,
  0.9396869551509949,
  0.9616372213979767,
  0.9706937153052201,
  0.9320501090289504,
  0.9247888079828549,
  0.94574621813289,
  0.9032646790408884,
  0.9757199566144366],
 [0.9682302046709592,
  0.9103626405245295,
  0.9253006479093149,
  0.9457362031483681,
  0.9583382371170203,
  0.9050443252102934,
  0.9199649059296433,
  0.9746565506177122,
  0.9074685983670032,
  0.9884343159105917,
  0.9204931396842726,
  0.9489471218745817,
  0.9790588011404842,
  0.9471450293232038,
  0.9586797271328892,
  0.9147504117956801,
  0.9297628315053842,
  0.9573354877762495,
  0.9204138401591815,
  0.9805070370806471,
  0.9462045657445619,
  0.9745820181592784,
  0.9575020555330657,
  0.9329716743401841,
  0.956527553347076,
  0.934083319573385,
  0.9207034963307464,
  0.9147746361140489,
  0.9417972338593544,
  0.9653700087636201,
  0.9370920755475166,
  0.964720014040716,
  0.9330142767263588,
  0.9588037506370231,
  0.9724341080387684,
  0.9581855173725538,
  0.9589524342065309,
  0.9065295588789496,
  1.0,
  0.9759478173972088,
  0.9549809771366097,
  0.9797483338001034,
  0.9119932979461569,
  0.9453106595073337,
  0.9897064350411776,
  0.9043970404910012,
  0.9525367630458254,
  0.9432760851246969,
  0.9309769368826497,
  0.933200786256015,
  0.9412611332397341,
  0.9582170058488,
  0.9515554174497003,
  0.9167626357612765,
  0.9216327622035108,
  0.9849830737559627,
  0.9618659691109644,
  0.9173585380634637,
  0.9298054896338603,
  0.9333423151384206,
  0.961967641810455,
  0.9753540958531637,
  0.9425024570703288,
  0.9594763470687276,
  0.9008532085618678,
  0.9082537451662646,
  0.9220498956807411,
  0.9040017179402093,
  0.9865000602324335,
  0.9434710002487242,
  0.9572632525219885,
  0.9469465357181528,
  0.9632376449097907,
  0.9213561899218337,
  0.9791839434851995,
  0.9368274464980794,
  0.9246215914374987,
  0.9853117215020373,
  0.9354790264709235,
  0.939024973018222,
  0.9631990868891889,
  0.9041276471181435,
  0.9874779822988793,
  0.9359037360146669,
  0.9328181403415454,
  0.9093773123493821,
  0.9466549774946099,
  0.927192823143667,
  0.9169260599773186,
  0.9034725558476016,
  0.9603858815168361,
  0.9418972077354943,
  0.9798163280824558,
  0.9559407989660228,
  0.9251777153529674,
  0.974414733487843,
  0.9358833743962245,
  0.9409730430534463,
  0.9749403787146752,
  0.9746676582839077,
  0.9166125111762037],
 [0.9488748594634031,
  0.963422498101482,
  0.9145263390701027,
  0.9890727866594056,
  0.97973658730127,
  0.9768499065231186,
  0.9186238092067197,
  0.9779960353453423,
  0.9702989247579388,
  0.9090924179904095,
  0.9343466361886075,
  0.9652249896271967,
  0.906994654616203,
  0.9353971252644239,
  0.9412521209194575,
  0.9097067837100236,
  0.9720750491366102,
  0.9813149256330895,
  0.9330098079538551,
  0.9715676903425681,
  0.9036594378259061,
  0.9713732894405525,
  0.9627282357935191,
  0.9262801993037724,
  0.9597299916070009,
  0.9474164670929079,
  0.9336551425856012,
  0.9278938475003436,
  0.9799449785476627,
  0.9804269987826664,
  0.939015764498425,
  0.9204715475863022,
  0.9729857502682399,
  0.9859572632708858,
  0.9138176908497211,
  0.9174237979330853,
  0.9890809439141478,
  0.9332943438245713,
  0.9759478173972088,
  1.0,
  0.9600604852985315,
  0.972507343065415,
  0.9423489890088981,
  0.9093640989455383,
  0.904279166882747,
  0.9415268912943976,
  0.9097615355002873,
  0.9237465923263498,
  0.9524638768446305,
  0.9424098064022584,
  0.9254887561299435,
  0.917254996890838,
  0.9373851257340928,
  0.9060750671615533,
  0.9302145369880203,
  0.9765064554389596,
  0.9843444899272817,
  0.9453646268855734,
  0.9464186868112657,
  0.9422077177188151,
  0.9061852640334657,
  0.9615039097434099,
  0.9100492743411983,
  0.9086974671672348,
  0.9727296915322106,
  0.922962684004142,
  0.9575305195866209,
  0.9302488500341448,
  0.9006812611021306,
  0.9789817870382368,
  0.9633318706476133,
  0.9375290647877208,
  0.9038429974954493,
  0.9371001910237531,
  0.9210865211744875,
  0.9080699348054313,
  0.9218273518345436,
  0.9508301189204814,
  0.9395376951750846,
  0.959185444191204,
  0.9819329208509939,
  0.9885223015890854,
  0.9207289091762859,
  0.9676715655169826,
  0.9873820344075162,
  0.9691493865823225,
  0.9108508471610066,
  0.9132419632730124,
  0.9759137909865049,
  0.9899305227168077,
  0.9757623575701915,
  0.9169610853126912,
  0.9773409881117521,
  0.9345193358103233,
  0.9483894144143347,
  0.9612409132507466,
  0.9507497164053078,
  0.9423206884784694,
  0.9084287856047225,
  0.9569511631624594,
  0.9296877566199266],
 [0.9249094594856685,
  0.9729979692440585,
  0.91799951906019,
  0.9894204293984115,
  0.9117207003424288,
  0.9515724807467428,
  0.9580236515970312,
  0.9271945377983373,
  0.9038878832354588,
  0.9074405766885866,
  0.9642163962685404,
  0.9431781346138649,
  0.9239360424482748,
  0.9878004230790672,
  0.9064123334019943,
  0.9010159006681893,
  0.9860305357258045,
  0.9192764836306794,
  0.944952362665116,
  0.9711352311144683,
  0.9352831917550037,
  0.971692459785777,
  0.9040940541539608,
  0.9602555373755266,
  0.9113504135260241,
  0.9785382852279352,
  0.959137520707047,
  0.9002306764339902,
  0.952430568151306,
  0.930513524392509,
  0.9030566104527697,
  0.9440333790867608,
  0.907840043420187,
  0.9786573450459063,
  0.9409568316689766,
  0.9559108916458673,
  0.9066550294790147,
  0.9093324161074036,
  0.9549809771366097,
  0.9600604852985315,
  1.0,
  0.9400302054079628,
  0.9330686037464236,
  0.9243866821333879,
  0.9571095842633522,
  0.9641366263741215,
  0.9280848953043709,
  0.913529974096336,
  0.9065974767819811,
  0.9411856756187429,
  0.9357822762919544,
  0.9887223106192734,
  0.9755100566931226,
  0.9625368762682794,
  0.9552828401273744,
  0.9412632627799228,
  0.9534255376953464,
  0.9599629770308798,
  0.9683943089472509,
  0.9532699248248165,
  0.9875157372569568,
  0.9447755671232468,
  0.9441296946636757,
  0.9238345383911932,
  0.9071232803904641,
  0.9842148241026903,
  0.9765953098549776,
  0.9452919911499753,
  0.9746640474750472,
  0.9779085324388677,
  0.9230097609496226,
  0.9359636975073167,
  0.9876977532826945,
  0.9005953124211672,
  0.9040175533462664,
  0.9116874617662606,
  0.9824945685964549,
  0.9492856104318921,
  0.911148346615232,
  0.9143546466888763,
  0.943530358779219,
  0.9433369303479784,
  0.9035632984795442,
  0.9038300495686353,
  0.9792711978557402,
  0.9511957465826658,
  0.9068556720149182,
  0.9620809670944925,
  0.9005560418563856,
  0.9828928401554247,
  0.9659464465107941,
  0.9330128811673211,
  0.9767155998956663,
  0.9765402539569874,
  0.914297363785819,
  0.9868748730752952,
  0.9446725929129003,
  0.9835081330706889,
  0.9045419612602171,
  0.9406725005824959,
  0.945798731734631],
 [0.9782960234441811,
  0.9780886712626243,
  0.9567405624676072,
  0.9062091125176988,
  0.9797346729303322,
  0.9326846790686593,
  0.915345139746792,
  0.9742302537150359,
  0.9134385637350376,
  0.9102755551122621,
  0.9526924145058486,
  0.9271052243905187,
  0.9051578855278399,
  0.9427918106139986,
  0.9394362343602781,
  0.9323121657924818,
  0.9321260888078413,
  0.9426542663957764,
  0.9732199148325337,
  0.9286866189459235,
  0.9193758610866232,
  0.9783459361300308,
  0.9297931601485337,
  0.9866585188991669,
  0.98991652249351,
  0.9799650017972479,
  0.9305443959794489,
  0.9666034949438029,
  0.9197782200574667,
  0.9889843403956563,
  0.9255533586390811,
  0.962048669003359,
  0.9774851274423552,
  0.9683738275883159,
  0.9587769122247825,
  0.9545362317922151,
  0.9799667593752311,
  0.9504407716678267,
  0.9797483338001034,
  0.972507343065415,
  0.9400302054079628,
  1.0,
  0.9284885788455497,
  0.9038185279209451,
  0.974754687219524,
  0.9023768164032867,
  0.928829784390203,
  0.9070793173937909,
  0.9079796743229991,
  0.910104257751516,
  0.9827023112824438,
  0.9515529868006495,
  0.9692044314665161,
  0.9773762441097501,
  0.9664513191903983,
  0.9322114549267121,
  0.94800139828919,
  0.9427100792199404,
  0.9521110849447004,
  0.978112732477463,
  0.9045356885091388,
  0.9761700183964387,
  0.9696719988293167,
  0.9884430264906868,
  0.9419522991626862,
  0.9758110828287315,
  0.9814662387245616,
  0.9199710287418783,
  0.9641407199482422,
  0.9794497781621558,
  0.9869996404064678,
  0.9566422938520048,
  0.9086775648446703,
  0.9612753935858757,
  0.9254933627387615,
  0.9198912187402821,
  0.9510875023309121,
  0.9837111501105343,
  0.9073177134964309,
  0.9191229932925982,
  0.94165565980924,
  0.9762134311975247,
  0.9025356078106932,
  0.9405374201450634,
  0.9023587177801775,
  0.9801168380625755,
  0.9794480091600873,
  0.9700494666160067,
  0.9039667542564386,
  0.9086816718742122,
  0.936395987458175,
  0.9225495317912354,
  0.9217034711384375,
  0.9732777125757052,
  0.9688771963792118,
  0.9237062451656721,
  0.9757213808236447,
  0.9192829525834657,
  0.9243195376402725,
  0.9641812201367512,
  0.952603139525052],
 [0.9492841523475114,
  0.9013454116168588,
  0.9849601927621102,
  0.9886921037426198,
  0.9635739293268811,
  0.9716779601447143,
  0.9474366827210018,
  0.952445973746511,
  0.9341385871926172,
  0.9010325285224303,
  0.9089118195911293,
  0.9768427968253309,
  0.9640776195813542,
  0.9650842576008102,
  0.9331484627221613,
  0.9143017134643201,
  0.9503034352785961,
  0.9711057279399596,
  0.9756144329167058,
  0.9026173805090348,
  0.9364400310438228,
  0.9771282705757971,
  0.9108304675687308,
  0.9783191643739606,
  0.9027620239085872,
  0.9681496838083374,
  0.923651494912914,
  0.9391896419545238,
  0.9326581027448185,
  0.9192320977764474,
  0.9786593555250231,
  0.9107657600028635,
  0.9781495866352731,
  0.9550694159072088,
  0.9611367376928717,
  0.988099502520974,
  0.9246624044114251,
  0.9751096673123979,
  0.9119932979461569,
  0.9423489890088981,
  0.9330686037464236,
  0.9284885788455497,
  1.0,
  0.9756884623098177,
  0.9737875896276742,
  0.9873532438890609,
  0.9149797815290934,
  0.9863633421460154,
  0.9248472422511959,
  0.9786080289277611,
  0.9834019566967921,
  0.949953224157496,
  0.905194449564272,
  0.9763175266929587,
  0.9239243476318962,
  0.9177056081840979,
  0.9543555891923273,
  0.9792563749212326,
  0.906334402352487,
  0.9062393231926879,
  0.9824558010236023,
  0.9813455400846502,
  0.9537956773277853,
  0.9866764318701524,
  0.9236041496633942,
  0.9752400656763444,
  0.9073033673794602,
  0.9352798917552126,
  0.9608808996038867,
  0.9153206341806233,
  0.9028554440886154,
  0.9119866298636454,
  0.9561451464732461,
  0.9292726193914914,
  0.9838248644194014,
  0.9507113562849951,
  0.9225225024591955,
  0.9200339852270103,
  0.9332192753022208,
  0.984232937365955,
  0.9269705378457516,
  0.9084879684552446,
  0.9065623382456827,
  0.9492020423470787,
  0.9098338526960768,
  0.9875860932778526,
  0.9653612641442327,
  0.9755679438892686,
  0.9030213031117285,
  0.9348434518369938,
  0.9500851111837825,
  0.9507103920913789,
  0.909658540757576,
  0.9627194027733198,
  0.9570670347728363,
  0.9401727988754418,
  0.9435516295726053,
  0.9544986492306334,
  0.9646697335668671,
  0.9621766489560396,
  0.9661792483602571],
 [0.9581481149636056,
  0.9150019712881291,
  0.9790453575916935,
  0.9236507800705153,
  0.9682246560257461,
  0.9553464471341679,
  0.938172809392428,
  0.9018403428950181,
  0.914759124800901,
  0.9011668683437973,
  0.9329376179122547,
  0.9788408101105013,
  0.9735924241072871,
  0.9040267053324232,
  0.9291989255238631,
  0.9702597142835487,
  0.9125236905618752,
  0.9438832160559787,
  0.9200928817173287,
  0.9166248042487064,
  0.9679996967108396,
  0.9270639529902724,
  0.9227535896865984,
  0.9748301488542308,
  0.9354127805821295,
  0.9696481880722188,
  0.9366361998526267,
  0.9738820950663429,
  0.9263199259188165,
  0.9339351104878715,
  0.9187389825066733,
  0.942280350473256,
  0.9646701350846218,
  0.9668206868029038,
  0.9443759799899545,
  0.9426195219564093,
  0.9066466383560179,
  0.9097899475562069,
  0.9453106595073337,
  0.9093640989455383,
  0.9243866821333879,
  0.9038185279209451,
  0.9756884623098177,
  1.0,
  0.9299207086413536,
  0.9069428728943821,
  0.9153910360713675,
  0.9616548458928749,
  0.937849884701798,
  0.908925113071898,
  0.9847046397721774,
  0.9282710751714158,
  0.9518901308387997,
  0.9646126755866419,
  0.9634048440280469,
  0.9177655002081752,
  0.9585268484817363,
  0.9369893174236196,
  0.934602196454965,
  0.980195040182612,
  0.9184722612817372,
  0.9787826177373221,
  0.9112813234933202,
  0.9248809127213949,
  0.9568030575634514,
  0.9099711261056732,
  0.9311372968463184,
  0.9697222997922275,
  0.9631983657319638,
  0.9838438343561637,
  0.9572356878256851,
  0.9894552586565148,
  0.9736019593765544,
  0.9199729942818742,
  0.9349916783336703,
  0.9478583164579208,
  0.9438660356010712,
  0.9692893235422554,
  0.9788932007339132,
  0.9758061620868569,
  0.9063532547922253,
  0.9223791968512663,
  0.9025031496977288,
  0.9753025898506442,
  0.9794214574866995,
  0.9317758777399259,
  0.9473717994578761,
  0.9767263909164435,
  0.9815194299078744,
  0.9051326490373036,
  0.9587461331939776,
  0.9582002333785318,
  0.9380563746872312,
  0.9507637845116128,
  0.9411582358538892,
  0.9760206846258505,
  0.900033102978665,
  0.9001118544327802,
  0.9296294029760821,
  0.9824092752824544,
  0.9044342690555763],
 [0.9894381485426307,
  0.9151414691052862,
  0.9391067921596826,
  0.9833008260002537,
  0.9770263607581904,
  0.9713314843729914,
  0.9246992378116999,
  0.9385962429943434,
  0.9558423350201288,
  0.9832633003126863,
  0.9274494437559464,
  0.9387738176345293,
  0.949544330418693,
  0.9700828775490685,
  0.954780846635584,
  0.9174134271901475,
  0.9476360850795615,
  0.9449780166159112,
  0.9460163887448698,
  0.9848732226365996,
  0.9324860264623058,
  0.9804472186818426,
  0.9147696218638162,
  0.9311997909123229,
  0.9746260021309784,
  0.9082216004628685,
  0.9201357314442691,
  0.9579543846640228,
  0.9803065450196897,
  0.9734655175480991,
  0.9261138746184806,
  0.9700718535040126,
  0.9654351265017755,
  0.9221161812085295,
  0.9076324519553095,
  0.9200285734951299,
  0.9248757042980768,
  0.9153123759039906,
  0.9897064350411776,
  0.904279166882747,
  0.9571095842633522,
  0.974754687219524,
  0.9737875896276742,
  0.9299207086413536,
  1.0,
  0.9482264785947171,
  0.958881333425021,
  0.9245380221107813,
  0.9423384822146682,
  0.9716749013089373,
  0.9542464413970276,
  0.9269222983065729,
  0.9125398801716303,
  0.9679172195101771,
  0.9723939785555944,
  0.980824259873391,
  0.9391656913332836,
  0.9062828079315725,
  0.9127104470049097,
  0.9092235551167767,
  0.9364836034021855,
  0.9226569702288391,
  0.9795260244674625,
  0.9147124544868075,
  0.9530192911246952,
  0.9023184302811734,
  0.9656976731074497,
  0.9499120021838918,
  0.942208940213793,
  0.9249736085561764,
  0.9586933691948202,
  0.9488329622509488,
  0.9669852386568487,
  0.9795349572878517,
  0.9221164687181387,
  0.9799064328231253,
  0.9453183213127216,
  0.9707001727387986,
  0.9140244004095692,
  0.9348324525642611,
  0.9165660110333631,
  0.966602704934721,
  0.9286802693232808,
  0.9530289313778566,
  0.9214132913239632,
  0.9143231315125363,
  0.9288507877995833,
  0.9738479710922472,
  0.9318386918315891,
  0.9604282095758385,
  0.9673767202894525,
  0.9754045287307463,
  0.928617964683636,
  0.9780684350989136,
  0.9257989522836848,
  0.9883484989805227,
  0.9333530221600883,
  0.90922936681961,
  0.9619305250875408,
  0.9439255807223998,
  0.9450022864130808],
 [0.9058649423758312,
  0.9229226728629186,
  0.9813929833940949,
  0.9629426464721298,
  0.961593674872201,
  0.9646139984352479,
  0.9258581375790175,
  0.9393526006284,
  0.9549772169176806,
  0.9400426671315094,
  0.9666143070943686,
  0.9825237963124682,
  0.9829400216751712,
  0.929701323268622,
  0.9742767940595003,
  0.9186564714591998,
  0.9712565958786664,
  0.9581536458557921,
  0.9238339537944382,
  0.9448216260884625,
  0.9124048051347616,
  0.9808273933945363,
  0.9883910890160974,
  0.9264571260128284,
  0.915463797694618,
  0.9781276603766489,
  0.94431600174029,
  0.9312491433224347,
  0.9434842414192147,
  0.9633679411272806,
  0.9149980402774975,
  0.9069280273020832,
  0.9819091541631337,
  0.9306709770490765,
  0.9511346836253555,
  0.9800383136225335,
  0.9693773005887605,
  0.9196820962106004,
  0.9043970404910012,
  0.9415268912943976,
  0.9641366263741215,
  0.9023768164032867,
  0.9873532438890609,
  0.9069428728943821,
  0.9482264785947171,
  1.0,
  0.9568357862854251,
  0.9302051923272544,
  0.9593508556473175,
  0.973634273426321,
  0.9520218247468979,
  0.92070813839147,
  0.9373300671468507,
  0.9599228861638816,
  0.9279818517084746,
  0.9203652122474855,
  0.9144607214360543,
  0.9340285821055229,
  0.9463005469017083,
  0.9609646804395601,
  0.9710879744242767,
  0.9162477275844044,
  0.9446715074376762,
  0.9108786455334704,
  0.9092429503052611,
  0.944642355123862,
  0.9662524714391405,
  0.9000229375565182,
  0.9721206388089474,
  0.9893250036295798,
  0.9087468740994825,
  0.9311576241784764,
  0.9236090500676444,
  0.9271874211153466,
  0.9800086819926156,
  0.9431175099597278,
  0.9534186442870477,
  0.92526839955715,
  0.919546199709288,
  0.9031687131635777,
  0.938625504658701,
  0.9467384446623274,
  0.9395521272513591,
  0.9293785795480463,
  0.9023259245736172,
  0.9061569194018344,
  0.921791425104784,
  0.9068588331946258,
  0.9130349742218037,
  0.9678947621033859,
  0.9041341359736148,
  0.9502005322998585,
  0.9048838024849399,
  0.9032647526805772,
  0.9395982405555569,
  0.9090619420732353,
  0.9400284047463214,
  0.937652900585442,
  0.9369566876678346,
  0.9190951914039279,
  0.9012693687306486],
 [0.9845333486395769,
  0.9211276218133329,
  0.9153856974313589,
  0.922228499882775,
  0.9039531719904984,
  0.9372769155161923,
  0.9762491314130113,
  0.9573800899844416,
  0.9760656712238863,
  0.9166484014788134,
  0.9282756921349592,
  0.9021530389161176,
  0.9657284476935839,
  0.9189000332410536,
  0.975648289273678,
  0.908450151458752,
  0.9846283361271061,
  0.9736509434064821,
  0.9219063090424034,
  0.9897001635291752,
  0.9690838052438282,
  0.9158912586732794,
  0.9299493818410641,
  0.9383187763262312,
  0.9724457934974655,
  0.9328061476147335,
  0.9576856911806125,
  0.9369023927008487,
  0.9077640753115421,
  0.9765698974151684,
  0.9651679131604007,
  0.951474550080156,
  0.9867953015956502,
  0.9150620388205954,
  0.9709718391764465,
  0.9678539715430302,
  0.9294116719388701,
  0.9541076201149558,
  0.9525367630458254,
  0.9097615355002873,
  0.9280848953043709,
  0.928829784390203,
  0.9149797815290934,
  0.9153910360713675,
  0.958881333425021,
  0.9568357862854251,
  1.0,
  0.9521215774918321,
  0.9469288956633095,
  0.9734266957152297,
  0.9110231193246989,
  0.9855639539871859,
  0.9665520797141558,
  0.9514533663243154,
  0.9255765596983812,
  0.9182748345914109,
  0.9266609822981531,
  0.9635866694271507,
  0.9406573884848118,
  0.9697999963729825,
  0.9036951182017356,
  0.9510218699450376,
  0.9654329434698857,
  0.9868985462804317,
  0.90790646730443,
  0.928532935271996,
  0.9209071038956008,
  0.9103953176436942,
  0.9377211906337544,
  0.9022569576866803,
  0.9116601832762644,
  0.9086295117374608,
  0.9616313015272658,
  0.9884283230317412,
  0.9570109750974514,
  0.9666390008854544,
  0.9307690819916675,
  0.9777124082991935,
  0.9638486936167187,
  0.920152803842138,
  0.9739187640037859,
  0.9166329880869364,
  0.9820018268637825,
  0.9353813598309698,
  0.9770316018482608,
  0.9076576848971102,
  0.9353301180349646,
  0.9809795836104974,
  0.9112756226691138,
  0.9479474629309917,
  0.9714225964982668,
  0.9763323738479688,
  0.9204896395753669,
  0.9373411244350899,
  0.9003609979382753,
  0.913084582848417,
  0.9400435301860787,
  0.970865982444368,
  0.9890132223737133,
  0.9642369037336179,
  0.9484622836198797],
 [0.9850692661904662,
  0.9456295020608955,
  0.9217551607832569,
  0.9171160389790285,
  0.9066967224735507,
  0.9051541205601654,
  0.9860441226268034,
  0.9269860589483515,
  0.9228966223020122,
  0.922141403164274,
  0.9304691383235166,
  0.967837435511313,
  0.9344611318757099,
  0.9084923187481702,
  0.9672930245885527,
  0.9216386965432961,
  0.9885185915919021,
  0.9166518384869375,
  0.9399860622274285,
  0.9679099843048036,
  0.9746403290292661,
  0.9173689181508213,
  0.9675741059375799,
  0.97242660964539,
  0.9205577846349859,
  0.9370178895372201,
  0.9305659340604365,
  0.9125326449314352,
  0.9306403439824321,
  0.9037074081859584,
  0.9516709577277481,
  0.9678974715197723,
  0.9385464505666282,
  0.9342853401954241,
  0.9402660501067204,
  0.9462778905698923,
  0.9628918545821094,
  0.908685842348331,
  0.9432760851246969,
  0.9237465923263498,
  0.913529974096336,
  0.9070793173937909,
  0.9863633421460154,
  0.9616548458928749,
  0.9245380221107813,
  0.9302051923272544,
  0.9521215774918321,
  1.0,
  0.9597406490255076,
  0.9668297908137244,
  0.9107077800525617,
  0.9343806376846342,
  0.9094541353150956,
  0.9182404137593363,
  0.9878806576496875,
  0.9894166275125492,
  0.9574795263464045,
  0.9434549401495487,
  0.9078757604950093,
  0.9849387623579976,
  0.9104907791328095,
  0.979507491220092,
  0.9785104932864965,
  0.9516139791871484,
  0.9252746515894773,
  0.9838391456281121,
  0.9661553031761458,
  0.9446417964287038,
  0.9646563723135139,
  0.9067942987744051,
  0.9414583866088092,
  0.920130015084481,
  0.9143118199006978,
  0.9450519164846,
  0.9515635550117791,
  0.9131177425667655,
  0.9607450998361495,
  0.9406481123322809,
  0.9321953108026977,
  0.9624996329486163,
  0.9273761874500408,
  0.9011504758705432,
  0.9084067843537937,
  0.9315027617947862,
  0.9086494858468653,
  0.9516172574796756,
  0.957109201397615,
  0.9373605476163587,
  0.9146890281243696,
  0.930800109235825,
  0.9049721020771238,
  0.9568822914405717,
  0.9096112626169495,
  0.9772261304726871,
  0.9681091482720917,
  0.9279587290202775,
  0.9374684351377817,
  0.9695517325156134,
  0.9662510118642185,
  0.9106518875750232,
  0.9265280534159118],
 [0.9754081333453845,
  0.9060945870733594,
  0.9118961598979952,
  0.977923361982207,
  0.9262906805129815,
  0.9158384705773109,
  0.931642610525704,
  0.9452000459708917,
  0.9377432321891607,
  0.9078660546957482,
  0.9356012787933308,
  0.9043328754167516,
  0.9876851123177772,
  0.9251587223203397,
  0.9350457063873638,
  0.9466643227174327,
  0.9495424243227759,
  0.9176531896434224,
  0.955890812833437,
  0.9831427859482122,
  0.9241045428085022,
  0.927047700804401,
  0.9504872994275791,
  0.9264755801901546,
  0.9694966448699907,
  0.9899749858571844,
  0.975803297462198,
  0.9721578966435814,
  0.9415913048541359,
  0.9332748682450709,
  0.9853774574526997,
  0.9400888561201496,
  0.9614654479748004,
  0.9716323056763252,
  0.950781021892456,
  0.9319582738129699,
  0.9292248675637883,
  0.963671883877471,
  0.9309769368826497,
  0.9524638768446305,
  0.9065974767819811,
  0.9079796743229991,
  0.9248472422511959,
  0.937849884701798,
  0.9423384822146682,
  0.9593508556473175,
  0.9469288956633095,
  0.9597406490255076,
  1.0,
  0.903526445322221,
  0.9198348751015222,
  0.9688978624271816,
  0.9154477941515511,
  0.9004110468729655,
  0.9233098052556975,
  0.9037504027973289,
  0.9184474367412794,
  0.9239033204485679,
  0.9855534511121039,
  0.9417877380154871,
  0.9777424848800884,
  0.961798763289021,
  0.9423279829049783,
  0.9080573221307313,
  0.9036070109713007,
  0.9553425354839312,
  0.9269079976933605,
  0.9444558334819697,
  0.9295375955796005,
  0.9778358523138985,
  0.9127984625191273,
  0.9139815529019829,
  0.9212747571643828,
  0.9628400690264531,
  0.925283956094407,
  0.9011627157465064,
  0.9113030826136268,
  0.9413601846807272,
  0.9013387460106425,
  0.9414667615834876,
  0.9846033555932062,
  0.9608560593409101,
  0.9394568031720029,
  0.9789373642521555,
  0.9243425058046041,
  0.9185585416655798,
  0.9840835018799067,
  0.9056060679136337,
  0.9371543138801504,
  0.9627803535929405,
  0.9867183322759985,
  0.966801282917473,
  0.9592663485784217,
  0.9266070183655897,
  0.9489555877853962,
  0.9380804714088136,
  0.920426304844996,
  0.941692380952576,
  0.9606190637993886,
  0.9698834916980716,
  0.9401152664723827],
 [0.9764157082837631,
  0.9829866726269613,
  0.9118816328948072,
  0.9220456597801203,
  0.9768756189337748,
  0.93386171306787,
  0.9080412364954606,
  0.9858425444847976,
  0.967008252883598,
  0.968984066362226,
  0.9217172177362424,
  0.9165912869347973,
  0.949497279244488,
  0.9178350122152157,
  0.9894342042289984,
  0.9710036522832532,
  0.9502740204028172,
  0.9764796372699533,
  0.9764481176644846,
  0.95860404769024,
  0.9383715713175952,
  0.9660170888293028,
  0.9434404710085518,
  0.9216488385866539,
  0.9899650189341901,
  0.9247067205923202,
  0.9256689836067297,
  0.9778581550415777,
  0.9797791844667418,
  0.9701298021395716,
  0.9040352613543587,
  0.9008983796576611,
  0.9341060604017697,
  0.9455514792415572,
  0.9176848318450407,
  0.9569270626079627,
  0.9149737981493178,
  0.9466407543763561,
  0.933200786256015,
  0.9424098064022584,
  0.9411856756187429,
  0.910104257751516,
  0.9786080289277611,
  0.908925113071898,
  0.9716749013089373,
  0.973634273426321,
  0.9734266957152297,
  0.9668297908137244,
  0.903526445322221,
  1.0,
  0.9216801883286022,
  0.9710161369326551,
  0.9260264670594595,
  0.9733678472530978,
  0.9287506008583268,
  0.9720082467879096,
  0.9261759945985674,
  0.9556552491694736,
  0.9800334014938358,
  0.9062935247849667,
  0.9632168396125859,
  0.9528490089742734,
  0.9491331763434999,
  0.9871202546782846,
  0.9746253998531448,
  0.9802366468279671,
  0.9696307150763442,
  0.9183982513339434,
  0.9548755255725551,
  0.9266019411978222,
  0.9137556068818211,
  0.9523093005901387,
  0.9858123213279724,
  0.9867671895392015,
  0.9680222916445321,
  0.9435554090176569,
  0.9091593847289259,
  0.977429123572859,
  0.9590138177972174,
  0.9756137821356143,
  0.9449093299070159,
  0.9875375282356039,
  0.9577453496988403,
  0.922133190076326,
  0.9781859945834944,
  0.9244738183376682,
  0.9370996458330499,
  0.9379272929071688,
  0.9533068886893162,
  0.9330889676348577,
  0.9732010491008416,
  0.9546121428937415,
  0.9842212324308518,
  0.9794809548765935,
  0.9242908337807646,
  0.975656581809397,
  0.9080851156193388,
  0.9733491355086233,
  0.9285976960443747,
  0.9172728308561415,
  0.9447452523422154],
 [0.9878151664178915,
  0.9149204067248345,
  0.9212447223693084,
  0.9869168078927089,
  0.9023521750069099,
  0.9182272599078273,
  0.9286681609016767,
  0.9677565861866433,
  0.9307444869704902,
  0.9017937584535801,
  0.9345283881451116,
  0.9367817076246243,
  0.9879146332639162,
  0.9110621391857555,
  0.9879093778734356,
  0.9175767041347651,
  0.9616094366935373,
  0.9037122712123775,
  0.9209124807347748,
  0.9799497124443822,
  0.9430237505846172,
  0.9011889483701314,
  0.929403915294481,
  0.9400829745822147,
  0.9848970153700111,
  0.9246480205110003,
  0.951184545022638,
  0.9518364816989692,
  0.9444313923970371,
  0.9370596536263406,
  0.9368400394025407,
  0.9524554528446534,
  0.9664205526423545,
  0.93307047377446,
  0.9528551405211219,
  0.9340904184226584,
  0.9775750558665393,
  0.9883581956408809,
  0.9412611332397341,
  0.9254887561299435,
  0.9357822762919544,
  0.9827023112824438,
  0.9834019566967921,
  0.9847046397721774,
  0.9542464413970276,
  0.9520218247468979,
  0.9110231193246989,
  0.9107077800525617,
  0.9198348751015222,
  0.9216801883286022,
  1.0,
  0.9116223956591366,
  0.9450977953092565,
  0.932550473428988,
  0.9390446805980848,
  0.9342307473052078,
  0.9348689270883335,
  0.9546252473954936,
  0.9467162004405005,
  0.9066586880875191,
  0.9143743036100169,
  0.9605779584480563,
  0.935142620781906,
  0.9042845442709532,
  0.9637600184531053,
  0.901487043450323,
  0.9418091890762955,
  0.9095716791778989,
  0.966489164833382,
  0.9728144943376497,
  0.9257673686338269,
  0.9868361152073295,
  0.9854404889545442,
  0.9241609907457786,
  0.9711090324953948,
  0.9732780299844501,
  0.9133004196000534,
  0.9390890757750541,
  0.9052236934650646,
  0.9242464706895885,
  0.9128883074494671,
  0.9287369111769415,
  0.9694317953167064,
  0.9251460154258667,
  0.9871344805999093,
  0.9004519538958081,
  0.9809297413871747,
  0.9555381299159147,
  0.9098834438979878,
  0.915191081196853,
  0.915495384313855,
  0.9579399147332951,
  0.9633542721313001,
  0.9386161742178984,
  0.9099088278370271,
  0.985902675334918,
  0.9833329232011793,
  0.9625859846278292,
  0.9853007419638331,
  0.9007957830849368,
  0.9170541004923332],
 [0.9552459472516684,
  0.9842634613387651,
  0.9499258691176985,
  0.9003411933934643,
  0.9823515971772948,
  0.9344367010616074,
  0.9896601131303604,
  0.9423977484478979,
  0.9286099014332403,
  0.9367293035743863,
  0.9359329712385065,
  0.9410889917775944,
  0.9776234536214853,
  0.9792397986345354,
  0.938366610601615,
  0.9352994828987473,
  0.9830580041375079,
  0.9557663542790068,
  0.9330183477615047,
  0.9662382897649389,
  0.9157412336842886,
  0.989249895284135,
  0.9176073410664173,
  0.9701327508176382,
  0.9232410418009124,
  0.9003719343263843,
  0.9668907712387825,
  0.9701944749242454,
  0.9512097544684973,
  0.9664249223718071,
  0.9551917370672348,
  0.9026411452708629,
  0.9295102368844411,
  0.9828895899335733,
  0.9756058165617683,
  0.9458324885634006,
  0.9294825629742306,
  0.9001373673001043,
  0.9582170058488,
  0.917254996890838,
  0.9887223106192734,
  0.9515529868006495,
  0.949953224157496,
  0.9282710751714158,
  0.9269222983065729,
  0.92070813839147,
  0.9855639539871859,
  0.9343806376846342,
  0.9688978624271816,
  0.9710161369326551,
  0.9116223956591366,
  1.0,
  0.9832435666887596,
  0.9701949125367504,
  0.9145851185026043,
  0.9664009086733032,
  0.9091335202935842,
  0.961033087538603,
  0.9864269303552855,
  0.954907762649583,
  0.9543387792539283,
  0.9451739598381611,
  0.9692556183055697,
  0.9203883532309591,
  0.9083260253789246,
  0.9791942203444289,
  0.9597412482046914,
  0.9534490720759102,
  0.9729020614675875,
  0.9772564601888443,
  0.9048942971809272,
  0.934306806296215,
  0.9653574758260273,
  0.9712247854496473,
  0.9201783816489174,
  0.9802683554529178,
  0.9200742610458665,
  0.9748741007863166,
  0.9238333558594921,
  0.9140758845003798,
  0.9859642342166285,
  0.9839740131040827,
  0.9856508854702958,
  0.9466633142316438,
  0.9446724296996839,
  0.9199209997472346,
  0.9864472812992569,
  0.9606128889268535,
  0.984639045817791,
  0.9116520741386874,
  0.9119406690366583,
  0.9672571837941428,
  0.9822128908551975,
  0.9846523187752592,
  0.9647780125983147,
  0.934840204808561,
  0.9336433162015768,
  0.9685220009874735,
  0.9186361636331897,
  0.9837106181567473,
  0.9674327135351708],
 [0.955635909837696,
  0.987775993972614,
  0.9862114039277184,
  0.9822825451375078,
  0.9183794696844674,
  0.9871465933450522,
  0.9725301530103764,
  0.9882449938020559,
  0.9046030341667046,
  0.9136235582737445,
  0.9367244738454993,
  0.9005570714054841,
  0.9164438958005574,
  0.9163406095584101,
  0.9808564788531543,
  0.9830631669279135,
  0.9487293544708538,
  0.9123459881184681,
  0.9891596633100076,
  0.9576232729985493,
  0.9077496662681345,
  0.9520959670303174,
  0.9103719759570461,
  0.9017212205348163,
  0.9313270152199314,
  0.92327626642311,
  0.9052891341361768,
  0.9492807197706262,
  0.9893912784417378,
  0.9597490735945919,
  0.9602407145845232,
  0.9806034444721657,
  0.9406267594948013,
  0.935550481367659,
  0.9883722163230542,
  0.9772504433955429,
  0.9845246166510078,
  0.926730025923766,
  0.9515554174497003,
  0.9373851257340928,
  0.9755100566931226,
  0.9692044314665161,
  0.905194449564272,
  0.9518901308387997,
  0.9125398801716303,
  0.9373300671468507,
  0.9665520797141558,
  0.9094541353150956,
  0.9154477941515511,
  0.9260264670594595,
  0.9450977953092565,
  0.9832435666887596,
  1.0,
  0.9500126880817069,
  0.9416211427381591,
  0.9720452513280997,
  0.9047011398116326,
  0.9261697995681246,
  0.9149330459592162,
  0.9176101246364655,
  0.917446450534205,
  0.9574807842661925,
  0.9045738749657787,
  0.9710559702719269,
  0.9031722186005302,
  0.976531199395809,
  0.9276849852152458,
  0.9505595302813413,
  0.967391296003181,
  0.9438410966019765,
  0.9765433736275223,
  0.9606630490084476,
  0.9793563350228273,
  0.9715437249711985,
  0.9559995664089714,
  0.9809343333875856,
  0.936588630803503,
  0.9752849683948698,
  0.9263029351195595,
  0.9478961897944821,
  0.9899780838846969,
  0.9861777280243216,
  0.9877319236617925,
  0.9242864765857681,
  0.989880390873634,
  0.9556142179713607,
  0.9292661341960744,
  0.9809215229374625,
  0.9833768478506555,
  0.9485961330622732,
  0.9049015211324885,
  0.9402956105783231,
  0.9076316489935126,
  0.9044622556768709,
  0.9577506199022398,
  0.9176268396576795,
  0.9504232222310115,
  0.9552260316787872,
  0.9871551875132142,
  0.9539476049482741,
  0.9899293888499756],
 [0.921841973333169,
  0.9874464334687996,
  0.9142094835121425,
  0.9095313694165815,
  0.9023603030737111,
  0.9020051209928865,
  0.9571547791614186,
  0.983271265381192,
  0.9509280750188817,
  0.944889552751944,
  0.9246328869050305,
  0.9890710731751513,
  0.9292995689130551,
  0.9432131847770101,
  0.9170301891916652,
  0.945483908842535,
  0.9605315897438872,
  0.912533937580846,
  0.9027011328123579,
  0.9059009885446688,
  0.9453950727377433,
  0.973832499455182,
  0.9694315823478615,
  0.9140115328195833,
  0.9365693045997343,
  0.9515277849788472,
  0.9525499865892126,
  0.9067463967500193,
  0.9050408026991345,
  0.9096680339556316,
  0.9356206318859132,
  0.9273571306452513,
  0.9175952374869404,
  0.9358932408994133,
  0.9729583697572011,
  0.9525127033017655,
  0.9482324346771828,
  0.9506723588968059,
  0.9167626357612765,
  0.9060750671615533,
  0.9625368762682794,
  0.9773762441097501,
  0.9763175266929587,
  0.9646126755866419,
  0.9679172195101771,
  0.9599228861638816,
  0.9514533663243154,
  0.9182404137593363,
  0.9004110468729655,
  0.9733678472530978,
  0.932550473428988,
  0.9701949125367504,
  0.9500126880817069,
  1.0,
  0.9067913977552579,
  0.9076308215567132,
  0.9297695822733952,
  0.9243917934715336,
  0.9013710296126154,
  0.9800899025279174,
  0.9051223235244246,
  0.9654637006881255,
  0.9599595334639998,
  0.9303614212407103,
  0.9259500023738915,
  0.9898162607091775,
  0.9805569457758545,
  0.9806809706282371,
  0.9893453986610921,
  0.9035519591215756,
  0.944694997954314,
  0.9427501907872088,
  0.9645578444032233,
  0.9181555180677416,
  0.9828613318170234,
  0.9565581761258063,
  0.93346085131033,
  0.971915507060375,
  0.9487873432963296,
  0.9848254836608957,
  0.9673934864998747,
  0.97667284672235,
  0.9758317800503926,
  0.9356063371717127,
  0.9772422002510767,
  0.9197780208129513,
  0.9739561644099425,
  0.9339341477535371,
  0.9627901946464144,
  0.949590011560368,
  0.9816388586302504,
  0.9232004640028332,
  0.9623593551196059,
  0.9458310669692493,
  0.9531864721250677,
  0.9798904931776119,
  0.9334740756982092,
  0.9694146433731952,
  0.9344184702605968,
  0.9513954019000929,
  0.9737204337395746],
 [0.9034800161729732,
  0.9484647766270315,
  0.9671127552902905,
  0.9778531272684624,
  0.9824823798180882,
  0.9150707885310018,
  0.9653682834231404,
  0.9807914550588809,
  0.9320635847709857,
  0.9405690519047505,
  0.9011996809291605,
  0.9058601641163471,
  0.9213458421791484,
  0.9666977014279632,
  0.9618305089025656,
  0.948944176968411,
  0.9571631647509455,
  0.9428841529546728,
  0.9363271292694929,
  0.9221715730140005,
  0.9222487888419588,
  0.9101646656269015,
  0.9114403087133709,
  0.9761694570510011,
  0.9579848990541947,
  0.9307770971536115,
  0.9048752415547175,
  0.9044283079277801,
  0.9578424616383161,
  0.967854519976362,
  0.9179856536430298,
  0.978457034030403,
  0.9753426915945433,
  0.9568039333051016,
  0.9421685772916021,
  0.9036226818396015,
  0.9016338299316775,
  0.9561022339030896,
  0.9216327622035108,
  0.9302145369880203,
  0.9552828401273744,
  0.9664513191903983,
  0.9239243476318962,
  0.9634048440280469,
  0.9723939785555944,
  0.9279818517084746,
  0.9255765596983812,
  0.9878806576496875,
  0.9233098052556975,
  0.9287506008583268,
  0.9390446805980848,
  0.9145851185026043,
  0.9416211427381591,
  0.9067913977552579,
  1.0,
  0.9447970894438907,
  0.9832406418787669,
  0.9397917559307485,
  0.940343123760178,
  0.965711077797846,
  0.9782105266437573,
  0.9424674977911222,
  0.9503038262433077,
  0.927556624248829,
  0.9642362587789787,
  0.9381478112768332,
  0.901138354729573,
  0.9316618243994833,
  0.9577071595075546,
  0.97465233202901,
  0.9297161548696247,
  0.9571640690949357,
  0.9706960261274251,
  0.9887453482307482,
  0.9575758362802329,
  0.96770059532717,
  0.9001768961308376,
  0.9421330975652424,
  0.9430974679799486,
  0.9809372001156942,
  0.9167126031683945,
  0.9535186300731536,
  0.9509826557949201,
  0.9068116798234064,
  0.974974943200095,
  0.9366056490924366,
  0.9691769742889152,
  0.9381383109670414,
  0.987324457892091,
  0.9157298255089019,
  0.9026336421323067,
  0.963722663882306,
  0.9236433678162518,
  0.9532029717998207,
  0.935706768133791,
  0.9124810846674188,
  0.9404012026751568,
  0.9883236525950705,
  0.9054755947559829,
  0.9770341046747981,
  0.9791929660760498],
 [0.9584335557969397,
  0.912685620611116,
  0.9711427631405136,
  0.9091811790913628,
  0.9170402649613297,
  0.9065859665210574,
  0.9749873998064194,
  0.9070955181247258,
  0.9759859807746256,
  0.918652189445807,
  0.9459813452433076,
  0.9085763210066644,
  0.9095090608814712,
  0.9265832669682856,
  0.9683430095187702,
  0.9597647140879249,
  0.9042185611996315,
  0.9531095811119796,
  0.9551704430192417,
  0.9796860482094817,
  0.9143390704698793,
  0.9224997402489913,
  0.9728214535563806,
  0.9707756767272216,
  0.9051632709473949,
  0.9809016109819829,
  0.976789048503999,
  0.931474474121141,
  0.9609893859508152,
  0.921590830237221,
  0.9170417416896106,
  0.9229988364723577,
  0.9289176093546095,
  0.96419706534626,
  0.954481816423282,
  0.9174595223850338,
  0.9368628671914544,
  0.912315121355287,
  0.9849830737559627,
  0.9765064554389596,
  0.9412632627799228,
  0.9322114549267121,
  0.9177056081840979,
  0.9177655002081752,
  0.980824259873391,
  0.9203652122474855,
  0.9182748345914109,
  0.9894166275125492,
  0.9037504027973289,
  0.9720082467879096,
  0.9342307473052078,
  0.9664009086733032,
  0.9720452513280997,
  0.9076308215567132,
  0.9447970894438907,
  1.0,
  0.983765936825925,
  0.9099580876654503,
  0.9232201832306667,
  0.940263363577276,
  0.9697050449551103,
  0.9072028643514699,
  0.9426160648018282,
  0.9427163268371618,
  0.9006570249373236,
  0.9441429377138291,
  0.9697864404247114,
  0.9794803016298381,
  0.9525713426151959,
  0.9685450958469279,
  0.9891027141705697,
  0.9266146051961026,
  0.9268324589155831,
  0.9189797045751461,
  0.9190919171856813,
  0.9506561752813774,
  0.9737555000404403,
  0.9393088283266454,
  0.9155758916732475,
  0.949671272707679,
  0.9560676548495759,
  0.9110150237327266,
  0.9375470664720054,
  0.9342429816234746,
  0.9200505080634797,
  0.9184239793414936,
  0.9505612087075914,
  0.9774574052774233,
  0.9556893416677975,
  0.9871662029273715,
  0.9641451212201172,
  0.9674883699937384,
  0.9872697062771048,
  0.9277856057484802,
  0.9021590885062378,
  0.9414864391839897,
  0.9781210761958419,
  0.9601202082042389,
  0.9677591045407677,
  0.9130779426154336,
  0.9318677473457699],
 [0.9110312953641584,
  0.9768327010735213,
  0.9753592822394052,
  0.9723954894720844,
  0.9064917806325253,
  0.9219157379627366,
  0.9671757463739045,
  0.9897883669720098,
  0.9242047049282516,
  0.9274587245393997,
  0.9508485185313837,
  0.9733120603801129,
  0.964666070991447,
  0.9205236800554588,
  0.9026023134605975,
  0.9840607736302145,
  0.9048885737563376,
  0.9622789725635628,
  0.9049045680191525,
  0.9068009769056344,
  0.9440613255403786,
  0.9090086713558989,
  0.9084577518239628,
  0.9378206593679985,
  0.9432735273750646,
  0.9091209655591155,
  0.9725154648933789,
  0.9773185471830764,
  0.9773623880323776,
  0.9265325387895866,
  0.9264778560424616,
  0.9636866582733926,
  0.9232660809526109,
  0.9515784499572945,
  0.957454684536379,
  0.9052253134909815,
  0.9556436325675077,
  0.9530567676563519,
  0.9618659691109644,
  0.9843444899272817,
  0.9534255376953464,
  0.94800139828919,
  0.9543555891923273,
  0.9585268484817363,
  0.9391656913332836,
  0.9144607214360543,
  0.9266609822981531,
  0.9574795263464045,
  0.9184474367412794,
  0.9261759945985674,
  0.9348689270883335,
  0.9091335202935842,
  0.9047011398116326,
  0.9297695822733952,
  0.9832406418787669,
  0.983765936825925,
  1.0,
  0.9152881937925232,
  0.9541601771743928,
  0.9155635336215882,
  0.9884434280163171,
  0.9767322385274962,
  0.9513624466170496,
  0.901634163739345,
  0.9255954560582066,
  0.9266334801171167,
  0.9831029573670982,
  0.9735909354514485,
  0.9134839458093023,
  0.9299735897888635,
  0.9638079874926804,
  0.9065939619984911,
  0.9799930006413797,
  0.9402548292096521,
  0.9388391818919783,
  0.9686702368317701,
  0.9176151316182576,
  0.9348662756577628,
  0.9807039697934543,
  0.9110741855438547,
  0.9075563447565109,
  0.9313689234946226,
  0.9113973952859973,
  0.9098943720714012,
  0.9459038761716578,
  0.9227580624137985,
  0.9437311967280778,
  0.9255607290557326,
  0.9884882927072971,
  0.9508022825584985,
  0.9828140462123088,
  0.9049664481232176,
  0.9174279923028665,
  0.989833628093355,
  0.9239624478364713,
  0.9168719512603826,
  0.9263704436613106,
  0.9327519843858091,
  0.9247408066151247,
  0.9863118550720044,
  0.9665929187105619],
 [0.9294602186419905,
  0.9047837041138609,
  0.9507674239516807,
  0.9112180417438788,
  0.9864970338768195,
  0.9815913536146591,
  0.9728863899797361,
  0.9832160033989725,
  0.9357611860378588,
  0.9610825621667651,
  0.9466676754175656,
  0.9761231650631921,
  0.9582096428055503,
  0.9360425933844664,
  0.9231304843430236,
  0.906475845952058,
  0.9365037484907488,
  0.9240007437907276,
  0.9824155735597282,
  0.9507468034595303,
  0.9408771886262681,
  0.9624022962837471,
  0.9236071714299526,
  0.9182761061286907,
  0.9336758757888391,
  0.9652365904306969,
  0.9682469406520569,
  0.9796796470902069,
  0.9849396931298992,
  0.9181793092931456,
  0.9416396804830368,
  0.9598617165001928,
  0.9574000867181208,
  0.9478540327608813,
  0.9201308262119192,
  0.9055578851235477,
  0.9565652465543235,
  0.9676791726678806,
  0.9173585380634637,
  0.9453646268855734,
  0.9599629770308798,
  0.9427100792199404,
  0.9792563749212326,
  0.9369893174236196,
  0.9062828079315725,
  0.9340285821055229,
  0.9635866694271507,
  0.9434549401495487,
  0.9239033204485679,
  0.9556552491694736,
  0.9546252473954936,
  0.961033087538603,
  0.9261697995681246,
  0.9243917934715336,
  0.9397917559307485,
  0.9099580876654503,
  0.9152881937925232,
  1.0,
  0.9333525971719788,
  0.9019682006894933,
  0.9263715592776525,
  0.9880952990440558,
  0.9825985038539826,
  0.9061782327859601,
  0.9055099496393965,
  0.9663459829344966,
  0.9244457543725569,
  0.918205811443461,
  0.9620285458082609,
  0.9015792429560183,
  0.9664988681819568,
  0.9853487248115917,
  0.915770859657155,
  0.914351118941373,
  0.9058979801419301,
  0.95041521965302,
  0.9273635927990113,
  0.9099472825834651,
  0.9142589435166012,
  0.96103299341083,
  0.9606133174683437,
  0.9486647234448385,
  0.9769948289711006,
  0.9405559686151853,
  0.9893796501744098,
  0.9700138837539152,
  0.9296138418823059,
  0.9270245311817199,
  0.9836717451173852,
  0.9075151380024155,
  0.9172254007365557,
  0.91792192619266,
  0.940097391645981,
  0.9765533376862093,
  0.9723865056433704,
  0.9710542505276256,
  0.9322586854454796,
  0.9215490482464085,
  0.9655504452344864,
  0.9705376705822897,
  0.9406031508493339],
 [0.9684218598724614,
  0.9103712307086982,
  0.9615260171235637,
  0.9383258392226326,
  0.9342213117089339,
  0.9515615364087473,
  0.9183142749221068,
  0.9033839914716351,
  0.9677980261519437,
  0.9452595810520654,
  0.902953305606489,
  0.9135514648956435,
  0.9871634935539505,
  0.9086126757202931,
  0.9433416224099798,
  0.9257956174672594,
  0.975892790282857,
  0.9732291849735291,
  0.9306178810566567,
  0.9425504613627458,
  0.9317196201925567,
  0.908094111492025,
  0.9049617622591888,
  0.9312726966535082,
  0.953607705906638,
  0.9771866474596504,
  0.9743842510532102,
  0.9140721010374661,
  0.9669521182797719,
  0.9372641480264886,
  0.9772430957761564,
  0.9499453344319407,
  0.9057317564623266,
  0.9805861314691794,
  0.9694674688691238,
  0.9388356275548364,
  0.9393242239143973,
  0.9158130736502174,
  0.9298054896338603,
  0.9464186868112657,
  0.9683943089472509,
  0.9521110849447004,
  0.906334402352487,
  0.934602196454965,
  0.9127104470049097,
  0.9463005469017083,
  0.9406573884848118,
  0.9078757604950093,
  0.9855534511121039,
  0.9800334014938358,
  0.9467162004405005,
  0.9864269303552855,
  0.9149330459592162,
  0.9013710296126154,
  0.940343123760178,
  0.9232201832306667,
  0.9541601771743928,
  0.9333525971719788,
  1.0,
  0.9434881137378319,
  0.958874731712293,
  0.9623285437017682,
  0.9574646174340782,
  0.9202301391206241,
  0.9603084571621714,
  0.9666188438240901,
  0.9202327823341031,
  0.9092174213284487,
  0.9151756614828106,
  0.952591260778891,
  0.9017554094864836,
  0.9828055166438376,
  0.966399506228782,
  0.9288077870116501,
  0.9004690070468828,
  0.9228145928955508,
  0.9590013275997504,
  0.9708727711734638,
  0.9715914759602519,
  0.9844458884560048,
  0.943950018988706,
  0.9005554074992408,
  0.9591423800536757,
  0.9575563991231981,
  0.9169000898037769,
  0.9377226846178343,
  0.9612064336569293,
  0.9426366365942159,
  0.9270382462741297,
  0.9698308516937719,
  0.9696951308962852,
  0.9836301117242225,
  0.9709214377996968,
  0.9508125085811124,
  0.9697422987648021,
  0.9730934853346325,
  0.9286617937614411,
  0.9519250546286455,
  0.913743916800622,
  0.9136162200099558,
  0.9882539035529394],
 [0.9704039194467989,
  0.9591023014656332,
  0.9717175428782927,
  0.9181214797634507,
  0.9423510632301931,
  0.925704790769791,
  0.9192954502885795,
  0.9439806141782093,
  0.939877719848343,
  0.9801786010329067,
  0.9169931287401188,
  0.9853623099894644,
  0.9228027893576202,
  0.9816310585787534,
  0.9034570777667842,
  0.9233395118453861,
  0.9475791391287711,
  0.9494930628661656,
  0.9865533314579146,
  0.9239205142343634,
  0.9045899872603981,
  0.9072675948804665,
  0.983598454053908,
  0.9342212070797824,
  0.9485515931655487,
  0.9723552951341822,
  0.9424003866756865,
  0.924881898740067,
  0.920268066681301,
  0.9574437662480165,
  0.953027483747065,
  0.9690462248933118,
  0.96312462528355,
  0.9255140481648915,
  0.9507662590648065,
  0.9480792832374644,
  0.9896664637653843,
  0.989385098899101,
  0.9333423151384206,
  0.9422077177188151,
  0.9532699248248165,
  0.978112732477463,
  0.9062393231926879,
  0.980195040182612,
  0.9092235551167767,
  0.9609646804395601,
  0.9697999963729825,
  0.9849387623579976,
  0.9417877380154871,
  0.9062935247849667,
  0.9066586880875191,
  0.954907762649583,
  0.9176101246364655,
  0.9800899025279174,
  0.965711077797846,
  0.940263363577276,
  0.9155635336215882,
  0.9019682006894933,
  0.9434881137378319,
  1.0,
  0.9224898565795085,
  0.9848492581250101,
  0.9611878092069257,
  0.9877777179724909,
  0.9407127054837474,
  0.9643667255051932,
  0.9842720457556817,
  0.9126706083092023,
  0.9387172551262056,
  0.9226089599123987,
  0.9764365270636097,
  0.9209826386660298,
  0.962437335990872,
  0.9557238088830688,
  0.9054706394767604,
  0.967945772899577,
  0.9351622751445776,
  0.9853519438991643,
  0.9762870363855743,
  0.9321123176818852,
  0.9737276591853838,
  0.9240405458363794,
  0.9566821164139179,
  0.9143837366111559,
  0.9724102300074048,
  0.932630641727291,
  0.9212220447915722,
  0.9180467231742696,
  0.913405940252741,
  0.9434142835416243,
  0.9060054256308104,
  0.9046773348881018,
  0.9442636090561431,
  0.9294878986708371,
  0.9868242810436356,
  0.9099781985475403,
  0.9809895075598172,
  0.9627883802919291,
  0.9588202321737002,
  0.9410161108985252,
  0.9241282957977983],
 [0.9060093497770917,
  0.9837427076997235,
  0.905610234295763,
  0.9284200624486754,
  0.9115519609143249,
  0.9866955961453625,
  0.9009877385097945,
  0.9796177481873043,
  0.9055900113320402,
  0.9369052133932714,
  0.9285308809873263,
  0.9396032045925142,
  0.9019858171979469,
  0.9483072686630799,
  0.9619642649521329,
  0.9674440639733652,
  0.9441575931927706,
  0.9582257579503751,
  0.9326023292133373,
  0.9560260567075485,
  0.9175813335877416,
  0.9068778858989587,
  0.9265622072863282,
  0.9297397023696924,
  0.9387112592955487,
  0.9861113653191126,
  0.9354982816157853,
  0.9180378994640074,
  0.9271725467483833,
  0.987775773605956,
  0.9388340011271605,
  0.9667379375225416,
  0.9252829829580926,
  0.9490457775340445,
  0.9002151646954828,
  0.9246197280433714,
  0.9028469568290848,
  0.9491407656218035,
  0.961967641810455,
  0.9061852640334657,
  0.9875157372569568,
  0.9045356885091388,
  0.9824558010236023,
  0.9184722612817372,
  0.9364836034021855,
  0.9710879744242767,
  0.9036951182017356,
  0.9104907791328095,
  0.9777424848800884,
  0.9632168396125859,
  0.9143743036100169,
  0.9543387792539283,
  0.917446450534205,
  0.9051223235244246,
  0.9782105266437573,
  0.9697050449551103,
  0.9884434280163171,
  0.9263715592776525,
  0.958874731712293,
  0.9224898565795085,
  1.0,
  0.9471434233084245,
  0.9705474887613945,
  0.9414573591697903,
  0.9604445696925923,
  0.9369215843897373,
  0.9146291590811214,
  0.9707281624324698,
  0.9082176186003342,
  0.9132867516162351,
  0.9871555031641902,
  0.9503913705603073,
  0.9197261420276613,
  0.9490693982181728,
  0.9417345770395342,
  0.9278551162648493,
  0.9161121624975124,
  0.935963256193887,
  0.945512604863363,
  0.975583245225065,
  0.9432519280911034,
  0.9675045817236297,
  0.9641426309037027,
  0.9434216261559988,
  0.9872550455832992,
  0.9336898300014009,
  0.9054013719507294,
  0.9410705006194503,
  0.9482948240193566,
  0.9322644421034924,
  0.9541156804155339,
  0.9648126519702925,
  0.9561598224900533,
  0.9308289752622101,
  0.9684826033728369,
  0.9727660458408093,
  0.9542632750953985,
  0.9357652335941322,
  0.9303197514512939,
  0.980982466690575,
  0.9614619654542784],
 [0.903804444878008,
  0.9231851206424307,
  0.9073679886376456,
  0.9260739202812406,
  0.9599181240723957,
  0.9146534522901809,
  0.9103208214660502,
  0.9809196260395019,
  0.9447564363692482,
  0.9726272084880452,
  0.9257777025161225,
  0.9121958759408761,
  0.9155581482208456,
  0.925538534932404,
  0.9205653958382791,
  0.9765650752163137,
  0.9270167374689329,
  0.9483642750481474,
  0.9803821238330203,
  0.9001615992762361,
  0.959832174226247,
  0.9320096956318056,
  0.9022871035386669,
  0.9128687688573002,
  0.9494834686566028,
  0.9801094186664928,
  0.9546352547011815,
  0.9005216712706419,
  0.9883211711912998,
  0.9820568022066894,
  0.9822443147773743,
  0.9200415595716506,
  0.9456893366578896,
  0.912202773454356,
  0.9590754725515257,
  0.983786984426102,
  0.9697235444281006,
  0.9290065889852555,
  0.9753540958531637,
  0.9615039097434099,
  0.9447755671232468,
  0.9761700183964387,
  0.9813455400846502,
  0.9787826177373221,
  0.9226569702288391,
  0.9162477275844044,
  0.9510218699450376,
  0.979507491220092,
  0.961798763289021,
  0.9528490089742734,
  0.9605779584480563,
  0.9451739598381611,
  0.9574807842661925,
  0.9654637006881255,
  0.9424674977911222,
  0.9072028643514699,
  0.9767322385274962,
  0.9880952990440558,
  0.9623285437017682,
  0.9848492581250101,
  0.9471434233084245,
  1.0,
  0.9348479689750417,
  0.9293276494530185,
  0.9525273018781292,
  0.9747891749913717,
  0.9489031001740276,
  0.9213300779388314,
  0.9099894503737225,
  0.9364586767937533,
  0.9404752698321382,
  0.9393483318251764,
  0.9309990647260084,
  0.9551734165008924,
  0.9148753337838993,
  0.9460251057759311,
  0.9011886549081243,
  0.9102730729913341,
  0.9663858025176599,
  0.9584522788507052,
  0.9606869452866196,
  0.9424683510668993,
  0.912185097014205,
  0.9124173817243613,
  0.9855551674545551,
  0.9068202335392763,
  0.963541251339039,
  0.9874819856556546,
  0.9039594465686643,
  0.9775597426892443,
  0.941225022505077,
  0.9324377678272174,
  0.9764531297672968,
  0.9434313976792874,
  0.923637280812821,
  0.9873494164223435,
  0.9378941048505136,
  0.955646971965961,
  0.9188045224538948,
  0.9716564262356525,
  0.9581334451914498],
 [0.9472258435016989,
  0.9335610605655829,
  0.9515587569323476,
  0.9161822265529403,
  0.9377763889084434,
  0.9135066894448596,
  0.9034773170817848,
  0.9096159373030192,
  0.9676254205560161,
  0.9102514465696635,
  0.9504704131645786,
  0.9589578468321681,
  0.9228506144525364,
  0.9595921436678758,
  0.9544759699267958,
  0.9456692167963336,
  0.9518035325979108,
  0.9752139183531321,
  0.9493334256023122,
  0.9301410934085133,
  0.9250721589074201,
  0.9671423069248354,
  0.9570537188466933,
  0.9330640959625692,
  0.9782954617205223,
  0.9245813564051181,
  0.9677180890774575,
  0.9217383156811401,
  0.9412677612182074,
  0.9384015898895337,
  0.9467258088820016,
  0.9136872461276871,
  0.9441357726868678,
  0.9235697840163213,
  0.9885161281070769,
  0.9117426723690548,
  0.90649956371304,
  0.9836641832031843,
  0.9425024570703288,
  0.9100492743411983,
  0.9441296946636757,
  0.9696719988293167,
  0.9537956773277853,
  0.9112813234933202,
  0.9795260244674625,
  0.9446715074376762,
  0.9654329434698857,
  0.9785104932864965,
  0.9423279829049783,
  0.9491331763434999,
  0.935142620781906,
  0.9692556183055697,
  0.9045738749657787,
  0.9599595334639998,
  0.9503038262433077,
  0.9426160648018282,
  0.9513624466170496,
  0.9825985038539826,
  0.9574646174340782,
  0.9611878092069257,
  0.9705474887613945,
  0.9348479689750417,
  1.0,
  0.9235047737916402,
  0.9226527393523908,
  0.9131112158826681,
  0.9819381978552572,
  0.964345167229732,
  0.9381174810710613,
  0.9110545267310969,
  0.950221665001031,
  0.9796022484059212,
  0.9850104586091708,
  0.9531938275437349,
  0.9725749408644205,
  0.9530815415749688,
  0.9615867056337248,
  0.9550270310409429,
  0.9868121327186484,
  0.9713455016279697,
  0.9367251598676485,
  0.9595425727525587,
  0.9602684688365155,
  0.9382929478417483,
  0.9261162824701702,
  0.9888623284598825,
  0.9842933451260325,
  0.9134652288969385,
  0.9043810757865532,
  0.9603700626058448,
  0.9760068158696689,
  0.9261663776546571,
  0.9457860477413053,
  0.9851868864337531,
  0.9077686463059017,
  0.9544596788864474,
  0.9400794573810664,
  0.9295479100845753,
  0.9163747789170801,
  0.9646213473826429,
  0.9000987009341679],
 [0.9845428460923785,
  0.9567471276673094,
  0.9198998396344072,
  0.9005509563483051,
  0.9261539962693213,
  0.9019794546948293,
  0.9591442686573103,
  0.9350906789301028,
  0.9730211300594441,
  0.9753255454912997,
  0.9448379902949215,
  0.933296856896945,
  0.9583438634425494,
  0.9126531313090028,
  0.916287418689859,
  0.9348186484071915,
  0.9243158422342107,
  0.9242152908410368,
  0.9839862624542485,
  0.9408377806598955,
  0.9477848433218189,
  0.9887347367904994,
  0.9213660433814655,
  0.9709514973354936,
  0.9823546306385024,
  0.9260870625672115,
  0.9423006768687096,
  0.9436727256564985,
  0.9269478737129756,
  0.9272306271568689,
  0.9738393986714302,
  0.9053942403619089,
  0.927053418573171,
  0.9790495310952364,
  0.9673885160852689,
  0.9125383748504166,
  0.9572244198592639,
  0.9643889418866988,
  0.9594763470687276,
  0.9086974671672348,
  0.9238345383911932,
  0.9884430264906868,
  0.9866764318701524,
  0.9248809127213949,
  0.9147124544868075,
  0.9108786455334704,
  0.9868985462804317,
  0.9516139791871484,
  0.9080573221307313,
  0.9871202546782846,
  0.9042845442709532,
  0.9203883532309591,
  0.9710559702719269,
  0.9303614212407103,
  0.927556624248829,
  0.9427163268371618,
  0.901634163739345,
  0.9061782327859601,
  0.9202301391206241,
  0.9877777179724909,
  0.9414573591697903,
  0.9293276494530185,
  0.9235047737916402,
  1.0,
  0.9821190575469595,
  0.9042501682843402,
  0.9369330292010377,
  0.95705856906186,
  0.9208457865923169,
  0.9604640642277222,
  0.9378717469567598,
  0.9343968039979985,
  0.9508859463478154,
  0.9356923813627369,
  0.9823848946391455,
  0.9726381298174931,
  0.9402180555949602,
  0.9840075929840184,
  0.937549558158583,
  0.90145072570206,
  0.9305807410133168,
  0.9831206816274426,
  0.9021823209802889,
  0.9715469114967106,
  0.923824864916948,
  0.9833073984574161,
  0.9664107503996365,
  0.9150999282115887,
  0.9597866464398441,
  0.9378456881689677,
  0.9456335152519378,
  0.9481617885849364,
  0.9375856417061923,
  0.9129191637773622,
  0.9221211814677552,
  0.9409088948678067,
  0.9894168092278235,
  0.9782513950663304,
  0.9483287302814778,
  0.9354996059964737,
  0.912773871018061],
 [0.9660058630717843,
  0.9817350012183479,
  0.9791252675971364,
  0.9198480721575102,
  0.9238589056494474,
  0.9795898012505801,
  0.9350582892607129,
  0.9450075098446773,
  0.9464975267169952,
  0.958689360071985,
  0.9833362521688194,
  0.982643433039222,
  0.9624155354695314,
  0.9278653273982118,
  0.9603785961435997,
  0.9828852525581728,
  0.9288687893066647,
  0.9269294957124531,
  0.9221037343464389,
  0.977807690122358,
  0.9375520354363637,
  0.9117681511624413,
  0.9711788479909428,
  0.9395525790402917,
  0.9140694662861987,
  0.902762158968427,
  0.947407062387088,
  0.9574111021134314,
  0.9439766701656453,
  0.9720590226044414,
  0.9180171132934499,
  0.984029441379178,
  0.9417686446357533,
  0.9433915535939124,
  0.9855679603396413,
  0.9067744108075164,
  0.9292353803175238,
  0.9106149620204423,
  0.9008532085618678,
  0.9727296915322106,
  0.9071232803904641,
  0.9419522991626862,
  0.9236041496633942,
  0.9568030575634514,
  0.9530192911246952,
  0.9092429503052611,
  0.90790646730443,
  0.9252746515894773,
  0.9036070109713007,
  0.9746253998531448,
  0.9637600184531053,
  0.9083260253789246,
  0.9031722186005302,
  0.9259500023738915,
  0.9642362587789787,
  0.9006570249373236,
  0.9255954560582066,
  0.9055099496393965,
  0.9603084571621714,
  0.9407127054837474,
  0.9604445696925923,
  0.9525273018781292,
  0.9226527393523908,
  0.9821190575469595,
  1.0,
  0.9201008319857751,
  0.9316157015692097,
  0.9282639839297592,
  0.9554769043909109,
  0.9292740534576468,
  0.9480836725264121,
  0.9647626093206367,
  0.9599087399541826,
  0.9107353737426103,
  0.9755717477225183,
  0.9613383563424747,
  0.9091647479465069,
  0.9636613806336866,
  0.9216015526121883,
  0.9322580820431537,
  0.9827108015993682,
  0.9370703091059897,
  0.9451525771056488,
  0.9215274569942145,
  0.9424446658162373,
  0.9181839848632929,
  0.9661288698996456,
  0.9678062293743478,
  0.916428934236073,
  0.9569345562632772,
  0.9325131112790176,
  0.977593268987142,
  0.9446406325100656,
  0.9061654816880623,
  0.9391817470710259,
  0.9581130197629885,
  0.9893500288154486,
  0.9412557710166054,
  0.9600173351179693,
  0.9511193206822217,
  0.9678079635392284],
 [0.9035740507712138,
  0.9113020210777063,
  0.9758048378164754,
  0.9687359961024435,
  0.9751668256090502,
  0.9066389911365658,
  0.9228800291272228,
  0.9875487741567925,
  0.950241693376005,
  0.9571879662449745,
  0.9180064023376172,
  0.9203035577672971,
  0.962899343304684,
  0.9190803707238075,
  0.9516428067021357,
  0.9481070282778562,
  0.9120551132058118,
  0.9191798172073066,
  0.9130529872400234,
  0.9511473229304759,
  0.9465727672633422,
  0.9023862160034423,
  0.9173375097576678,
  0.9593126988521776,
  0.9759972745859394,
  0.9630393481666402,
  0.9306077331071778,
  0.9121193016371205,
  0.9585373196918844,
  0.9435454874524748,
  0.9028843787054088,
  0.9496589671329935,
  0.9108010795046037,
  0.9548003768738218,
  0.965542600283203,
  0.9598913368072753,
  0.9416631211669358,
  0.9882394077958236,
  0.9082537451662646,
  0.922962684004142,
  0.9842148241026903,
  0.9758110828287315,
  0.9752400656763444,
  0.9099711261056732,
  0.9023184302811734,
  0.944642355123862,
  0.928532935271996,
  0.9838391456281121,
  0.9553425354839312,
  0.9802366468279671,
  0.901487043450323,
  0.9791942203444289,
  0.976531199395809,
  0.9898162607091775,
  0.9381478112768332,
  0.9441429377138291,
  0.9266334801171167,
  0.9663459829344966,
  0.9666188438240901,
  0.9643667255051932,
  0.9369215843897373,
  0.9747891749913717,
  0.9131112158826681,
  0.9042501682843402,
  0.9201008319857751,
  1.0,
  0.9471501419150885,
  0.9422682955242486,
  0.930370612520629,
  0.9350304844803906,
  0.9229269204882805,
  0.9542105853286823,
  0.9163571265972009,
  0.9032323636848163,
  0.9069538016270744,
  0.9618787553312309,
  0.9041794815174878,
  0.909942227439801,
  0.981768825406419,
  0.9629082651817944,
  0.9136607746648147,
  0.9393457267164966,
  0.944041852522204,
  0.9093101817556228,
  0.9116268560363137,
  0.9100936682663281,
  0.9485001605722437,
  0.9633636584476202,
  0.9281143714817832,
  0.9087502353107234,
  0.9899869198550992,
  0.977936731083047,
  0.9751542522950878,
  0.9427089318256697,
  0.9331106040205772,
  0.9644009893538342,
  0.9045878110926516,
  0.9130737360455229,
  0.96343091888064,
  0.9300394394312559,
  0.9014449771932501],
 [0.921882565300697,
  0.960600489660732,
  0.9677104674204046,
  0.9564192992115033,
  0.9351958489324155,
  0.9031557818206761,
  0.9805583273983066,
  0.9217302720697675,
  0.9425171000972773,
  0.9788219030908831,
  0.9496246124656673,
  0.9761350408287369,
  0.9573635884450686,
  0.9634905765220347,
  0.9358702510280534,
  0.9863983302979652,
  0.9599553063244796,
  0.9052580570190355,
  0.9021888938463031,
  0.9221596494695643,
  0.954556052935196,
  0.9815162484438279,
  0.9435642501368844,
  0.9863740437445104,
  0.9311710689293616,
  0.9849192855191653,
  0.9116071091043699,
  0.9484234779860142,
  0.9332334502623841,
  0.9637006277343629,
  0.9217476807429169,
  0.9454515685443048,
  0.9108642287688368,
  0.9820511413538218,
  0.9182580096514843,
  0.9252933617565834,
  0.9272184825447007,
  0.9778481167216169,
  0.9220498956807411,
  0.9575305195866209,
  0.9765953098549776,
  0.9814662387245616,
  0.9073033673794602,
  0.9311372968463184,
  0.9656976731074497,
  0.9662524714391405,
  0.9209071038956008,
  0.9661553031761458,
  0.9269079976933605,
  0.9696307150763442,
  0.9418091890762955,
  0.9597412482046914,
  0.9276849852152458,
  0.9805569457758545,
  0.901138354729573,
  0.9697864404247114,
  0.9831029573670982,
  0.9244457543725569,
  0.9202327823341031,
  0.9842720457556817,
  0.9146291590811214,
  0.9489031001740276,
  0.9819381978552572,
  0.9369330292010377,
  0.9316157015692097,
  0.9471501419150885,
  1.0,
  0.9135762732903533,
  0.9865968684885463,
  0.9495215841926394,
  0.9613909282205383,
  0.9391647289107498,
  0.9724466538586285,
  0.9524902783679317,
  0.9422895988137876,
  0.9437984266662222,
  0.9898147604261077,
  0.9163801347103425,
  0.9506399242089484,
  0.9773728250401498,
  0.9402939165362563,
  0.9434196121856516,
  0.9533881165181128,
  0.9176899994513259,
  0.9602635904544228,
  0.9500186196158438,
  0.9663886681531885,
  0.9497263496156098,
  0.9646109351011619,
  0.9320959721323959,
  0.9044483630983561,
  0.9108524434417665,
  0.9795565299131054,
  0.9690088614001172,
  0.9025352218287497,
  0.9025393005879562,
  0.9845092175126746,
  0.9791498269323305,
  0.9186259775965927,
  0.9238188688404055,
  0.9582210950007167],
 [0.9846667314238203,
  0.97536700033498,
  0.9119597024698604,
  0.929704478655797,
  0.9713518186558754,
  0.9681246333114856,
  0.9714006117215237,
  0.9315476485927286,
  0.9503763997844038,
  0.9754071974760246,
  0.928202075286651,
  0.9847187097459151,
  0.9245857310001506,
  0.9573659635296283,
  0.9643804554008676,
  0.9760328554316002,
  0.9203858987469294,
  0.9107175975979211,
  0.9413816657176999,
  0.9896076163178434,
  0.9069584492452153,
  0.9262684065443261,
  0.9080648364004142,
  0.9460392517330448,
  0.9654657378456806,
  0.9568724420625799,
  0.9294481946524573,
  0.9612181019874416,
  0.9129288300777645,
  0.9847149521897126,
  0.9026071652665768,
  0.9426789973035251,
  0.9654208201183261,
  0.9264085694559094,
  0.9661159994838591,
  0.9040675738764664,
  0.9773361355906452,
  0.9143606706169136,
  0.9040017179402093,
  0.9302488500341448,
  0.9452919911499753,
  0.9199710287418783,
  0.9352798917552126,
  0.9697222997922275,
  0.9499120021838918,
  0.9000229375565182,
  0.9103953176436942,
  0.9446417964287038,
  0.9444558334819697,
  0.9183982513339434,
  0.9095716791778989,
  0.9534490720759102,
  0.9505595302813413,
  0.9806809706282371,
  0.9316618243994833,
  0.9794803016298381,
  0.9735909354514485,
  0.918205811443461,
  0.9092174213284487,
  0.9126706083092023,
  0.9707281624324698,
  0.9213300779388314,
  0.964345167229732,
  0.95705856906186,
  0.9282639839297592,
  0.9422682955242486,
  0.9135762732903533,
  1.0,
  0.9394806231716069,
  0.9603687202753035,
  0.9335797399949255,
  0.9217795178704833,
  0.9609338609429487,
  0.920064718640589,
  0.9899522318663994,
  0.9720004481377089,
  0.9474279273756014,
  0.9431329738449529,
  0.9836153144693928,
  0.9883779295221891,
  0.916151449772446,
  0.9082503195051501,
  0.9126787421667518,
  0.9319025140872006,
  0.9416059316857416,
  0.9361677565095142,
  0.9114245284213962,
  0.918279747917738,
  0.934240108083561,
  0.9658258160067742,
  0.9705617652201973,
  0.970831758806529,
  0.9387924298808573,
  0.9294935956489181,
  0.9677354397726128,
  0.9136875188089836,
  0.9465200364025127,
  0.9806145037176236,
  0.9132251636741073,
  0.9231515945318177,
  0.902367984299144],
 [0.9268993980003662,
  0.9889135341850649,
  0.932766716491513,
  0.9671636923944399,
  0.9387992629957871,
  0.9006915287211226,
  0.9502515406873407,
  0.9120012207392345,
  0.9616845711174578,
  0.9153027070486183,
  0.9481786415626828,
  0.9449055800037474,
  0.9300088686202396,
  0.9550217952982859,
  0.981826910151038,
  0.9466926239460411,
  0.98412128491968,
  0.9315863508686167,
  0.9464466698875442,
  0.9513698131515673,
  0.928028212426961,
  0.9089930308891099,
  0.9033845827725102,
  0.9494296029786126,
  0.9560063544719837,
  0.9539526713478618,
  0.9051711926761089,
  0.9232496302927643,
  0.9390271862222076,
  0.9611943114883049,
  0.9655990565776351,
  0.915991534863954,
  0.9140807050881693,
  0.9482107108179628,
  0.9819360107344499,
  0.963410339452135,
  0.9475250787921726,
  0.9690064091415542,
  0.9865000602324335,
  0.9006812611021306,
  0.9746640474750472,
  0.9641407199482422,
  0.9608808996038867,
  0.9631983657319638,
  0.942208940213793,
  0.9721206388089474,
  0.9377211906337544,
  0.9646563723135139,
  0.9295375955796005,
  0.9548755255725551,
  0.966489164833382,
  0.9729020614675875,
  0.967391296003181,
  0.9893453986610921,
  0.9577071595075546,
  0.9525713426151959,
  0.9134839458093023,
  0.9620285458082609,
  0.9151756614828106,
  0.9387172551262056,
  0.9082176186003342,
  0.9099894503737225,
  0.9381174810710613,
  0.9208457865923169,
  0.9554769043909109,
  0.930370612520629,
  0.9865968684885463,
  0.9394806231716069,
  1.0,
  0.9122169764627392,
  0.9117043324211226,
  0.9216688923649495,
  0.976674458991772,
  0.9315378970737638,
  0.9505128302231998,
  0.9685160276774964,
  0.9404851974954442,
  0.9504683449675696,
  0.9291083938041655,
  0.9356556694968272,
  0.9025264300794225,
  0.913819242163349,
  0.9162531160707197,
  0.9579950967327383,
  0.9339783620835383,
  0.9760574975140897,
  0.9319643434469457,
  0.9735881588730524,
  0.9528956866963961,
  0.9700493665525916,
  0.9111837111842641,
  0.9754677950000396,
  0.9133993553753859,
  0.9581862172045259,
  0.9731109285252673,
  0.9086288883006116,
  0.913255893545684,
  0.9090983287842377,
  0.9678484347646754,
  0.9239999899503082,
  0.9777484247330883],
 [0.9004409161068476,
  0.9766113099611357,
  0.9048852689284461,
  0.9577439210253087,
  0.9131015574098298,
  0.9279523036702522,
  0.9628923140035653,
  0.9016288815172862,
  0.9316512635149284,
  0.9005762701577246,
  0.9710245961393918,
  0.9634795828766398,
  0.9461636399091266,
  0.9743270490431731,
  0.9844483286145627,
  0.9358159448443818,
  0.9880297593669576,
  0.9505715119548,
  0.9159425269761956,
  0.9271984662768595,
  0.9020524374278306,
  0.9391700899224474,
  0.9374876030389986,
  0.9844683389575082,
  0.9826835557800586,
  0.9891844470708958,
  0.9630278473403997,
  0.9102385993010189,
  0.9840402344609838,
  0.9317736974271651,
  0.9480188702253247,
  0.91991764984235,
  0.9301256186469729,
  0.9513123942035896,
  0.9674118258177999,
  0.9417994110034347,
  0.9362750881350376,
  0.9323948719534308,
  0.9434710002487242,
  0.9789817870382368,
  0.9779085324388677,
  0.9794497781621558,
  0.9153206341806233,
  0.9838438343561637,
  0.9249736085561764,
  0.9893250036295798,
  0.9022569576866803,
  0.9067942987744051,
  0.9778358523138985,
  0.9266019411978222,
  0.9728144943376497,
  0.9772564601888443,
  0.9438410966019765,
  0.9035519591215756,
  0.97465233202901,
  0.9685450958469279,
  0.9299735897888635,
  0.9015792429560183,
  0.952591260778891,
  0.9226089599123987,
  0.9132867516162351,
  0.9364586767937533,
  0.9110545267310969,
  0.9604640642277222,
  0.9292740534576468,
  0.9350304844803906,
  0.9495215841926394,
  0.9603687202753035,
  0.9122169764627392,
  1.0,
  0.9261970354758731,
  0.9639162760611352,
  0.9839393181744752,
  0.9688273176481965,
  0.9309184811951727,
  0.9508986981261295,
  0.9174514827644255,
  0.9463951447280422,
  0.9818378938325867,
  0.9283246226181421,
  0.925120913694986,
  0.9792727512624335,
  0.9359502128286321,
  0.9198591815443515,
  0.9203414841647917,
  0.9373418295858129,
  0.9092124439000537,
  0.9455747689224436,
  0.950839896147835,
  0.9878698322354226,
  0.9644655493598646,
  0.9181141544063149,
  0.9026676089281902,
  0.9828976761646055,
  0.9631854590626384,
  0.9833481580103791,
  0.946979863880194,
  0.9600171504064441,
  0.9639788636743052,
  0.9208573281791872,
  0.9467973298369314],
 [0.9520208786210711,
  0.9671525122462152,
  0.9001607922923942,
  0.9265257925670599,
  0.9540231084958383,
  0.9011693596172063,
  0.9469136974667663,
  0.9662458602320306,
  0.9517753392536629,
  0.9141580169966409,
  0.9647793062549463,
  0.9300262173937418,
  0.9070687889196107,
  0.9498788733428215,
  0.9260284524601585,
  0.9476940548630916,
  0.9636025473122334,
  0.9622412157476401,
  0.944962695806635,
  0.953835866288533,
  0.939982751208601,
  0.9476511185038634,
  0.9628307560241885,
  0.9725204649623836,
  0.9332764103742979,
  0.9330685388162236,
  0.9506227893773274,
  0.903283446620705,
  0.9060058773136823,
  0.9640738837624536,
  0.9276178875795509,
  0.9771441971764647,
  0.9891278695030696,
  0.9266493311422243,
  0.9521274632942216,
  0.9065267861174209,
  0.9686126817452639,
  0.9462908468088544,
  0.9572632525219885,
  0.9633318706476133,
  0.9230097609496226,
  0.9869996404064678,
  0.9028554440886154,
  0.9572356878256851,
  0.9586933691948202,
  0.9087468740994825,
  0.9116601832762644,
  0.9414583866088092,
  0.9127984625191273,
  0.9137556068818211,
  0.9257673686338269,
  0.9048942971809272,
  0.9765433736275223,
  0.944694997954314,
  0.9297161548696247,
  0.9891027141705697,
  0.9638079874926804,
  0.9664988681819568,
  0.9017554094864836,
  0.9764365270636097,
  0.9871555031641902,
  0.9404752698321382,
  0.950221665001031,
  0.9378717469567598,
  0.9480836725264121,
  0.9229269204882805,
  0.9613909282205383,
  0.9335797399949255,
  0.9117043324211226,
  0.9261970354758731,
  1.0,
  0.9726365059049635,
  0.9021222904176712,
  0.9720025102871866,
  0.9742620945285436,
  0.9620745275024328,
  0.9748156783306092,
  0.9644950918403421,
  0.9836532244621635,
  0.9584795405198031,
  0.9491022335809474,
  0.9796757366882859,
  0.9438149778957299,
  0.9579995234184835,
  0.9261493831265329,
  0.9144553828915128,
  0.9515243983606596,
  0.9794772704000747,
  0.9633877998464837,
  0.9193370002915974,
  0.9264845037099775,
  0.9091798966089188,
  0.9693400561502914,
  0.9552096056359137,
  0.9358907842960699,
  0.9393460094747351,
  0.9153821522454227,
  0.9739903971940318,
  0.9027610386199726,
  0.9099830906489607,
  0.9588361593011634],
 [0.920529974243873,
  0.9297399580321839,
  0.9264358550640237,
  0.9151275443497547,
  0.9091394625860935,
  0.9108875338259299,
  0.9151149473335013,
  0.9757931437088018,
  0.9176414584372817,
  0.926942468506696,
  0.9143718880326491,
  0.9451168407667827,
  0.9552951949423124,
  0.9507572516055981,
  0.9540408669650157,
  0.9024874833665625,
  0.9410613837479549,
  0.9616145590892818,
  0.9890155032304262,
  0.9782031590168146,
  0.9236993864913353,
  0.9624279586463627,
  0.9553384573187941,
  0.97252771602574,
  0.9291968675083907,
  0.9341408247224134,
  0.9199107220829128,
  0.9386114736164105,
  0.9632469481733504,
  0.9442795792908956,
  0.9319430452596229,
  0.9518365129059458,
  0.9555304070384875,
  0.9313186211145864,
  0.9295621241239805,
  0.9829510693025544,
  0.9511611000297789,
  0.9712603986994979,
  0.9469465357181528,
  0.9375290647877208,
  0.9359636975073167,
  0.9566422938520048,
  0.9119866298636454,
  0.9894552586565148,
  0.9488329622509488,
  0.9311576241784764,
  0.9086295117374608,
  0.920130015084481,
  0.9139815529019829,
  0.9523093005901387,
  0.9868361152073295,
  0.934306806296215,
  0.9606630490084476,
  0.9427501907872088,
  0.9571640690949357,
  0.9266146051961026,
  0.9065939619984911,
  0.9853487248115917,
  0.9828055166438376,
  0.9209826386660298,
  0.9503913705603073,
  0.9393483318251764,
  0.9796022484059212,
  0.9343968039979985,
  0.9647626093206367,
  0.9542105853286823,
  0.9391647289107498,
  0.9217795178704833,
  0.9216688923649495,
  0.9639162760611352,
  0.9726365059049635,
  1.0,
  0.9046885341077814,
  0.9824829405637243,
  0.9655285661805201,
  0.9045049221877461,
  0.9624894729713502,
  0.988180577435151,
  0.9568482368326533,
  0.9438945241577709,
  0.9550713620999467,
  0.901674675450599,
  0.9828139314672302,
  0.9817485575620476,
  0.9117620930344625,
  0.98056060136153,
  0.9129917142162437,
  0.9390636940081996,
  0.9100675359554338,
  0.9465282786356893,
  0.9317581098122442,
  0.904854858198442,
  0.919531098337504,
  0.97756291084115,
  0.9314012968150024,
  0.9689998827777522,
  0.9877728529768326,
  0.9293229838325975,
  0.9347546273397092,
  0.9073967274504229,
  0.9724082976181203],
 [0.9014916880800823,
  0.9141226593018361,
  0.9152947987378248,
  0.9423689113805728,
  0.9390155126312201,
  0.9003386051718733,
  0.9107871783133793,
  0.978124796947596,
  0.9164079169959609,
  0.9831557571096696,
  0.9127682917333592,
  0.9319036343097968,
  0.9204279421833247,
  0.9337749759112804,
  0.9881421134281245,
  0.9790710620618954,
  0.945469644991721,
  0.9045312560588512,
  0.9804117803777981,
  0.9891047272882112,
  0.9262814686415376,
  0.9373132241339417,
  0.9138543179792803,
  0.9466384081718804,
  0.9891724060655254,
  0.9899366028456736,
  0.960620535037708,
  0.9816878752294742,
  0.9780986523402674,
  0.9435854069392487,
  0.9765775794482435,
  0.964212992406499,
  0.9432539998569758,
  0.9157312131141021,
  0.9222708612130803,
  0.956990703052428,
  0.912607614587836,
  0.9873526965953849,
  0.9632376449097907,
  0.9038429974954493,
  0.9876977532826945,
  0.9086775648446703,
  0.9561451464732461,
  0.9736019593765544,
  0.9669852386568487,
  0.9236090500676444,
  0.9616313015272658,
  0.9143118199006978,
  0.9212747571643828,
  0.9858123213279724,
  0.9854404889545442,
  0.9653574758260273,
  0.9793563350228273,
  0.9645578444032233,
  0.9706960261274251,
  0.9268324589155831,
  0.9799930006413797,
  0.915770859657155,
  0.966399506228782,
  0.962437335990872,
  0.9197261420276613,
  0.9309990647260084,
  0.9850104586091708,
  0.9508859463478154,
  0.9599087399541826,
  0.9163571265972009,
  0.9724466538586285,
  0.9609338609429487,
  0.976674458991772,
  0.9839393181744752,
  0.9021222904176712,
  0.9046885341077814,
  1.0,
  0.9292326680499091,
  0.9264343611958564,
  0.962466334914358,
  0.9309304779432603,
  0.9401324141215676,
  0.9362388565643084,
  0.9488984682832378,
  0.9260922337856262,
  0.9601243764035688,
  0.9646968403817127,
  0.9387454642856233,
  0.9150830939063436,
  0.9710736841215339,
  0.9580425117580257,
  0.9010212770580512,
  0.9127540806036789,
  0.9452053961442235,
  0.9057096247558845,
  0.9205624854995508,
  0.9221874282485886,
  0.9557457403171778,
  0.9287000559722606,
  0.9714768663650671,
  0.9755015712736049,
  0.9560764080012569,
  0.962114598668309,
  0.9377568518638807,
  0.9513725676705234],
 [0.9383760747475616,
  0.9701726265057271,
  0.9024386151391303,
  0.96480892824423,
  0.9142356381473113,
  0.9428252987386015,
  0.9453303935582661,
  0.9277440455704472,
  0.9607873424103748,
  0.9352235184376305,
  0.9148075353351092,
  0.9021135238336664,
  0.981565408938178,
  0.9096887915150025,
  0.9571671821458981,
  0.9505395408716424,
  0.9727230653727106,
  0.9366700809760453,
  0.973962960445119,
  0.947568957177382,
  0.9560685104134962,
  0.9617908597129288,
  0.9241940993585622,
  0.9686170271005445,
  0.987921175936355,
  0.9274238891072343,
  0.9791252236135584,
  0.9453932821479271,
  0.9060002618010747,
  0.9282948497827538,
  0.9753473662152662,
  0.9326098015585517,
  0.9152978188678879,
  0.9100586217274973,
  0.9358724739690978,
  0.9362540355923308,
  0.9398889915039146,
  0.9655986042249383,
  0.9213561899218337,
  0.9371001910237531,
  0.9005953124211672,
  0.9612753935858757,
  0.9292726193914914,
  0.9199729942818742,
  0.9795349572878517,
  0.9271874211153466,
  0.9884283230317412,
  0.9450519164846,
  0.9628400690264531,
  0.9867671895392015,
  0.9241609907457786,
  0.9712247854496473,
  0.9715437249711985,
  0.9181555180677416,
  0.9887453482307482,
  0.9189797045751461,
  0.9402548292096521,
  0.914351118941373,
  0.9288077870116501,
  0.9557238088830688,
  0.9490693982181728,
  0.9551734165008924,
  0.9531938275437349,
  0.9356923813627369,
  0.9107353737426103,
  0.9032323636848163,
  0.9524902783679317,
  0.920064718640589,
  0.9315378970737638,
  0.9688273176481965,
  0.9720025102871866,
  0.9824829405637243,
  0.9292326680499091,
  1.0,
  0.9564046342933749,
  0.9518599449502003,
  0.9842204353744293,
  0.9857092376713663,
  0.9385163573979183,
  0.9160934270450763,
  0.9004623009716924,
  0.9828170972433655,
  0.9741341171656097,
  0.9696938772448993,
  0.9037325825710922,
  0.9672581888774379,
  0.9869467819642666,
  0.9348945498670077,
  0.9493645904609858,
  0.9311767623407263,
  0.9539128032064247,
  0.9878436045996791,
  0.9151112777733638,
  0.9411984700442466,
  0.9386158954212486,
  0.9795230481069873,
  0.9455714131196976,
  0.919641306995418,
  0.9349145336711229,
  0.940173634091592,
  0.9709555074336575],
 [0.9207211559760083,
  0.9027885926999124,
  0.9061756677960288,
  0.9212798969026689,
  0.9231794639908991,
  0.9476867918598955,
  0.9834587191374877,
  0.9840450203575659,
  0.9029134673365237,
  0.9393789635206498,
  0.9700309297033196,
  0.9397905205201161,
  0.9230652909689646,
  0.9536678986572488,
  0.9328691145001543,
  0.9887074191597648,
  0.9865668730312682,
  0.9188640530387745,
  0.9721383419017633,
  0.9293306503445962,
  0.976009698677405,
  0.9571637050649575,
  0.9284539244276346,
  0.9727298774809903,
  0.9675855559934747,
  0.9883599045973811,
  0.9395233252816144,
  0.9319925592263659,
  0.9608384940774058,
  0.9195868953089018,
  0.9713564847112728,
  0.9278395687446399,
  0.9422212366235045,
  0.9470506023550475,
  0.9847515688682352,
  0.972860531209726,
  0.9176463087448967,
  0.9146801723117939,
  0.9791839434851995,
  0.9210865211744875,
  0.9040175533462664,
  0.9254933627387615,
  0.9838248644194014,
  0.9349916783336703,
  0.9221164687181387,
  0.9800086819926156,
  0.9570109750974514,
  0.9515635550117791,
  0.925283956094407,
  0.9680222916445321,
  0.9711090324953948,
  0.9201783816489174,
  0.9559995664089714,
  0.9828613318170234,
  0.9575758362802329,
  0.9190919171856813,
  0.9388391818919783,
  0.9058979801419301,
  0.9004690070468828,
  0.9054706394767604,
  0.9417345770395342,
  0.9148753337838993,
  0.9725749408644205,
  0.9823848946391455,
  0.9755717477225183,
  0.9069538016270744,
  0.9422895988137876,
  0.9899522318663994,
  0.9505128302231998,
  0.9309184811951727,
  0.9742620945285436,
  0.9655285661805201,
  0.9264343611958564,
  0.9564046342933749,
  1.0,
  0.9856646918577578,
  0.9631490932853447,
  0.9724226318158006,
  0.9653959832877134,
  0.9482198923203172,
  0.9504782111708764,
  0.9233880633276168,
  0.9073022515235644,
  0.9654805844945492,
  0.9584690120159548,
  0.9638794452280278,
  0.9214721356621672,
  0.9558094250893401,
  0.9660221672216521,
  0.9853302393323454,
  0.9749742562720843,
  0.9362929440191224,
  0.957165845095153,
  0.945596852661998,
  0.9874482035182764,
  0.9623193081428651,
  0.9186555598630551,
  0.961696234413942,
  0.9599486525842408,
  0.9456046247609549,
  0.9443608555584353],
 [0.9224474642052818,
  0.9779636257905121,
  0.9081997342899152,
  0.9206253067684917,
  0.9746291208750921,
  0.94784689238068,
  0.9315995871595166,
  0.9081140020871284,
  0.9355860302202691,
  0.9413672187993523,
  0.9044277297196823,
  0.9891817237189608,
  0.9473921024485125,
  0.9010266518481136,
  0.9523044325946745,
  0.913376398923291,
  0.9014912389999395,
  0.9334228168473279,
  0.9619020927476363,
  0.9574731060574673,
  0.978414792375773,
  0.9046075349152828,
  0.9736414137834416,
  0.9660354320648462,
  0.9638606519191045,
  0.9791831209288904,
  0.955739726002146,
  0.9195523820047743,
  0.9487503045442347,
  0.9602970592937878,
  0.9392432968374687,
  0.9265985799894642,
  0.9696464693481887,
  0.9269250537089772,
  0.9174655728616894,
  0.9101676290864618,
  0.9139971369676325,
  0.9195514557347286,
  0.9368274464980794,
  0.9080699348054313,
  0.9116874617662606,
  0.9198912187402821,
  0.9507113562849951,
  0.9478583164579208,
  0.9799064328231253,
  0.9431175099597278,
  0.9666390008854544,
  0.9131177425667655,
  0.9011627157465064,
  0.9435554090176569,
  0.9732780299844501,
  0.9802683554529178,
  0.9809343333875856,
  0.9565581761258063,
  0.96770059532717,
  0.9506561752813774,
  0.9686702368317701,
  0.95041521965302,
  0.9228145928955508,
  0.967945772899577,
  0.9278551162648493,
  0.9460251057759311,
  0.9530815415749688,
  0.9726381298174931,
  0.9613383563424747,
  0.9618787553312309,
  0.9437984266662222,
  0.9720004481377089,
  0.9685160276774964,
  0.9508986981261295,
  0.9620745275024328,
  0.9045049221877461,
  0.962466334914358,
  0.9518599449502003,
  0.9856646918577578,
  1.0,
  0.9857362080891896,
  0.9715714130290012,
  0.9069234877159232,
  0.9453437876511411,
  0.9884485258419407,
  0.9045959392253289,
  0.9028204998856276,
  0.9281290940147879,
  0.9073154917351909,
  0.9347981665003348,
  0.9281840850090285,
  0.948213704777952,
  0.9778364661261993,
  0.9817751717004014,
  0.982322541878612,
  0.9067835972513447,
  0.9760418857954436,
  0.9384651454457378,
  0.9747569245209192,
  0.9301728066073658,
  0.9615628201480524,
  0.9029183585303411,
  0.9094554624040144,
  0.91017881065149,
  0.9846298658079666],
 [0.9522928188114389,
  0.9620240999325361,
  0.9373906164533262,
  0.9336880019099314,
  0.9883022716043659,
  0.9265576708111933,
  0.9101504135120534,
  0.967134051655747,
  0.9719422966380592,
  0.9392186311750882,
  0.9317042484482284,
  0.9830092286359375,
  0.9597032014071897,
  0.9230231471061554,
  0.950516753319042,
  0.9203056073496729,
  0.9794579990698733,
  0.9127663746077742,
  0.9551121725390552,
  0.959688238744434,
  0.9782333122539902,
  0.9419185723442653,
  0.9898435003100318,
  0.9789422520162714,
  0.9750307658220795,
  0.9144596230755967,
  0.9704208648857797,
  0.9313283698118486,
  0.9528750483624959,
  0.934348277425682,
  0.9071211152001852,
  0.9654198522453556,
  0.9764849780051237,
  0.9594482029477,
  0.9063406550177063,
  0.9569614148685907,
  0.9335728867300609,
  0.9636992320950637,
  0.9246215914374987,
  0.9218273518345436,
  0.9824945685964549,
  0.9510875023309121,
  0.9225225024591955,
  0.9438660356010712,
  0.9453183213127216,
  0.9534186442870477,
  0.9307690819916675,
  0.9607450998361495,
  0.9113030826136268,
  0.9091593847289259,
  0.9133004196000534,
  0.9200742610458665,
  0.936588630803503,
  0.93346085131033,
  0.9001768961308376,
  0.9737555000404403,
  0.9176151316182576,
  0.9273635927990113,
  0.9590013275997504,
  0.9351622751445776,
  0.9161121624975124,
  0.9011886549081243,
  0.9615867056337248,
  0.9402180555949602,
  0.9091647479465069,
  0.9041794815174878,
  0.9898147604261077,
  0.9474279273756014,
  0.9404851974954442,
  0.9174514827644255,
  0.9748156783306092,
  0.9624894729713502,
  0.9309304779432603,
  0.9842204353744293,
  0.9631490932853447,
  0.9857362080891896,
  1.0,
  0.9121220978315977,
  0.9336558286763382,
  0.9491126903450344,
  0.9788986483663196,
  0.9713267860397087,
  0.9124556891916319,
  0.961974246436921,
  0.987509220339645,
  0.9451342709139408,
  0.9246976613402638,
  0.9168588304779224,
  0.904407286511445,
  0.9103049607518543,
  0.9477963894931417,
  0.9445957257697181,
  0.935303303646704,
  0.9289405358427518,
  0.9495578325114933,
  0.9592933074237786,
  0.9319449107490212,
  0.9658787261543096,
  0.9000344952619073,
  0.9101202836286175,
  0.925712623197755],
 [0.9199961525121685,
  0.9479440166369044,
  0.9872880272549558,
  0.9383216246771582,
  0.9110791584650055,
  0.9786340817816828,
  0.9562678676286002,
  0.9238542919728423,
  0.9464736027560853,
  0.9801362638040084,
  0.9415625952943784,
  0.9096722622001644,
  0.9434893298045298,
  0.9268325266083476,
  0.932005432337673,
  0.9446542137894907,
  0.9774948925122662,
  0.9671811806447657,
  0.9004962094389087,
  0.9858068574456972,
  0.9438265052742111,
  0.9422967021277732,
  0.9653518291955873,
  0.9517560689608162,
  0.9118140689721386,
  0.9891544751824282,
  0.9007435822482046,
  0.9414282037480969,
  0.9780541747598428,
  0.9638073288619897,
  0.9646185025389106,
  0.9551159864154386,
  0.9643632741982497,
  0.9475368502174926,
  0.9094908974545218,
  0.9733082162478744,
  0.9880292147440937,
  0.9072014000741044,
  0.9853117215020373,
  0.9508301189204814,
  0.9492856104318921,
  0.9837111501105343,
  0.9200339852270103,
  0.9692893235422554,
  0.9707001727387986,
  0.92526839955715,
  0.9777124082991935,
  0.9406481123322809,
  0.9413601846807272,
  0.977429123572859,
  0.9390890757750541,
  0.9748741007863166,
  0.9752849683948698,
  0.971915507060375,
  0.9421330975652424,
  0.9393088283266454,
  0.9348662756577628,
  0.9099472825834651,
  0.9708727711734638,
  0.9853519438991643,
  0.935963256193887,
  0.9102730729913341,
  0.9550270310409429,
  0.9840075929840184,
  0.9636613806336866,
  0.909942227439801,
  0.9163801347103425,
  0.9431329738449529,
  0.9504683449675696,
  0.9463951447280422,
  0.9644950918403421,
  0.988180577435151,
  0.9401324141215676,
  0.9857092376713663,
  0.9724226318158006,
  0.9715714130290012,
  0.9121220978315977,
  1.0,
  0.9549782608482853,
  0.9671463417228932,
  0.9614325154264444,
  0.9401506425869788,
  0.9537575590955853,
  0.9371919325200203,
  0.9083812108298113,
  0.9121729377064858,
  0.9765764011891916,
  0.9733170411953209,
  0.9623868468580853,
  0.9825649586908793,
  0.9488432072210596,
  0.9118406422652924,
  0.9859803563832649,
  0.9215523596317694,
  0.9879283986099284,
  0.9651445692550777,
  0.9192203844010853,
  0.9716412295868676,
  0.9556768081284739,
  0.9879880952640332,
  0.988746680573355],
 [0.9632044157114901,
  0.9468702029322017,
  0.9485632208318525,
  0.9730465866243213,
  0.9438891134124272,
  0.9813811561624751,
  0.9617000540968607,
  0.9345327097560583,
  0.924158425430106,
  0.9246239865509539,
  0.9423019515388917,
  0.9285346670779067,
  0.9758748620859604,
  0.9264664611176879,
  0.9288486037872103,
  0.9690177745115875,
  0.9872858523774659,
  0.9424170002504895,
  0.9399190198277899,
  0.9495064439189116,
  0.9739819524629753,
  0.9614350908331243,
  0.9655370008891004,
  0.9306827014252799,
  0.9343379987787273,
  0.9348837186389561,
  0.9636803189546249,
  0.9445674062708606,
  0.940505990779442,
  0.9380566311645717,
  0.9245433481798372,
  0.9222205304076141,
  0.9454615134192406,
  0.9784380121037084,
  0.9152493993813204,
  0.9274051513020085,
  0.9565770897859128,
  0.9448497598712553,
  0.9354790264709235,
  0.9395376951750846,
  0.911148346615232,
  0.9073177134964309,
  0.9332192753022208,
  0.9788932007339132,
  0.9140244004095692,
  0.919546199709288,
  0.9638486936167187,
  0.9321953108026977,
  0.9013387460106425,
  0.9590138177972174,
  0.9052236934650646,
  0.9238333558594921,
  0.9263029351195595,
  0.9487873432963296,
  0.9430974679799486,
  0.9155758916732475,
  0.9807039697934543,
  0.9142589435166012,
  0.9715914759602519,
  0.9762870363855743,
  0.945512604863363,
  0.9663858025176599,
  0.9868121327186484,
  0.937549558158583,
  0.9216015526121883,
  0.981768825406419,
  0.9506399242089484,
  0.9836153144693928,
  0.9291083938041655,
  0.9818378938325867,
  0.9836532244621635,
  0.9568482368326533,
  0.9362388565643084,
  0.9385163573979183,
  0.9653959832877134,
  0.9069234877159232,
  0.9336558286763382,
  0.9549782608482853,
  1.0,
  0.9555666785000603,
  0.9373047675560182,
  0.9710479369608903,
  0.9511125050435333,
  0.9700366903224845,
  0.9256671184277744,
  0.9874413379184896,
  0.9182489503653471,
  0.9385476569481046,
  0.9373041837872264,
  0.9880359861513303,
  0.9786140031878028,
  0.9890863797007483,
  0.9043149464044793,
  0.9250941639080026,
  0.9036102355315533,
  0.920679254920783,
  0.9491045889802641,
  0.9685179062511391,
  0.960992521327694,
  0.9271528729879739,
  0.9538259447975725],
 [0.9491542612356813,
  0.9554307151114116,
  0.9293792382472923,
  0.986242467041733,
  0.9113553033450963,
  0.9710091031200823,
  0.9217858915974388,
  0.9110728305469357,
  0.9312611966249718,
  0.933837716106758,
  0.9247776286910833,
  0.9580061821367594,
  0.9635565751852145,
  0.9027269268522753,
  0.9574910128986589,
  0.9445100876957984,
  0.930376698738652,
  0.9196337261707582,
  0.9701617128365914,
  0.9446067871293174,
  0.9226593045458273,
  0.9077787245852976,
  0.9889523601936084,
  0.9620339662075076,
  0.9476426892029851,
  0.9004700371502267,
  0.9124984208255341,
  0.9015751775581216,
  0.911549384958575,
  0.9196482795397307,
  0.9218634603721533,
  0.9435786272519502,
  0.9821661530225735,
  0.9651103976940834,
  0.9757579941789584,
  0.9250055657502904,
  0.9171754083080405,
  0.9075270719973489,
  0.939024973018222,
  0.959185444191204,
  0.9143546466888763,
  0.9191229932925982,
  0.984232937365955,
  0.9758061620868569,
  0.9348324525642611,
  0.9031687131635777,
  0.920152803842138,
  0.9624996329486163,
  0.9414667615834876,
  0.9756137821356143,
  0.9242464706895885,
  0.9140758845003798,
  0.9478961897944821,
  0.9848254836608957,
  0.9809372001156942,
  0.949671272707679,
  0.9110741855438547,
  0.96103299341083,
  0.9844458884560048,
  0.9321123176818852,
  0.975583245225065,
  0.9584522788507052,
  0.9713455016279697,
  0.90145072570206,
  0.9322580820431537,
  0.9629082651817944,
  0.9773728250401498,
  0.9883779295221891,
  0.9356556694968272,
  0.9283246226181421,
  0.9584795405198031,
  0.9438945241577709,
  0.9488984682832378,
  0.9160934270450763,
  0.9482198923203172,
  0.9453437876511411,
  0.9491126903450344,
  0.9671463417228932,
  0.9555666785000603,
  1.0,
  0.9499794563549284,
  0.9102128555130549,
  0.9735108605786693,
  0.9478214015124161,
  0.9009166583151587,
  0.9155366752457706,
  0.9100401517292493,
  0.9687649110032387,
  0.9164730321384676,
  0.9125376675128992,
  0.9404412756701211,
  0.9076540389386906,
  0.9700616789425465,
  0.9109903878281567,
  0.9063610718936623,
  0.9859648269512684,
  0.9377983482421781,
  0.9232770856414216,
  0.9084159999923851,
  0.9522230351143632,
  0.924882278724804],
 [0.9337984090384096,
  0.9040827500385848,
  0.9437450466602555,
  0.9856255324050301,
  0.9582324018486614,
  0.9202244497934501,
  0.9396462786454763,
  0.9255235569913431,
  0.9262873922048747,
  0.9449445202098778,
  0.9096398729535121,
  0.9456254226479763,
  0.9291694097920242,
  0.9223153943160102,
  0.9146338327690842,
  0.9884069526848746,
  0.9566366013533673,
  0.9413099456587602,
  0.9022229529273156,
  0.9059523685105059,
  0.9303817710791313,
  0.9451250000894256,
  0.9859941392997256,
  0.9307645100546135,
  0.9127638904163443,
  0.9000408228887664,
  0.9545895049882293,
  0.9253833356940919,
  0.9854493864471257,
  0.9190191021499637,
  0.931838202292004,
  0.919151092647737,
  0.9811818309434606,
  0.958577984929933,
  0.9833954565101548,
  0.9540637948237166,
  0.9338938621739913,
  0.9332522757739061,
  0.9631990868891889,
  0.9819329208509939,
  0.943530358779219,
  0.94165565980924,
  0.9269705378457516,
  0.9063532547922253,
  0.9165660110333631,
  0.938625504658701,
  0.9739187640037859,
  0.9273761874500408,
  0.9846033555932062,
  0.9449093299070159,
  0.9128883074494671,
  0.9859642342166285,
  0.9899780838846969,
  0.9673934864998747,
  0.9167126031683945,
  0.9560676548495759,
  0.9075563447565109,
  0.9606133174683437,
  0.943950018988706,
  0.9737276591853838,
  0.9432519280911034,
  0.9606869452866196,
  0.9367251598676485,
  0.9305807410133168,
  0.9827108015993682,
  0.9136607746648147,
  0.9402939165362563,
  0.916151449772446,
  0.9025264300794225,
  0.925120913694986,
  0.9491022335809474,
  0.9550713620999467,
  0.9260922337856262,
  0.9004623009716924,
  0.9504782111708764,
  0.9884485258419407,
  0.9788986483663196,
  0.9614325154264444,
  0.9373047675560182,
  0.9499794563549284,
  1.0,
  0.9309465281543146,
  0.9107441238388069,
  0.9016156172145475,
  0.9842618016097415,
  0.9271223383440765,
  0.9840308430526192,
  0.9783695327127209,
  0.9557009561784972,
  0.9007503035330189,
  0.9507328465120731,
  0.9755618589234928,
  0.9726081844642036,
  0.9327957346391299,
  0.9597594152560882,
  0.9398420987487701,
  0.979718656396388,
  0.9699399039807494,
  0.9393375966525137,
  0.93469047020103,
  0.9427943869165551],
 [0.9484291964555271,
  0.9673668404459292,
  0.9130148580787044,
  0.9180899057703888,
  0.9311885979750019,
  0.9823363478576825,
  0.9689218096163301,
  0.9419511953108008,
  0.9370998934510114,
  0.9348103674027415,
  0.9530413277467168,
  0.9576387599953516,
  0.9172657892733536,
  0.9048165594531055,
  0.9672461563734607,
  0.9870211405021594,
  0.9822264598619874,
  0.9043650587850246,
  0.9166036560439312,
  0.9341903859946796,
  0.9698641522914164,
  0.9168245773440011,
  0.9744439293124526,
  0.9409329135532691,
  0.9027368513749251,
  0.966966458439488,
  0.9072322842266999,
  0.9560358095035252,
  0.9439664696020329,
  0.9023471129696665,
  0.9692679275240244,
  0.9507730033627284,
  0.9632858080800953,
  0.9855477792227614,
  0.9163591822374421,
  0.9841671431892753,
  0.9242955001353036,
  0.9347427193204959,
  0.9041276471181435,
  0.9885223015890854,
  0.9433369303479784,
  0.9762134311975247,
  0.9084879684552446,
  0.9223791968512663,
  0.966602704934721,
  0.9467384446623274,
  0.9166329880869364,
  0.9011504758705432,
  0.9608560593409101,
  0.9875375282356039,
  0.9287369111769415,
  0.9839740131040827,
  0.9861777280243216,
  0.97667284672235,
  0.9535186300731536,
  0.9110150237327266,
  0.9313689234946226,
  0.9486647234448385,
  0.9005554074992408,
  0.9240405458363794,
  0.9675045817236297,
  0.9424683510668993,
  0.9595425727525587,
  0.9831206816274426,
  0.9370703091059897,
  0.9393457267164966,
  0.9434196121856516,
  0.9082503195051501,
  0.913819242163349,
  0.9792727512624335,
  0.9796757366882859,
  0.901674675450599,
  0.9601243764035688,
  0.9828170972433655,
  0.9233880633276168,
  0.9045959392253289,
  0.9713267860397087,
  0.9401506425869788,
  0.9710479369608903,
  0.9102128555130549,
  0.9309465281543146,
  1.0,
  0.9064599920707576,
  0.9206390867419392,
  0.970832821929872,
  0.9618151212439335,
  0.9406110791389382,
  0.9194890336008632,
  0.981310277304891,
  0.9432057566931068,
  0.9525902920921924,
  0.9691339457229394,
  0.952773019908622,
  0.9686821458376074,
  0.932631358538738,
  0.9858175210860458,
  0.9598758213536994,
  0.972546340913574,
  0.9640122439152483,
  0.9743399464829599,
  0.9874996822407519],
 [0.9846609414768962,
  0.9210423368590352,
  0.9409353410196135,
  0.9226247847468302,
  0.9526287185555448,
  0.9394610206325801,
  0.944193134007439,
  0.9563258050852578,
  0.9046475684138413,
  0.9567863914224574,
  0.9731978459818708,
  0.9694512876921514,
  0.9499269279894499,
  0.968512457759007,
  0.9030926169592485,
  0.9057821235185937,
  0.956034186119812,
  0.9354970431085607,
  0.900578209127893,
  0.9557430237217872,
  0.9079387738923055,
  0.9529484927227977,
  0.9770388046600812,
  0.9431972477844721,
  0.9772159145419227,
  0.9237240712644342,
  0.9489296532999523,
  0.9671221980143467,
  0.9524447418756639,
  0.9244330091967284,
  0.967713706190998,
  0.9825088152880594,
  0.9584006334387275,
  0.9682552031150536,
  0.9086657795295059,
  0.9019314839944551,
  0.9531710569474247,
  0.924507897638919,
  0.9874779822988793,
  0.9207289091762859,
  0.9035632984795442,
  0.9025356078106932,
  0.9065623382456827,
  0.9025031496977288,
  0.9286802693232808,
  0.9395521272513591,
  0.9820018268637825,
  0.9084067843537937,
  0.9394568031720029,
  0.9577453496988403,
  0.9694317953167064,
  0.9856508854702958,
  0.9877319236617925,
  0.9758317800503926,
  0.9509826557949201,
  0.9375470664720054,
  0.9113973952859973,
  0.9769948289711006,
  0.9591423800536757,
  0.9566821164139179,
  0.9641426309037027,
  0.912185097014205,
  0.9602684688365155,
  0.9021823209802889,
  0.9451525771056488,
  0.944041852522204,
  0.9533881165181128,
  0.9126787421667518,
  0.9162531160707197,
  0.9359502128286321,
  0.9438149778957299,
  0.9828139314672302,
  0.9646968403817127,
  0.9741341171656097,
  0.9073022515235644,
  0.9028204998856276,
  0.9124556891916319,
  0.9537575590955853,
  0.9511125050435333,
  0.9735108605786693,
  0.9107441238388069,
  0.9064599920707576,
  1.0,
  0.9300565762274785,
  0.9270261886624803,
  0.9850692157751022,
  0.9028292171978458,
  0.914057586605542,
  0.976594734566858,
  0.9856353990637433,
  0.9270306031439078,
  0.929647769400689,
  0.9422418880512519,
  0.952337567414618,
  0.954210402184985,
  0.9177080905308656,
  0.9873094413813696,
  0.938607522288734,
  0.9627927020299971,
  0.971755930082604,
  0.9648585464928434],
 [0.9104546030167203,
  0.9210675966330805,
  0.9577292704481413,
  0.9221934131949906,
  0.9653198681988948,
  0.9662518197929026,
  0.9857393820832754,
  0.9157470478798622,
  0.9508717441179884,
  0.9402583449587366,
  0.9217444980486076,
  0.9854621826560133,
  0.9550587689899612,
  0.9150833201694224,
  0.9637894052166687,
  0.9321003614396561,
  0.980898779184155,
  0.9468640246386331,
  0.9669515152584365,
  0.9300000665233388,
  0.9757313193894155,
  0.9176221725194796,
  0.958472988499714,
  0.9824685238940627,
  0.9075269535794376,
  0.9260654235574608,
  0.9513389125696444,
  0.9555791799183185,
  0.9456629907342652,
  0.9083528492484522,
  0.9099147892322917,
  0.912857648162201,
  0.9502514352380262,
  0.9684687699996991,
  0.9581481787534554,
  0.9584613647806689,
  0.9589388004552564,
  0.9706996353892967,
  0.9359037360146669,
  0.9676715655169826,
  0.9038300495686353,
  0.9405374201450634,
  0.9492020423470787,
  0.9753025898506442,
  0.9530289313778566,
  0.9293785795480463,
  0.9353813598309698,
  0.9315027617947862,
  0.9789373642521555,
  0.922133190076326,
  0.9251460154258667,
  0.9466633142316438,
  0.9242864765857681,
  0.9356063371717127,
  0.9068116798234064,
  0.9342429816234746,
  0.9098943720714012,
  0.9405559686151853,
  0.9575563991231981,
  0.9143837366111559,
  0.9434216261559988,
  0.9124173817243613,
  0.9382929478417483,
  0.9715469114967106,
  0.9215274569942145,
  0.9093101817556228,
  0.9176899994513259,
  0.9319025140872006,
  0.9579950967327383,
  0.9198591815443515,
  0.9579995234184835,
  0.9817485575620476,
  0.9387454642856233,
  0.9696938772448993,
  0.9654805844945492,
  0.9281290940147879,
  0.961974246436921,
  0.9371919325200203,
  0.9700366903224845,
  0.9478214015124161,
  0.9016156172145475,
  0.9206390867419392,
  0.9300565762274785,
  1.0,
  0.9644401268083809,
  0.9417070743195473,
  0.9729812927407245,
  0.9879514163919116,
  0.9647086468419237,
  0.9220198335587778,
  0.905146253787433,
  0.9034512880111728,
  0.9737295787905238,
  0.9488801203309365,
  0.978481059090762,
  0.9461350783709827,
  0.9650796299028582,
  0.9680493047472235,
  0.9389242479713026,
  0.9483469781978988,
  0.9875735418873368],
 [0.9837140385340799,
  0.9483937372430169,
  0.9433029530319824,
  0.9049783209673271,
  0.9804401222534213,
  0.9285701188769739,
  0.9081114669261903,
  0.9626837524582719,
  0.9313788433936824,
  0.9372047891548749,
  0.9601045607101693,
  0.9360644283787163,
  0.9803151229033447,
  0.9622806732975029,
  0.9787798098239482,
  0.9452715832677132,
  0.9698413602382628,
  0.9568606813742531,
  0.9062832724189729,
  0.9732738137184012,
  0.9523511441648641,
  0.9699246160765338,
  0.9899816023149554,
  0.9273312512517375,
  0.9263623132618012,
  0.9676426814503961,
  0.988936423872484,
  0.9585746909715853,
  0.9072605494668003,
  0.9271469290103598,
  0.9401335874051009,
  0.9299139371535382,
  0.9295130180919544,
  0.9495741466212028,
  0.9768228659850717,
  0.9571238690868347,
  0.9595322355062279,
  0.919295836456497,
  0.9328181403415454,
  0.9873820344075162,
  0.9792711978557402,
  0.9023587177801775,
  0.9098338526960768,
  0.9794214574866995,
  0.9214132913239632,
  0.9023259245736172,
  0.9770316018482608,
  0.9086494858468653,
  0.9243425058046041,
  0.9781859945834944,
  0.9871344805999093,
  0.9446724296996839,
  0.989880390873634,
  0.9772422002510767,
  0.974974943200095,
  0.9200505080634797,
  0.9459038761716578,
  0.9893796501744098,
  0.9169000898037769,
  0.9724102300074048,
  0.9872550455832992,
  0.9855551674545551,
  0.9261162824701702,
  0.923824864916948,
  0.9424446658162373,
  0.9116268560363137,
  0.9602635904544228,
  0.9416059316857416,
  0.9339783620835383,
  0.9203414841647917,
  0.9261493831265329,
  0.9117620930344625,
  0.9150830939063436,
  0.9037325825710922,
  0.9584690120159548,
  0.9073154917351909,
  0.987509220339645,
  0.9083812108298113,
  0.9256671184277744,
  0.9009166583151587,
  0.9842618016097415,
  0.970832821929872,
  0.9270261886624803,
  0.9644401268083809,
  1.0,
  0.9753050871229167,
  0.902621989521346,
  0.9831528509525234,
  0.9753083746033668,
  0.97792918960459,
  0.948664286530149,
  0.9639220722525391,
  0.9032590310236273,
  0.9150840266793495,
  0.935773396337412,
  0.9675137109011305,
  0.9334372125085082,
  0.9009956569079991,
  0.9180146627306689,
  0.9096609139311365,
  0.9753221735812817],
 [0.9291905123876091,
  0.9781771252696233,
  0.9513039091272953,
  0.9773556405528409,
  0.9388396957976104,
  0.9587361913614733,
  0.9179277611222224,
  0.9375588646533515,
  0.9001879019906361,
  0.9709133247625905,
  0.9243167716777986,
  0.9090963268614349,
  0.9863699510611169,
  0.9830642899068051,
  0.9078117183636217,
  0.9073555618992019,
  0.9093092250487821,
  0.9684535080801877,
  0.9050358248050643,
  0.9835129924305277,
  0.947905025132871,
  0.9123982684930144,
  0.9246936355899148,
  0.9066622401794391,
  0.9275303948567741,
  0.9734143791713032,
  0.9067807427313819,
  0.9389402846342957,
  0.9015712510647345,
  0.9435782065136344,
  0.9203909773539549,
  0.9437257828742676,
  0.9048181489808992,
  0.9229916422189552,
  0.9350510982280111,
  0.9444172969153816,
  0.9096971846278562,
  0.9463174205790521,
  0.9093773123493821,
  0.9691493865823225,
  0.9511957465826658,
  0.9801168380625755,
  0.9875860932778526,
  0.9317758777399259,
  0.9143231315125363,
  0.9061569194018344,
  0.9076576848971102,
  0.9516172574796756,
  0.9185585416655798,
  0.9244738183376682,
  0.9004519538958081,
  0.9199209997472346,
  0.9556142179713607,
  0.9197780208129513,
  0.9366056490924366,
  0.9184239793414936,
  0.9227580624137985,
  0.9700138837539152,
  0.9377226846178343,
  0.932630641727291,
  0.9336898300014009,
  0.9068202335392763,
  0.9888623284598825,
  0.9833073984574161,
  0.9181839848632929,
  0.9100936682663281,
  0.9500186196158438,
  0.9361677565095142,
  0.9760574975140897,
  0.9373418295858129,
  0.9144553828915128,
  0.98056060136153,
  0.9710736841215339,
  0.9672581888774379,
  0.9638794452280278,
  0.9347981665003348,
  0.9451342709139408,
  0.9121729377064858,
  0.9874413379184896,
  0.9155366752457706,
  0.9271223383440765,
  0.9618151212439335,
  0.9850692157751022,
  0.9417070743195473,
  0.9753050871229167,
  1.0,
  0.9082778947396768,
  0.9694499341980919,
  0.9166857340962422,
  0.9823706365182223,
  0.9262075216857918,
  0.9784683752800174,
  0.9603140302046517,
  0.9838260990860287,
  0.9247485355903885,
  0.9091403780417333,
  0.9076200108702007,
  0.9191361419197284,
  0.9107530861430656,
  0.9272293586091025,
  0.9427194873084582],
 [0.986081161031118,
  0.9157690587671056,
  0.954332050416287,
  0.9113874833823531,
  0.9407027296702644,
  0.9366547224083744,
  0.9749206115663465,
  0.9345842593255442,
  0.9270681853403947,
  0.9122976472996416,
  0.9338501079351269,
  0.902042972955073,
  0.9601210747995981,
  0.9882136002423153,
  0.9407778130666438,
  0.9004696190070574,
  0.9618761548446686,
  0.9636844910444018,
  0.9597107087302021,
  0.9324604499424028,
  0.9167023437431103,
  0.9072670490511148,
  0.9027635069479992,
  0.9036043796362732,
  0.9442169084176412,
  0.9274280813836402,
  0.9851193090505271,
  0.9897634708264751,
  0.9396516923065713,
  0.9012960093157669,
  0.9079326474899669,
  0.9263538357359808,
  0.9784121232943276,
  0.9758025997687939,
  0.9605878149986246,
  0.9239748088960238,
  0.9888706754290275,
  0.9412002071929979,
  0.9466549774946099,
  0.9108508471610066,
  0.9068556720149182,
  0.9794480091600873,
  0.9653612641442327,
  0.9473717994578761,
  0.9288507877995833,
  0.921791425104784,
  0.9353301180349646,
  0.957109201397615,
  0.9840835018799067,
  0.9370996458330499,
  0.9809297413871747,
  0.9864472812992569,
  0.9292661341960744,
  0.9739561644099425,
  0.9691769742889152,
  0.9505612087075914,
  0.9437311967280778,
  0.9296138418823059,
  0.9612064336569293,
  0.9212220447915722,
  0.9054013719507294,
  0.963541251339039,
  0.9842933451260325,
  0.9664107503996365,
  0.9661288698996456,
  0.9485001605722437,
  0.9663886681531885,
  0.9114245284213962,
  0.9319643434469457,
  0.9092124439000537,
  0.9515243983606596,
  0.9129917142162437,
  0.9580425117580257,
  0.9869467819642666,
  0.9214721356621672,
  0.9281840850090285,
  0.9246976613402638,
  0.9765764011891916,
  0.9182489503653471,
  0.9100401517292493,
  0.9840308430526192,
  0.9406110791389382,
  0.9028292171978458,
  0.9729812927407245,
  0.902621989521346,
  0.9082778947396768,
  1.0,
  0.9276010885312591,
  0.9289824744492412,
  0.9893645852025735,
  0.9686404227416319,
  0.9736540332561447,
  0.9163966377769521,
  0.9623512391506549,
  0.909727470363306,
  0.938121575146708,
  0.976831883169106,
  0.9804020725873355,
  0.9617548657766809,
  0.9129451379914857,
  0.9520372866599605],
 [0.915232467599517,
  0.9530568742319269,
  0.9295552211319354,
  0.9377111091567681,
  0.9317919224042623,
  0.9396697665140386,
  0.9634296829049244,
  0.9140164878242837,
  0.9882627652678686,
  0.9391340003864534,
  0.9799761234457907,
  0.9512301852630274,
  0.9037984080864863,
  0.9391371446363111,
  0.9876276585666527,
  0.9477824544738216,
  0.9504548740297386,
  0.9108495294181381,
  0.9878537382265692,
  0.98167118154414,
  0.9688809750359815,
  0.951538666759882,
  0.9368513017508611,
  0.9133562943544433,
  0.9748662320868607,
  0.9277474201488176,
  0.9152972037176089,
  0.9043837057569254,
  0.9694548341034465,
  0.9763756829896254,
  0.952216841214409,
  0.9871032466141402,
  0.9021688395745193,
  0.9258230647068234,
  0.940605328452071,
  0.9347445187415141,
  0.978718148009521,
  0.9053100990689059,
  0.927192823143667,
  0.9132419632730124,
  0.9620809670944925,
  0.9700494666160067,
  0.9755679438892686,
  0.9767263909164435,
  0.9738479710922472,
  0.9068588331946258,
  0.9809795836104974,
  0.9373605476163587,
  0.9056060679136337,
  0.9379272929071688,
  0.9555381299159147,
  0.9606128889268535,
  0.9809215229374625,
  0.9339341477535371,
  0.9381383109670414,
  0.9774574052774233,
  0.9255607290557326,
  0.9270245311817199,
  0.9426366365942159,
  0.9180467231742696,
  0.9410705006194503,
  0.9874819856556546,
  0.9134652288969385,
  0.9150999282115887,
  0.9678062293743478,
  0.9633636584476202,
  0.9497263496156098,
  0.918279747917738,
  0.9735881588730524,
  0.9455747689224436,
  0.9794772704000747,
  0.9390636940081996,
  0.9010212770580512,
  0.9348945498670077,
  0.9558094250893401,
  0.948213704777952,
  0.9168588304779224,
  0.9733170411953209,
  0.9385476569481046,
  0.9687649110032387,
  0.9783695327127209,
  0.9194890336008632,
  0.914057586605542,
  0.9879514163919116,
  0.9831528509525234,
  0.9694499341980919,
  0.9276010885312591,
  1.0,
  0.9858355867332402,
  0.9437609795626564,
  0.9143341946609007,
  0.9043411667148112,
  0.9221810923519762,
  0.978008867268698,
  0.9276038859053829,
  0.9341914642225467,
  0.9256455773426318,
  0.9683923076618891,
  0.9308056282593941,
  0.9656537960862426,
  0.9118689174894458],
 [0.9197834845596761,
  0.9838542591840752,
  0.9548394050351378,
  0.957602051471542,
  0.9139198754743347,
  0.9211599876320072,
  0.926920786641035,
  0.910795918033516,
  0.9798222939597364,
  0.9345186489236844,
  0.9574421383181161,
  0.9779139130187506,
  0.9008955121440656,
  0.9508458276099914,
  0.9002757066548722,
  0.9880298825334772,
  0.9312113772991549,
  0.9231248034768038,
  0.9095360188563819,
  0.9008535756182351,
  0.9700428299355286,
  0.94279883174312,
  0.9074928043339082,
  0.9310162185040853,
  0.9702747164265306,
  0.9480239639572323,
  0.9442305237250873,
  0.9835867987026576,
  0.9762345267020659,
  0.9019478076985454,
  0.9196300045452267,
  0.9631437575035667,
  0.9674766605514712,
  0.9433053066956704,
  0.9368785777243221,
  0.9722386322583377,
  0.915386890978162,
  0.9566576071105366,
  0.9169260599773186,
  0.9759137909865049,
  0.9005560418563856,
  0.9039667542564386,
  0.9030213031117285,
  0.9815194299078744,
  0.9318386918315891,
  0.9130349742218037,
  0.9112756226691138,
  0.9146890281243696,
  0.9371543138801504,
  0.9533068886893162,
  0.9098834438979878,
  0.984639045817791,
  0.9833768478506555,
  0.9627901946464144,
  0.987324457892091,
  0.9556893416677975,
  0.9884882927072971,
  0.9836717451173852,
  0.9270382462741297,
  0.913405940252741,
  0.9482948240193566,
  0.9039594465686643,
  0.9043810757865532,
  0.9597866464398441,
  0.916428934236073,
  0.9281143714817832,
  0.9646109351011619,
  0.934240108083561,
  0.9528956866963961,
  0.950839896147835,
  0.9633877998464837,
  0.9100675359554338,
  0.9127540806036789,
  0.9493645904609858,
  0.9660221672216521,
  0.9778364661261993,
  0.904407286511445,
  0.9623868468580853,
  0.9373041837872264,
  0.9164730321384676,
  0.9557009561784972,
  0.981310277304891,
  0.976594734566858,
  0.9647086468419237,
  0.9753083746033668,
  0.9166857340962422,
  0.9289824744492412,
  0.9858355867332402,
  1.0,
  0.9061578122735517,
  0.9306400228497377,
  0.9479652802156376,
  0.9833806995120059,
  0.9712525643529744,
  0.9660508478888444,
  0.9414333845206536,
  0.9004679148513729,
  0.9346880115610994,
  0.9475084271255458,
  0.9711428568838683,
  0.9809113127021731],
 [0.9688850176606381,
  0.9022113693025251,
  0.9529639991404897,
  0.9884613668974102,
  0.9108342942078465,
  0.9144610480776421,
  0.9311243781398391,
  0.9295550828434405,
  0.9005416168014148,
  0.9308739896132155,
  0.971595675433933,
  0.9357273636776446,
  0.9170828739452104,
  0.9488910763307484,
  0.9421230580941371,
  0.9439287921145288,
  0.9642854209226257,
  0.9480975973140044,
  0.9309032938933073,
  0.9842895717440013,
  0.9643769075916235,
  0.9306269579995332,
  0.9376957169436735,
  0.9712021316680354,
  0.9736774823671832,
  0.9115075478300357,
  0.9405407899179122,
  0.9062848638430008,
  0.9227796551903896,
  0.9083511115891132,
  0.9816279308940118,
  0.968543578981093,
  0.9315506877657892,
  0.9025242837921388,
  0.9485512344987436,
  0.9301557181901969,
  0.948983060567938,
  0.9214115973479562,
  0.9034725558476016,
  0.9899305227168077,
  0.9828928401554247,
  0.9086816718742122,
  0.9348434518369938,
  0.9051326490373036,
  0.9604282095758385,
  0.9678947621033859,
  0.9479474629309917,
  0.930800109235825,
  0.9627803535929405,
  0.9330889676348577,
  0.915191081196853,
  0.9116520741386874,
  0.9485961330622732,
  0.949590011560368,
  0.9157298255089019,
  0.9871662029273715,
  0.9508022825584985,
  0.9075151380024155,
  0.9698308516937719,
  0.9434142835416243,
  0.9322644421034924,
  0.9775597426892443,
  0.9603700626058448,
  0.9378456881689677,
  0.9569345562632772,
  0.9087502353107234,
  0.9320959721323959,
  0.9658258160067742,
  0.9700493665525916,
  0.9878698322354226,
  0.9193370002915974,
  0.9465282786356893,
  0.9452053961442235,
  0.9311767623407263,
  0.9853302393323454,
  0.9817751717004014,
  0.9103049607518543,
  0.9825649586908793,
  0.9880359861513303,
  0.9125376675128992,
  0.9007503035330189,
  0.9432057566931068,
  0.9856353990637433,
  0.9220198335587778,
  0.97792918960459,
  0.9823706365182223,
  0.9893645852025735,
  0.9437609795626564,
  0.9061578122735517,
  1.0,
  0.9517712290027461,
  0.9051710070715204,
  0.9762377137671896,
  0.9683889140157852,
  0.9860198585025821,
  0.9760516709225344,
  0.9396489956342075,
  0.93914218696776,
  0.9654792475924587,
  0.9389856602131719,
  0.9763160486981385],
 [0.9564990944102124,
  0.9830014938144935,
  0.9720439492666926,
  0.9852446561192079,
  0.9533609796960338,
  0.9275317936627363,
  0.9212472182668917,
  0.926360665187761,
  0.9685449130335967,
  0.9107132820052632,
  0.9578088680491942,
  0.9779807220275347,
  0.9896138794776023,
  0.9817446041198988,
  0.9813665643890263,
  0.9053364250773918,
  0.9162349199055619,
  0.9118666700069922,
  0.9120359055005556,
  0.9859703493572681,
  0.9157775099512823,
  0.9856720469627873,
  0.915475152220204,
  0.9808825953774267,
  0.9413925249604959,
  0.9033235550107561,
  0.935241475581954,
  0.9347467085997985,
  0.9156342069824874,
  0.9626538724044805,
  0.9423398542726112,
  0.955747332340625,
  0.9544062822098162,
  0.9210256608578115,
  0.9576630950265361,
  0.9186560646604337,
  0.9081676941950033,
  0.9427935359668701,
  0.9603858815168361,
  0.9757623575701915,
  0.9659464465107941,
  0.936395987458175,
  0.9500851111837825,
  0.9587461331939776,
  0.9673767202894525,
  0.9041341359736148,
  0.9714225964982668,
  0.9049721020771238,
  0.9867183322759985,
  0.9732010491008416,
  0.915495384313855,
  0.9119406690366583,
  0.9049015211324885,
  0.9816388586302504,
  0.9026336421323067,
  0.9641451212201172,
  0.9828140462123088,
  0.9172254007365557,
  0.9696951308962852,
  0.9060054256308104,
  0.9541156804155339,
  0.941225022505077,
  0.9760068158696689,
  0.9456335152519378,
  0.9325131112790176,
  0.9899869198550992,
  0.9044483630983561,
  0.9705617652201973,
  0.9111837111842641,
  0.9644655493598646,
  0.9264845037099775,
  0.9317581098122442,
  0.9057096247558845,
  0.9539128032064247,
  0.9749742562720843,
  0.982322541878612,
  0.9477963894931417,
  0.9488432072210596,
  0.9786140031878028,
  0.9404412756701211,
  0.9507328465120731,
  0.9525902920921924,
  0.9270306031439078,
  0.905146253787433,
  0.948664286530149,
  0.9262075216857918,
  0.9686404227416319,
  0.9143341946609007,
  0.9306400228497377,
  0.9517712290027461,
  1.0,
  0.9815858173453205,
  0.9038188778744942,
  0.9256095719759033,
  0.9732230281115044,
  0.9857213868645996,
  0.987899017816546,
  0.9530403075245835,
  0.9288900393228792,
  0.9512419492986187,
  0.9767616900756325],
 [0.969961532534186,
  0.9456415452699569,
  0.9834240546246776,
  0.95346482865546,
  0.9672191181244569,
  0.9625264002165742,
  0.9457515797808117,
  0.9493895908474382,
  0.9447634939028591,
  0.912104050183933,
  0.9041571652930454,
  0.948402779276762,
  0.9519597663259595,
  0.9208259775264638,
  0.9689513637940246,
  0.9735260936553586,
  0.91785429356576,
  0.9837768143268515,
  0.9209784014976867,
  0.9007621532617549,
  0.9509716891293087,
  0.9128850686952946,
  0.9747274236331107,
  0.9379164412171189,
  0.9830264447281055,
  0.9853071213868161,
  0.9376761039049227,
  0.9623087248962476,
  0.9690158477590964,
  0.9776893174458814,
  0.9353129203441322,
  0.9346896445736259,
  0.9504960075013804,
  0.9062579965458616,
  0.9616026720184588,
  0.9135359215657993,
  0.9001092234385183,
  0.940111480545694,
  0.9418972077354943,
  0.9169610853126912,
  0.9330128811673211,
  0.9225495317912354,
  0.9507103920913789,
  0.9582002333785318,
  0.9754045287307463,
  0.9502005322998585,
  0.9763323738479688,
  0.9568822914405717,
  0.966801282917473,
  0.9546121428937415,
  0.9579399147332951,
  0.9672571837941428,
  0.9402956105783231,
  0.9232004640028332,
  0.963722663882306,
  0.9674883699937384,
  0.9049664481232176,
  0.91792192619266,
  0.9836301117242225,
  0.9046773348881018,
  0.9648126519702925,
  0.9324377678272174,
  0.9261663776546571,
  0.9481617885849364,
  0.977593268987142,
  0.977936731083047,
  0.9108524434417665,
  0.970831758806529,
  0.9754677950000396,
  0.9181141544063149,
  0.9091798966089188,
  0.904854858198442,
  0.9205624854995508,
  0.9878436045996791,
  0.9362929440191224,
  0.9067835972513447,
  0.9445957257697181,
  0.9118406422652924,
  0.9890863797007483,
  0.9076540389386906,
  0.9755618589234928,
  0.9691339457229394,
  0.929647769400689,
  0.9034512880111728,
  0.9639220722525391,
  0.9784683752800174,
  0.9736540332561447,
  0.9043411667148112,
  0.9479652802156376,
  0.9051710070715204,
  0.9815858173453205,
  1.0,
  0.9652802543935499,
  0.966556813777686,
  0.9442345980368618,
  0.9733285197712577,
  0.9504633008559031,
  0.9566583844843815,
  0.9596429818061954,
  0.939282707992201,
  0.9026813025385813],
 [0.9489810228663218,
  0.9705002514715124,
  0.9252675228855638,
  0.9419224896898969,
  0.9467804489650743,
  0.9164523861060092,
  0.9223843377813329,
  0.9599806706163636,
  0.9814800905985602,
  0.9134025727188986,
  0.9569849613155189,
  0.9534904890397691,
  0.9121247946168879,
  0.907977662487982,
  0.9514824385372641,
  0.9550675078714875,
  0.9893781731900874,
  0.9121756712080281,
  0.9495992465807367,
  0.908864908755223,
  0.932225100399395,
  0.969263467304254,
  0.9110196834007147,
  0.9230485142893241,
  0.9371643660867279,
  0.9532310484866285,
  0.9855615392940328,
  0.9121873823979911,
  0.9576644262545283,
  0.9413209189532267,
  0.9436405758069657,
  0.919039209915643,
  0.9293584841509297,
  0.971536401325152,
  0.978080181450719,
  0.9563292211015215,
  0.9362487278095785,
  0.9493403490533893,
  0.9798163280824558,
  0.9773409881117521,
  0.9767155998956663,
  0.9217034711384375,
  0.909658540757576,
  0.9380563746872312,
  0.928617964683636,
  0.9048838024849399,
  0.9204896395753669,
  0.9096112626169495,
  0.9592663485784217,
  0.9842212324308518,
  0.9633542721313001,
  0.9822128908551975,
  0.9076316489935126,
  0.9623593551196059,
  0.9236433678162518,
  0.9872697062771048,
  0.9174279923028665,
  0.940097391645981,
  0.9709214377996968,
  0.9442636090561431,
  0.9561598224900533,
  0.9764531297672968,
  0.9457860477413053,
  0.9375856417061923,
  0.9446406325100656,
  0.9751542522950878,
  0.9795565299131054,
  0.9387924298808573,
  0.9133993553753859,
  0.9026676089281902,
  0.9693400561502914,
  0.919531098337504,
  0.9221874282485886,
  0.9151112777733638,
  0.957165845095153,
  0.9760418857954436,
  0.935303303646704,
  0.9859803563832649,
  0.9043149464044793,
  0.9700616789425465,
  0.9726081844642036,
  0.952773019908622,
  0.9422418880512519,
  0.9737295787905238,
  0.9032590310236273,
  0.9603140302046517,
  0.9163966377769521,
  0.9221810923519762,
  0.9833806995120059,
  0.9762377137671896,
  0.9038188778744942,
  0.9652802543935499,
  1.0,
  0.9736730461675396,
  0.9330776769938355,
  0.9237412913583216,
  0.9689671694159032,
  0.9732820746328207,
  0.9546442962683682,
  0.9792171426907585,
  0.911911214228838],
 [0.9592214752534944,
  0.9622104038780451,
  0.9082172150910793,
  0.9510585858234081,
  0.9121730211585821,
  0.961451995304374,
  0.961458082596444,
  0.9725866991881403,
  0.9372285402879951,
  0.9713123798677095,
  0.953159624930583,
  0.9876833139387285,
  0.9105942453209633,
  0.9549528843956718,
  0.9830190019107927,
  0.9213362161192169,
  0.9757089595215538,
  0.9279847965772015,
  0.9658575303708046,
  0.9374394161184354,
  0.9084560903311364,
  0.9889861933858365,
  0.9538845574122357,
  0.966683532810816,
  0.909290328311126,
  0.9276159936217653,
  0.9185859240126931,
  0.9351971306343693,
  0.9012545800617208,
  0.9793546939555673,
  0.9381562749052458,
  0.9414667991159787,
  0.9201084719577257,
  0.9873552281841033,
  0.9740806497086981,
  0.9452355912496085,
  0.9844101925720411,
  0.9396869551509949,
  0.9559407989660228,
  0.9345193358103233,
  0.9765402539569874,
  0.9732777125757052,
  0.9627194027733198,
  0.9507637845116128,
  0.9780684350989136,
  0.9032647526805772,
  0.9373411244350899,
  0.9772261304726871,
  0.9266070183655897,
  0.9794809548765935,
  0.9386161742178984,
  0.9846523187752592,
  0.9044622556768709,
  0.9458310669692493,
  0.9532029717998207,
  0.9277856057484802,
  0.989833628093355,
  0.9765533376862093,
  0.9508125085811124,
  0.9294878986708371,
  0.9308289752622101,
  0.9434313976792874,
  0.9851868864337531,
  0.9129191637773622,
  0.9061654816880623,
  0.9427089318256697,
  0.9690088614001172,
  0.9294935956489181,
  0.9581862172045259,
  0.9828976761646055,
  0.9552096056359137,
  0.97756291084115,
  0.9557457403171778,
  0.9411984700442466,
  0.945596852661998,
  0.9384651454457378,
  0.9289405358427518,
  0.9215523596317694,
  0.9250941639080026,
  0.9109903878281567,
  0.9327957346391299,
  0.9686821458376074,
  0.952337567414618,
  0.9488801203309365,
  0.9150840266793495,
  0.9838260990860287,
  0.9623512391506549,
  0.978008867268698,
  0.9712525643529744,
  0.9683889140157852,
  0.9256095719759033,
  0.966556813777686,
  0.9736730461675396,
  1.0,
  0.9898817185711138,
  0.9220749742341672,
  0.9459742276427239,
  0.9752659110506561,
  0.9345047587510819,
  0.9138551693461665,
  0.9123485573051237],
 [0.9394374916621978,
  0.9139227733076694,
  0.9198488844281028,
  0.9422342113196825,
  0.9112913818662507,
  0.9697556902254334,
  0.9638502669405773,
  0.9416063517819685,
  0.9197042379762259,
  0.9705037479047063,
  0.9180904900161252,
  0.9006235065093822,
  0.9279821421691672,
  0.9821535592036157,
  0.9541709626636532,
  0.9234567472701724,
  0.9042571096392501,
  0.9231663347327608,
  0.9702287191575983,
  0.9688684378479231,
  0.9156665284528166,
  0.966533771445169,
  0.965749271971788,
  0.948068295537283,
  0.9103027523194471,
  0.9531519496706814,
  0.977828336096316,
  0.9608997905275349,
  0.9516303824411829,
  0.9058030525950205,
  0.9558982529564272,
  0.9039859327957729,
  0.9117381974381333,
  0.9812593100781939,
  0.9831643868522509,
  0.9795561322327064,
  0.9229792790150839,
  0.9616372213979767,
  0.9251777153529674,
  0.9483894144143347,
  0.914297363785819,
  0.9688771963792118,
  0.9570670347728363,
  0.9411582358538892,
  0.9257989522836848,
  0.9395982405555569,
  0.9003609979382753,
  0.9681091482720917,
  0.9489555877853962,
  0.9242908337807646,
  0.9099088278370271,
  0.9647780125983147,
  0.9577506199022398,
  0.9531864721250677,
  0.935706768133791,
  0.9021590885062378,
  0.9239624478364713,
  0.9723865056433704,
  0.9697422987648021,
  0.9868242810436356,
  0.9684826033728369,
  0.923637280812821,
  0.9077686463059017,
  0.9221211814677552,
  0.9391817470710259,
  0.9331106040205772,
  0.9025352218287497,
  0.9677354397726128,
  0.9731109285252673,
  0.9631854590626384,
  0.9358907842960699,
  0.9314012968150024,
  0.9287000559722606,
  0.9386158954212486,
  0.9874482035182764,
  0.9747569245209192,
  0.9495578325114933,
  0.9879283986099284,
  0.9036102355315533,
  0.9063610718936623,
  0.9597594152560882,
  0.932631358538738,
  0.954210402184985,
  0.978481059090762,
  0.935773396337412,
  0.9247485355903885,
  0.909727470363306,
  0.9276038859053829,
  0.9660508478888444,
  0.9860198585025821,
  0.9732230281115044,
  0.9442345980368618,
  0.9330776769938355,
  0.9898817185711138,
  1.0,
  0.9225037010369104,
  0.9582499237503523,
  0.9782279187998908,
  0.9845415236575562,
  0.9046940742889924,
  0.9197792224840016],
 [0.9746635307179137,
  0.9052512048298385,
  0.9667101260440565,
  0.9708547729912261,
  0.9784594035800734,
  0.9578876426634878,
  0.9713894824003098,
  0.9765232539323693,
  0.9592997177688566,
  0.9418294502189787,
  0.9893424043119107,
  0.9799136345092502,
  0.9532626192106376,
  0.937882233185513,
  0.9469202557875915,
  0.985646423076993,
  0.9618307066677394,
  0.9682544376785472,
  0.9045682690080434,
  0.9210853381204925,
  0.9598735889438424,
  0.9837269031744768,
  0.9703839420474053,
  0.9392456682684115,
  0.9044626485859255,
  0.9121242973424747,
  0.9637640550080117,
  0.9436778317337786,
  0.9169130755475885,
  0.9068712568166498,
  0.9076647543192344,
  0.9844496310753473,
  0.9230376556165956,
  0.9778945399088116,
  0.9310929240108063,
  0.9753733649661233,
  0.9562996483863645,
  0.9706937153052201,
  0.974414733487843,
  0.9612409132507466,
  0.9868748730752952,
  0.9237062451656721,
  0.9401727988754418,
  0.9760206846258505,
  0.9883484989805227,
  0.9090619420732353,
  0.913084582848417,
  0.9279587290202775,
  0.9380804714088136,
  0.975656581809397,
  0.985902675334918,
  0.934840204808561,
  0.9176268396576795,
  0.9798904931776119,
  0.9124810846674188,
  0.9414864391839897,
  0.9168719512603826,
  0.9710542505276256,
  0.9730934853346325,
  0.9099781985475403,
  0.9727660458408093,
  0.9873494164223435,
  0.9544596788864474,
  0.9409088948678067,
  0.9581130197629885,
  0.9644009893538342,
  0.9025393005879562,
  0.9136875188089836,
  0.9086288883006116,
  0.9833481580103791,
  0.9393460094747351,
  0.9689998827777522,
  0.9714768663650671,
  0.9795230481069873,
  0.9623193081428651,
  0.9301728066073658,
  0.9592933074237786,
  0.9651445692550777,
  0.920679254920783,
  0.9859648269512684,
  0.9398420987487701,
  0.9858175210860458,
  0.9177080905308656,
  0.9461350783709827,
  0.9675137109011305,
  0.9091403780417333,
  0.938121575146708,
  0.9341914642225467,
  0.9414333845206536,
  0.9760516709225344,
  0.9857213868645996,
  0.9733285197712577,
  0.9237412913583216,
  0.9220749742341672,
  0.9225037010369104,
  1.0,
  0.9364433127397285,
  0.9619529313236906,
  0.9796696206891213,
  0.9855893924554732,
  0.9079503993155071],
 [0.9875432694044755,
  0.9650552874307947,
  0.9275926054229632,
  0.9663861354478775,
  0.9734914809782923,
  0.9706080772443023,
  0.9755077459677062,
  0.9764084368461006,
  0.9866264019677111,
  0.9417946715987244,
  0.979145281243226,
  0.9002173143469614,
  0.911741352096691,
  0.9392618551402059,
  0.9176171109334095,
  0.9846197130298506,
  0.9138013339702167,
  0.9619318135001145,
  0.9616694496519705,
  0.9566892972344538,
  0.9884209308799218,
  0.9743356874605721,
  0.987888657952863,
  0.9743277176962821,
  0.9514407266638553,
  0.9651604478797615,
  0.9680753812547446,
  0.9046611039055434,
  0.918736292473787,
  0.9635274491082683,
  0.9176792463802924,
  0.981085000973762,
  0.9814991452833528,
  0.9480970102448724,
  0.9767450555189859,
  0.9345672538471326,
  0.933073887647953,
  0.9320501090289504,
  0.9358833743962245,
  0.9507497164053078,
  0.9446725929129003,
  0.9757213808236447,
  0.9435516295726053,
  0.900033102978665,
  0.9333530221600883,
  0.9400284047463214,
  0.9400435301860787,
  0.9374684351377817,
  0.920426304844996,
  0.9080851156193388,
  0.9833329232011793,
  0.9336433162015768,
  0.9504232222310115,
  0.9334740756982092,
  0.9404012026751568,
  0.9781210761958419,
  0.9263704436613106,
  0.9322586854454796,
  0.9286617937614411,
  0.9809895075598172,
  0.9542632750953985,
  0.9378941048505136,
  0.9400794573810664,
  0.9894168092278235,
  0.9893500288154486,
  0.9045878110926516,
  0.9845092175126746,
  0.9465200364025127,
  0.913255893545684,
  0.946979863880194,
  0.9153821522454227,
  0.9877728529768326,
  0.9755015712736049,
  0.9455714131196976,
  0.9186555598630551,
  0.9615628201480524,
  0.9319449107490212,
  0.9192203844010853,
  0.9491045889802641,
  0.9377983482421781,
  0.979718656396388,
  0.9598758213536994,
  0.9873094413813696,
  0.9650796299028582,
  0.9334372125085082,
  0.9076200108702007,
  0.976831883169106,
  0.9256455773426318,
  0.9004679148513729,
  0.9396489956342075,
  0.987899017816546,
  0.9504633008559031,
  0.9689671694159032,
  0.9459742276427239,
  0.9582499237503523,
  0.9364433127397285,
  1.0,
  0.9627891972419714,
  0.9845675524386892,
  0.9515243831451498,
  0.9873206523722772],
 [0.9749877834724527,
  0.9710152660824791,
  0.9794632014532665,
  0.9674099196587453,
  0.9208954980685825,
  0.9894108579487654,
  0.9384260300600941,
  0.9622159237419832,
  0.9568830922482185,
  0.9148630091254671,
  0.9708805500916725,
  0.941273754888333,
  0.9062895226959804,
  0.9719635552273497,
  0.9575827383353805,
  0.9604078577864346,
  0.956141960963595,
  0.9753811113889825,
  0.9591212351063234,
  0.9728064657683089,
  0.9881084057610078,
  0.9376183301109005,
  0.9045104869965825,
  0.9215634639236503,
  0.9444229086890267,
  0.901759436433743,
  0.9059311511470918,
  0.9159479064742024,
  0.9875367160961837,
  0.9077050772097138,
  0.9182429031222206,
  0.9728834911832382,
  0.9224080816188539,
  0.913184850938815,
  0.982616840537816,
  0.9358859775230554,
  0.916977042063248,
  0.9247888079828549,
  0.9409730430534463,
  0.9423206884784694,
  0.9835081330706889,
  0.9192829525834657,
  0.9544986492306334,
  0.9001118544327802,
  0.90922936681961,
  0.937652900585442,
  0.970865982444368,
  0.9695517325156134,
  0.941692380952576,
  0.9733491355086233,
  0.9625859846278292,
  0.9685220009874735,
  0.9552260316787872,
  0.9694146433731952,
  0.9883236525950705,
  0.9601202082042389,
  0.9327519843858091,
  0.9215490482464085,
  0.9519250546286455,
  0.9627883802919291,
  0.9357652335941322,
  0.955646971965961,
  0.9295479100845753,
  0.9782513950663304,
  0.9412557710166054,
  0.9130737360455229,
  0.9791498269323305,
  0.9806145037176236,
  0.9090983287842377,
  0.9600171504064441,
  0.9739903971940318,
  0.9293229838325975,
  0.9560764080012569,
  0.919641306995418,
  0.961696234413942,
  0.9029183585303411,
  0.9658787261543096,
  0.9716412295868676,
  0.9685179062511391,
  0.9232770856414216,
  0.9699399039807494,
  0.972546340913574,
  0.938607522288734,
  0.9680493047472235,
  0.9009956569079991,
  0.9191361419197284,
  0.9804020725873355,
  0.9683923076618891,
  0.9346880115610994,
  0.93914218696776,
  0.9530403075245835,
  0.9566583844843815,
  0.9732820746328207,
  0.9752659110506561,
  0.9782279187998908,
  0.9619529313236906,
  0.9627891972419714,
  1.0,
  0.9569591913328765,
  0.9237121359975923,
  0.9062948042601013],
 [0.9187018485443904,
  0.9600075381184601,
  0.9416492140091738,
  0.9180976439309915,
  0.9431787048581922,
  0.9823420510488757,
  0.9786974327474048,
  0.9755725508403259,
  0.9866320722265403,
  0.9460647170170281,
  0.9011703169671622,
  0.9706503392069625,
  0.9099153321563229,
  0.9005625420179837,
  0.919130604374147,
  0.970198220823661,
  0.9411997747304206,
  0.9080172262237192,
  0.9391227108643931,
  0.9600463038595628,
  0.9723002162757196,
  0.9798359835775486,
  0.9369767396175926,
  0.9248592190301916,
  0.9628509451516944,
  0.9694168007134838,
  0.9868824458681537,
  0.9061123737361891,
  0.9690233164363206,
  0.9676358379573112,
  0.9565034507314498,
  0.9230839859514539,
  0.9453478298355816,
  0.9704592329529649,
  0.9699272546673201,
  0.981999664824497,
  0.9112961188210413,
  0.94574621813289,
  0.9749403787146752,
  0.9084287856047225,
  0.9045419612602171,
  0.9243195376402725,
  0.9646697335668671,
  0.9296294029760821,
  0.9619305250875408,
  0.9369566876678346,
  0.9890132223737133,
  0.9662510118642185,
  0.9606190637993886,
  0.9285976960443747,
  0.9853007419638331,
  0.9186361636331897,
  0.9871551875132142,
  0.9344184702605968,
  0.9054755947559829,
  0.9677591045407677,
  0.9247408066151247,
  0.9655504452344864,
  0.913743916800622,
  0.9588202321737002,
  0.9303197514512939,
  0.9188045224538948,
  0.9163747789170801,
  0.9483287302814778,
  0.9600173351179693,
  0.96343091888064,
  0.9186259775965927,
  0.9132251636741073,
  0.9678484347646754,
  0.9639788636743052,
  0.9027610386199726,
  0.9347546273397092,
  0.962114598668309,
  0.9349145336711229,
  0.9599486525842408,
  0.9094554624040144,
  0.9000344952619073,
  0.9556768081284739,
  0.960992521327694,
  0.9084159999923851,
  0.9393375966525137,
  0.9640122439152483,
  0.9627927020299971,
  0.9389242479713026,
  0.9180146627306689,
  0.9107530861430656,
  0.9617548657766809,
  0.9308056282593941,
  0.9475084271255458,
  0.9654792475924587,
  0.9288900393228792,
  0.9596429818061954,
  0.9546442962683682,
  0.9345047587510819,
  0.9845415236575562,
  0.9796696206891213,
  0.9845675524386892,
  0.9569591913328765,
  1.0,
  0.91839982896531,
  0.9338274950575173],
 [0.9169419557537821,
  0.9089848178817389,
  0.9337638599494841,
  0.902430063076905,
  0.9583641046553162,
  0.9304266836861865,
  0.9158296688084018,
  0.9705474331723195,
  0.9552716220126036,
  0.9359310438687916,
  0.9295629235799205,
  0.9173372137778976,
  0.9170262203166208,
  0.9061063481866285,
  0.9753038562721309,
  0.9460587831379966,
  0.9451406008547633,
  0.9347646505565286,
  0.923014662364758,
  0.9144044280624041,
  0.9789854479358289,
  0.956648359224659,
  0.9715328863830949,
  0.9393683282965594,
  0.9877449373373509,
  0.9024952960425028,
  0.9528589547597666,
  0.954432267570153,
  0.9002236823117465,
  0.9564322826501916,
  0.9389910017644532,
  0.9187628751861977,
  0.9357849364103452,
  0.9461661413818909,
  0.9192523138721469,
  0.9598641609629828,
  0.9331007293606018,
  0.9032646790408884,
  0.9746676582839077,
  0.9569511631624594,
  0.9406725005824959,
  0.9641812201367512,
  0.9621766489560396,
  0.9824092752824544,
  0.9439255807223998,
  0.9190951914039279,
  0.9642369037336179,
  0.9106518875750232,
  0.9698834916980716,
  0.9172728308561415,
  0.9007957830849368,
  0.9837106181567473,
  0.9539476049482741,
  0.9513954019000929,
  0.9770341046747981,
  0.9130779426154336,
  0.9863118550720044,
  0.9705376705822897,
  0.9136162200099558,
  0.9410161108985252,
  0.980982466690575,
  0.9716564262356525,
  0.9646213473826429,
  0.9354996059964737,
  0.9511193206822217,
  0.9300394394312559,
  0.9238188688404055,
  0.9231515945318177,
  0.9239999899503082,
  0.9208573281791872,
  0.9099830906489607,
  0.9073967274504229,
  0.9377568518638807,
  0.940173634091592,
  0.9456046247609549,
  0.91017881065149,
  0.9101202836286175,
  0.9879880952640332,
  0.9271528729879739,
  0.9522230351143632,
  0.93469047020103,
  0.9743399464829599,
  0.971755930082604,
  0.9483469781978988,
  0.9096609139311365,
  0.9272293586091025,
  0.9129451379914857,
  0.9656537960862426,
  0.9711428568838683,
  0.9389856602131719,
  0.9512419492986187,
  0.939282707992201,
  0.9792171426907585,
  0.9138551693461665,
  0.9046940742889924,
  0.9855893924554732,
  0.9515243831451498,
  0.9237121359975923,
  0.91839982896531,
  1.0,
  0.9625314054922661],
 [0.9247271830715339,
  0.9005337438623175,
  0.9474936754328233,
  0.9048691949312988,
  0.9184994137978334,
  0.9379357337277883,
  0.9615644918557574,
  0.9615439009296021,
  0.9338417013012185,
  0.9504841828158912,
  0.972497802643929,
  0.944486661282334,
  0.9446667197459618,
  0.9412401104580236,
  0.9544400953600026,
  0.9268633008530615,
  0.9805457320937786,
  0.9872077058775133,
  0.9522450578858266,
  0.9590637522804667,
  0.9843762832994367,
  0.9823233637939395,
  0.9540383177945491,
  0.9230432144621876,
  0.9370257469014018,
  0.9370342037110511,
  0.9850449599487191,
  0.97454108962601,
  0.9220494540230287,
  0.9869887875351231,
  0.9242389006244203,
  0.9680235054622467,
  0.9340811897514321,
  0.9422418214500403,
  0.9400322495396499,
  0.9071839984991587,
  0.9875278612175764,
  0.9757199566144366,
  0.9166125111762037,
  0.9296877566199266,
  0.945798731734631,
  0.952603139525052,
  0.9661792483602571,
  0.9044342690555763,
  0.9450022864130808,
  0.9012693687306486,
  0.9484622836198797,
  0.9265280534159118,
  0.9401152664723827,
  0.9447452523422154,
  0.9170541004923332,
  0.9674327135351708,
  0.9899293888499756,
  0.9737204337395746,
  0.9791929660760498,
  0.9318677473457699,
  0.9665929187105619,
  0.9406031508493339,
  0.9882539035529394,
  0.9241282957977983,
  0.9614619654542784,
  0.9581334451914498,
  0.9000987009341679,
  0.912773871018061,
  0.9678079635392284,
  0.9014449771932501,
  0.9582210950007167,
  0.902367984299144,
  0.9777484247330883,
  0.9467973298369314,
  0.9588361593011634,
  0.9724082976181203,
  0.9513725676705234,
  0.9709555074336575,
  0.9443608555584353,
  0.9846298658079666,
  0.925712623197755,
  0.988746680573355,
  0.9538259447975725,
  0.924882278724804,
  0.9427943869165551,
  0.9874996822407519,
  0.9648585464928434,
  0.9875735418873368,
  0.9753221735812817,
  0.9427194873084582,
  0.9520372866599605,
  0.9118689174894458,
  0.9809113127021731,
  0.9763160486981385,
  0.9767616900756325,
  0.9026813025385813,
  0.911911214228838,
  0.9123485573051237,
  0.9197792224840016,
  0.9079503993155071,
  0.9873206523722772,
  0.9062948042601013,
  0.9338274950575173,
  0.9625314054922661,
  1.0]]

# %% [markdown]
# ('Combination', 13, 0.5, 0.5, 'demand', 'yes', 0)

# %%
# Setting Parameters
# Optimal Value from Data Source
# Number of Iterations
it = iterations_to_run# 50000 #1000
# Solution with split deliveries
#split_sol = 'No'
split_sol = 'Yes'
# Stagmation parameter
#stg = round(it*0.9,0)
stg = round(it*0.9,0)
if optimal_value == None:
    known = 1e-10
    #known = 18.67292881108081
else:
    known = optimal_value
# Split information from Data Source
if split_sol == 'Yes':
    optm = 'split'
else: 
    optm = 'no_split'
# Logic to reintegrate initial solution by nearest neighbour
if optm == 'no_split':
    reit = 1
else:
    reit = round(stg*0.8,0)
sps = split_sol
pl = 0 # known*.15
#pl = known*.15 


# Increment Threshold
ith = 10 #10 #1000
# Optimization Solution Finder ("tier", "random", "mixed", "cost", "inter_route", "min_demand_route")
#osf = "tier" #"random" "mixed"
#osf = 'mixed'

#osf = "random"
#osf = 'cost'
#osf = 'inter_route'
osf = 'min_demand_route'
# Alpha factor for restricted candidate list
rcl = 0.5#0.5 #0.8 #0.8
# rcl = 0.8
# Perturbation percentage
prt = 0.5#0.5 #0.6
# prt = 0.8
# Initial seed (does not apply anymore)
sed = 1
# Interdiction prob (manual or generated--> "None" clause)
iprob = None
iprob = iprob1
# Min no interdiction matrix
min_nint = 1#0.92#1#0.95#0.97 # 0.88 #0.98 #0.95
# Max no interdiction matrix
max_nint = 1#0.92#1 #0.999#0.95#0.97 #0.88 #0.99 #0.99

# Threshold when reaching optimal solution
thres = 0.00001

# Percentage over iterations for no improvement
pert_ct = 0.1
# Local search method ('2-opt', '3-opt', 'segment-reversal', 'random') all include swap-local-search method
#lso = '2-opt'
lso = 'random'
#lso = '3-opt'
#lso = 'segment-reversal'


# Measuring time and time restriction
start_time = time.time()
timeout_minutes = tmot
timeout_duration = 60*timeout_minutes

# Prepare the arguments
args = (num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Create VRP instance
vrp_instance = VRP(num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Run the VRP run method with a timeout
result = vrp_instance.run_with_timeout(vrp_instance.run_vrp, timeout_duration, args)

if result is not None:
    cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = result
    print("VRP run completed successfully.")
else:
    print("VRP run did not complete within the timeout period.")
    improvement_time = 1e20
    finish_time = time.time()-start_time
    sl = "NA"
    solution = "NA"


# vrp = VRP(num_vehicles=num_vehicles, num_customers=num_customers, locations=locations, demands=demands, vehicle_capacity=vehicle_capacity, rcl_factor=rcl, iterations=it, local_search_option= lso, stagnation_limit=stg, perturb_percentage=prt,split_penalty= pl, sdd = sed, reintegrate_it=reit, split_sol= sps, min_prob_matrix= min_nint, max_prob_matrix= max_nint, int_prob = iprob, threshold_increment = ith, optimization_solution_finder = osf, maximus_time = maxxx_time)
# cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = vrp.run()
print('Improvement Time:', improvement_time)
print('Finish Time: ',finish_time)
print('Stag Level: ',sl)
if improvement_time == 1e20:
    diff = "NA"
else:
    diff = str(round(abs((cost/known-1)),2)*100)+'%'
print(improvement_time)
print(finish_time)
if improvement_time == 0  and finish_time == 0:
    pot_impr = str(round((1e10/1e10),2)*100)+'%'   
elif improvement_time == 1e20:
    pot_impr = "NA" 
else:
    pot_impr = str(round((improvement_time/finish_time),2)*100)+'%'
print('Diff_Cost%: ', diff)
print('Pot_Improv%: ', pot_impr)
print("Solution status: ", solution)
# Out:
# Interdiction Probabilities:  [[1.0, 0.9507679535949476, 0.9171009531226609, 0.9816929252010751, 0.9556031383837665, 0.9119915331443227, 0.9686085611421599, 0.9404912632070668, 0.9793768398982458, 0.9145446609142734, 0.9222895634918089, 0.9233556411534923, 0.9605759499366471, 0.9389023090852183, 0.9738191058696316, 0.9329665288561366, 0.9734051928422213, 0.9814347642098326, 0.9053115218539525, 0.969547716443647, 0.9736094840670293, 0.9818346933236656, 0.9051386494708944, 0.9080345461646157, 0.9477124125489895, 0.9054380000443489, 0.908945043426306, 0.9710528534934019, 0.9575770991397257, 0.9097881238682727, 0.9327654549911849, 0.9760133937241467, 0.9340064716575198, 0.9450098846028525, 0.9170790724049441, 0.9533083877322311, 0.944362216333655, 0.9174397639787502, 0.9682302046709592, 0.9488748594634031, 0.9249094594856685, 0.9782960234441811, 0.9492841523475114, 0.9581481149636056, 0.9894381485426307, 0.9058649423758312, 0.9845333486395769, 0.9850692661904662, 0.9754081333453845, 0.976
# ...

# %% [markdown]
# ('Combination', 14, 0.5, 0.5, 'demand', 'yes', 50)

# %%
# Setting Parameters
# Optimal Value from Data Source
# Number of Iterations
it = iterations_to_run# 50000 #1000
# Solution with split deliveries
#split_sol = 'No'
split_sol = 'Yes'
# Stagmation parameter
#stg = round(it*0.9,0)
stg = round(it*0.9,0)
if optimal_value == None:
    known = 1e-10
    #known = 18.67292881108081
else:
    known = optimal_value
# Split information from Data Source
if split_sol == 'Yes':
    optm = 'split'
else: 
    optm = 'no_split'
# Logic to reintegrate initial solution by nearest neighbour
if optm == 'no_split':
    reit = 1
else:
    reit = round(stg*0.8,0)
sps = split_sol
#pl = 0 # known*.15
pl = known*.15 


# Increment Threshold
ith = 10 #10 #1000
# Optimization Solution Finder ("tier", "random", "mixed", "cost", "inter_route", "min_demand_route")
#osf = "tier" #"random" "mixed"
#osf = 'mixed'

#osf = "random"
#osf = 'cost'
#osf = 'inter_route'
osf = 'min_demand_route'
# Alpha factor for restricted candidate list
rcl = 0.5#0.5 #0.8 #0.8
# rcl = 0.8
# Perturbation percentage
prt = 0.5#0.5 #0.6
# prt = 0.8
# Initial seed (does not apply anymore)
sed = 1
# Interdiction prob (manual or generated--> "None" clause)
iprob = None
iprob = iprob1
# Min no interdiction matrix
min_nint = 1#0.92#1#0.95#0.97 # 0.88 #0.98 #0.95
# Max no interdiction matrix
max_nint = 1#0.92#1 #0.999#0.95#0.97 #0.88 #0.99 #0.99

# Threshold when reaching optimal solution
thres = 0.00001

# Percentage over iterations for no improvement
pert_ct = 0.1
# Local search method ('2-opt', '3-opt', 'segment-reversal', 'random') all include swap-local-search method
#lso = '2-opt'
lso = 'random'
#lso = '3-opt'
#lso = 'segment-reversal'


# Measuring time and time restriction
start_time = time.time()
timeout_minutes = tmot
timeout_duration = 60*timeout_minutes

# Prepare the arguments
args = (num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Create VRP instance
vrp_instance = VRP(num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Run the VRP run method with a timeout
result = vrp_instance.run_with_timeout(vrp_instance.run_vrp, timeout_duration, args)

if result is not None:
    cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = result
    print("VRP run completed successfully.")
else:
    print("VRP run did not complete within the timeout period.")
    improvement_time = 1e20
    finish_time = time.time()-start_time
    sl = "NA"
    solution = "NA"


# vrp = VRP(num_vehicles=num_vehicles, num_customers=num_customers, locations=locations, demands=demands, vehicle_capacity=vehicle_capacity, rcl_factor=rcl, iterations=it, local_search_option= lso, stagnation_limit=stg, perturb_percentage=prt,split_penalty= pl, sdd = sed, reintegrate_it=reit, split_sol= sps, min_prob_matrix= min_nint, max_prob_matrix= max_nint, int_prob = iprob, threshold_increment = ith, optimization_solution_finder = osf, maximus_time = maxxx_time)
# cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = vrp.run()
print('Improvement Time:', improvement_time)
print('Finish Time: ',finish_time)
print('Stag Level: ',sl)
if improvement_time == 1e20:
    diff = "NA"
else:
    diff = str(round(abs((cost/known-1)),2)*100)+'%'
print(improvement_time)
print(finish_time)
if improvement_time == 0  and finish_time == 0:
    pot_impr = str(round((1e10/1e10),2)*100)+'%'   
elif improvement_time == 1e20:
    pot_impr = "NA" 
else:
    pot_impr = str(round((improvement_time/finish_time),2)*100)+'%'
print('Diff_Cost%: ', diff)
print('Pot_Improv%: ', pot_impr)
print("Solution status: ", solution)
# Out:
# Interdiction Probabilities:  [[1.0, 0.9507679535949476, 0.9171009531226609, 0.9816929252010751, 0.9556031383837665, 0.9119915331443227, 0.9686085611421599, 0.9404912632070668, 0.9793768398982458, 0.9145446609142734, 0.9222895634918089, 0.9233556411534923, 0.9605759499366471, 0.9389023090852183, 0.9738191058696316, 0.9329665288561366, 0.9734051928422213, 0.9814347642098326, 0.9053115218539525, 0.969547716443647, 0.9736094840670293, 0.9818346933236656, 0.9051386494708944, 0.9080345461646157, 0.9477124125489895, 0.9054380000443489, 0.908945043426306, 0.9710528534934019, 0.9575770991397257, 0.9097881238682727, 0.9327654549911849, 0.9760133937241467, 0.9340064716575198, 0.9450098846028525, 0.9170790724049441, 0.9533083877322311, 0.944362216333655, 0.9174397639787502, 0.9682302046709592, 0.9488748594634031, 0.9249094594856685, 0.9782960234441811, 0.9492841523475114, 0.9581481149636056, 0.9894381485426307, 0.9058649423758312, 0.9845333486395769, 0.9850692661904662, 0.9754081333453845, 0.976
# ...

# %% [markdown]
# ('Combination', 15, 0.5, 0.5, 'demand', 'no', 0)

# %%
# Setting Parameters
# Optimal Value from Data Source
# Number of Iterations
it = iterations_to_run# 50000 #1000
# Solution with split deliveries
split_sol = 'No'
#split_sol = 'Yes'
# Stagmation parameter
#stg = round(it*0.9,0)
stg = round(it*0.9,0)
if optimal_value == None:
    known = 1e-10
    #known = 18.67292881108081
else:
    known = optimal_value
# Split information from Data Source
if split_sol == 'Yes':
    optm = 'split'
else: 
    optm = 'no_split'
# Logic to reintegrate initial solution by nearest neighbour
if optm == 'no_split':
    reit = 1
else:
    reit = round(stg*0.8,0)
sps = split_sol
pl = 0 # known*.15
#pl = known*.15 


# Increment Threshold
ith = 10 #10 #1000
# Optimization Solution Finder ("tier", "random", "mixed", "cost", "inter_route", "min_demand_route")
#osf = "tier" #"random" "mixed"
#osf = 'mixed'

#osf = "random"
#osf = 'cost'
#osf = 'inter_route'
osf = 'min_demand_route'
# Alpha factor for restricted candidate list
rcl = 0.5#0.5 #0.8 #0.8
# rcl = 0.8
# Perturbation percentage
prt = 0.5#0.5 #0.6
# prt = 0.8
# Initial seed (does not apply anymore)
sed = 1
# Interdiction prob (manual or generated--> "None" clause)
iprob = None
iprob = iprob1
# Min no interdiction matrix
min_nint = 1#0.92#1#0.95#0.97 # 0.88 #0.98 #0.95
# Max no interdiction matrix
max_nint = 1#0.92#1 #0.999#0.95#0.97 #0.88 #0.99 #0.99

# Threshold when reaching optimal solution
thres = 0.00001

# Percentage over iterations for no improvement
pert_ct = 0.1
# Local search method ('2-opt', '3-opt', 'segment-reversal', 'random') all include swap-local-search method
#lso = '2-opt'
lso = 'random'
#lso = '3-opt'
#lso = 'segment-reversal'


# Measuring time and time restriction
start_time = time.time()
timeout_minutes = tmot
timeout_duration = 60*timeout_minutes

# Prepare the arguments
args = (num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Create VRP instance
vrp_instance = VRP(num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Run the VRP run method with a timeout
result = vrp_instance.run_with_timeout(vrp_instance.run_vrp, timeout_duration, args)

if result is not None:
    cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = result
    print("VRP run completed successfully.")
else:
    print("VRP run did not complete within the timeout period.")
    improvement_time = 1e20
    finish_time = time.time()-start_time
    sl = "NA"
    solution = "NA"


# vrp = VRP(num_vehicles=num_vehicles, num_customers=num_customers, locations=locations, demands=demands, vehicle_capacity=vehicle_capacity, rcl_factor=rcl, iterations=it, local_search_option= lso, stagnation_limit=stg, perturb_percentage=prt,split_penalty= pl, sdd = sed, reintegrate_it=reit, split_sol= sps, min_prob_matrix= min_nint, max_prob_matrix= max_nint, int_prob = iprob, threshold_increment = ith, optimization_solution_finder = osf, maximus_time = maxxx_time)
# cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = vrp.run()
print('Improvement Time:', improvement_time)
print('Finish Time: ',finish_time)
print('Stag Level: ',sl)
if improvement_time == 1e20:
    diff = "NA"
else:
    diff = str(round(abs((cost/known-1)),2)*100)+'%'
print(improvement_time)
print(finish_time)
if improvement_time == 0  and finish_time == 0:
    pot_impr = str(round((1e10/1e10),2)*100)+'%'   
elif improvement_time == 1e20:
    pot_impr = "NA" 
else:
    pot_impr = str(round((improvement_time/finish_time),2)*100)+'%'
print('Diff_Cost%: ', diff)
print('Pot_Improv%: ', pot_impr)
print("Solution status: ", solution)
# Out:
# Interdiction Probabilities:  [[1.0, 0.9507679535949476, 0.9171009531226609, 0.9816929252010751, 0.9556031383837665, 0.9119915331443227, 0.9686085611421599, 0.9404912632070668, 0.9793768398982458, 0.9145446609142734, 0.9222895634918089, 0.9233556411534923, 0.9605759499366471, 0.9389023090852183, 0.9738191058696316, 0.9329665288561366, 0.9734051928422213, 0.9814347642098326, 0.9053115218539525, 0.969547716443647, 0.9736094840670293, 0.9818346933236656, 0.9051386494708944, 0.9080345461646157, 0.9477124125489895, 0.9054380000443489, 0.908945043426306, 0.9710528534934019, 0.9575770991397257, 0.9097881238682727, 0.9327654549911849, 0.9760133937241467, 0.9340064716575198, 0.9450098846028525, 0.9170790724049441, 0.9533083877322311, 0.944362216333655, 0.9174397639787502, 0.9682302046709592, 0.9488748594634031, 0.9249094594856685, 0.9782960234441811, 0.9492841523475114, 0.9581481149636056, 0.9894381485426307, 0.9058649423758312, 0.9845333486395769, 0.9850692661904662, 0.9754081333453845, 0.976
# ...

# %% [markdown]
# ('Combination', 16, 0.5, 0.5, 'demand', 'no', 50)

# %%
# Setting Parameters
# Optimal Value from Data Source
# Number of Iterations
it = iterations_to_run# 50000 #1000
# Solution with split deliveries
split_sol = 'No'
##split_sol = 'Yes'
# Stagmation parameter
#stg = round(it*0.9,0)
stg = round(it*0.9,0)
if optimal_value == None:
    known = 1e-10
    #known = 18.67292881108081
else:
    known = optimal_value
# Split information from Data Source
if split_sol == 'Yes':
    optm = 'split'
else: 
    optm = 'no_split'
# Logic to reintegrate initial solution by nearest neighbour
if optm == 'no_split':
    reit = 1
else:
    reit = round(stg*0.8,0)
sps = split_sol
#pl = 0 # known*.15
pl = known*.15 


# Increment Threshold
ith = 10 #10 #1000
# Optimization Solution Finder ("tier", "random", "mixed", "cost", "inter_route", "min_demand_route")
#osf = "tier" #"random" "mixed"
#osf = 'mixed'

#osf = "random"
#osf = 'cost'
#osf = 'inter_route'
osf = 'min_demand_route'
# Alpha factor for restricted candidate list
rcl = 0.5#0.5 #0.8 #0.8
# rcl = 0.8
# Perturbation percentage
prt = 0.5#0.5 #0.6
# prt = 0.8
# Initial seed (does not apply anymore)
sed = 1
# Interdiction prob (manual or generated--> "None" clause)
iprob = None
iprob = iprob1
# Min no interdiction matrix
min_nint = 1#0.92#1#0.95#0.97 # 0.88 #0.98 #0.95
# Max no interdiction matrix
max_nint = 1#0.92#1 #0.999#0.95#0.97 #0.88 #0.99 #0.99

# Threshold when reaching optimal solution
thres = 0.00001

# Percentage over iterations for no improvement
pert_ct = 0.1
# Local search method ('2-opt', '3-opt', 'segment-reversal', 'random') all include swap-local-search method
#lso = '2-opt'
lso = 'random'
#lso = '3-opt'
#lso = 'segment-reversal'


# Measuring time and time restriction
start_time = time.time()
timeout_minutes = tmot
timeout_duration = 60*timeout_minutes

# Prepare the arguments
args = (num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Create VRP instance
vrp_instance = VRP(num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Run the VRP run method with a timeout
result = vrp_instance.run_with_timeout(vrp_instance.run_vrp, timeout_duration, args)

if result is not None:
    cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = result
    print("VRP run completed successfully.")
else:
    print("VRP run did not complete within the timeout period.")
    improvement_time = 1e20
    finish_time = time.time()-start_time
    sl = "NA"
    solution = "NA"


# vrp = VRP(num_vehicles=num_vehicles, num_customers=num_customers, locations=locations, demands=demands, vehicle_capacity=vehicle_capacity, rcl_factor=rcl, iterations=it, local_search_option= lso, stagnation_limit=stg, perturb_percentage=prt,split_penalty= pl, sdd = sed, reintegrate_it=reit, split_sol= sps, min_prob_matrix= min_nint, max_prob_matrix= max_nint, int_prob = iprob, threshold_increment = ith, optimization_solution_finder = osf, maximus_time = maxxx_time)
# cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = vrp.run()
print('Improvement Time:', improvement_time)
print('Finish Time: ',finish_time)
print('Stag Level: ',sl)
if improvement_time == 1e20:
    diff = "NA"
else:
    diff = str(round(abs((cost/known-1)),2)*100)+'%'
print(improvement_time)
print(finish_time)
if improvement_time == 0  and finish_time == 0:
    pot_impr = str(round((1e10/1e10),2)*100)+'%'   
elif improvement_time == 1e20:
    pot_impr = "NA" 
else:
    pot_impr = str(round((improvement_time/finish_time),2)*100)+'%'
print('Diff_Cost%: ', diff)
print('Pot_Improv%: ', pot_impr)
print("Solution status: ", solution)
# Out:
# Interdiction Probabilities:  [[1.0, 0.9672551539540488, 0.9638876608955883, 0.9801379183282182, 0.9818476925313667, 0.9860674380500639, 0.983180483028797, 0.9607307291024034, 0.9714866559145053, 0.9641882572092678, 0.9539079920545569, 0.98134559189041, 0.9538871595066267, 0.9799788089592626, 0.9897072628356737, 0.9583003198363448, 0.9671027312041413, 0.9761575674445448, 0.9708143818374455, 0.973382976607342, 0.97904813219065, 0.979413221081161, 0.9782795480059931], [0.9672551539540488, 1.0, 0.9827775640844607, 0.9617729991904667, 0.9834719743558445, 0.9516392232387394, 0.9519116265963267, 0.9679573557812353, 0.9763106441136158, 0.9801398489577229, 0.9713139726988939, 0.9582549151187828, 0.9718702576508466, 0.98898713064164, 0.9559973797689285, 0.9568947890912257, 0.9670439185470685, 0.9619944088293336, 0.9799943713104146, 0.9866586614312411, 0.9706923923116029, 0.9545561538175249, 0.9516005159016943], [0.9638876608955883, 0.9827775640844607, 1.0, 0.9644244632339277, 0.977413173269360
# ...

# %% [markdown]
# ('Combination', 29, 0.5, 0.8, 'demand', 'yes', 0)

# %%
# Setting Parameters
# Optimal Value from Data Source
# Number of Iterations
it = iterations_to_run# 50000 #1000
# Solution with split deliveries
#split_sol = 'No'
split_sol = 'Yes'
# Stagmation parameter
#stg = round(it*0.9,0)
stg = round(it*0.9,0)
if optimal_value == None:
    known = 1e-10
    #known = 18.67292881108081
else:
    known = optimal_value
# Split information from Data Source
if split_sol == 'Yes':
    optm = 'split'
else: 
    optm = 'no_split'
# Logic to reintegrate initial solution by nearest neighbour
if optm == 'no_split':
    reit = 1
else:
    reit = round(stg*0.8,0)
sps = split_sol
pl = 0 # known*.15
#pl = known*.15 


# Increment Threshold
ith = 10 #10 #1000
# Optimization Solution Finder ("tier", "random", "mixed", "cost", "inter_route", "min_demand_route")
#osf = "tier" #"random" "mixed"
#osf = 'mixed'

#osf = "random"
#osf = 'cost'
#osf = 'inter_route'
osf = 'min_demand_route'
# Alpha factor for restricted candidate list
rcl = 0.5#0.5 #0.8 #0.8
# rcl = 0.8
# Perturbation percentage
prt = 0.8#0.5 #0.6
# prt = 0.8
# Initial seed (does not apply anymore)
sed = 1
# Interdiction prob (manual or generated--> "None" clause)
iprob = None
iprob = iprob1
# Min no interdiction matrix
min_nint = 1#0.92#1#0.95#0.97 # 0.88 #0.98 #0.95
# Max no interdiction matrix
max_nint = 1#0.92#1 #0.999#0.95#0.97 #0.88 #0.99 #0.99

# Threshold when reaching optimal solution
thres = 0.00001

# Percentage over iterations for no improvement
pert_ct = 0.1
# Local search method ('2-opt', '3-opt', 'segment-reversal', 'random') all include swap-local-search method
#lso = '2-opt'
lso = 'random'
#lso = '3-opt'
#lso = 'segment-reversal'


# Measuring time and time restriction
start_time = time.time()
timeout_minutes = tmot
timeout_duration = 60*timeout_minutes

# Prepare the arguments
args = (num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Create VRP instance
vrp_instance = VRP(num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Run the VRP run method with a timeout
result = vrp_instance.run_with_timeout(vrp_instance.run_vrp, timeout_duration, args)

if result is not None:
    cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = result
    print("VRP run completed successfully.")
else:
    print("VRP run did not complete within the timeout period.")
    improvement_time = 1e20
    finish_time = time.time()-start_time
    sl = "NA"
    solution = "NA"


# vrp = VRP(num_vehicles=num_vehicles, num_customers=num_customers, locations=locations, demands=demands, vehicle_capacity=vehicle_capacity, rcl_factor=rcl, iterations=it, local_search_option= lso, stagnation_limit=stg, perturb_percentage=prt,split_penalty= pl, sdd = sed, reintegrate_it=reit, split_sol= sps, min_prob_matrix= min_nint, max_prob_matrix= max_nint, int_prob = iprob, threshold_increment = ith, optimization_solution_finder = osf, maximus_time = maxxx_time)
# cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = vrp.run()
print('Improvement Time:', improvement_time)
print('Finish Time: ',finish_time)
print('Stag Level: ',sl)
if improvement_time == 1e20:
    diff = "NA"
else:
    diff = str(round(abs((cost/known-1)),2)*100)+'%'
print(improvement_time)
print(finish_time)
if improvement_time == 0  and finish_time == 0:
    pot_impr = str(round((1e10/1e10),2)*100)+'%'   
elif improvement_time == 1e20:
    pot_impr = "NA" 
else:
    pot_impr = str(round((improvement_time/finish_time),2)*100)+'%'
print('Diff_Cost%: ', diff)
print('Pot_Improv%: ', pot_impr)
print("Solution status: ", solution)
# Out:
# Interdiction Probabilities:  [[1.0, 0.9672551539540488, 0.9638876608955883, 0.9801379183282182, 0.9818476925313667, 0.9860674380500639, 0.983180483028797, 0.9607307291024034, 0.9714866559145053, 0.9641882572092678, 0.9539079920545569, 0.98134559189041, 0.9538871595066267, 0.9799788089592626, 0.9897072628356737, 0.9583003198363448, 0.9671027312041413, 0.9761575674445448, 0.9708143818374455, 0.973382976607342, 0.97904813219065, 0.979413221081161, 0.9782795480059931], [0.9672551539540488, 1.0, 0.9827775640844607, 0.9617729991904667, 0.9834719743558445, 0.9516392232387394, 0.9519116265963267, 0.9679573557812353, 0.9763106441136158, 0.9801398489577229, 0.9713139726988939, 0.9582549151187828, 0.9718702576508466, 0.98898713064164, 0.9559973797689285, 0.9568947890912257, 0.9670439185470685, 0.9619944088293336, 0.9799943713104146, 0.9866586614312411, 0.9706923923116029, 0.9545561538175249, 0.9516005159016943], [0.9638876608955883, 0.9827775640844607, 1.0, 0.9644244632339277, 0.977413173269360
# ...

# %% [markdown]
#  ('Combination', 30, 0.5, 0.8, 'demand', 'yes', 50)

# %%
# Setting Parameters
# Optimal Value from Data Source
# Number of Iterations
it = iterations_to_run# 50000 #1000
# Solution with split deliveries
#split_sol = 'No'
split_sol = 'Yes'
# Stagmation parameter
#stg = round(it*0.9,0)
stg = round(it*0.9,0)
if optimal_value == None:
    known = 1e-10
    #known = 18.67292881108081
else:
    known = optimal_value
# Split information from Data Source
if split_sol == 'Yes':
    optm = 'split'
else: 
    optm = 'no_split'
# Logic to reintegrate initial solution by nearest neighbour
if optm == 'no_split':
    reit = 1
else:
    reit = round(stg*0.8,0)
sps = split_sol
#pl = 0 # known*.15
pl = known*.15 


# Increment Threshold
ith = 10 #10 #1000
# Optimization Solution Finder ("tier", "random", "mixed", "cost", "inter_route", "min_demand_route")
#osf = "tier" #"random" "mixed"
#osf = 'mixed'

#osf = "random"
#osf = 'cost'
#osf = 'inter_route'
osf = 'min_demand_route'
# Alpha factor for restricted candidate list
rcl = 0.5#0.5 #0.8 #0.8
# rcl = 0.8
# Perturbation percentage
prt = 0.8#0.5 #0.6
# prt = 0.8
# Initial seed (does not apply anymore)
sed = 1
# Interdiction prob (manual or generated--> "None" clause)
iprob = None
iprob = iprob1
# Min no interdiction matrix
min_nint = 1#0.92#1#0.95#0.97 # 0.88 #0.98 #0.95
# Max no interdiction matrix
max_nint = 1#0.92#1 #0.999#0.95#0.97 #0.88 #0.99 #0.99

# Threshold when reaching optimal solution
thres = 0.00001

# Percentage over iterations for no improvement
pert_ct = 0.1
# Local search method ('2-opt', '3-opt', 'segment-reversal', 'random') all include swap-local-search method
#lso = '2-opt'
lso = 'random'
#lso = '3-opt'
#lso = 'segment-reversal'


# Measuring time and time restriction
start_time = time.time()
timeout_minutes = tmot
timeout_duration = 60*timeout_minutes

# Prepare the arguments
args = (num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Create VRP instance
vrp_instance = VRP(num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Run the VRP run method with a timeout
result = vrp_instance.run_with_timeout(vrp_instance.run_vrp, timeout_duration, args)

if result is not None:
    cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = result
    print("VRP run completed successfully.")
else:
    print("VRP run did not complete within the timeout period.")
    improvement_time = 1e20
    finish_time = time.time()-start_time
    sl = "NA"
    solution = "NA"


# vrp = VRP(num_vehicles=num_vehicles, num_customers=num_customers, locations=locations, demands=demands, vehicle_capacity=vehicle_capacity, rcl_factor=rcl, iterations=it, local_search_option= lso, stagnation_limit=stg, perturb_percentage=prt,split_penalty= pl, sdd = sed, reintegrate_it=reit, split_sol= sps, min_prob_matrix= min_nint, max_prob_matrix= max_nint, int_prob = iprob, threshold_increment = ith, optimization_solution_finder = osf, maximus_time = maxxx_time)
# cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = vrp.run()
print('Improvement Time:', improvement_time)
print('Finish Time: ',finish_time)
print('Stag Level: ',sl)
if improvement_time == 1e20:
    diff = "NA"
else:
    diff = str(round(abs((cost/known-1)),2)*100)+'%'
print(improvement_time)
print(finish_time)
if improvement_time == 0  and finish_time == 0:
    pot_impr = str(round((1e10/1e10),2)*100)+'%'   
elif improvement_time == 1e20:
    pot_impr = "NA" 
else:
    pot_impr = str(round((improvement_time/finish_time),2)*100)+'%'
print('Diff_Cost%: ', diff)
print('Pot_Improv%: ', pot_impr)
print("Solution status: ", solution)
# Out:
# Interdiction Probabilities:  [[1.0, 0.9672551539540488, 0.9638876608955883, 0.9801379183282182, 0.9818476925313667, 0.9860674380500639, 0.983180483028797, 0.9607307291024034, 0.9714866559145053, 0.9641882572092678, 0.9539079920545569, 0.98134559189041, 0.9538871595066267, 0.9799788089592626, 0.9897072628356737, 0.9583003198363448, 0.9671027312041413, 0.9761575674445448, 0.9708143818374455, 0.973382976607342, 0.97904813219065, 0.979413221081161, 0.9782795480059931], [0.9672551539540488, 1.0, 0.9827775640844607, 0.9617729991904667, 0.9834719743558445, 0.9516392232387394, 0.9519116265963267, 0.9679573557812353, 0.9763106441136158, 0.9801398489577229, 0.9713139726988939, 0.9582549151187828, 0.9718702576508466, 0.98898713064164, 0.9559973797689285, 0.9568947890912257, 0.9670439185470685, 0.9619944088293336, 0.9799943713104146, 0.9866586614312411, 0.9706923923116029, 0.9545561538175249, 0.9516005159016943], [0.9638876608955883, 0.9827775640844607, 1.0, 0.9644244632339277, 0.977413173269360
# ...

# %% [markdown]
# ('Combination', 31, 0.5, 0.8, 'demand', 'no', 0)

# %%
# Setting Parameters
# Optimal Value from Data Source
# Number of Iterations
it = iterations_to_run# 50000 #1000
# Solution with split deliveries
split_sol = 'No'
#split_sol = 'Yes'
# Stagmation parameter
#stg = round(it*0.9,0)
stg = round(it*0.9,0)
if optimal_value == None:
    known = 1e-10
    #known = 18.67292881108081
else:
    known = optimal_value
# Split information from Data Source
if split_sol == 'Yes':
    optm = 'split'
else: 
    optm = 'no_split'
# Logic to reintegrate initial solution by nearest neighbour
if optm == 'no_split':
    reit = 1
else:
    reit = round(stg*0.8,0)
sps = split_sol
pl = 0 # known*.15
#pl = known*.15 


# Increment Threshold
ith = 10 #10 #1000
# Optimization Solution Finder ("tier", "random", "mixed", "cost", "inter_route", "min_demand_route")
#osf = "tier" #"random" "mixed"
#osf = 'mixed'

#osf = "random"
#osf = 'cost'
#osf = 'inter_route'
osf = 'min_demand_route'
# Alpha factor for restricted candidate list
rcl = 0.5#0.5 #0.8 #0.8
# rcl = 0.8
# Perturbation percentage
prt = 0.8#0.5 #0.6
# prt = 0.8
# Initial seed (does not apply anymore)
sed = 1
# Interdiction prob (manual or generated--> "None" clause)
iprob = None
iprob = iprob1
# Min no interdiction matrix
min_nint = 1#0.92#1#0.95#0.97 # 0.88 #0.98 #0.95
# Max no interdiction matrix
max_nint = 1#0.92#1 #0.999#0.95#0.97 #0.88 #0.99 #0.99

# Threshold when reaching optimal solution
thres = 0.00001

# Percentage over iterations for no improvement
pert_ct = 0.1
# Local search method ('2-opt', '3-opt', 'segment-reversal', 'random') all include swap-local-search method
#lso = '2-opt'
lso = 'random'
#lso = '3-opt'
#lso = 'segment-reversal'


# Measuring time and time restriction
start_time = time.time()
timeout_minutes = tmot
timeout_duration = 60*timeout_minutes

# Prepare the arguments
args = (num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Create VRP instance
vrp_instance = VRP(num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Run the VRP run method with a timeout
result = vrp_instance.run_with_timeout(vrp_instance.run_vrp, timeout_duration, args)

if result is not None:
    cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = result
    print("VRP run completed successfully.")
else:
    print("VRP run did not complete within the timeout period.")
    improvement_time = 1e20
    finish_time = time.time()-start_time
    sl = "NA"
    solution = "NA"


# vrp = VRP(num_vehicles=num_vehicles, num_customers=num_customers, locations=locations, demands=demands, vehicle_capacity=vehicle_capacity, rcl_factor=rcl, iterations=it, local_search_option= lso, stagnation_limit=stg, perturb_percentage=prt,split_penalty= pl, sdd = sed, reintegrate_it=reit, split_sol= sps, min_prob_matrix= min_nint, max_prob_matrix= max_nint, int_prob = iprob, threshold_increment = ith, optimization_solution_finder = osf, maximus_time = maxxx_time)
# cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = vrp.run()
print('Improvement Time:', improvement_time)
print('Finish Time: ',finish_time)
print('Stag Level: ',sl)
if improvement_time == 1e20:
    diff = "NA"
else:
    diff = str(round(abs((cost/known-1)),2)*100)+'%'
print(improvement_time)
print(finish_time)
if improvement_time == 0  and finish_time == 0:
    pot_impr = str(round((1e10/1e10),2)*100)+'%'   
elif improvement_time == 1e20:
    pot_impr = "NA" 
else:
    pot_impr = str(round((improvement_time/finish_time),2)*100)+'%'
print('Diff_Cost%: ', diff)
print('Pot_Improv%: ', pot_impr)
print("Solution status: ", solution)
# Out:
# Interdiction Probabilities:  [[1.0, 0.9672551539540488, 0.9638876608955883, 0.9801379183282182, 0.9818476925313667, 0.9860674380500639, 0.983180483028797, 0.9607307291024034, 0.9714866559145053, 0.9641882572092678, 0.9539079920545569, 0.98134559189041, 0.9538871595066267, 0.9799788089592626, 0.9897072628356737, 0.9583003198363448, 0.9671027312041413, 0.9761575674445448, 0.9708143818374455, 0.973382976607342, 0.97904813219065, 0.979413221081161, 0.9782795480059931], [0.9672551539540488, 1.0, 0.9827775640844607, 0.9617729991904667, 0.9834719743558445, 0.9516392232387394, 0.9519116265963267, 0.9679573557812353, 0.9763106441136158, 0.9801398489577229, 0.9713139726988939, 0.9582549151187828, 0.9718702576508466, 0.98898713064164, 0.9559973797689285, 0.9568947890912257, 0.9670439185470685, 0.9619944088293336, 0.9799943713104146, 0.9866586614312411, 0.9706923923116029, 0.9545561538175249, 0.9516005159016943], [0.9638876608955883, 0.9827775640844607, 1.0, 0.9644244632339277, 0.977413173269360
# ...

# %% [markdown]
# ('Combination', 32, 0.5, 0.8, 'demand', 'no', 50)

# %%
# Setting Parameters
# Optimal Value from Data Source
# Number of Iterations
it = iterations_to_run# 50000 #1000
# Solution with split deliveries
split_sol = 'No'
#split_sol = 'Yes'
# Stagmation parameter
#stg = round(it*0.9,0)
stg = round(it*0.9,0)
if optimal_value == None:
    known = 1e-10
    #known = 18.67292881108081
else:
    known = optimal_value
# Split information from Data Source
if split_sol == 'Yes':
    optm = 'split'
else: 
    optm = 'no_split'
# Logic to reintegrate initial solution by nearest neighbour
if optm == 'no_split':
    reit = 1
else:
    reit = round(stg*0.8,0)
sps = split_sol
#pl = 0 # known*.15
pl = known*.15 


# Increment Threshold
ith = 10 #10 #1000
# Optimization Solution Finder ("tier", "random", "mixed", "cost", "inter_route", "min_demand_route")
#osf = "tier" #"random" "mixed"
#osf = 'mixed'

#osf = "random"
#osf = 'cost'
#osf = 'inter_route'
osf = 'min_demand_route'
# Alpha factor for restricted candidate list
rcl = 0.5#0.5 #0.8 #0.8
# rcl = 0.8
# Perturbation percentage
prt = 0.8#0.5 #0.6
# prt = 0.8
# Initial seed (does not apply anymore)
sed = 1
# Interdiction prob (manual or generated--> "None" clause)
iprob = None
iprob = iprob1
# Min no interdiction matrix
min_nint = 1#0.92#1#0.95#0.97 # 0.88 #0.98 #0.95
# Max no interdiction matrix
max_nint = 1#0.92#1 #0.999#0.95#0.97 #0.88 #0.99 #0.99

# Threshold when reaching optimal solution
thres = 0.00001

# Percentage over iterations for no improvement
pert_ct = 0.1
# Local search method ('2-opt', '3-opt', 'segment-reversal', 'random') all include swap-local-search method
#lso = '2-opt'
lso = 'random'
#lso = '3-opt'
#lso = 'segment-reversal'


# Measuring time and time restriction
start_time = time.time()
timeout_minutes = tmot
timeout_duration = 60*timeout_minutes

# Prepare the arguments
args = (num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Create VRP instance
vrp_instance = VRP(num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Run the VRP run method with a timeout
result = vrp_instance.run_with_timeout(vrp_instance.run_vrp, timeout_duration, args)

if result is not None:
    cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = result
    print("VRP run completed successfully.")
else:
    print("VRP run did not complete within the timeout period.")
    improvement_time = 1e20
    finish_time = time.time()-start_time
    sl = "NA"
    solution = "NA"


# vrp = VRP(num_vehicles=num_vehicles, num_customers=num_customers, locations=locations, demands=demands, vehicle_capacity=vehicle_capacity, rcl_factor=rcl, iterations=it, local_search_option= lso, stagnation_limit=stg, perturb_percentage=prt,split_penalty= pl, sdd = sed, reintegrate_it=reit, split_sol= sps, min_prob_matrix= min_nint, max_prob_matrix= max_nint, int_prob = iprob, threshold_increment = ith, optimization_solution_finder = osf, maximus_time = maxxx_time)
# cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = vrp.run()
print('Improvement Time:', improvement_time)
print('Finish Time: ',finish_time)
print('Stag Level: ',sl)
if improvement_time == 1e20:
    diff = "NA"
else:
    diff = str(round(abs((cost/known-1)),2)*100)+'%'
print(improvement_time)
print(finish_time)
if improvement_time == 0  and finish_time == 0:
    pot_impr = str(round((1e10/1e10),2)*100)+'%'   
elif improvement_time == 1e20:
    pot_impr = "NA" 
else:
    pot_impr = str(round((improvement_time/finish_time),2)*100)+'%'
print('Diff_Cost%: ', diff)
print('Pot_Improv%: ', pot_impr)
print("Solution status: ", solution)
# Out:
# Interdiction Probabilities:  [[1.0, 0.9672551539540488, 0.9638876608955883, 0.9801379183282182, 0.9818476925313667, 0.9860674380500639, 0.983180483028797, 0.9607307291024034, 0.9714866559145053, 0.9641882572092678, 0.9539079920545569, 0.98134559189041, 0.9538871595066267, 0.9799788089592626, 0.9897072628356737, 0.9583003198363448, 0.9671027312041413, 0.9761575674445448, 0.9708143818374455, 0.973382976607342, 0.97904813219065, 0.979413221081161, 0.9782795480059931], [0.9672551539540488, 1.0, 0.9827775640844607, 0.9617729991904667, 0.9834719743558445, 0.9516392232387394, 0.9519116265963267, 0.9679573557812353, 0.9763106441136158, 0.9801398489577229, 0.9713139726988939, 0.9582549151187828, 0.9718702576508466, 0.98898713064164, 0.9559973797689285, 0.9568947890912257, 0.9670439185470685, 0.9619944088293336, 0.9799943713104146, 0.9866586614312411, 0.9706923923116029, 0.9545561538175249, 0.9516005159016943], [0.9638876608955883, 0.9827775640844607, 1.0, 0.9644244632339277, 0.977413173269360
# ...

# %% [markdown]
# ('Combination', 45, 0.8, 0.5, 'demand', 'yes', 0)

# %%
# Setting Parameters
# Optimal Value from Data Source
# Number of Iterations
it = iterations_to_run# 50000 #1000
# Solution with split deliveries
#split_sol = 'No'
split_sol = 'Yes'
# Stagmation parameter
#stg = round(it*0.9,0)
stg = round(it*0.9,0)
if optimal_value == None:
    known = 1e-10
    #known = 18.67292881108081
else:
    known = optimal_value
# Split information from Data Source
if split_sol == 'Yes':
    optm = 'split'
else: 
    optm = 'no_split'
# Logic to reintegrate initial solution by nearest neighbour
if optm == 'no_split':
    reit = 1
else:
    reit = round(stg*0.8,0)
sps = split_sol
pl = 0 # known*.15
#pl = known*.15 


# Increment Threshold
ith = 10 #10 #1000
# Optimization Solution Finder ("tier", "random", "mixed", "cost", "inter_route", "min_demand_route")
#osf = "tier" #"random" "mixed"
#osf = 'mixed'

#osf = "random"
#osf = 'cost'
#osf = 'inter_route'
osf = 'min_demand_route'
# Alpha factor for restricted candidate list
rcl = 0.8#0.5 #0.8 #0.8
# rcl = 0.8
# Perturbation percentage
prt = 0.5#0.5 #0.6
# prt = 0.8
# Initial seed (does not apply anymore)
sed = 1
# Interdiction prob (manual or generated--> "None" clause)
iprob = None
iprob = iprob1
# Min no interdiction matrix
min_nint = 1#0.92#1#0.95#0.97 # 0.88 #0.98 #0.95
# Max no interdiction matrix
max_nint = 1#0.92#1 #0.999#0.95#0.97 #0.88 #0.99 #0.99

# Threshold when reaching optimal solution
thres = 0.00001

# Percentage over iterations for no improvement
pert_ct = 0.1
# Local search method ('2-opt', '3-opt', 'segment-reversal', 'random') all include swap-local-search method
#lso = '2-opt'
lso = 'random'
#lso = '3-opt'
#lso = 'segment-reversal'


# Measuring time and time restriction
start_time = time.time()
timeout_minutes = tmot
timeout_duration = 60*timeout_minutes

# Prepare the arguments
args = (num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Create VRP instance
vrp_instance = VRP(num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Run the VRP run method with a timeout
result = vrp_instance.run_with_timeout(vrp_instance.run_vrp, timeout_duration, args)

if result is not None:
    cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = result
    print("VRP run completed successfully.")
else:
    print("VRP run did not complete within the timeout period.")
    improvement_time = 1e20
    finish_time = time.time()-start_time
    sl = "NA"
    solution = "NA"


# vrp = VRP(num_vehicles=num_vehicles, num_customers=num_customers, locations=locations, demands=demands, vehicle_capacity=vehicle_capacity, rcl_factor=rcl, iterations=it, local_search_option= lso, stagnation_limit=stg, perturb_percentage=prt,split_penalty= pl, sdd = sed, reintegrate_it=reit, split_sol= sps, min_prob_matrix= min_nint, max_prob_matrix= max_nint, int_prob = iprob, threshold_increment = ith, optimization_solution_finder = osf, maximus_time = maxxx_time)
# cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = vrp.run()
print('Improvement Time:', improvement_time)
print('Finish Time: ',finish_time)
print('Stag Level: ',sl)
if improvement_time == 1e20:
    diff = "NA"
else:
    diff = str(round(abs((cost/known-1)),2)*100)+'%'
print(improvement_time)
print(finish_time)
if improvement_time == 0  and finish_time == 0:
    pot_impr = str(round((1e10/1e10),2)*100)+'%'   
elif improvement_time == 1e20:
    pot_impr = "NA" 
else:
    pot_impr = str(round((improvement_time/finish_time),2)*100)+'%'
print('Diff_Cost%: ', diff)
print('Pot_Improv%: ', pot_impr)
print("Solution status: ", solution)
# Out:
# Interdiction Probabilities:  [[1.0, 0.9672551539540488, 0.9638876608955883, 0.9801379183282182, 0.9818476925313667, 0.9860674380500639, 0.983180483028797, 0.9607307291024034, 0.9714866559145053, 0.9641882572092678, 0.9539079920545569, 0.98134559189041, 0.9538871595066267, 0.9799788089592626, 0.9897072628356737, 0.9583003198363448, 0.9671027312041413, 0.9761575674445448, 0.9708143818374455, 0.973382976607342, 0.97904813219065, 0.979413221081161, 0.9782795480059931], [0.9672551539540488, 1.0, 0.9827775640844607, 0.9617729991904667, 0.9834719743558445, 0.9516392232387394, 0.9519116265963267, 0.9679573557812353, 0.9763106441136158, 0.9801398489577229, 0.9713139726988939, 0.9582549151187828, 0.9718702576508466, 0.98898713064164, 0.9559973797689285, 0.9568947890912257, 0.9670439185470685, 0.9619944088293336, 0.9799943713104146, 0.9866586614312411, 0.9706923923116029, 0.9545561538175249, 0.9516005159016943], [0.9638876608955883, 0.9827775640844607, 1.0, 0.9644244632339277, 0.977413173269360
# ...

# %% [markdown]
# ('Combination', 46, 0.8, 0.5, 'demand', 'yes', 50)

# %%
# Setting Parameters
# Optimal Value from Data Source
# Number of Iterations
it = iterations_to_run# 50000 #1000
# Solution with split deliveries
#split_sol = 'No'
split_sol = 'Yes'
# Stagmation parameter
#stg = round(it*0.9,0)
stg = round(it*0.9,0)
if optimal_value == None:
    known = 1e-10
    #known = 18.67292881108081
else:
    known = optimal_value
# Split information from Data Source
if split_sol == 'Yes':
    optm = 'split'
else: 
    optm = 'no_split'
# Logic to reintegrate initial solution by nearest neighbour
if optm == 'no_split':
    reit = 1
else:
    reit = round(stg*0.8,0)
sps = split_sol
#pl = 0 # known*.15
pl = known*.15 


# Increment Threshold
ith = 10 #10 #1000
# Optimization Solution Finder ("tier", "random", "mixed", "cost", "inter_route", "min_demand_route")
#osf = "tier" #"random" "mixed"
#osf = 'mixed'

#osf = "random"
#osf = 'cost'
#osf = 'inter_route'
osf = 'min_demand_route'
# Alpha factor for restricted candidate list
rcl = 0.8#0.5 #0.8 #0.8
# rcl = 0.8
# Perturbation percentage
prt = 0.5#0.5 #0.6
# prt = 0.8
# Initial seed (does not apply anymore)
sed = 1
# Interdiction prob (manual or generated--> "None" clause)
iprob = None
iprob = iprob1
# Min no interdiction matrix
min_nint = 1#0.92#1#0.95#0.97 # 0.88 #0.98 #0.95
# Max no interdiction matrix
max_nint = 1#0.92#1 #0.999#0.95#0.97 #0.88 #0.99 #0.99

# Threshold when reaching optimal solution
thres = 0.00001

# Percentage over iterations for no improvement
pert_ct = 0.1
# Local search method ('2-opt', '3-opt', 'segment-reversal', 'random') all include swap-local-search method
#lso = '2-opt'
lso = 'random'
#lso = '3-opt'
#lso = 'segment-reversal'


# Measuring time and time restriction
start_time = time.time()
timeout_minutes = tmot
timeout_duration = 60*timeout_minutes

# Prepare the arguments
args = (num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Create VRP instance
vrp_instance = VRP(num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Run the VRP run method with a timeout
result = vrp_instance.run_with_timeout(vrp_instance.run_vrp, timeout_duration, args)

if result is not None:
    cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = result
    print("VRP run completed successfully.")
else:
    print("VRP run did not complete within the timeout period.")
    improvement_time = 1e20
    finish_time = time.time()-start_time
    sl = "NA"
    solution = "NA"


# vrp = VRP(num_vehicles=num_vehicles, num_customers=num_customers, locations=locations, demands=demands, vehicle_capacity=vehicle_capacity, rcl_factor=rcl, iterations=it, local_search_option= lso, stagnation_limit=stg, perturb_percentage=prt,split_penalty= pl, sdd = sed, reintegrate_it=reit, split_sol= sps, min_prob_matrix= min_nint, max_prob_matrix= max_nint, int_prob = iprob, threshold_increment = ith, optimization_solution_finder = osf, maximus_time = maxxx_time)
# cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = vrp.run()
print('Improvement Time:', improvement_time)
print('Finish Time: ',finish_time)
print('Stag Level: ',sl)
if improvement_time == 1e20:
    diff = "NA"
else:
    diff = str(round(abs((cost/known-1)),2)*100)+'%'
print(improvement_time)
print(finish_time)
if improvement_time == 0  and finish_time == 0:
    pot_impr = str(round((1e10/1e10),2)*100)+'%'   
elif improvement_time == 1e20:
    pot_impr = "NA" 
else:
    pot_impr = str(round((improvement_time/finish_time),2)*100)+'%'
print('Diff_Cost%: ', diff)
print('Pot_Improv%: ', pot_impr)
print("Solution status: ", solution)
# Out:
# Interdiction Probabilities:  [[1.0, 0.9672551539540488, 0.9638876608955883, 0.9801379183282182, 0.9818476925313667, 0.9860674380500639, 0.983180483028797, 0.9607307291024034, 0.9714866559145053, 0.9641882572092678, 0.9539079920545569, 0.98134559189041, 0.9538871595066267, 0.9799788089592626, 0.9897072628356737, 0.9583003198363448, 0.9671027312041413, 0.9761575674445448, 0.9708143818374455, 0.973382976607342, 0.97904813219065, 0.979413221081161, 0.9782795480059931], [0.9672551539540488, 1.0, 0.9827775640844607, 0.9617729991904667, 0.9834719743558445, 0.9516392232387394, 0.9519116265963267, 0.9679573557812353, 0.9763106441136158, 0.9801398489577229, 0.9713139726988939, 0.9582549151187828, 0.9718702576508466, 0.98898713064164, 0.9559973797689285, 0.9568947890912257, 0.9670439185470685, 0.9619944088293336, 0.9799943713104146, 0.9866586614312411, 0.9706923923116029, 0.9545561538175249, 0.9516005159016943], [0.9638876608955883, 0.9827775640844607, 1.0, 0.9644244632339277, 0.977413173269360
# ...

# %% [markdown]
# ('Combination', 47, 0.8, 0.5, 'demand', 'no', 0)

# %%
# Setting Parameters
# Optimal Value from Data Source
# Number of Iterations
it = iterations_to_run# 50000 #1000
# Solution with split deliveries
split_sol = 'No'
#split_sol = 'Yes'
# Stagmation parameter
#stg = round(it*0.9,0)
stg = round(it*0.9,0)
if optimal_value == None:
    known = 1e-10
    #known = 18.67292881108081
else:
    known = optimal_value
# Split information from Data Source
if split_sol == 'Yes':
    optm = 'split'
else: 
    optm = 'no_split'
# Logic to reintegrate initial solution by nearest neighbour
if optm == 'no_split':
    reit = 1
else:
    reit = round(stg*0.8,0)
sps = split_sol
pl = 0 # known*.15
#pl = known*.15 


# Increment Threshold
ith = 10 #10 #1000
# Optimization Solution Finder ("tier", "random", "mixed", "cost", "inter_route", "min_demand_route")
#osf = "tier" #"random" "mixed"
#osf = 'mixed'

#osf = "random"
#osf = 'cost'
#osf = 'inter_route'
osf = 'min_demand_route'
# Alpha factor for restricted candidate list
rcl = 0.8#0.5 #0.8 #0.8
# rcl = 0.8
# Perturbation percentage
prt = 0.5#0.5 #0.6
# prt = 0.8
# Initial seed (does not apply anymore)
sed = 1
# Interdiction prob (manual or generated--> "None" clause)
iprob = None
iprob = iprob1
# Min no interdiction matrix
min_nint = 1#0.92#1#0.95#0.97 # 0.88 #0.98 #0.95
# Max no interdiction matrix
max_nint = 1#0.92#1 #0.999#0.95#0.97 #0.88 #0.99 #0.99

# Threshold when reaching optimal solution
thres = 0.00001

# Percentage over iterations for no improvement
pert_ct = 0.1
# Local search method ('2-opt', '3-opt', 'segment-reversal', 'random') all include swap-local-search method
#lso = '2-opt'
lso = 'random'
#lso = '3-opt'
#lso = 'segment-reversal'


# Measuring time and time restriction
start_time = time.time()
timeout_minutes = tmot
timeout_duration = 60*timeout_minutes

# Prepare the arguments
args = (num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Create VRP instance
vrp_instance = VRP(num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Run the VRP run method with a timeout
result = vrp_instance.run_with_timeout(vrp_instance.run_vrp, timeout_duration, args)

if result is not None:
    cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = result
    print("VRP run completed successfully.")
else:
    print("VRP run did not complete within the timeout period.")
    improvement_time = 1e20
    finish_time = time.time()-start_time
    sl = "NA"
    solution = "NA"


# vrp = VRP(num_vehicles=num_vehicles, num_customers=num_customers, locations=locations, demands=demands, vehicle_capacity=vehicle_capacity, rcl_factor=rcl, iterations=it, local_search_option= lso, stagnation_limit=stg, perturb_percentage=prt,split_penalty= pl, sdd = sed, reintegrate_it=reit, split_sol= sps, min_prob_matrix= min_nint, max_prob_matrix= max_nint, int_prob = iprob, threshold_increment = ith, optimization_solution_finder = osf, maximus_time = maxxx_time)
# cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = vrp.run()
print('Improvement Time:', improvement_time)
print('Finish Time: ',finish_time)
print('Stag Level: ',sl)
if improvement_time == 1e20:
    diff = "NA"
else:
    diff = str(round(abs((cost/known-1)),2)*100)+'%'
print(improvement_time)
print(finish_time)
if improvement_time == 0  and finish_time == 0:
    pot_impr = str(round((1e10/1e10),2)*100)+'%'   
elif improvement_time == 1e20:
    pot_impr = "NA" 
else:
    pot_impr = str(round((improvement_time/finish_time),2)*100)+'%'
print('Diff_Cost%: ', diff)
print('Pot_Improv%: ', pot_impr)
print("Solution status: ", solution)
# Out:
# Interdiction Probabilities:  [[1.0, 0.9672551539540488, 0.9638876608955883, 0.9801379183282182, 0.9818476925313667, 0.9860674380500639, 0.983180483028797, 0.9607307291024034, 0.9714866559145053, 0.9641882572092678, 0.9539079920545569, 0.98134559189041, 0.9538871595066267, 0.9799788089592626, 0.9897072628356737, 0.9583003198363448, 0.9671027312041413, 0.9761575674445448, 0.9708143818374455, 0.973382976607342, 0.97904813219065, 0.979413221081161, 0.9782795480059931], [0.9672551539540488, 1.0, 0.9827775640844607, 0.9617729991904667, 0.9834719743558445, 0.9516392232387394, 0.9519116265963267, 0.9679573557812353, 0.9763106441136158, 0.9801398489577229, 0.9713139726988939, 0.9582549151187828, 0.9718702576508466, 0.98898713064164, 0.9559973797689285, 0.9568947890912257, 0.9670439185470685, 0.9619944088293336, 0.9799943713104146, 0.9866586614312411, 0.9706923923116029, 0.9545561538175249, 0.9516005159016943], [0.9638876608955883, 0.9827775640844607, 1.0, 0.9644244632339277, 0.977413173269360
# ...

# %% [markdown]
# ('Combination', 48, 0.8, 0.5, 'demand', 'no', 50)

# %%
# Setting Parameters
# Optimal Value from Data Source
# Number of Iterations
it = iterations_to_run# 50000 #1000
# Solution with split deliveries
split_sol = 'No'
#split_sol = 'Yes'
# Stagmation parameter
#stg = round(it*0.9,0)
stg = round(it*0.9,0)
if optimal_value == None:
    known = 1e-10
    #known = 18.67292881108081
else:
    known = optimal_value
# Split information from Data Source
if split_sol == 'Yes':
    optm = 'split'
else: 
    optm = 'no_split'
# Logic to reintegrate initial solution by nearest neighbour
if optm == 'no_split':
    reit = 1
else:
    reit = round(stg*0.8,0)
sps = split_sol
#pl = 0 # known*.15
pl = known*.15 


# Increment Threshold
ith = 10 #10 #1000
# Optimization Solution Finder ("tier", "random", "mixed", "cost", "inter_route", "min_demand_route")
#osf = "tier" #"random" "mixed"
#osf = 'mixed'

#osf = "random"
#osf = 'cost'
#osf = 'inter_route'
osf = 'min_demand_route'
# Alpha factor for restricted candidate list
rcl = 0.8#0.5 #0.8 #0.8
# rcl = 0.8
# Perturbation percentage
prt = 0.5#0.5 #0.6
# prt = 0.8
# Initial seed (does not apply anymore)
sed = 1
# Interdiction prob (manual or generated--> "None" clause)
iprob = None
iprob = iprob1
# Min no interdiction matrix
min_nint = 1#0.92#1#0.95#0.97 # 0.88 #0.98 #0.95
# Max no interdiction matrix
max_nint = 1#0.92#1 #0.999#0.95#0.97 #0.88 #0.99 #0.99

# Threshold when reaching optimal solution
thres = 0.00001

# Percentage over iterations for no improvement
pert_ct = 0.1
# Local search method ('2-opt', '3-opt', 'segment-reversal', 'random') all include swap-local-search method
#lso = '2-opt'
lso = 'random'
#lso = '3-opt'
#lso = 'segment-reversal'


# Measuring time and time restriction
start_time = time.time()
timeout_minutes = tmot
timeout_duration = 60*timeout_minutes

# Prepare the arguments
args = (num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Create VRP instance
vrp_instance = VRP(num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Run the VRP run method with a timeout
result = vrp_instance.run_with_timeout(vrp_instance.run_vrp, timeout_duration, args)

if result is not None:
    cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = result
    print("VRP run completed successfully.")
else:
    print("VRP run did not complete within the timeout period.")
    improvement_time = 1e20
    finish_time = time.time()-start_time
    sl = "NA"
    solution = "NA"


# vrp = VRP(num_vehicles=num_vehicles, num_customers=num_customers, locations=locations, demands=demands, vehicle_capacity=vehicle_capacity, rcl_factor=rcl, iterations=it, local_search_option= lso, stagnation_limit=stg, perturb_percentage=prt,split_penalty= pl, sdd = sed, reintegrate_it=reit, split_sol= sps, min_prob_matrix= min_nint, max_prob_matrix= max_nint, int_prob = iprob, threshold_increment = ith, optimization_solution_finder = osf, maximus_time = maxxx_time)
# cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = vrp.run()
print('Improvement Time:', improvement_time)
print('Finish Time: ',finish_time)
print('Stag Level: ',sl)
if improvement_time == 1e20:
    diff = "NA"
else:
    diff = str(round(abs((cost/known-1)),2)*100)+'%'
print(improvement_time)
print(finish_time)
if improvement_time == 0  and finish_time == 0:
    pot_impr = str(round((1e10/1e10),2)*100)+'%'   
elif improvement_time == 1e20:
    pot_impr = "NA" 
else:
    pot_impr = str(round((improvement_time/finish_time),2)*100)+'%'
print('Diff_Cost%: ', diff)
print('Pot_Improv%: ', pot_impr)
print("Solution status: ", solution)
# Out:
# Interdiction Probabilities:  [[1.0, 0.9672551539540488, 0.9638876608955883, 0.9801379183282182, 0.9818476925313667, 0.9860674380500639, 0.983180483028797, 0.9607307291024034, 0.9714866559145053, 0.9641882572092678, 0.9539079920545569, 0.98134559189041, 0.9538871595066267, 0.9799788089592626, 0.9897072628356737, 0.9583003198363448, 0.9671027312041413, 0.9761575674445448, 0.9708143818374455, 0.973382976607342, 0.97904813219065, 0.979413221081161, 0.9782795480059931], [0.9672551539540488, 1.0, 0.9827775640844607, 0.9617729991904667, 0.9834719743558445, 0.9516392232387394, 0.9519116265963267, 0.9679573557812353, 0.9763106441136158, 0.9801398489577229, 0.9713139726988939, 0.9582549151187828, 0.9718702576508466, 0.98898713064164, 0.9559973797689285, 0.9568947890912257, 0.9670439185470685, 0.9619944088293336, 0.9799943713104146, 0.9866586614312411, 0.9706923923116029, 0.9545561538175249, 0.9516005159016943], [0.9638876608955883, 0.9827775640844607, 1.0, 0.9644244632339277, 0.977413173269360
# ...

# %% [markdown]
#  ('Combination', 61, 0.8, 0.8, 'demand', 'yes', 0)

# %%
# Setting Parameters
# Optimal Value from Data Source
# Number of Iterations
it = iterations_to_run# 50000 #1000
# Solution with split deliveries
#split_sol = 'No'
split_sol = 'Yes'
# Stagmation parameter
#stg = round(it*0.9,0)
stg = round(it*0.9,0)
if optimal_value == None:
    known = 1e-10
    #known = 18.67292881108081
else:
    known = optimal_value
# Split information from Data Source
if split_sol == 'Yes':
    optm = 'split'
else: 
    optm = 'no_split'
# Logic to reintegrate initial solution by nearest neighbour
if optm == 'no_split':
    reit = 1
else:
    reit = round(stg*0.8,0)
sps = split_sol
pl = 0 # known*.15
#pl = known*.15 


# Increment Threshold
ith = 10 #10 #1000
# Optimization Solution Finder ("tier", "random", "mixed", "cost", "inter_route", "min_demand_route")
#osf = "tier" #"random" "mixed"
#osf = 'mixed'

#osf = "random"
#osf = 'cost'
#osf = 'inter_route'
osf = 'min_demand_route'
# Alpha factor for restricted candidate list
rcl = 0.8#0.5 #0.8 #0.8
# rcl = 0.8
# Perturbation percentage
prt = 0.8#0.5 #0.6
# prt = 0.8
# Initial seed (does not apply anymore)
sed = 1
# Interdiction prob (manual or generated--> "None" clause)
iprob = None
iprob = iprob1
# Min no interdiction matrix
min_nint = 1#0.92#1#0.95#0.97 # 0.88 #0.98 #0.95
# Max no interdiction matrix
max_nint = 1#0.92#1 #0.999#0.95#0.97 #0.88 #0.99 #0.99

# Threshold when reaching optimal solution
thres = 0.00001

# Percentage over iterations for no improvement
pert_ct = 0.1
# Local search method ('2-opt', '3-opt', 'segment-reversal', 'random') all include swap-local-search method
#lso = '2-opt'
lso = 'random'
#lso = '3-opt'
#lso = 'segment-reversal'


# Measuring time and time restriction
start_time = time.time()
timeout_minutes = tmot
timeout_duration = 60*timeout_minutes

# Prepare the arguments
args = (num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Create VRP instance
vrp_instance = VRP(num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Run the VRP run method with a timeout
result = vrp_instance.run_with_timeout(vrp_instance.run_vrp, timeout_duration, args)

if result is not None:
    cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = result
    print("VRP run completed successfully.")
else:
    print("VRP run did not complete within the timeout period.")
    improvement_time = 1e20
    finish_time = time.time()-start_time
    sl = "NA"
    solution = "NA"


# vrp = VRP(num_vehicles=num_vehicles, num_customers=num_customers, locations=locations, demands=demands, vehicle_capacity=vehicle_capacity, rcl_factor=rcl, iterations=it, local_search_option= lso, stagnation_limit=stg, perturb_percentage=prt,split_penalty= pl, sdd = sed, reintegrate_it=reit, split_sol= sps, min_prob_matrix= min_nint, max_prob_matrix= max_nint, int_prob = iprob, threshold_increment = ith, optimization_solution_finder = osf, maximus_time = maxxx_time)
# cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = vrp.run()
print('Improvement Time:', improvement_time)
print('Finish Time: ',finish_time)
print('Stag Level: ',sl)
if improvement_time == 1e20:
    diff = "NA"
else:
    diff = str(round(abs((cost/known-1)),2)*100)+'%'
print(improvement_time)
print(finish_time)
if improvement_time == 0  and finish_time == 0:
    pot_impr = str(round((1e10/1e10),2)*100)+'%'   
elif improvement_time == 1e20:
    pot_impr = "NA" 
else:
    pot_impr = str(round((improvement_time/finish_time),2)*100)+'%'
print('Diff_Cost%: ', diff)
print('Pot_Improv%: ', pot_impr)
print("Solution status: ", solution)
# Out:
# Interdiction Probabilities:  [[1.0, 0.9672551539540488, 0.9638876608955883, 0.9801379183282182, 0.9818476925313667, 0.9860674380500639, 0.983180483028797, 0.9607307291024034, 0.9714866559145053, 0.9641882572092678, 0.9539079920545569, 0.98134559189041, 0.9538871595066267, 0.9799788089592626, 0.9897072628356737, 0.9583003198363448, 0.9671027312041413, 0.9761575674445448, 0.9708143818374455, 0.973382976607342, 0.97904813219065, 0.979413221081161, 0.9782795480059931], [0.9672551539540488, 1.0, 0.9827775640844607, 0.9617729991904667, 0.9834719743558445, 0.9516392232387394, 0.9519116265963267, 0.9679573557812353, 0.9763106441136158, 0.9801398489577229, 0.9713139726988939, 0.9582549151187828, 0.9718702576508466, 0.98898713064164, 0.9559973797689285, 0.9568947890912257, 0.9670439185470685, 0.9619944088293336, 0.9799943713104146, 0.9866586614312411, 0.9706923923116029, 0.9545561538175249, 0.9516005159016943], [0.9638876608955883, 0.9827775640844607, 1.0, 0.9644244632339277, 0.977413173269360
# ...

# %% [markdown]
# ('Combination', 62, 0.8, 0.8, 'demand', 'yes', 50)

# %%
# Setting Parameters
# Optimal Value from Data Source
# Number of Iterations
it = iterations_to_run# 50000 #1000
# Solution with split deliveries
#split_sol = 'No'
split_sol = 'Yes'
# Stagmation parameter
#stg = round(it*0.9,0)
stg = round(it*0.9,0)
if optimal_value == None:
    known = 1e-10
    #known = 18.67292881108081
else:
    known = optimal_value
# Split information from Data Source
if split_sol == 'Yes':
    optm = 'split'
else: 
    optm = 'no_split'
# Logic to reintegrate initial solution by nearest neighbour
if optm == 'no_split':
    reit = 1
else:
    reit = round(stg*0.8,0)
sps = split_sol
#pl = 0 # known*.15
pl = known*.15 


# Increment Threshold
ith = 10 #10 #1000
# Optimization Solution Finder ("tier", "random", "mixed", "cost", "inter_route", "min_demand_route")
#osf = "tier" #"random" "mixed"
#osf = 'mixed'

#osf = "random"
#osf = 'cost'
#osf = 'inter_route'
osf = 'min_demand_route'
# Alpha factor for restricted candidate list
rcl = 0.8#0.5 #0.8 #0.8
# rcl = 0.8
# Perturbation percentage
prt = 0.8#0.5 #0.6
# prt = 0.8
# Initial seed (does not apply anymore)
sed = 1
# Interdiction prob (manual or generated--> "None" clause)
iprob = None
iprob = iprob1
# Min no interdiction matrix
min_nint = 1#0.92#1#0.95#0.97 # 0.88 #0.98 #0.95
# Max no interdiction matrix
max_nint = 1#0.92#1 #0.999#0.95#0.97 #0.88 #0.99 #0.99

# Threshold when reaching optimal solution
thres = 0.00001

# Percentage over iterations for no improvement
pert_ct = 0.1
# Local search method ('2-opt', '3-opt', 'segment-reversal', 'random') all include swap-local-search method
#lso = '2-opt'
lso = 'random'
#lso = '3-opt'
#lso = 'segment-reversal'


# Measuring time and time restriction
start_time = time.time()
timeout_minutes = tmot
timeout_duration = 60*timeout_minutes

# Prepare the arguments
args = (num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Create VRP instance
vrp_instance = VRP(num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Run the VRP run method with a timeout
result = vrp_instance.run_with_timeout(vrp_instance.run_vrp, timeout_duration, args)

if result is not None:
    cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = result
    print("VRP run completed successfully.")
else:
    print("VRP run did not complete within the timeout period.")
    improvement_time = 1e20
    finish_time = time.time()-start_time
    sl = "NA"
    solution = "NA"


# vrp = VRP(num_vehicles=num_vehicles, num_customers=num_customers, locations=locations, demands=demands, vehicle_capacity=vehicle_capacity, rcl_factor=rcl, iterations=it, local_search_option= lso, stagnation_limit=stg, perturb_percentage=prt,split_penalty= pl, sdd = sed, reintegrate_it=reit, split_sol= sps, min_prob_matrix= min_nint, max_prob_matrix= max_nint, int_prob = iprob, threshold_increment = ith, optimization_solution_finder = osf, maximus_time = maxxx_time)
# cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = vrp.run()
print('Improvement Time:', improvement_time)
print('Finish Time: ',finish_time)
print('Stag Level: ',sl)
if improvement_time == 1e20:
    diff = "NA"
else:
    diff = str(round(abs((cost/known-1)),2)*100)+'%'
print(improvement_time)
print(finish_time)
if improvement_time == 0  and finish_time == 0:
    pot_impr = str(round((1e10/1e10),2)*100)+'%'   
elif improvement_time == 1e20:
    pot_impr = "NA" 
else:
    pot_impr = str(round((improvement_time/finish_time),2)*100)+'%'
print('Diff_Cost%: ', diff)
print('Pot_Improv%: ', pot_impr)
print("Solution status: ", solution)
# Out:
# Interdiction Probabilities:  [[1.0, 0.9672551539540488, 0.9638876608955883, 0.9801379183282182, 0.9818476925313667, 0.9860674380500639, 0.983180483028797, 0.9607307291024034, 0.9714866559145053, 0.9641882572092678, 0.9539079920545569, 0.98134559189041, 0.9538871595066267, 0.9799788089592626, 0.9897072628356737, 0.9583003198363448, 0.9671027312041413, 0.9761575674445448, 0.9708143818374455, 0.973382976607342, 0.97904813219065, 0.979413221081161, 0.9782795480059931], [0.9672551539540488, 1.0, 0.9827775640844607, 0.9617729991904667, 0.9834719743558445, 0.9516392232387394, 0.9519116265963267, 0.9679573557812353, 0.9763106441136158, 0.9801398489577229, 0.9713139726988939, 0.9582549151187828, 0.9718702576508466, 0.98898713064164, 0.9559973797689285, 0.9568947890912257, 0.9670439185470685, 0.9619944088293336, 0.9799943713104146, 0.9866586614312411, 0.9706923923116029, 0.9545561538175249, 0.9516005159016943], [0.9638876608955883, 0.9827775640844607, 1.0, 0.9644244632339277, 0.977413173269360
# ...

# %% [markdown]
#  ('Combination', 63, 0.8, 0.8, 'demand', 'no', 0)

# %%
# Setting Parameters
# Optimal Value from Data Source
# Number of Iterations
it = iterations_to_run# 50000 #1000
# Solution with split deliveries
split_sol = 'No'
#split_sol = 'Yes'
# Stagmation parameter
#stg = round(it*0.9,0)
stg = round(it*0.9,0)
if optimal_value == None:
    known = 1e-10
    #known = 18.67292881108081
else:
    known = optimal_value
# Split information from Data Source
if split_sol == 'Yes':
    optm = 'split'
else: 
    optm = 'no_split'
# Logic to reintegrate initial solution by nearest neighbour
if optm == 'no_split':
    reit = 1
else:
    reit = round(stg*0.8,0)
sps = split_sol
pl = 0 # known*.15
#pl = known*.15 


# Increment Threshold
ith = 10 #10 #1000
# Optimization Solution Finder ("tier", "random", "mixed", "cost", "inter_route", "min_demand_route")
#osf = "tier" #"random" "mixed"
#osf = 'mixed'

#osf = "random"
#osf = 'cost'
#osf = 'inter_route'
osf = 'min_demand_route'
# Alpha factor for restricted candidate list
rcl = 0.8#0.5 #0.8 #0.8
# rcl = 0.8
# Perturbation percentage
prt = 0.8#0.5 #0.6
# prt = 0.8
# Initial seed (does not apply anymore)
sed = 1
# Interdiction prob (manual or generated--> "None" clause)
iprob = None
iprob = iprob1
# Min no interdiction matrix
min_nint = 1#0.92#1#0.95#0.97 # 0.88 #0.98 #0.95
# Max no interdiction matrix
max_nint = 1#0.92#1 #0.999#0.95#0.97 #0.88 #0.99 #0.99

# Threshold when reaching optimal solution
thres = 0.00001

# Percentage over iterations for no improvement
pert_ct = 0.1
# Local search method ('2-opt', '3-opt', 'segment-reversal', 'random') all include swap-local-search method
#lso = '2-opt'
lso = 'random'
#lso = '3-opt'
#lso = 'segment-reversal'


# Measuring time and time restriction
start_time = time.time()
timeout_minutes = tmot
timeout_duration = 60*timeout_minutes

# Prepare the arguments
args = (num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Create VRP instance
vrp_instance = VRP(num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Run the VRP run method with a timeout
result = vrp_instance.run_with_timeout(vrp_instance.run_vrp, timeout_duration, args)

if result is not None:
    cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = result
    print("VRP run completed successfully.")
else:
    print("VRP run did not complete within the timeout period.")
    improvement_time = 1e20
    finish_time = time.time()-start_time
    sl = "NA"
    solution = "NA"


# vrp = VRP(num_vehicles=num_vehicles, num_customers=num_customers, locations=locations, demands=demands, vehicle_capacity=vehicle_capacity, rcl_factor=rcl, iterations=it, local_search_option= lso, stagnation_limit=stg, perturb_percentage=prt,split_penalty= pl, sdd = sed, reintegrate_it=reit, split_sol= sps, min_prob_matrix= min_nint, max_prob_matrix= max_nint, int_prob = iprob, threshold_increment = ith, optimization_solution_finder = osf, maximus_time = maxxx_time)
# cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = vrp.run()
print('Improvement Time:', improvement_time)
print('Finish Time: ',finish_time)
print('Stag Level: ',sl)
if improvement_time == 1e20:
    diff = "NA"
else:
    diff = str(round(abs((cost/known-1)),2)*100)+'%'
print(improvement_time)
print(finish_time)
if improvement_time == 0  and finish_time == 0:
    pot_impr = str(round((1e10/1e10),2)*100)+'%'   
elif improvement_time == 1e20:
    pot_impr = "NA" 
else:
    pot_impr = str(round((improvement_time/finish_time),2)*100)+'%'
print('Diff_Cost%: ', diff)
print('Pot_Improv%: ', pot_impr)
print("Solution status: ", solution)
# Out:
# Interdiction Probabilities:  [[1.0, 0.9672551539540488, 0.9638876608955883, 0.9801379183282182, 0.9818476925313667, 0.9860674380500639, 0.983180483028797, 0.9607307291024034, 0.9714866559145053, 0.9641882572092678, 0.9539079920545569, 0.98134559189041, 0.9538871595066267, 0.9799788089592626, 0.9897072628356737, 0.9583003198363448, 0.9671027312041413, 0.9761575674445448, 0.9708143818374455, 0.973382976607342, 0.97904813219065, 0.979413221081161, 0.9782795480059931], [0.9672551539540488, 1.0, 0.9827775640844607, 0.9617729991904667, 0.9834719743558445, 0.9516392232387394, 0.9519116265963267, 0.9679573557812353, 0.9763106441136158, 0.9801398489577229, 0.9713139726988939, 0.9582549151187828, 0.9718702576508466, 0.98898713064164, 0.9559973797689285, 0.9568947890912257, 0.9670439185470685, 0.9619944088293336, 0.9799943713104146, 0.9866586614312411, 0.9706923923116029, 0.9545561538175249, 0.9516005159016943], [0.9638876608955883, 0.9827775640844607, 1.0, 0.9644244632339277, 0.977413173269360
# ...

# %% [markdown]
# ('Combination', 64, 0.8, 0.8, 'demand', 'no', 50)

# %%
# Setting Parameters
# Optimal Value from Data Source
# Number of Iterations
it = iterations_to_run# 50000 #1000
# Solution with split deliveries
split_sol = 'No'
#split_sol = 'Yes'
# Stagmation parameter
#stg = round(it*0.9,0)
stg = round(it*0.9,0)
if optimal_value == None:
    known = 1e-10
    #known = 18.67292881108081
else:
    known = optimal_value
# Split information from Data Source
if split_sol == 'Yes':
    optm = 'split'
else: 
    optm = 'no_split'
# Logic to reintegrate initial solution by nearest neighbour
if optm == 'no_split':
    reit = 1
else:
    reit = round(stg*0.8,0)
sps = split_sol
#pl = 0 # known*.15
pl = known*.15 


# Increment Threshold
ith = 10 #10 #1000
# Optimization Solution Finder ("tier", "random", "mixed", "cost", "inter_route", "min_demand_route")
#osf = "tier" #"random" "mixed"
#osf = 'mixed'

#osf = "random"
#osf = 'cost'
#osf = 'inter_route'
osf = 'min_demand_route'
# Alpha factor for restricted candidate list
rcl = 0.8#0.5 #0.8 #0.8
# rcl = 0.8
# Perturbation percentage
prt = 0.8#0.5 #0.6
# prt = 0.8
# Initial seed (does not apply anymore)
sed = 1
# Interdiction prob (manual or generated--> "None" clause)
iprob = None
iprob = iprob1
# Min no interdiction matrix
min_nint = 1#0.92#1#0.95#0.97 # 0.88 #0.98 #0.95
# Max no interdiction matrix
max_nint = 1#0.92#1 #0.999#0.95#0.97 #0.88 #0.99 #0.99

# Threshold when reaching optimal solution
thres = 0.00001

# Percentage over iterations for no improvement
pert_ct = 0.1
# Local search method ('2-opt', '3-opt', 'segment-reversal', 'random') all include swap-local-search method
#lso = '2-opt'
lso = 'random'
#lso = '3-opt'
#lso = 'segment-reversal'


# Measuring time and time restriction
start_time = time.time()
timeout_minutes = tmot
timeout_duration = 60*timeout_minutes

# Prepare the arguments
args = (num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Create VRP instance
vrp_instance = VRP(num_vehicles, num_customers, locations, demands, vehicle_capacity, rcl, it, lso, stg, prt, pl, sed, reit, sps, min_nint, max_nint, iprob, ith, osf)

# Run the VRP run method with a timeout
result = vrp_instance.run_with_timeout(vrp_instance.run_vrp, timeout_duration, args)

if result is not None:
    cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = result
    print("VRP run completed successfully.")
else:
    print("VRP run did not complete within the timeout period.")
    improvement_time = 1e20
    finish_time = time.time()-start_time
    sl = "NA"
    solution = "NA"


# vrp = VRP(num_vehicles=num_vehicles, num_customers=num_customers, locations=locations, demands=demands, vehicle_capacity=vehicle_capacity, rcl_factor=rcl, iterations=it, local_search_option= lso, stagnation_limit=stg, perturb_percentage=prt,split_penalty= pl, sdd = sed, reintegrate_it=reit, split_sol= sps, min_prob_matrix= min_nint, max_prob_matrix= max_nint, int_prob = iprob, threshold_increment = ith, optimization_solution_finder = osf, maximus_time = maxxx_time)
# cost, num_split_clients, num_non_split_clients, total_clients, improvement_time, finish_time, sl, solution = vrp.run()
print('Improvement Time:', improvement_time)
print('Finish Time: ',finish_time)
print('Stag Level: ',sl)
if improvement_time == 1e20:
    diff = "NA"
else:
    diff = str(round(abs((cost/known-1)),2)*100)+'%'
print(improvement_time)
print(finish_time)
if improvement_time == 0  and finish_time == 0:
    pot_impr = str(round((1e10/1e10),2)*100)+'%'   
elif improvement_time == 1e20:
    pot_impr = "NA" 
else:
    pot_impr = str(round((improvement_time/finish_time),2)*100)+'%'
print('Diff_Cost%: ', diff)
print('Pot_Improv%: ', pot_impr)
print("Solution status: ", solution)
# Out:
# Interdiction Probabilities:  [[1.0, 0.9672551539540488, 0.9638876608955883, 0.9801379183282182, 0.9818476925313667, 0.9860674380500639, 0.983180483028797, 0.9607307291024034, 0.9714866559145053, 0.9641882572092678, 0.9539079920545569, 0.98134559189041, 0.9538871595066267, 0.9799788089592626, 0.9897072628356737, 0.9583003198363448, 0.9671027312041413, 0.9761575674445448, 0.9708143818374455, 0.973382976607342, 0.97904813219065, 0.979413221081161, 0.9782795480059931], [0.9672551539540488, 1.0, 0.9827775640844607, 0.9617729991904667, 0.9834719743558445, 0.9516392232387394, 0.9519116265963267, 0.9679573557812353, 0.9763106441136158, 0.9801398489577229, 0.9713139726988939, 0.9582549151187828, 0.9718702576508466, 0.98898713064164, 0.9559973797689285, 0.9568947890912257, 0.9670439185470685, 0.9619944088293336, 0.9799943713104146, 0.9866586614312411, 0.9706923923116029, 0.9545561538175249, 0.9516005159016943], [0.9638876608955883, 0.9827775640844607, 1.0, 0.9644244632339277, 0.977413173269360
# ...
