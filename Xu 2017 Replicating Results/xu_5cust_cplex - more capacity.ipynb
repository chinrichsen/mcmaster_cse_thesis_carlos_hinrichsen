# %% [markdown]
# #### Reading the instances

# %%
# Step 1: Read the text file and store its lines in a list.
name = 'xu_5ct.txt'
with open(name, 'r') as f:
    lines = f.readlines()

# Step 2: Extract necessary information from the list.
num_vehicles = None
vehicle_capacity = None
demands = []
locations = []

for i, line in enumerate(lines):
    if "Min no of trucks" in line:
        num_vehicles = int(line.split("Min no of trucks:")[1].split(",")[0].strip())
    elif "CAPACITY" in line:
        vehicle_capacity = int(line.split(":")[1].strip())
    elif "NODE_COORD_SECTION" in line:
        j = i + 1
        while lines[j].strip() != "DEMAND_SECTION":
            _, x, y = map(float, lines[j].split())
            locations.append((x, y))
            j += 1
    elif "DEMAND_SECTION" in line:
        j = i + 1
        while lines[j].strip() != "DEPOT_SECTION":
            _, demand = map(float, lines[j].split())
            demands.append(demand)
            j += 1

# Removing the depot's demand, which is always 0
demands.pop(0)
num_customers = len(demands)

# Step 3: Use the extracted information to generate the desired Python output.
print("# Given data")
print(f"num_vehicles = {num_vehicles}")
print(f"num_customers = {num_customers}")
print(f"vehicle_capacity = {vehicle_capacity}")
print(f"demands = {demands}")
print("\nlocations = [")
for i, (x, y) in enumerate(locations):
    if i == 0:
        print(f"    ({x}, {y}),  # depot")
    else:
        print(f"    ({x}, {y}),  # customer {i}")
print("]")
# Out:
# # Given data
# num_vehicles = 3
# num_customers = 5
# vehicle_capacity = 50
# demands = [24.0, 24.0, 42.0, 25.0, 21.0]
#
# locations = [
#     (0.0, 0.0),  # depot
#     (-122.0, 132.0),  # customer 1
#     (-132.0, -60.0),  # customer 2
#     (50.0, 108.0),  # customer 3
#     (-160.0, 62.0),  # customer 4
#     (-143.0, -124.0),  # customer 5
# ]

# %%
vehicle_capacity = 65

# %%
interdiction_probabilities_0 = [
    # This is a placeholder; you would fill this with your actual data
    # The first row and column are ignored because they represent the depot, which we assume cannot be interdicted.
    [1, 0.96, 0.97, 0.99, 0.95, 0.99],
    [0.96, 1, 0.99, 0.98, 0.98, 0.97],
    [0.97, 0.99, 1, 0.95, 0.95, 0.95],
    [0.99, 0.98, 0.95, 1, 0.96, 0.97],
    [0.95, 0.98, 0.95, 0.96, 1, 0.96],
    [0.99, 0.97, 0.95, 0.97, 0.96, 1],
]

# %% [markdown]
# #### Formulation Not visiting Customers with demand 0 to be serviced

# %% [markdown]
# Eliminating cosntraint that if path is selected, it must have at least 1.0 demand serviced

# %% [markdown]
# Adding cumulative probabilities and all paths (no symmetry when there are interdictions)

# %%
from itertools import chain, combinations, permutations
from docplex.mp.model import Model
import time

matrx = '0'
if matrx == '0':
    interdiction_probabilities = interdiction_probabilities_0
else:
    interdiction_probabilities = interdiction_probabilities_1

# Given data
max_time = 7200

start_time = time.time()
# Generate a distance matrix based on Euclidean distance
distance_matrix = [[(((x1-x2)**2 + (y1-y2)**2)**0.5) for x2, y2 in locations] for x1, y1 in locations]

def is_matrix_uniform(inter_prob_matrix):
    """Check if the interdiction matrix has all elements as 1."""
    for row in inter_prob_matrix:
        for prob in row:
            if prob != 1:
                return False
    return True

uniform_matrix = is_matrix_uniform(interdiction_probabilities)

# Create the model
mdl = Model("SDVRP")

# Generate all feasible paths considering symmetry
def generate_all_paths():
    def is_unique_path(path, existing_paths_set):
        # Check if path or its reverse is not already in existing_paths_set
        return tuple(path) not in existing_paths_set and tuple(path[::-1]) not in existing_paths_set

    unique_paths_set = set()
    all_paths = []

    for length in range(1, num_customers + 1):  # Length of customer subset
        for subset in combinations(range(1, num_customers + 1), length):
            for perm in permutations(subset):
                path = (0,) + perm + (0,)
                if is_unique_path(path, unique_paths_set):
                    unique_paths_set.add(tuple(path))  # Add to set for quick lookup
                    all_paths.append(path)  # Add to list for output

    return all_paths

def generate_all_paths_no_symmetry(num_customers):
    """Generate all paths without considering symmetry, for any number of customers."""
    all_paths = []
    # Generate paths for all possible subsets of customers (including subsets of size 1 to num_customers)
    for r in range(1, num_customers + 1):
        for subset in combinations(range(1, num_customers + 1), r):
            for perm in permutations(subset):
                path = (0,) + perm + (0,)  # Adding depot at the start and end
                all_paths.append(path)
    return all_paths

# Generate all feasible paths
#def generate_all_paths():
#    all_paths = []
#    for length in range(2, num_customers + 2):
#        for subset in combinations(range(1, num_customers + 1), length - 2):
#            all_paths.append((0,) + subset + (0,))
#    return all_paths


#all_paths = generate_all_paths()

# Assuming num_customers is defined
if uniform_matrix:
    all_paths = generate_all_paths()  # Use your existing symmetry-considering function
else:
    all_paths = generate_all_paths_no_symmetry(num_customers)


print('all paths were generated')
print('elapsed time: ', time.time()-start_time)

# Function to calculate cumulative interdiction probabilities for each customer in a path
def calculate_cumulative_probability(path, interdiction_probabilities):
    cumulative_probabilities = {path[0]: 1}  # Start with depot having a cumulative probability of 1
    for i in range(1, len(path)):
        cumulative_probabilities[path[i]] = cumulative_probabilities[path[i-1]] * interdiction_probabilities[path[i-1]][path[i]]
    return cumulative_probabilities

print('all cumulative probabilities for all paths were generated')
print('elapsed time: ', time.time()-start_time)

# Define binary variables for each path and continuous variables for the demand delivered on each path to a customer
path_vars = mdl.binary_var_dict(all_paths, name="path")

print('all paths vars were generated')
print('elapsed time: ', time.time()-start_time)

deliver_vars = mdl.continuous_var_matrix(all_paths, range(1, num_customers + 1), lb=0, name="deliver")

print('all deliver vars were generated')
print('elapsed time: ', time.time()-start_time)

# Objective: Minimize total distance traveled
mdl.minimize(mdl.sum(path_vars[p] * sum(distance_matrix[p[i]][p[i+1]] for i in range(len(p)-1)) for p in all_paths))

# Constraints
#for customer in range(1, num_customers + 1):
#    mdl.add_constraint(mdl.sum(deliver_vars[p, customer] for p in all_paths if customer in p) == demands[customer-1])

#for customer in range(1, num_customers + 1):
#    # This constraint considers interdiction probabilities for routes starting and ending at the depot
#    mdl.add_constraint(
#        mdl.sum(
#            interdiction_probabilities[0][customer] * deliver_vars[p, customer] if p[1] == customer and len(p) == 3
#            else interdiction_probabilities[customer][p[customer_pos+1]] * deliver_vars[p, customer]
#            for p in all_paths if customer in p
#            for customer_pos in range(1, len(p) - 1) if p[customer_pos] == customer
#        ) >= demands[customer-1],
#        "demand_satisfaction_%d" % customer
#    )

# After defining 'all_paths', 'path_vars', and 'deliver_vars'
for customer in range(1, num_customers + 1):
    mdl.add_constraint(
        mdl.sum(
            calculate_cumulative_probability(p, interdiction_probabilities)[customer] * deliver_vars[p, customer]
            for p in all_paths if customer in p[1:-1]  # Ensure customer is in the path (excluding depot)
        ) >= demands[customer-1],
        f"demand_satisfaction_with_interdiction_{customer}"
    )



print('1st part of constraints were generated')
print('elapsed time: ', time.time()-start_time)

for p in all_paths:
    #for customer in p:
        #if customer != 0:  # exclude depot
            #mdl.add_constraint(deliver_vars[p, customer] <= demands[customer-1] * path_vars[p])
            #mdl.add_constraint(deliver_vars[p, customer] >= path_vars[p])
    mdl.add_constraint(mdl.sum(deliver_vars[p, customer] for customer in p if customer != 0) <= vehicle_capacity * path_vars[p])

for p in all_paths:
    for customer in range(1, num_customers + 1):
        if customer in p:  # Only apply if the customer is in the path
            # This constraint ensures demand serviced to a customer in a route is less or equal to vehicle capacity if route is selected
            mdl.add_constraint(deliver_vars[p, customer] <= vehicle_capacity * path_vars[p], f"vehicle_cap_{p}_{customer}")

#mdl.add_constraint(mdl.sum(path_vars[p] for p in all_paths) <= num_customers)  # The number of vehicles is equal to the number of customers in this case
mdl.add_constraint(mdl.sum(path_vars[p] for p in all_paths) <= num_vehicles)  # The number of vehicles is equal to the number of customers in this case


print('all paths constraints were generated')
print('elapsed time: ', time.time()-start_time)

# Solve the model
mdl.parameters.timelimit = max_time
mdl.parameters.mip.display = 4
solution = mdl.solve(log_output=True)

end_time = time.time()
elapsed_time = end_time - start_time

# Print solution
if solution:
    print(f"Solution Status: {mdl.solve_details.status}")
    print(f"Total cost (distance traveled): {solution.objective_value}")
    total_demand_serviced = sum(demands)
    print(f"Total demand serviced: {total_demand_serviced}")
    print()

    print("\nConstraint Details with Cumulative Interdiction Probabilities and Deliveries:")
    for customer in range(1, num_customers + 1):
        print(f"\nCustomer {customer} demand: {demands[customer-1]}")
        for p in all_paths:
            if customer in p:
                # Calculate cumulative probabilities for this path
                cumulative_probabilities = calculate_cumulative_probability(p, interdiction_probabilities)
                customer_pos = p.index(customer)
                # Determine if the customer is directly after the depot in the route
                if customer_pos == 1:  # Customer is the first after the depot
                    prev_node = 0
                else:  # Customer is not the first, find the previous node
                    prev_node = p[customer_pos - 1]
                
                interdiction_probability = cumulative_probabilities[customer]
                delivery_amount = deliver_vars[p, customer].solution_value if solution else 0
                adjusted_delivery = interdiction_probability * delivery_amount

                # Print the path, cumulative interdiction probability, and adjusted delivery amount
                print(f"  Path {p}: Cumulative Interdiction Probability to Customer {customer}: {interdiction_probability}")
                print(f"    Expected delivery amount (adjusted for interdiction): {adjusted_delivery}")


   
    
    route_number = 1
    for p, var in path_vars.items():
        if var.solution_value > 0.5:
            route_cost = sum(distance_matrix[p[i]][p[i+1]] for i in range(len(p)-1))
            total_demand_route = sum(deliver_vars[p, customer].solution_value for customer in p if customer != 0)
            print(f"Route {route_number}: {p}")
            print(f"  Cost: {route_cost}")
            print(f"  Total demand serviced by route: {total_demand_route}")
            for customer in p:
                if customer != 0:  # exclude depot
                    print(f"    Customer {customer} demand serviced: {deliver_vars[p, customer].solution_value}")
            route_number += 1
    
    print()
    
    split_customers = [c for c in range(1, num_customers + 1) if sum(path_vars[p].solution_value for p in all_paths if c in p and deliver_vars[p, c].solution_value > 0) > 1]
    if split_customers:
        print("Customers with split delivery:")
        for c in split_customers:
            print(f"  Customer {c}:")
            for p, var in path_vars.items():
                if c in p and var.solution_value > 0.5:
                    print(f"    Demand serviced by route {p}: {deliver_vars[p, c].solution_value}")
    else:
        print("No customers have split delivery.")
else:
    print("No solution found.")

print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# all paths were generated
# elapsed time:  0.007333993911743164
# all cumulative probabilities for all paths were generated
# elapsed time:  0.007333993911743164
# all paths vars were generated
# elapsed time:  0.007333993911743164
# all deliver vars were generated
# elapsed time:  0.017312288284301758
# 1st part of constraints were generated
# elapsed time:  0.033648014068603516
# all paths constraints were generated
# elapsed time:  0.16921138763427734
# Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_MIP_Display                             4
# CPXPARAM_TimeLimit                               7200
# Tried aggregator 2 times.
# MIP Presolve eliminated 1305 rows and 320 columns.
# MIP Presolve modified 5 coefficients.
# Aggregator did 5 substitutions.
# Reduced MIP has 326 rows, 1625 columns, and 3250 nonzeros.
# Reduced MIP has 325 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (4.22 ticks)
# Probing time = 0.00 sec. (0.15 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# Reduced MIP has 326 rows, 1625 columns, and 3250 nonzeros.
# Reduced MIP has 325 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (1.87 ticks)
# Probing time = 0.00 sec. (0.15 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Parallel mode: deterministic, using up to 2 threads for parallel tasks at root LP.
# Parallel mode: deterministic, using up to 6 threads for concurrent optimization:
#  * Starting dual Simplex on 1 thread...
#  * Starting Barrier on 4 threads...
#  * Starting primal Simplex on 1 thread...
# Tried aggregator 1 time.
# No LP presolve or aggregator reductions.
# Presolve time = 0.02 sec. (0.54 ticks)
# Initializing dual steep norms . . .
#
# Iteration log . . .
# Iteration:     1   Dual objective     =             0.000000
# Iteration:    62   Dual objective     =             0.000000
# Perturbation started.
# Iteration:   101   Dual objective     =             0.000000
# Iteration:   171   Dual objective     =             0.000018
# Iteration:   243   Dual objective     =             0.000054
# Iteration:   312   Dual objective     =           791.318114
# Iteration:   374   Dual objective     =           844.396203
# Iteration:   436   Dual objective     =           860.515009
# Removing perturbation.
#
# Dual simplex solved model.
#
# Root relaxation solution time = 0.11 sec. (6.17 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                         3414.9894        0.0000           100.00%
# Found incumbent of value 3414.989434 after 0.16 sec. (17.57 ticks)
#       0     0      860.5150     4     3414.9894      860.5150      436   74.80%
# *     0+    0                         1068.2212      860.5150            19.44%
# Found incumbent of value 1068.221160 after 0.17 sec. (20.73 ticks)
#       0     0        cutoff           1068.2212     1068.2212      510    0.00%
# Elapsed time = 0.48 sec. (157.48 ticks, tree = 0.01 MB, solutions = 2)
#
# Cover cuts applied:  2
# Flow cuts applied:  4
# Gomory fractional cuts applied:  4
#
# Root node processing (before b&c):
#   Real time             =    0.50 sec. (157.57 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.50 sec. (157.57 ticks)
# Solution Status: integer optimal solution
# Total cost (distance traveled): 1068.2211595307215
# Total demand serviced: 136.0
#
#
# Constraint Details with Cumulative Interdiction Probabilities and Deliveries:
#
# Customer 1 demand: 24.0
#   Path (0, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.9702
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.9309999999999999
#     Expected delivery amount (adjusted for interdiction): 23.999999999999996
#   Path (0, 1, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 2, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 3, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 3, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.9030699999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 1, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.9702
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 2, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.931095
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 2, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 4, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 4, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.9030699999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 1, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.9309999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 2, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8934749999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 2, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 5, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 5, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.893855
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 1, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 2, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.931095
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 3, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 4, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 1, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.9702
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 4, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.9313919999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 1, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.9309999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 3, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8937599999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 3, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 5, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 1, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.9702
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 5, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.931491
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 1, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 3, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.9410939999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 4, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 5, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 1, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.9309999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 5, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8846399999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 1, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 4, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.9313919999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 2, 3, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 2, 4, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 3, 2, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 3, 4, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 4, 2, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 4, 3, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 3, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 4, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 3, 1, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.9030699999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 3, 4, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8669471999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 4, 1, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.9030699999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 4, 3, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8669471999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 1, 2, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.9702
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 1, 4, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.9702
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 2, 1, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.931095
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 2, 4, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8756054999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 4, 1, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.9313919999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 4, 2, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8938511999999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 1, 2, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.9309999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 1, 3, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.9309999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 2, 1, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.8934749999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 2, 3, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8402274999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 3, 1, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.8937599999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 3, 2, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8577359999999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 2, 3, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 2, 5, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 3, 2, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 3, 5, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 5, 2, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 5, 3, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 3, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 5, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 3, 1, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.9030699999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 3, 5, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.86703935
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 5, 1, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.893855
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 5, 3, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8759779
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 1, 2, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.9702
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 1, 5, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.9702
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 2, 1, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.931095
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 2, 5, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8666707499999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 5, 1, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.931491
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 5, 2, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.9031621499999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 1, 2, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 1, 3, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 2, 1, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.931095
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 2, 3, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8756054999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 3, 1, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.9410939999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 3, 2, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.9031621499999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 2, 4, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 2, 5, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 4, 2, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 4, 5, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 5, 2, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 5, 4, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 4, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 5, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 4, 1, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.9030699999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 4, 5, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8581008
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 5, 1, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.893855
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 5, 4, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8669471999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 1, 2, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.9309999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 1, 5, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.9309999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 2, 1, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.8934749999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 2, 5, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8316537499999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 5, 1, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.8846399999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 5, 2, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8577359999999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 1, 2, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 1, 4, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 2, 1, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.931095
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 2, 4, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8756054999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 4, 1, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.9313919999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 4, 2, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8938511999999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 3, 4, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 3, 5, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 4, 3, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 4, 5, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 5, 3, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 5, 4, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 1, 4, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.9702
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 1, 5, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.9702
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 4, 1, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.9313919999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 4, 5, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8850124799999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 5, 1, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.931491
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 5, 4, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.90345024
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 1, 3, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.9309999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 1, 5, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.9309999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 3, 1, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.8937599999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 3, 5, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8581007999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 5, 1, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.8846399999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 5, 3, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8669471999999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 1, 3, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 1, 4, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 3, 1, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.9410939999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 3, 4, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.90345024
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 4, 1, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.9313919999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 4, 3, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8941363199999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 2, 3, 4, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 2, 3, 5, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 2, 4, 3, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 2, 4, 5, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 2, 5, 3, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 2, 5, 4, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 3, 2, 4, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 3, 2, 5, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 3, 4, 2, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 3, 4, 5, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 3, 5, 2, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 3, 5, 4, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 4, 2, 3, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 4, 2, 5, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 4, 3, 2, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 4, 3, 5, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 4, 5, 2, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 4, 5, 3, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 5, 2, 3, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 5, 2, 4, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 5, 3, 2, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 5, 3, 4, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 5, 4, 2, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 5, 4, 3, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.96
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 3, 4, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 3, 5, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 4, 3, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 4, 5, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 5, 3, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 5, 4, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 3, 1, 4, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.9030699999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 3, 1, 5, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.9030699999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 3, 4, 1, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.8669471999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 3, 4, 5, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.823776768
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 3, 5, 1, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.86703935
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 3, 5, 4, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8409387839999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 4, 1, 3, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.9030699999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 4, 1, 5, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.9030699999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 4, 3, 1, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.8669471999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 4, 3, 5, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8323577759999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 4, 5, 1, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.8581008
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 4, 5, 3, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.840938784
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 5, 1, 3, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.893855
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 5, 1, 4, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.893855
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 5, 3, 1, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.8759779
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 5, 3, 4, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8409387839999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 5, 4, 1, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.8669471999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 5, 4, 3, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.832269312
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 1, 2, 4, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.9702
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 1, 2, 5, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.9702
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 1, 4, 2, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.9702
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 1, 4, 5, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.9702
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 1, 5, 2, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.9702
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 1, 5, 4, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.9702
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 2, 1, 4, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.931095
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 2, 1, 5, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.931095
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 2, 4, 1, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.8756054999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 2, 4, 5, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8320039199999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 2, 5, 1, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.8666707499999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 2, 5, 4, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8405812799999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 4, 1, 2, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.9313919999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 4, 1, 5, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.9313919999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 4, 2, 1, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.8938511999999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 4, 2, 5, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8320039199999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 4, 5, 1, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.8850124799999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 4, 5, 2, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8580971519999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 5, 1, 2, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.931491
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 5, 1, 4, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.931491
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 5, 2, 1, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.9031621499999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 5, 2, 4, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8493373349999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 5, 4, 1, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.90345024
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 5, 4, 2, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8670356639999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 1, 2, 3, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.9309999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 1, 2, 5, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.9309999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 1, 3, 2, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.9309999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 1, 3, 5, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.9309999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 1, 5, 2, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.9309999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 1, 5, 3, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.9309999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 2, 1, 3, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.8934749999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 2, 1, 5, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.8934749999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 2, 3, 1, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.8402274999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 2, 3, 5, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8067041374999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 2, 5, 1, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.8316537499999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 2, 5, 3, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8150206749999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 3, 1, 2, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.8937599999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 3, 1, 5, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.8937599999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 3, 2, 1, 5, 0): Cumulative Interdiction Probability to Customer 1: 0.8577359999999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 3, 2, 5, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.7983875999999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 3, 5, 1, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.8581007999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 3, 5, 2, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8320039199999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 5, 1, 2, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.8846399999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 5, 1, 3, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.8846399999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 5, 2, 1, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.8577359999999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 5, 2, 3, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8066183999999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 5, 3, 1, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.8669471999999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 5, 3, 2, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8320039199999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 1, 2, 3, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 1, 2, 4, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 1, 3, 2, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 1, 3, 4, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 1, 4, 2, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 1, 4, 3, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 2, 1, 3, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.931095
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 2, 1, 4, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.931095
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 2, 3, 1, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.8756054999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 2, 3, 4, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8405812799999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 2, 4, 1, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.8756054999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 2, 4, 3, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8405812799999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 3, 1, 2, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.9410939999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 3, 1, 4, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.9410939999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 3, 2, 1, 4, 0): Cumulative Interdiction Probability to Customer 1: 0.9031621499999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 3, 2, 4, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8493373349999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 3, 4, 1, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.90345024
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 3, 4, 2, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8670356639999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 4, 1, 2, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.9313919999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 4, 1, 3, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.9313919999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 4, 2, 1, 3, 0): Cumulative Interdiction Probability to Customer 1: 0.8938511999999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 4, 2, 3, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8405812799999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 4, 3, 1, 2, 0): Cumulative Interdiction Probability to Customer 1: 0.8941363199999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 4, 3, 2, 1, 0): Cumulative Interdiction Probability to Customer 1: 0.8580971519999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#
# Customer 2 demand: 24.0
#   Path (0, 2, 0): Cumulative Interdiction Probability to Customer 2: 0.97
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 2, 0): Cumulative Interdiction Probability to Customer 2: 0.9503999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 0): Cumulative Interdiction Probability to Customer 2: 0.97
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 3, 0): Cumulative Interdiction Probability to Customer 2: 0.97
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 2, 0): Cumulative Interdiction Probability to Customer 2: 0.9405
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 4, 0): Cumulative Interdiction Probability to Customer 2: 0.97
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 2, 0): Cumulative Interdiction Probability to Customer 2: 0.9025
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 5, 0): Cumulative Interdiction Probability to Customer 2: 0.97
#     Expected delivery amount (adjusted for interdiction): 24.000000000000004
#   Path (0, 5, 2, 0): Cumulative Interdiction Probability to Customer 2: 0.9405
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 2, 3, 0): Cumulative Interdiction Probability to Customer 2: 0.9503999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 3, 2, 0): Cumulative Interdiction Probability to Customer 2: 0.8937599999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 3, 0): Cumulative Interdiction Probability to Customer 2: 0.97
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 3, 1, 0): Cumulative Interdiction Probability to Customer 2: 0.97
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 1, 2, 0): Cumulative Interdiction Probability to Customer 2: 0.960498
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 2, 1, 0): Cumulative Interdiction Probability to Customer 2: 0.9405
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 2, 4, 0): Cumulative Interdiction Probability to Customer 2: 0.9503999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 4, 2, 0): Cumulative Interdiction Probability to Customer 2: 0.8937599999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 4, 0): Cumulative Interdiction Probability to Customer 2: 0.97
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 4, 1, 0): Cumulative Interdiction Probability to Customer 2: 0.97
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 1, 2, 0): Cumulative Interdiction Probability to Customer 2: 0.9216899999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 2, 1, 0): Cumulative Interdiction Probability to Customer 2: 0.9025
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 2, 5, 0): Cumulative Interdiction Probability to Customer 2: 0.9503999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 5, 2, 0): Cumulative Interdiction Probability to Customer 2: 0.8846399999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 5, 0): Cumulative Interdiction Probability to Customer 2: 0.97
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 5, 1, 0): Cumulative Interdiction Probability to Customer 2: 0.97
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 1, 2, 0): Cumulative Interdiction Probability to Customer 2: 0.9506969999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 2, 1, 0): Cumulative Interdiction Probability to Customer 2: 0.9405
# ...
#   Path (0, 1, 5, 4, 2, 3, 0): Cumulative Interdiction Probability to Customer 5: 0.9311999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 1, 5, 4, 3, 2, 0): Cumulative Interdiction Probability to Customer 5: 0.9311999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 3, 4, 5, 0): Cumulative Interdiction Probability to Customer 5: 0.8673122303999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 3, 5, 4, 0): Cumulative Interdiction Probability to Customer 5: 0.9128611799999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 4, 3, 5, 0): Cumulative Interdiction Probability to Customer 5: 0.8763467327999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 4, 5, 3, 0): Cumulative Interdiction Probability to Customer 5: 0.9034502399999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 5, 3, 4, 0): Cumulative Interdiction Probability to Customer 5: 0.931491
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 1, 5, 4, 3, 0): Cumulative Interdiction Probability to Customer 5: 0.931491
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 3, 1, 4, 5, 0): Cumulative Interdiction Probability to Customer 5: 0.8496082559999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 3, 1, 5, 4, 0): Cumulative Interdiction Probability to Customer 5: 0.8759778999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 3, 4, 1, 5, 0): Cumulative Interdiction Probability to Customer 5: 0.8409387839999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 3, 4, 5, 1, 0): Cumulative Interdiction Probability to Customer 5: 0.8492544
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 3, 5, 1, 4, 0): Cumulative Interdiction Probability to Customer 5: 0.893855
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 3, 5, 4, 1, 0): Cumulative Interdiction Probability to Customer 5: 0.893855
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 4, 1, 3, 5, 0): Cumulative Interdiction Probability to Customer 5: 0.8584583419999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 4, 1, 5, 3, 0): Cumulative Interdiction Probability to Customer 5: 0.8759778999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 4, 3, 1, 5, 0): Cumulative Interdiction Probability to Customer 5: 0.8409387839999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 4, 3, 5, 1, 0): Cumulative Interdiction Probability to Customer 5: 0.8581008
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 4, 5, 1, 3, 0): Cumulative Interdiction Probability to Customer 5: 0.88464
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 4, 5, 3, 1, 0): Cumulative Interdiction Probability to Customer 5: 0.88464
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 5, 1, 3, 4, 0): Cumulative Interdiction Probability to Customer 5: 0.9215
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 5, 1, 4, 3, 0): Cumulative Interdiction Probability to Customer 5: 0.9215
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 5, 3, 1, 4, 0): Cumulative Interdiction Probability to Customer 5: 0.9215
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 5, 3, 4, 1, 0): Cumulative Interdiction Probability to Customer 5: 0.9215
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 5, 4, 1, 3, 0): Cumulative Interdiction Probability to Customer 5: 0.9215
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 2, 5, 4, 3, 1, 0): Cumulative Interdiction Probability to Customer 5: 0.9215
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 1, 2, 4, 5, 0): Cumulative Interdiction Probability to Customer 5: 0.8759741759999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 1, 2, 5, 4, 0): Cumulative Interdiction Probability to Customer 5: 0.9124730999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 1, 4, 2, 5, 0): Cumulative Interdiction Probability to Customer 5: 0.85809339
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 1, 4, 5, 2, 0): Cumulative Interdiction Probability to Customer 5: 0.9127641599999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 1, 5, 2, 4, 0): Cumulative Interdiction Probability to Customer 5: 0.9410939999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 1, 5, 4, 2, 0): Cumulative Interdiction Probability to Customer 5: 0.9410939999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 2, 1, 4, 5, 0): Cumulative Interdiction Probability to Customer 5: 0.875974176
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 2, 1, 5, 4, 0): Cumulative Interdiction Probability to Customer 5: 0.90316215
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 2, 4, 1, 5, 0): Cumulative Interdiction Probability to Customer 5: 0.8493373349999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 2, 4, 5, 1, 0): Cumulative Interdiction Probability to Customer 5: 0.8577359999999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 2, 5, 1, 4, 0): Cumulative Interdiction Probability to Customer 5: 0.8934749999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 2, 5, 4, 1, 0): Cumulative Interdiction Probability to Customer 5: 0.8934749999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 4, 1, 2, 5, 0): Cumulative Interdiction Probability to Customer 5: 0.8759741759999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 4, 1, 5, 2, 0): Cumulative Interdiction Probability to Customer 5: 0.9034502399999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 4, 2, 1, 5, 0): Cumulative Interdiction Probability to Customer 5: 0.8670356639999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 4, 2, 5, 1, 0): Cumulative Interdiction Probability to Customer 5: 0.8577359999999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 4, 5, 1, 2, 0): Cumulative Interdiction Probability to Customer 5: 0.9123839999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 4, 5, 2, 1, 0): Cumulative Interdiction Probability to Customer 5: 0.9123839999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 5, 1, 2, 4, 0): Cumulative Interdiction Probability to Customer 5: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 5, 1, 4, 2, 0): Cumulative Interdiction Probability to Customer 5: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 5, 2, 1, 4, 0): Cumulative Interdiction Probability to Customer 5: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 5, 2, 4, 1, 0): Cumulative Interdiction Probability to Customer 5: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 5, 4, 1, 2, 0): Cumulative Interdiction Probability to Customer 5: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 3, 5, 4, 2, 1, 0): Cumulative Interdiction Probability to Customer 5: 0.9602999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 1, 2, 3, 5, 0): Cumulative Interdiction Probability to Customer 5: 0.8493373349999997
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 1, 2, 5, 3, 0): Cumulative Interdiction Probability to Customer 5: 0.8756054999999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 1, 3, 2, 5, 0): Cumulative Interdiction Probability to Customer 5: 0.8234229499999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 1, 3, 5, 2, 0): Cumulative Interdiction Probability to Customer 5: 0.8850085999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 1, 5, 2, 3, 0): Cumulative Interdiction Probability to Customer 5: 0.9030699999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 1, 5, 3, 2, 0): Cumulative Interdiction Probability to Customer 5: 0.9030699999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 2, 1, 3, 5, 0): Cumulative Interdiction Probability to Customer 5: 0.8493373349999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 2, 1, 5, 3, 0): Cumulative Interdiction Probability to Customer 5: 0.8666707499999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 2, 3, 1, 5, 0): Cumulative Interdiction Probability to Customer 5: 0.8150206749999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 2, 3, 5, 1, 0): Cumulative Interdiction Probability to Customer 5: 0.8316537499999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 2, 5, 1, 3, 0): Cumulative Interdiction Probability to Customer 5: 0.8573749999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 2, 5, 3, 1, 0): Cumulative Interdiction Probability to Customer 5: 0.8573749999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 3, 1, 2, 5, 0): Cumulative Interdiction Probability to Customer 5: 0.8405812799999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 3, 1, 5, 2, 0): Cumulative Interdiction Probability to Customer 5: 0.8669471999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 3, 2, 1, 5, 0): Cumulative Interdiction Probability to Customer 5: 0.8320039199999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 3, 2, 5, 1, 0): Cumulative Interdiction Probability to Customer 5: 0.8230799999999998
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 3, 5, 1, 2, 0): Cumulative Interdiction Probability to Customer 5: 0.8846399999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 3, 5, 2, 1, 0): Cumulative Interdiction Probability to Customer 5: 0.8846399999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 5, 1, 2, 3, 0): Cumulative Interdiction Probability to Customer 5: 0.9119999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 5, 1, 3, 2, 0): Cumulative Interdiction Probability to Customer 5: 0.9119999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 5, 2, 1, 3, 0): Cumulative Interdiction Probability to Customer 5: 0.9119999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 5, 2, 3, 1, 0): Cumulative Interdiction Probability to Customer 5: 0.9119999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 5, 3, 1, 2, 0): Cumulative Interdiction Probability to Customer 5: 0.9119999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 4, 5, 3, 2, 1, 0): Cumulative Interdiction Probability to Customer 5: 0.9119999999999999
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 1, 2, 3, 4, 0): Cumulative Interdiction Probability to Customer 5: 0.99
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 1, 2, 4, 3, 0): Cumulative Interdiction Probability to Customer 5: 0.99
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 1, 3, 2, 4, 0): Cumulative Interdiction Probability to Customer 5: 0.99
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 1, 3, 4, 2, 0): Cumulative Interdiction Probability to Customer 5: 0.99
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 1, 4, 2, 3, 0): Cumulative Interdiction Probability to Customer 5: 0.99
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 1, 4, 3, 2, 0): Cumulative Interdiction Probability to Customer 5: 0.99
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 2, 1, 3, 4, 0): Cumulative Interdiction Probability to Customer 5: 0.99
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 2, 1, 4, 3, 0): Cumulative Interdiction Probability to Customer 5: 0.99
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 2, 3, 1, 4, 0): Cumulative Interdiction Probability to Customer 5: 0.99
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 2, 3, 4, 1, 0): Cumulative Interdiction Probability to Customer 5: 0.99
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 2, 4, 1, 3, 0): Cumulative Interdiction Probability to Customer 5: 0.99
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 2, 4, 3, 1, 0): Cumulative Interdiction Probability to Customer 5: 0.99
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 3, 1, 2, 4, 0): Cumulative Interdiction Probability to Customer 5: 0.99
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 3, 1, 4, 2, 0): Cumulative Interdiction Probability to Customer 5: 0.99
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 3, 2, 1, 4, 0): Cumulative Interdiction Probability to Customer 5: 0.99
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 3, 2, 4, 1, 0): Cumulative Interdiction Probability to Customer 5: 0.99
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 3, 4, 1, 2, 0): Cumulative Interdiction Probability to Customer 5: 0.99
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 3, 4, 2, 1, 0): Cumulative Interdiction Probability to Customer 5: 0.99
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 4, 1, 2, 3, 0): Cumulative Interdiction Probability to Customer 5: 0.99
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 4, 1, 3, 2, 0): Cumulative Interdiction Probability to Customer 5: 0.99
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 4, 2, 1, 3, 0): Cumulative Interdiction Probability to Customer 5: 0.99
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 4, 2, 3, 1, 0): Cumulative Interdiction Probability to Customer 5: 0.99
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 4, 3, 1, 2, 0): Cumulative Interdiction Probability to Customer 5: 0.99
#     Expected delivery amount (adjusted for interdiction): 0.0
#   Path (0, 5, 4, 3, 2, 1, 0): Cumulative Interdiction Probability to Customer 5: 0.99
#     Expected delivery amount (adjusted for interdiction): 0.0
# Route 1: (0, 3, 0)
#   Cost: 238.02520874898943
#   Total demand serviced by route: 65.0
#     Customer 3 demand serviced: 65.0
# Route 2: (0, 4, 1, 0)
#   Cost: 430.98603441090324
#   Total demand serviced by route: 65.0
#     Customer 4 demand serviced: 39.22126745435016
#     Customer 1 demand serviced: 25.778732545649838
# Route 3: (0, 2, 5, 0)
#   Cost: 399.20991637082875
#   Total demand serviced by route: 65.0
#     Customer 2 demand serviced: 24.742268041237118
#     Customer 5 demand serviced: 40.25773195876288
#
# No customers have split delivery.
# Elapsed time: 0.7021851539611816 seconds
